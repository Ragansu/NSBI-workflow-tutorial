# %% [markdown]
# Train Neural Networks to estimate Likelihood Ratios
# ===
#
# In this notebook we will setup the neural networks that train unbiased and low-variance density ratios to be then used for inference. The statistical model we have is:
#
# $$p(x|\mu, \alpha) = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot p_c\left(x|\alpha\right)$$
#
# where $c$ stands for the various physics channels that contribute to the final state $x$, $\mu$ is the signal-strength parameter and $\alpha$ is the vector of nuisance parameters associated with the various systematic uncertainties in the model. Note that we are assuming that the parameter $\mu$-dependence is known analytically and that we have simulation models for each of the channels $p_c(x)$.
#
# The objective is to build the test statistic for composite hypothesis testing:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})}{p(x_i|\hat{\mu}, \hat{\alpha})} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
# A direct approach would then be to model the probability density $p(x|\mu, \alpha)$ using NNs. But that is a more difficult task than training probability density ratios. We use a simple trick:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})/p_{ref}(x)}{p(x_i|\hat{\mu}, \hat{\alpha})/p_{ref}(x)} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
#
# to turn this into a density ratio estimation problem:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot \frac{p_c\left(x|\alpha\right)}{p_{ref}(x)}$$
#
# Factorizing out the $\alpha$-dependence in the density ratios:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\sum_c G_c(\alpha) \cdot f_c(\mu) \cdot \nu_c} \sum_c f_c(\mu) \cdot G_c(\alpha)\cdot \nu_c \cdot g_c(x|\alpha) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}$$
#
# **Factorized approach:**
#
# Instead of training NNs parameterized on $\mu$ and $\alpha$, we use analytical parameterizations to simplify the problem to training only parameter-independent density ratios.
#
# Let's set this up for the toy ttbar model we are using. Neglecting the nuisance parameter dependence for now,
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}\right] = \mu \cdot \frac{p_\text{ttbar}\left(x\right)}{p_{ref}(x)} + \frac{p_\text{wjets}\left(x\right)}{p_{ref}(x)} + \frac{p_\text{single top}\left(x\right)}{p_{ref}(x)}$$

# %%
import os, sys, importlib
sys.path.append('../')

import common_utils
from common_utils import plotting, training
from common_utils.training import TrainEvaluate_NN, TrainEvaluatePreselNN
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt
import pickle

from coffea.analysis_tools import PackedSelection

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

hep.style.use(hep.style.ATLAS)
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:10: FutureWarning: ``set_style`` is deprecated: Naming convention is changing to match mpl. Use ``mplhep.style.use()``.
#   hep.set_style("ATLAS")
# 2025-04-18 09:54:00.064754: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-04-18 09:54:00.720543: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load the datasets from pre-processed input
saved_data='./cached_data/'

syst_labels = np.load(f"{saved_data}syst_labels.npy")
mask_nominal = syst_labels=='nominal'

training_features = np.load(f"{saved_data}features.npy")[mask_nominal]
train_labels = np.load(f"{saved_data}train_labels.npy")[mask_nominal]
weights = np.load(f"{saved_data}weights.npy")[mask_nominal]

# %%
# Keep only a subset of the background for illustration
labels_dict = {"ttbar": 0,              # signal process
              "single_top_t_chan":1, 
              "wjets":2}

# Uncomment below for a full analysis with all backgrounds
# labels_dict = {"ttbar": 0,
#                "single_top_s_chan":1,
#               "single_top_t_chan":2,
#               "single_top_tW":3,
#               "wjets":4}

# %%
type_vec = np.array(train_labels, dtype='object')

for key in labels_dict:
    type_vec[type_vec==labels_dict[key]] = key

# %%
# Build a pandas dataframe from the arrays for density ratio training and validation
# columns = ['lepton_pt', 'lepton_eta', 'lepton_phi']
columns = ['lepton_pt', 'lepton_eta', 'lepton_phi', 'H_T', 'n_jets']
dataset_incl = pd.DataFrame(training_features, columns=columns)

# Some scaling to reduce the spread of pt distributions 
dataset_incl['log_lepton_pt'] = np.log(dataset_incl['lepton_pt'].ravel())
dataset_incl['log_H_T'] = np.log(dataset_incl['H_T'].ravel())

# Some scaling to reduce the spread of pt distributions 
dataset_incl['train_labels_presel'] = train_labels
dataset_incl['type'] = type_vec
dataset_incl['weights'] = weights

# %%
# Normalizing the training weights - only discriminating shapes, not norms

weights_normed = weights.copy()

for key in labels_dict:

    weights_normed[train_labels==labels_dict[key]] /= weights[train_labels==labels_dict[key]].sum()

dataset_incl['weights_normed'] = weights_normed

# %% [markdown]
# Training the Preselection NN
# ===

# %% [markdown]
# **Choice of reference sample**
#
# The density ratios need to be trained on phase space regions with support for the reference hypothesis $p_{ref}(x) > 0$.
#
# To ensure this, we make a selection that selects events in the phase space regions with $p_{ref}(x) > 0$, or $p_c(x) \gg p_{ref}(x)$, and only perform the NSBI fit in this selected analysis region. **A natural choice for the reference hypothesis is then the signal-rich hypotheses**. This is referred to in the ATLAS publications as the Search-Oriented Mixture Models approach:
#
# $$p_{ref}(x) = \frac{1}{\sum_S \nu_S} \sum_S \frac{d\sigma_S}{dx} = \frac{1}{\nu_\text{ttbar}} \frac{d\sigma_\text{ttbar}}{dx}$$
#
# where the sum runs over all signal hypothesis in the model and the second equality is due to the sole signal hypothesis in our toy model, $pp \to {t\bar{t}}$.
#
# **Selecting out regions with $p_{ref}\sim 0$**
#
# A multi-class classification NN, with softmax output, is trained to output a score:
#
# $$ \text{NN}_\text{presel} = \log \left[\frac{\sum_S P_S (x)}{\sum_B P_B(x)} \right]$$
#
# where $P_c$ are the probability scores outputted from the softmax layer of the trained NN.

# %%
# Only use lepton kinematics - use log pT for reduced spread
columns = ['log_lepton_pt', 'lepton_eta', 'lepton_phi', 'H_T', 'n_jets']
columns_scaling = ['log_lepton_pt', 'lepton_eta', 'lepton_phi', 'H_T']

# # Use lepton kinematics and the sum of jet pT observable 
# columns = ['log_lepton_pt', 'log_H_T', 'lepton_eta', 'lepton_phi']
# columns_scaling = ['log_lepton_pt', 'log_H_T', 'lepton_eta', 'lepton_phi'] # Subset of features which need scaling

# %%
importlib.reload(sys.modules['common_utils.training'])
from common_utils.training import TrainEvaluatePreselNN

preselectionTraining = TrainEvaluatePreselNN(dataset_incl, columns, columns_scaling)

# %%
path_to_saved_presel_model = './preselection_saved_NN/'
USE_SAVED_MODEL_PRESEL=True

if not USE_SAVED_MODEL_PRESEL:
    preselectionTraining.train(test_size=0.15, 
                               random_state=42, 
                               path_to_save=path_to_saved_presel_model,
                              batch_size=4096,
                              epochs=50)

else:
    preselectionTraining.get_trained_model(path_to_saved_presel_model)
# Out:
# 2025-04-18 09:54:03.487213: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9615 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:b1:00.0, compute capability: 7.5

# %%
# Get predictions (softmax outputs)
pred_NN = preselectionTraining.predict(dataset_incl)
# Out:
# 46492/46492 [==============================] - 33s 699us/step

# %%
# the preselection score as defined above - log(P_S/P_B)
presel_score = np.log(pred_NN[:, labels_dict["ttbar"]]/(pred_NN[:, labels_dict["single_top_t_chan"]] + pred_NN[:, labels_dict["wjets"]]))

min_pred = np.amin(presel_score)
max_pred = np.amax(presel_score)

bins = np.linspace(min_pred, max_pred, num=150)

hist_NN_output = {}
for key in labels_dict: 
    hist_NN_output[key], _ = np.histogram(presel_score[train_labels==labels_dict[key]], weights = weights[train_labels==labels_dict[key]], bins=bins)


for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins=bins, 
             alpha=0.6, label=key, 
             density=True, linewidth=2.0)

plt.xlabel("Preselection Score", size=18)
plt.ylabel("Density", size=18)
plt.legend()
plt.yscale('log')
plt.show()

# %% [markdown]
# Making the cut
# ===
#
# Make a selection cut for regions with $p_{ref} \gg 0$ for performing the NSBI analysis. The remaining events - which by definition are background-dominated - can be used as a **Control Region** for data-driven background estimation, pre-unblinding validations, etc.
#
# Moreover, the preselections act as a tuning know for the tradeoff in selecting as many signal events as possible to go into the **Signal Region** (increasing sensitivity) and the feasibility of training accurate and precise NNs over a large phase space (need bigger models and more statistics). The preselections can also weed out phase space regions with low background statistics to avoid poorly modelled regions.
#
# Heres a first cut that you can optimize as much as you like to get the desired final results.

# %%
preselection_cut_lower = -0.6 # Play around with this selection - 
                              # decrease if estimators are unbiased but need more sensitivity 
                              # and increase if the model is biased to reduce complexity

# Uncomment the line below if an upper cut is also needed
# preselection_cut_upper = -5.0

for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins=bins, 
             alpha=0.6, label=key, 
             density=True, linewidth=2.0)

plt.xlabel("Preselection Score", size=18)
plt.axvline(preselection_cut_lower, ymax=0.9, linestyle='--', label=f'preselection cut (>{preselection_cut_lower})')

# Uncomment the line below if an upper cut is also needed
# plt.axvline(preselection_cut_upper, ymax=0.9, linestyle='--', label=f'preselection cut (<{preselection_cut_upper})')

plt.ylabel("Density", size=18)
plt.legend()
plt.yscale('log')
plt.show()

# %% [markdown]
# Signal and Control Regions
# ===
#
# The high signal over background phase space towards the right of the preselection cut shown above will be categorized as the **Signal Region** where the NSBI analysis is performed.
#
# The low signal phase space towards the left will be used as a **Control Region**, with typical uses such as background estimation, pre-unblinding data-MC checks, etc. In this phase space, we will use a binned summary observable like in any traditional analysis.

# %%
# Make the preselections - defined the Signal Region

dataset_incl['presel_score'] = presel_score

dataset = dataset_incl[(dataset_incl.presel_score>=preselection_cut_lower)].copy()

# Uncomment the line below if an upper cut is also needed
# dataset = dataset_incl[(dataset_incl.presel_score>=preselection_cut_lower) & (dataset_incl.presel_score<=preselection_cut_upper)].copy()

# Additional selections - change as needed to get unbiased estimators / remove unwanted or badly modelled phase space regions
dataset = dataset[(dataset.lepton_pt<=200.0)].copy()
dataset = dataset[(dataset.H_T<=1000.0)].copy()

# %%
# The events that do not make the cut go into a Control Region - here we perform a binned fit
dataset_CR = dataset_incl[(dataset_incl.presel_score<preselection_cut_lower)].copy()
dataset_CR.to_hdf(f"{saved_data}dataset_CR_ttbar.h5", key="dataset", mode='w')

# Build a summary observable for Control Region
hist_CR = {}
num_bins = 5
min_presel_bin = -0.9
min_presel_bin = -7
max_presel_bin = preselection_cut_lower

bins = np.linspace(min_presel_bin, max_presel_bin, num = num_bins)

# Use the high-level preselection NN score as a summary observable for Control Region
for channel_ in labels_dict:
    hist_CR[channel_], _ = np.histogram(np.clip(dataset_CR[dataset_CR.type==channel_]['presel_score'].ravel(), min_presel_bin, max_presel_bin), 
                                  weights = dataset_CR[dataset_CR.type==channel_]['weights'].ravel(),
                                  bins = bins)

# Save the Control Region observable
with open(f"{saved_data}hist_CR_ttbar.pkl", "wb") as fp:
    pickle.dump(hist_CR, fp)

# %%
# Plot the Control Region observable

for channel_ in labels_dict:
    hep.histplot(hist_CR[channel_], bins=bins, label=channel_, density=1, linewidth=2.0)

plt.legend()
plt.xlabel('Control Region Observable')
# plt.yscale('log')
plt.ylabel('Density')
# Out:
# Text(0, 1, 'Density')

# %%
# Normalizing the training weights post preselection 
weights_normed = dataset['weights'].ravel().copy()
weights = dataset['weights'].ravel().copy()

for key in labels_dict:

    weights_normed[dataset['train_labels_presel']==labels_dict[key]] /= weights[dataset['train_labels_presel']==labels_dict[key]].sum()

dataset['weights_normed'] = weights_normed

# %%
# Save the preselected Nominal dataframe for inference use later on
dataset.to_hdf(f"{saved_data}dataset_preselected_ttbar.h5", key="dataset", mode='w')

# %% [markdown]
# Density ratio training
# ===
#
# Now we train the NNs for $\frac{p_c}{p_{ref}}(x)$ density ratios to build the full model. Our choice of reference hypothesis, motivated by the search-oriented mixture model described above, is:
#
# $$p_{ref}(x) = p_\text{ttbar}(x) = \frac{1}{\nu_\text{ttbar}} \frac{d\sigma_\text{ttbar}}{dx} $$
#
# gives the POI $\mu-$parameterized model:
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} \right]= \mu + \frac{p_\text{wjets}\left(x\right)}{p_\text{ttbar}(x)} + \frac{p_\text{single top}\left(x\right)}{p_\text{ttbar}(x)}$$
#
# The task of estimating the $\mu-$parameterized density ratio is thus reduced to estimating two $\mu-$independent density ratios $\frac{p_\text{single top}}{p_{t\bar{t}}}(x)$ and $\frac{p_\text{wjets}}{p_{t\bar{t}}}(x)$ mixed together with an analytical parameterization (hence the name mixture model).

# %%
importlib.reload(sys.modules['common_utils.training'])
from common_utils.training import TrainEvaluate_NN

mix_model_hypotheses = ['wjets', 'single_top_t_chan']
ref_processes = ['ttbar']
mask_ref = np.isin(dataset.type, ref_processes)

dataset_mix_model = {}
NN_training_mix_model = {}

rnd_seed_traintestsplit = 42 # can also be randomized, fixed for now

for process_type in mix_model_hypotheses:
    
    mask_process = dataset['type']==process_type
    
    # Build a training dataset for the training of p_<process_type>/p_<ref_processes> density ratio
    dataset_mix_model[process_type] = pd.concat([dataset[mask_process].copy(), 
                                                      dataset[mask_ref].copy()])

    mask_ref_mix_model = np.isin(dataset_mix_model[process_type].type, ref_processes)
    dataset_mix_model[process_type]['train_labels'] = 0
    dataset_mix_model[process_type].loc[mask_ref_mix_model, 'train_labels'] = 1

    # Save paths
    top_path = f'./output_training_nominal/'
    output_name = f'{process_type}'
    output_dir = f'{top_path}general_output_{process_type}'
    path_to_ratios = f'{top_path}output_ratios_{process_type}/'
    path_to_figures = f'{top_path}output_figures_{process_type}/'
    path_to_models = f'{top_path}output_model_params_{process_type}/'

    NN_training_mix_model[process_type] = TrainEvaluate_NN(dataset_mix_model[process_type], 
                                                           dataset_mix_model[process_type]['weights_normed'],
                                                           dataset_mix_model[process_type]['train_labels'],
                                                           columns, 
                                                           columns_scaling, rnd_seed_traintestsplit,
                                                           [process_type, 'ref'], output_dir, output_name, 
                                                            path_to_figures=path_to_figures,
                                                            path_to_ratios=path_to_ratios, 
                                                            path_to_models=path_to_models)

# %% [markdown]
# Neural Network architecture
# ===
#
# Here we will start with a multi-layer perceptron (simple feed-forward Neural Network with fully-connected layers). This can be supplemented with more complex architectures like transformers.
#
# After detailed tuning during the off-shell Higgs boson analysis effort, we found that a network with very wide layers ($\geq 1000$) and a depth of less than 10 works best - alongside batch size of a few hundreds and a gradually declining learning rate that starts with a value just large enough to not blow up.

# %% [markdown]
# Starting with the training and validation of the wjets density ratio:
#
# $$\frac{p_\text{wjets}(x)}{p_\text{ttbar}(x)}$$

# %%
# Train the density ratio NN
NN_training_mix_model['wjets'].train (   hidden_layers        = 2, 
                                         neurons              = 1000, 
                                         number_of_epochs     = 70, 
                                         batch_size           = 512, 
                                         learning_rate        = 0.1, 
                                         scalerType           = 'MinMax', 
                                         calibration          = False, 
                                         num_bins_cal         = 10, 
                                         callback             = True, 
                                         callback_patience    = 30, 
                                         callback_factor      = 0.01     )
# Out:
# Sum of weights of class 0: 0.8000176273576592
# Sum of weights of class 1: 0.8000000000000012
# Using swish activation function
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1000)              6000
#
#  dense_1 (Dense)             (None, 1000)              1001000
#
#  dense_2 (Dense)             (None, 1)                 1001
#
# =================================================================
# Total params: 1008001 (3.85 MB)
# Trainable params: 1008001 (3.85 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Using Callbacks
# Epoch 1/70
# 2025-04-18 09:55:03.021791: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7fd3107d1d20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-04-18 09:55:03.021848: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2025-04-18 09:55:03.030655: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-04-18 09:55:03.047468: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8906
# 2025-04-18 09:55:03.108726: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2025-04-18 09:55:03.171010: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 687/687 - 3s - loss: 2.2322e-06 - binary_accuracy: 0.7325 - val_loss: 2.7102e-06 - val_binary_accuracy: 0.6496 - lr: 0.1000 - 3s/epoch - 5ms/step
# Epoch 2/70
# 687/687 - 1s - loss: 2.1638e-06 - binary_accuracy: 0.7457 - val_loss: 3.0215e-06 - val_binary_accuracy: 0.5895 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 3/70
# 687/687 - 1s - loss: 2.1814e-06 - binary_accuracy: 0.7449 - val_loss: 2.3656e-06 - val_binary_accuracy: 0.7006 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 4/70
# 687/687 - 1s - loss: 2.1496e-06 - binary_accuracy: 0.7479 - val_loss: 2.1865e-06 - val_binary_accuracy: 0.7414 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 5/70
# 687/687 - 1s - loss: 2.1468e-06 - binary_accuracy: 0.7477 - val_loss: 2.9370e-06 - val_binary_accuracy: 0.7005 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 6/70
# 687/687 - 1s - loss: 2.1463e-06 - binary_accuracy: 0.7488 - val_loss: 2.3393e-06 - val_binary_accuracy: 0.7322 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 7/70
# 687/687 - 1s - loss: 2.1443e-06 - binary_accuracy: 0.7493 - val_loss: 2.3156e-06 - val_binary_accuracy: 0.7166 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 8/70
# 687/687 - 1s - loss: 2.1414e-06 - binary_accuracy: 0.7498 - val_loss: 2.2258e-06 - val_binary_accuracy: 0.7316 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 9/70
# 687/687 - 1s - loss: 2.1390e-06 - binary_accuracy: 0.7499 - val_loss: 3.0161e-06 - val_binary_accuracy: 0.7067 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 10/70
# 687/687 - 1s - loss: 2.1463e-06 - binary_accuracy: 0.7489 - val_loss: 2.2558e-06 - val_binary_accuracy: 0.7404 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 11/70
# 687/687 - 1s - loss: 2.1417e-06 - binary_accuracy: 0.7497 - val_loss: 2.6116e-06 - val_binary_accuracy: 0.7170 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 12/70
# 687/687 - 1s - loss: 2.1407e-06 - binary_accuracy: 0.7502 - val_loss: 2.2267e-06 - val_binary_accuracy: 0.7388 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 13/70
# 687/687 - 1s - loss: 2.1380e-06 - binary_accuracy: 0.7506 - val_loss: 2.1704e-06 - val_binary_accuracy: 0.7381 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 14/70
# 687/687 - 1s - loss: 2.1366e-06 - binary_accuracy: 0.7508 - val_loss: 2.2387e-06 - val_binary_accuracy: 0.7260 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 15/70
# 687/687 - 1s - loss: 2.1380e-06 - binary_accuracy: 0.7505 - val_loss: 2.2932e-06 - val_binary_accuracy: 0.7428 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 16/70
# 687/687 - 1s - loss: 2.1359e-06 - binary_accuracy: 0.7503 - val_loss: 2.3002e-06 - val_binary_accuracy: 0.7290 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 17/70
# 687/687 - 1s - loss: 2.1376e-06 - binary_accuracy: 0.7502 - val_loss: 2.1754e-06 - val_binary_accuracy: 0.7450 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 18/70
# 687/687 - 1s - loss: 2.1341e-06 - binary_accuracy: 0.7502 - val_loss: 2.2091e-06 - val_binary_accuracy: 0.7333 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 19/70
# 687/687 - 1s - loss: 2.1331e-06 - binary_accuracy: 0.7512 - val_loss: 2.3713e-06 - val_binary_accuracy: 0.7349 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 20/70
# 687/687 - 1s - loss: 2.1496e-06 - binary_accuracy: 0.7494 - val_loss: 2.2461e-06 - val_binary_accuracy: 0.7244 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 21/70
# 687/687 - 1s - loss: 2.1339e-06 - binary_accuracy: 0.7509 - val_loss: 2.1753e-06 - val_binary_accuracy: 0.7370 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 22/70
# 687/687 - 1s - loss: 2.1349e-06 - binary_accuracy: 0.7506 - val_loss: 2.1450e-06 - val_binary_accuracy: 0.7446 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 23/70
# 687/687 - 1s - loss: 2.1323e-06 - binary_accuracy: 0.7516 - val_loss: 2.9410e-06 - val_binary_accuracy: 0.6713 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 24/70
# 687/687 - 1s - loss: 2.1404e-06 - binary_accuracy: 0.7496 - val_loss: 2.2766e-06 - val_binary_accuracy: 0.7211 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 25/70
# 687/687 - 1s - loss: 2.1332e-06 - binary_accuracy: 0.7508 - val_loss: 2.1781e-06 - val_binary_accuracy: 0.7397 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 26/70
# 687/687 - 1s - loss: 2.1314e-06 - binary_accuracy: 0.7517 - val_loss: 2.1752e-06 - val_binary_accuracy: 0.7381 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 27/70
# 687/687 - 1s - loss: 2.1322e-06 - binary_accuracy: 0.7505 - val_loss: 2.2217e-06 - val_binary_accuracy: 0.7409 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 28/70
# 687/687 - 1s - loss: 2.1316e-06 - binary_accuracy: 0.7514 - val_loss: 2.2840e-06 - val_binary_accuracy: 0.7243 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 29/70
# 687/687 - 1s - loss: 2.1312e-06 - binary_accuracy: 0.7509 - val_loss: 2.1621e-06 - val_binary_accuracy: 0.7430 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 30/70
# 687/687 - 1s - loss: 2.1296e-06 - binary_accuracy: 0.7515 - val_loss: 2.1543e-06 - val_binary_accuracy: 0.7435 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 31/70
# 687/687 - 1s - loss: 2.1278e-06 - binary_accuracy: 0.7516 - val_loss: 2.1415e-06 - val_binary_accuracy: 0.7504 - lr: 0.1000 - 1s/epoch - 2ms/step
# Epoch 32/70
# 687/687 - 1s - loss: 2.1097e-06 - binary_accuracy: 0.7541 - val_loss: 2.1370e-06 - val_binary_accuracy: 0.7483 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 33/70
# 687/687 - 1s - loss: 2.1060e-06 - binary_accuracy: 0.7540 - val_loss: 2.1363e-06 - val_binary_accuracy: 0.7477 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 34/70
# 687/687 - 1s - loss: 2.1046e-06 - binary_accuracy: 0.7543 - val_loss: 2.1365e-06 - val_binary_accuracy: 0.7483 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 35/70
# 687/687 - 1s - loss: 2.1040e-06 - binary_accuracy: 0.7542 - val_loss: 2.1357e-06 - val_binary_accuracy: 0.7482 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 36/70
# 687/687 - 1s - loss: 2.1032e-06 - binary_accuracy: 0.7541 - val_loss: 2.1361e-06 - val_binary_accuracy: 0.7468 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 37/70
# 687/687 - 1s - loss: 2.1029e-06 - binary_accuracy: 0.7549 - val_loss: 2.1351e-06 - val_binary_accuracy: 0.7477 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 38/70
# 687/687 - 1s - loss: 2.1026e-06 - binary_accuracy: 0.7546 - val_loss: 2.1363e-06 - val_binary_accuracy: 0.7471 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 39/70
# 687/687 - 1s - loss: 2.1027e-06 - binary_accuracy: 0.7546 - val_loss: 2.1351e-06 - val_binary_accuracy: 0.7477 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 40/70
# 687/687 - 1s - loss: 2.1024e-06 - binary_accuracy: 0.7545 - val_loss: 2.1358e-06 - val_binary_accuracy: 0.7473 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 41/70
# 687/687 - 1s - loss: 2.1022e-06 - binary_accuracy: 0.7547 - val_loss: 2.1362e-06 - val_binary_accuracy: 0.7478 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 42/70
# 687/687 - 1s - loss: 2.1021e-06 - binary_accuracy: 0.7547 - val_loss: 2.1348e-06 - val_binary_accuracy: 0.7474 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 43/70
# 687/687 - 1s - loss: 2.1019e-06 - binary_accuracy: 0.7546 - val_loss: 2.1359e-06 - val_binary_accuracy: 0.7477 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 44/70
# 687/687 - 1s - loss: 2.1018e-06 - binary_accuracy: 0.7540 - val_loss: 2.1351e-06 - val_binary_accuracy: 0.7466 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 45/70
# 687/687 - 1s - loss: 2.1018e-06 - binary_accuracy: 0.7550 - val_loss: 2.1355e-06 - val_binary_accuracy: 0.7474 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 46/70
# 687/687 - 1s - loss: 2.1017e-06 - binary_accuracy: 0.7545 - val_loss: 2.1351e-06 - val_binary_accuracy: 0.7474 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 47/70
# 687/687 - 1s - loss: 2.1017e-06 - binary_accuracy: 0.7547 - val_loss: 2.1345e-06 - val_binary_accuracy: 0.7470 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 48/70
# 687/687 - 1s - loss: 2.1016e-06 - binary_accuracy: 0.7548 - val_loss: 2.1356e-06 - val_binary_accuracy: 0.7477 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 49/70
# 687/687 - 1s - loss: 2.1013e-06 - binary_accuracy: 0.7549 - val_loss: 2.1340e-06 - val_binary_accuracy: 0.7473 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 50/70
# 687/687 - 1s - loss: 2.1014e-06 - binary_accuracy: 0.7545 - val_loss: 2.1353e-06 - val_binary_accuracy: 0.7476 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 51/70
# 687/687 - 1s - loss: 2.1014e-06 - binary_accuracy: 0.7549 - val_loss: 2.1340e-06 - val_binary_accuracy: 0.7478 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 52/70
# 687/687 - 1s - loss: 2.1013e-06 - binary_accuracy: 0.7545 - val_loss: 2.1347e-06 - val_binary_accuracy: 0.7475 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 53/70
# 687/687 - 1s - loss: 2.1013e-06 - binary_accuracy: 0.7547 - val_loss: 2.1345e-06 - val_binary_accuracy: 0.7478 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 54/70
# 687/687 - 1s - loss: 2.1012e-06 - binary_accuracy: 0.7551 - val_loss: 2.1337e-06 - val_binary_accuracy: 0.7475 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 55/70
# 687/687 - 1s - loss: 2.1010e-06 - binary_accuracy: 0.7549 - val_loss: 2.1343e-06 - val_binary_accuracy: 0.7480 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 56/70
# 687/687 - 1s - loss: 2.1010e-06 - binary_accuracy: 0.7548 - val_loss: 2.1336e-06 - val_binary_accuracy: 0.7474 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 57/70
# 687/687 - 1s - loss: 2.1008e-06 - binary_accuracy: 0.7549 - val_loss: 2.1356e-06 - val_binary_accuracy: 0.7476 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 58/70
# 687/687 - 1s - loss: 2.1009e-06 - binary_accuracy: 0.7549 - val_loss: 2.1345e-06 - val_binary_accuracy: 0.7478 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 59/70
# 687/687 - 1s - loss: 2.1006e-06 - binary_accuracy: 0.7552 - val_loss: 2.1332e-06 - val_binary_accuracy: 0.7476 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 60/70
# 687/687 - 1s - loss: 2.1006e-06 - binary_accuracy: 0.7550 - val_loss: 2.1351e-06 - val_binary_accuracy: 0.7468 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 61/70
# 687/687 - 1s - loss: 2.1005e-06 - binary_accuracy: 0.7548 - val_loss: 2.1327e-06 - val_binary_accuracy: 0.7476 - lr: 0.0010 - 1s/epoch - 2ms/step
# Epoch 62/70
# 687/687 - 1s - loss: 2.1001e-06 - binary_accuracy: 0.7552 - val_loss: 2.1328e-06 - val_binary_accuracy: 0.7475 - lr: 1.0000e-05 - 1s/epoch - 2ms/step
# Epoch 63/70
# 687/687 - 1s - loss: 2.1000e-06 - binary_accuracy: 0.7550 - val_loss: 2.1328e-06 - val_binary_accuracy: 0.7478 - lr: 1.0000e-05 - 1s/epoch - 2ms/step
# Epoch 64/70
# 687/687 - 1s - loss: 2.1000e-06 - binary_accuracy: 0.7550 - val_loss: 2.1328e-06 - val_binary_accuracy: 0.7480 - lr: 1.0000e-05 - 1s/epoch - 2ms/step
# Epoch 65/70
# 687/687 - 1s - loss: 2.1000e-06 - binary_accuracy: 0.7549 - val_loss: 2.1328e-06 - val_binary_accuracy: 0.7478 - lr: 1.0000e-05 - 1s/epoch - 2ms/step
# Epoch 66/70
# 687/687 - 1s - loss: 2.1000e-06 - binary_accuracy: 0.7549 - val_loss: 2.1329e-06 - val_binary_accuracy: 0.7479 - lr: 1.0000e-05 - 1s/epoch - 2ms/step
# Epoch 67/70
# 687/687 - 1s - loss: 2.0999e-06 - binary_accuracy: 0.7550 - val_loss: 2.1329e-06 - val_binary_accuracy: 0.7479 - lr: 1.0000e-05 - 1s/epoch - 2ms/step
# Epoch 68/70
# 687/687 - 1s - loss: 2.0999e-06 - binary_accuracy: 0.7550 - val_loss: 2.1329e-06 - val_binary_accuracy: 0.7481 - lr: 1.0000e-05 - 1s/epoch - 2ms/step
# Epoch 69/70
# 687/687 - 1s - loss: 2.0999e-06 - binary_accuracy: 0.7549 - val_loss: 2.1329e-06 - val_binary_accuracy: 0.7481 - lr: 1.0000e-05 - 1s/epoch - 2ms/step
# Epoch 70/70
# 687/687 - 1s - loss: 2.0999e-06 - binary_accuracy: 0.7550 - val_loss: 2.1330e-06 - val_binary_accuracy: 0.7479 - lr: 1.0000e-05 - 1s/epoch - 2ms/step
# Finished Training
# ./output_training_nominal/output_model_params_wjets/model_scaler.bin
# 3049/3049 - 2s - 2s/epoch - 630us/step
# 12197/12197 - 7s - 7s/epoch - 590us/step

# %% [markdown]
# Check for overtraining by comparing the NN output distributions between training and holdout datasets. The holdout dataset is the subset of events not used during training.

# %%
NN_training_mix_model['wjets'].make_overfit_plots()

# %% [markdown]
# Diagnostic Checks
# ===
#
# While traditionally, a NN observable is judged on the basis of its accuracy - for NSBI we are interested in the quality of the density ratios more than the discrimination power. The latter comes from the perfect modelling of the multi-dimensional likelihood ratios.
#
# To ensure correct modelling, we run two main checks on the training:
#
# - **Calibration closure test**
#
#   The NNs are trained using the binary cross-entropy loss, which under ideal conditions leads to the NN converging to the score function:
#
#   $$\hat{s}_\text{pred} = \frac{p_\text{ttbar}(x)}{p_\text{ttbar}(x)+p_\text{wjets}(x)}$$
#
#   that can be converted into the probability ratio we desire (likelihood ratio trick):
#
#   $$\frac{p_\text{wjets}(x)}{p_\text{ttbar}(x)} = \frac{\hat{s}_\text{pred}(x)}{1-\hat{s}_\text{pred}(x)}$$
#
#   For the NNs to be well-calibrated, we use the Monte Carlo samples to verify the equality:
#
#
#   $$\left[\frac{p_c(x)}{p_c(x)+p_{ref}(x)}\right]_\text{NN} \sim \left[\frac{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}}{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}+\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}}\right]_\text{MC}$$
#
#   where we bin the events from $p_c$ and $p_\text{ref}$ MC samples, denoted by $\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}$ and $\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}$ respectively where $I(x|\hat{s}_\text{pred})$ returns the index of the $\hat{s}_\text{pred}$ bin in which an event $x$ falls.

# %%
num_bins_cal = 50
NN_training_mix_model['wjets'].make_calib_plots(nbins=num_bins_cal, observable='score')
# Out:
# observable not recognized

# %%
num_bins_cal = 50
NN_training_mix_model['wjets'].make_calib_plots(nbins=num_bins_cal, observable='llr')

# %% [markdown]
# - **Density ratio reweighting closure tests**
#
#   Despite having a well-calibrated output and thus a robust probabilistic interpretation, the trained density ratios might not capture the full multi-dimensional event information $x$. In other words, the NNs might still be biased estimators of the optimal score function, as defined in the CARL paper (link).
#
#   The next diagnostic involves verifying the following equality using 1D projections of $x$:
#
#   $$\frac{p_c(x)}{p_{ref}(x)} \times p_{ref}(x) \sim p_c(x)$$
#
#   We can do this one-by-one for all the observables used to model the density ratios, and also possibly the observables not used directly in the training but can still be well-estimated due to the NN learning the right physics.

# %%
variables_to_plot=['lepton_pt'] # The 1D variable for reweighting closure
yscale_type='log'
num_bins_plotting=21

NN_training_mix_model['wjets'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['lepton_phi']
yscale_type='log'
num_bins_plotting=21

NN_training_mix_model['wjets'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['lepton_eta']
yscale_type='log'
num_bins_plotting=21

NN_training_mix_model['wjets'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['H_T']
yscale_type='log'
num_bins_plotting=21

NN_training_mix_model['wjets'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['presel_score']
yscale_type='log'
num_bins_plotting=21

NN_training_mix_model['wjets'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
# Evaluate the density ratios p_wjets/p_ttbar for the full dataset and save for the inference step
NN_training_mix_model['wjets'].evaluate_and_save_ratios(dataset)
# Out:
# 21172/21172 - 12s - 12s/epoch - 570us/step

# %% [markdown]
# Now for the training and validation of the other density ratio:
#
# $$\frac{p_\text{single top}(x)}{p_\text{ttbar}(x)}$$

# %%
# Train the density ratio NN
NN_training_mix_model['single_top_t_chan'].train (   hidden_layers        = 2, 
                                                     neurons              = 1000, 
                                                     number_of_epochs     = 70, 
                                                     batch_size           = 512, 
                                                     learning_rate        = 0.1, 
                                                     scalerType           = 'MinMax', 
                                                     calibration          = False, 
                                                     num_bins_cal         = 10, 
                                                     callback             = True, 
                                                     callback_patience    = 30, 
                                                     callback_factor      = 0.01     )
# Out:
# Sum of weights of class 0: 0.8000031636726019
# Sum of weights of class 1: 0.8000000000000012
# Using swish activation function
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 1000)              6000
#
#  dense_4 (Dense)             (None, 1000)              1001000
#
#  dense_5 (Dense)             (None, 1)                 1001
#
# =================================================================
# Total params: 1008001 (3.85 MB)
# Trainable params: 1008001 (3.85 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Using Callbacks
# Epoch 1/70
# 921/921 - 3s - loss: 1.9497e-06 - binary_accuracy: 0.6439 - val_loss: 1.9311e-06 - val_binary_accuracy: 0.6516 - lr: 0.1000 - 3s/epoch - 4ms/step
# Epoch 2/70
# 921/921 - 2s - loss: 1.9302e-06 - binary_accuracy: 0.6515 - val_loss: 1.9739e-06 - val_binary_accuracy: 0.6401 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 3/70
# 921/921 - 2s - loss: 1.9276e-06 - binary_accuracy: 0.6519 - val_loss: 1.9359e-06 - val_binary_accuracy: 0.6527 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 4/70
# 921/921 - 2s - loss: 1.9262e-06 - binary_accuracy: 0.6524 - val_loss: 1.9282e-06 - val_binary_accuracy: 0.6521 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 5/70
# 921/921 - 2s - loss: 1.9248e-06 - binary_accuracy: 0.6530 - val_loss: 1.9322e-06 - val_binary_accuracy: 0.6517 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 6/70
# 921/921 - 2s - loss: 1.9234e-06 - binary_accuracy: 0.6532 - val_loss: 1.9282e-06 - val_binary_accuracy: 0.6517 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 7/70
# 921/921 - 2s - loss: 1.9225e-06 - binary_accuracy: 0.6539 - val_loss: 1.9225e-06 - val_binary_accuracy: 0.6538 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 8/70
# 921/921 - 2s - loss: 1.9202e-06 - binary_accuracy: 0.6547 - val_loss: 1.9234e-06 - val_binary_accuracy: 0.6555 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 9/70
# 921/921 - 2s - loss: 1.9186e-06 - binary_accuracy: 0.6549 - val_loss: 1.9206e-06 - val_binary_accuracy: 0.6542 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 10/70
# 921/921 - 2s - loss: 1.9181e-06 - binary_accuracy: 0.6550 - val_loss: 1.9206e-06 - val_binary_accuracy: 0.6545 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 11/70
# 921/921 - 2s - loss: 1.9175e-06 - binary_accuracy: 0.6549 - val_loss: 1.9216e-06 - val_binary_accuracy: 0.6548 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 12/70
# 921/921 - 2s - loss: 1.9168e-06 - binary_accuracy: 0.6550 - val_loss: 1.9241e-06 - val_binary_accuracy: 0.6541 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 13/70
# 921/921 - 2s - loss: 1.9164e-06 - binary_accuracy: 0.6556 - val_loss: 1.9250e-06 - val_binary_accuracy: 0.6525 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 14/70
# 921/921 - 2s - loss: 1.9167e-06 - binary_accuracy: 0.6553 - val_loss: 1.9220e-06 - val_binary_accuracy: 0.6543 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 15/70
# 921/921 - 2s - loss: 1.9165e-06 - binary_accuracy: 0.6552 - val_loss: 1.9200e-06 - val_binary_accuracy: 0.6561 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 16/70
# 921/921 - 2s - loss: 1.9163e-06 - binary_accuracy: 0.6551 - val_loss: 1.9223e-06 - val_binary_accuracy: 0.6537 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 17/70
# 921/921 - 2s - loss: 1.9165e-06 - binary_accuracy: 0.6553 - val_loss: 1.9226e-06 - val_binary_accuracy: 0.6550 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 18/70
# 921/921 - 2s - loss: 1.9163e-06 - binary_accuracy: 0.6554 - val_loss: 1.9190e-06 - val_binary_accuracy: 0.6554 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 19/70
# 921/921 - 2s - loss: 1.9162e-06 - binary_accuracy: 0.6555 - val_loss: 1.9197e-06 - val_binary_accuracy: 0.6552 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 20/70
# 921/921 - 2s - loss: 1.9157e-06 - binary_accuracy: 0.6556 - val_loss: 1.9184e-06 - val_binary_accuracy: 0.6553 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 21/70
# 921/921 - 2s - loss: 1.9159e-06 - binary_accuracy: 0.6552 - val_loss: 1.9206e-06 - val_binary_accuracy: 0.6545 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 22/70
# 921/921 - 2s - loss: 1.9157e-06 - binary_accuracy: 0.6552 - val_loss: 1.9213e-06 - val_binary_accuracy: 0.6548 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 23/70
# 921/921 - 2s - loss: 1.9158e-06 - binary_accuracy: 0.6553 - val_loss: 1.9190e-06 - val_binary_accuracy: 0.6552 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 24/70
# 921/921 - 2s - loss: 1.9157e-06 - binary_accuracy: 0.6553 - val_loss: 1.9209e-06 - val_binary_accuracy: 0.6544 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 25/70
# 921/921 - 2s - loss: 1.9157e-06 - binary_accuracy: 0.6557 - val_loss: 1.9210e-06 - val_binary_accuracy: 0.6544 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 26/70
# 921/921 - 2s - loss: 1.9157e-06 - binary_accuracy: 0.6552 - val_loss: 1.9196e-06 - val_binary_accuracy: 0.6551 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 27/70
# 921/921 - 2s - loss: 1.9157e-06 - binary_accuracy: 0.6556 - val_loss: 1.9200e-06 - val_binary_accuracy: 0.6549 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 28/70
# 921/921 - 2s - loss: 1.9154e-06 - binary_accuracy: 0.6553 - val_loss: 1.9194e-06 - val_binary_accuracy: 0.6557 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 29/70
# 921/921 - 2s - loss: 1.9154e-06 - binary_accuracy: 0.6555 - val_loss: 1.9239e-06 - val_binary_accuracy: 0.6531 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 30/70
# 921/921 - 2s - loss: 1.9156e-06 - binary_accuracy: 0.6555 - val_loss: 1.9179e-06 - val_binary_accuracy: 0.6558 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 31/70
# 921/921 - 2s - loss: 1.9157e-06 - binary_accuracy: 0.6555 - val_loss: 1.9181e-06 - val_binary_accuracy: 0.6556 - lr: 0.1000 - 2s/epoch - 2ms/step
# Epoch 32/70
# 921/921 - 2s - loss: 1.9125e-06 - binary_accuracy: 0.6560 - val_loss: 1.9179e-06 - val_binary_accuracy: 0.6557 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 33/70
# 921/921 - 2s - loss: 1.9124e-06 - binary_accuracy: 0.6560 - val_loss: 1.9178e-06 - val_binary_accuracy: 0.6557 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 34/70
# 921/921 - 2s - loss: 1.9124e-06 - binary_accuracy: 0.6560 - val_loss: 1.9178e-06 - val_binary_accuracy: 0.6556 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 35/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6560 - val_loss: 1.9178e-06 - val_binary_accuracy: 0.6555 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 36/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6561 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6555 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 37/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6560 - val_loss: 1.9178e-06 - val_binary_accuracy: 0.6555 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 38/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6559 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6553 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 39/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6562 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6553 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 40/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6562 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6555 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 41/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6562 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6553 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 42/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6560 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6555 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 43/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6561 - val_loss: 1.9176e-06 - val_binary_accuracy: 0.6554 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 44/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6562 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6556 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 45/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6561 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6553 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 46/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6561 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6555 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 47/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6561 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6554 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 48/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6561 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6555 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 49/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6562 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6554 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 50/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6561 - val_loss: 1.9178e-06 - val_binary_accuracy: 0.6551 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 51/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6561 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6556 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 52/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6561 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6553 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 53/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6561 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6551 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 54/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6560 - val_loss: 1.9176e-06 - val_binary_accuracy: 0.6554 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 55/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6562 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6553 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 56/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6560 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6553 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 57/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6561 - val_loss: 1.9176e-06 - val_binary_accuracy: 0.6554 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 58/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6561 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6550 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 59/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6561 - val_loss: 1.9176e-06 - val_binary_accuracy: 0.6556 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 60/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6561 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6553 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 61/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6562 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6554 - lr: 0.0010 - 2s/epoch - 2ms/step
# Epoch 62/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6562 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6553 - lr: 1.0000e-05 - 2s/epoch - 2ms/step
# Epoch 63/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6562 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6554 - lr: 1.0000e-05 - 2s/epoch - 2ms/step
# Epoch 64/70
# 921/921 - 2s - loss: 1.9123e-06 - binary_accuracy: 0.6562 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6554 - lr: 1.0000e-05 - 2s/epoch - 2ms/step
# Epoch 65/70
# 921/921 - 2s - loss: 1.9122e-06 - binary_accuracy: 0.6562 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6554 - lr: 1.0000e-05 - 2s/epoch - 2ms/step
# Epoch 66/70
# 921/921 - 2s - loss: 1.9122e-06 - binary_accuracy: 0.6562 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6554 - lr: 1.0000e-05 - 2s/epoch - 2ms/step
# Epoch 67/70
# 921/921 - 2s - loss: 1.9122e-06 - binary_accuracy: 0.6561 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6554 - lr: 1.0000e-05 - 2s/epoch - 2ms/step
# Epoch 68/70
# 921/921 - 2s - loss: 1.9122e-06 - binary_accuracy: 0.6561 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6554 - lr: 1.0000e-05 - 2s/epoch - 2ms/step
# Epoch 69/70
# 921/921 - 2s - loss: 1.9122e-06 - binary_accuracy: 0.6561 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6554 - lr: 1.0000e-05 - 2s/epoch - 2ms/step
# Epoch 70/70
# 921/921 - 2s - loss: 1.9122e-06 - binary_accuracy: 0.6561 - val_loss: 1.9177e-06 - val_binary_accuracy: 0.6554 - lr: 1.0000e-05 - 2s/epoch - 2ms/step
# Finished Training
# ./output_training_nominal/output_model_params_single_top_t_chan/model_scaler.bin
# 4093/4093 - 2s - 2s/epoch - 584us/step
# 16371/16371 - 9s - 9s/epoch - 580us/step

# %%
NN_training_mix_model['single_top_t_chan'].make_overfit_plots()

# %%
num_bins_cal = 50
NN_training_mix_model['single_top_t_chan'].make_calib_plots(nbins=num_bins_cal, observable='score')
# Out:
# observable not recognized

# %%
NN_training_mix_model['single_top_t_chan'].make_calib_plots(nbins=num_bins_cal, observable='llr')

# %%
variables_to_plot=['lepton_pt']
yscale_type='log'
num_bins_plotting=21

NN_training_mix_model['single_top_t_chan'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['lepton_phi']
yscale_type='log'
num_bins_plotting=21

NN_training_mix_model['single_top_t_chan'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['lepton_eta']
yscale_type='log'
num_bins_plotting=21

NN_training_mix_model['single_top_t_chan'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['H_T']
yscale_type='log'
num_bins_plotting=21

NN_training_mix_model['single_top_t_chan'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['presel_score']
yscale_type='log'
num_bins_plotting=21

NN_training_mix_model['single_top_t_chan'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
# Evaluate the density ratios p_singletop/p_ttbar for the full dataset and save for the inference step
NN_training_mix_model['single_top_t_chan'].evaluate_and_save_ratios(dataset)
# Out:
# 21172/21172 - 12s - 12s/epoch - 574us/step

# %% [markdown]
# Systematic Uncertainty Modelling
# ===
#
# So far we have left out the nuisance parameter piece of the parameterized density ratio decomposition shown before:
#
# $$g_c(x|\alpha) = \frac{p_c(x|\alpha)}{p_c(x)}$$
#
# which will be estimated in the `Systematic_Uncertainty_Estimation.ipynb` notebook.

# %% [markdown]
# Training an Ensemble of NNs
# ===
#
# In a realistic analysis, a large ensemble of NNs are trained to estimate density ratios, for *each* of the channels. **This reduces not only the variance but has also been found to reduce biases in the final fits.**
#
# In the off-shell Higgs boson analysis, we used k-fold cross-validation, with k=10, to train an ensemble $N_{ens}\sim 250$ of NNs per density ratio $p_c(x)/p_{ref}(x)$. The density ratios used in the final fit are always evaluated on the holdout dataset and by using each of the folds as holdout once, the entire model for $p_c(x)/p_{ref}(x)$ consists of $N_{ens}\times k \sim 2500$ NNs. Each NN in the ensemble is trained by resampling data without replacement from the k-1 folds used for training.
