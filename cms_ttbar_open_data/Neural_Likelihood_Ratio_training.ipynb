# %% [markdown]
# Train Neural Networks to estimate Likelihood Ratios
# ===
#
# In this notebook we will setup the neural networks that train unbiased and low-variance density ratios to be then used for inference. The statistical model we have is:
#
# $$p(x|\mu, \alpha) = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot p_c\left(x|\alpha\right)$$

# %%
import os, sys, importlib
sys.path.append('../')

import common_utils
from common_utils import plotting, training
from common_utils.training import TrainEvaluate_NN
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt
hep.style.use(hep.style.ATLAS)
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:10: FutureWarning: ``set_style`` is deprecated: Naming convention is changing to match mpl. Use ``mplhep.style.use()``.
#   hep.set_style("ATLAS")
# 2025-02-11 09:26:51.079289: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-11 09:26:52.138879: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load the datasets from pre-processed input
saved_data='./cached_data/'

training_features = np.load(f"{saved_data}features.npy")
train_labels = np.load(f"{saved_data}train_labels.npy")
preselection_score = np.load(f"{saved_data}preselection_score.npy")
weights = np.load(f"{saved_data}weights.npy")

# %%
# labels_dict = {"ttbar": 0,
#                "single_top_s_chan":1,
#               "single_top_t_chan":2,
#               "single_top_tW":3,
#               "wjets":4}

# Keep only a subset of the background for illustration
labels_dict = {"ttbar": 0,
              "single_top_t_chan":1,
              "wjets":2}

# %%
min_pred = np.amin(preselection_score)
max_pred = np.amax(preselection_score)

bins = np.linspace(min_pred, max_pred, num=150)

hist_NN_output = {}

for key in labels_dict: 
    hist_NN_output[key], _ = np.histogram(preselection_score[train_labels==labels_dict[key]], weights = weights[train_labels==labels_dict[key]], bins=bins)

# %% [markdown]
# Make a selection cut for performing the NSBI analysis, balancing the number of signal events that go into the signal region (increasing sensitivity) and the feasibility of training accurate and precise NNs over a large phase space (need bigger models and more statistics).
#
# As a first cut, we choose a loose preselection and see if it works.

# %%
preselection_cut = -19 # Lets start with a very loose cut

for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins=bins, 
             alpha=0.6, label=key, 
             density=True, linewidth=2.0)

plt.xlabel("Preselection Score", size=18)
plt.axvline(preselection_cut, ymax=0.9, linestyle='--', label=f'preselection cut ({preselection_cut})')
plt.ylabel("Density", size=18)
plt.legend()
plt.yscale('log')
plt.show()

# %%
# Make the preselections

training_features = training_features[preselection_score>=preselection_cut].copy()
train_labels = train_labels[preselection_score>=preselection_cut].copy()
weights = weights[preselection_score>=preselection_cut].copy()

preselection_score_selected = preselection_score[preselection_score>=preselection_cut].copy()

# %%
type_vec = np.array(train_labels, dtype='object')

for key in labels_dict:
    type_vec[type_vec==labels_dict[key]] = key

# %%
# Build a pandas dataframe from the arrays for density ratio training and validation
columns = ['lepton_pt', 'lepton_eta', 'lepton_phi', 'H_T']
dataset = pd.DataFrame(training_features, columns=columns)

dataset['log_lepton_pt'] = np.log(dataset['lepton_pt'].ravel())
dataset['log_H_T'] = np.log(dataset['H_T'].ravel()+1.0)

dataset['presel_score'] = preselection_score_selected
dataset['train_labels'] = train_labels
dataset['type'] = type_vec
dataset['weights'] = weights

# %%
# Normalizing the training weights - only discriminating shapes, not norms

weights_normed = weights.copy()

for key in labels_dict:

    weights_normed[train_labels==labels_dict[key]] /= weights[train_labels==labels_dict[key]].sum()

dataset['weights_normed'] = weights_normed

# %%
# Save the preselected dataframe for inference use later on
dataset.to_hdf(f"{saved_data}dataset_preselected_ttbar.h5", key="dataset", mode='w')

# %%
columns = ['lepton_pt', 'lepton_eta', 'lepton_phi']
columns_scaling = ['lepton_pt', 'lepton_eta', 'lepton_phi']

columns = ['log_lepton_pt', 'lepton_eta', 'lepton_phi']
columns_scaling = ['log_lepton_pt', 'lepton_eta', 'lepton_phi']

columns = ['log_lepton_pt', 'log_H_T', 'lepton_eta', 'lepton_phi']
columns_scaling = ['log_lepton_pt', 'log_H_T', 'lepton_eta', 'lepton_phi']

# %%
# Choose ttbar as the reference hypothesis
dataset_ch_wjets_ref = pd.concat([dataset[dataset['type']=='wjets'], 
                                  dataset[dataset['type']=='ttbar']])

dataset_ch_wjets_ref['train_labels'] = 0
dataset_ch_wjets_ref.loc[dataset_ch_wjets_ref['type']=='ttbar', 'train_labels'] = 1

# %%
NN_training_channels_dict = {}

# %%
rnd_seed_traintestsplit = 42
channel_names = ['wjets', 'ttbar']

# Save paths
output_dir = './output_general_wjets/'
output_name = 'first_training_wjets'
path_to_ratios = './output_ratios_wjets/'
path_to_figures = './output_figures_wjets/'
path_to_models = './output_model_params_wjets/'

importlib.reload(sys.modules['common_utils.training'])
from common_utils.training import TrainEvaluate_NN

# Initialize the training class
NN_training_channels_dict['wjets'] = TrainEvaluate_NN(dataset_ch_wjets_ref, 
                                                       dataset_ch_wjets_ref['weights_normed'],
                                                       dataset_ch_wjets_ref['train_labels'],
                                                       columns, 
                                                       columns_scaling, rnd_seed_traintestsplit, 
                                                       channel_names, output_dir, output_name, 
                                                        path_to_figures=path_to_figures,
                                                        path_to_ratios=path_to_ratios, 
                                                        path_to_models=path_to_models)

# %%
# Train the density ratio NN
NN_training_channels_dict['wjets'].train(hidden_layers=2, 
                        neurons=1000, 
                        number_of_epochs=50, 
                        batch_size=1024, 
                        learning_rate=0.1, 
                        scalerType='MinMax', 
                        calibration=False, 
                        num_bins_cal = 10, 
                        callback=True, 
                        callback_patience=30, 
                        callback_factor=0.01)
# Out:
# Sum of weights of class 0: 0.8000009548544802
# Sum of weights of class 1: 0.7999898267849939
# Using swish activation function
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1000)              5000
#
#  dense_1 (Dense)             (None, 1000)              1001000
#
#  dense_2 (Dense)             (None, 1)                 1001
#
# =================================================================
# Total params: 1007001 (3.84 MB)
# Trainable params: 1007001 (3.84 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Using Callbacks
# Epoch 1/50
# 1947/1947 - 92s - loss: 1.9934e-07 - binary_accuracy: 0.8960 - val_loss: 1.9201e-07 - val_binary_accuracy: 0.8998 - lr: 0.1000 - 92s/epoch - 47ms/step
# Epoch 2/50
# 1947/1947 - 89s - loss: 1.9126e-07 - binary_accuracy: 0.8996 - val_loss: 1.9479e-07 - val_binary_accuracy: 0.8982 - lr: 0.1000 - 89s/epoch - 46ms/step
# Epoch 3/50
# 1947/1947 - 87s - loss: 1.9082e-07 - binary_accuracy: 0.8998 - val_loss: 1.9112e-07 - val_binary_accuracy: 0.9014 - lr: 0.1000 - 87s/epoch - 45ms/step
# Epoch 4/50
# 1947/1947 - 86s - loss: 1.9052e-07 - binary_accuracy: 0.8998 - val_loss: 1.9091e-07 - val_binary_accuracy: 0.9007 - lr: 0.1000 - 86s/epoch - 44ms/step
# Epoch 5/50
# 1947/1947 - 86s - loss: 1.9013e-07 - binary_accuracy: 0.8998 - val_loss: 1.8897e-07 - val_binary_accuracy: 0.9019 - lr: 0.1000 - 86s/epoch - 44ms/step
# Epoch 6/50
# 1947/1947 - 86s - loss: 1.8976e-07 - binary_accuracy: 0.9000 - val_loss: 1.8846e-07 - val_binary_accuracy: 0.9019 - lr: 0.1000 - 86s/epoch - 44ms/step
# Epoch 7/50
# 1947/1947 - 86s - loss: 1.8926e-07 - binary_accuracy: 0.8999 - val_loss: 1.8788e-07 - val_binary_accuracy: 0.9022 - lr: 0.1000 - 86s/epoch - 44ms/step
# Epoch 8/50
# 1947/1947 - 86s - loss: 1.8864e-07 - binary_accuracy: 0.9000 - val_loss: 1.8792e-07 - val_binary_accuracy: 0.9018 - lr: 0.1000 - 86s/epoch - 44ms/step
# Epoch 9/50
# 1947/1947 - 86s - loss: 1.8807e-07 - binary_accuracy: 0.8998 - val_loss: 1.8633e-07 - val_binary_accuracy: 0.9022 - lr: 0.1000 - 86s/epoch - 44ms/step
# Epoch 10/50
# 1947/1947 - 85s - loss: 1.8747e-07 - binary_accuracy: 0.8999 - val_loss: 1.8608e-07 - val_binary_accuracy: 0.9021 - lr: 0.1000 - 85s/epoch - 44ms/step
# Epoch 11/50
# 1947/1947 - 86s - loss: 1.8658e-07 - binary_accuracy: 0.8999 - val_loss: 1.8557e-07 - val_binary_accuracy: 0.9020 - lr: 0.1000 - 86s/epoch - 44ms/step
# Epoch 13/50
# 1947/1947 - 86s - loss: 1.8645e-07 - binary_accuracy: 0.8999 - val_loss: 1.8684e-07 - val_binary_accuracy: 0.9016 - lr: 0.1000 - 86s/epoch - 44ms/step
# Epoch 14/50
# 1947/1947 - 87s - loss: 1.8633e-07 - binary_accuracy: 0.8998 - val_loss: 1.8485e-07 - val_binary_accuracy: 0.9024 - lr: 0.1000 - 87s/epoch - 44ms/step
# Epoch 15/50
# 1947/1947 - 88s - loss: 1.8623e-07 - binary_accuracy: 0.9000 - val_loss: 1.8482e-07 - val_binary_accuracy: 0.9020 - lr: 0.1000 - 88s/epoch - 45ms/step
# Epoch 16/50
# 1947/1947 - 87s - loss: 1.8610e-07 - binary_accuracy: 0.9001 - val_loss: 1.8603e-07 - val_binary_accuracy: 0.9014 - lr: 0.1000 - 87s/epoch - 45ms/step
# Epoch 17/50
# 1947/1947 - 88s - loss: 1.8606e-07 - binary_accuracy: 0.9001 - val_loss: 1.8538e-07 - val_binary_accuracy: 0.9020 - lr: 0.1000 - 88s/epoch - 45ms/step
# Epoch 18/50
# 1947/1947 - 87s - loss: 1.8602e-07 - binary_accuracy: 0.9000 - val_loss: 1.8528e-07 - val_binary_accuracy: 0.9015 - lr: 0.1000 - 87s/epoch - 45ms/step
# Epoch 19/50
# 1947/1947 - 87s - loss: 1.8595e-07 - binary_accuracy: 0.9000 - val_loss: 1.8515e-07 - val_binary_accuracy: 0.9019 - lr: 0.1000 - 87s/epoch - 45ms/step
# Epoch 20/50
# 1947/1947 - 87s - loss: 1.8588e-07 - binary_accuracy: 0.9002 - val_loss: 1.8457e-07 - val_binary_accuracy: 0.9020 - lr: 0.1000 - 87s/epoch - 45ms/step
# Epoch 21/50
# 1947/1947 - 86s - loss: 1.8584e-07 - binary_accuracy: 0.9001 - val_loss: 1.8493e-07 - val_binary_accuracy: 0.9019 - lr: 0.1000 - 86s/epoch - 44ms/step
# Epoch 22/50
# 1947/1947 - 86s - loss: 1.8579e-07 - binary_accuracy: 0.9002 - val_loss: 1.8491e-07 - val_binary_accuracy: 0.9026 - lr: 0.1000 - 86s/epoch - 44ms/step
# Epoch 23/50
# 1947/1947 - 87s - loss: 1.8576e-07 - binary_accuracy: 0.9003 - val_loss: 1.8458e-07 - val_binary_accuracy: 0.9022 - lr: 0.1000 - 87s/epoch - 44ms/step
# Epoch 24/50
# 1947/1947 - 87s - loss: 1.8576e-07 - binary_accuracy: 0.9003 - val_loss: 1.8450e-07 - val_binary_accuracy: 0.9023 - lr: 0.1000 - 87s/epoch - 44ms/step
# Epoch 25/50
# 1947/1947 - 86s - loss: 1.8573e-07 - binary_accuracy: 0.9002 - val_loss: 1.8460e-07 - val_binary_accuracy: 0.9025 - lr: 0.1000 - 86s/epoch - 44ms/step
# Epoch 26/50
# 1947/1947 - 86s - loss: 1.8571e-07 - binary_accuracy: 0.9003 - val_loss: 1.8470e-07 - val_binary_accuracy: 0.9023 - lr: 0.1000 - 86s/epoch - 44ms/step
# Epoch 27/50
# 1947/1947 - 86s - loss: 1.8562e-07 - binary_accuracy: 0.9004 - val_loss: 1.8446e-07 - val_binary_accuracy: 0.9025 - lr: 0.1000 - 86s/epoch - 44ms/step
# Epoch 28/50
# 1947/1947 - 87s - loss: 1.8554e-07 - binary_accuracy: 0.9004 - val_loss: 1.8498e-07 - val_binary_accuracy: 0.9016 - lr: 0.1000 - 87s/epoch - 45ms/step
# Epoch 29/50
# 1947/1947 - 86s - loss: 1.8554e-07 - binary_accuracy: 0.9007 - val_loss: 1.8507e-07 - val_binary_accuracy: 0.9018 - lr: 0.1000 - 86s/epoch - 44ms/step
# Epoch 30/50
# 1947/1947 - 86s - loss: 1.8550e-07 - binary_accuracy: 0.9005 - val_loss: 1.8422e-07 - val_binary_accuracy: 0.9026 - lr: 0.1000 - 86s/epoch - 44ms/step
# Epoch 31/50
# 1947/1947 - 86s - loss: 1.8549e-07 - binary_accuracy: 0.9005 - val_loss: 1.8419e-07 - val_binary_accuracy: 0.9026 - lr: 0.1000 - 86s/epoch - 44ms/step
# Epoch 32/50
# 1947/1947 - 87s - loss: 1.8503e-07 - binary_accuracy: 0.9006 - val_loss: 1.8386e-07 - val_binary_accuracy: 0.9025 - lr: 0.0010 - 87s/epoch - 44ms/step
# Epoch 33/50
# 1947/1947 - 87s - loss: 1.8498e-07 - binary_accuracy: 0.9007 - val_loss: 1.8387e-07 - val_binary_accuracy: 0.9029 - lr: 0.0010 - 87s/epoch - 45ms/step
# Epoch 34/50
# 1947/1947 - 86s - loss: 1.8498e-07 - binary_accuracy: 0.9007 - val_loss: 1.8387e-07 - val_binary_accuracy: 0.9027 - lr: 0.0010 - 86s/epoch - 44ms/step
# Epoch 35/50
# 1947/1947 - 86s - loss: 1.8498e-07 - binary_accuracy: 0.9007 - val_loss: 1.8386e-07 - val_binary_accuracy: 0.9028 - lr: 0.0010 - 86s/epoch - 44ms/step
# Epoch 36/50
# 1947/1947 - 86s - loss: 1.8497e-07 - binary_accuracy: 0.9008 - val_loss: 1.8388e-07 - val_binary_accuracy: 0.9028 - lr: 0.0010 - 86s/epoch - 44ms/step
# Epoch 37/50
# 1947/1947 - 86s - loss: 1.8497e-07 - binary_accuracy: 0.9007 - val_loss: 1.8387e-07 - val_binary_accuracy: 0.9029 - lr: 0.0010 - 86s/epoch - 44ms/step
# Epoch 38/50
# 1947/1947 - 86s - loss: 1.8497e-07 - binary_accuracy: 0.9007 - val_loss: 1.8387e-07 - val_binary_accuracy: 0.9029 - lr: 0.0010 - 86s/epoch - 44ms/step
# Epoch 39/50
# 1947/1947 - 86s - loss: 1.8497e-07 - binary_accuracy: 0.9007 - val_loss: 1.8387e-07 - val_binary_accuracy: 0.9028 - lr: 0.0010 - 86s/epoch - 44ms/step
# Epoch 40/50
# 1947/1947 - 86s - loss: 1.8497e-07 - binary_accuracy: 0.9007 - val_loss: 1.8386e-07 - val_binary_accuracy: 0.9028 - lr: 0.0010 - 86s/epoch - 44ms/step
# Epoch 41/50
# 1947/1947 - 87s - loss: 1.8497e-07 - binary_accuracy: 0.9007 - val_loss: 1.8386e-07 - val_binary_accuracy: 0.9028 - lr: 0.0010 - 87s/epoch - 44ms/step
# Epoch 42/50
# 1947/1947 - 87s - loss: 1.8497e-07 - binary_accuracy: 0.9007 - val_loss: 1.8386e-07 - val_binary_accuracy: 0.9028 - lr: 0.0010 - 87s/epoch - 45ms/step
# Epoch 43/50
# 1947/1947 - 87s - loss: 1.8497e-07 - binary_accuracy: 0.9007 - val_loss: 1.8386e-07 - val_binary_accuracy: 0.9028 - lr: 0.0010 - 87s/epoch - 45ms/step
# Epoch 44/50
# 1947/1947 - 87s - loss: 1.8497e-07 - binary_accuracy: 0.9007 - val_loss: 1.8387e-07 - val_binary_accuracy: 0.9029 - lr: 0.0010 - 87s/epoch - 45ms/step
# Epoch 45/50
# 1947/1947 - 86s - loss: 1.8497e-07 - binary_accuracy: 0.9007 - val_loss: 1.8386e-07 - val_binary_accuracy: 0.9028 - lr: 0.0010 - 86s/epoch - 44ms/step
# Epoch 46/50
# 1947/1947 - 86s - loss: 1.8497e-07 - binary_accuracy: 0.9007 - val_loss: 1.8386e-07 - val_binary_accuracy: 0.9027 - lr: 0.0010 - 86s/epoch - 44ms/step
# Epoch 47/50
# 1947/1947 - 86s - loss: 1.8496e-07 - binary_accuracy: 0.9007 - val_loss: 1.8386e-07 - val_binary_accuracy: 0.9028 - lr: 0.0010 - 86s/epoch - 44ms/step
# Epoch 48/50
# 1947/1947 - 86s - loss: 1.8496e-07 - binary_accuracy: 0.9007 - val_loss: 1.8386e-07 - val_binary_accuracy: 0.9028 - lr: 0.0010 - 86s/epoch - 44ms/step
# Epoch 49/50
# 1947/1947 - 86s - loss: 1.8496e-07 - binary_accuracy: 0.9007 - val_loss: 1.8386e-07 - val_binary_accuracy: 0.9028 - lr: 0.0010 - 86s/epoch - 44ms/step
# Epoch 50/50
# 1947/1947 - 86s - loss: 1.8496e-07 - binary_accuracy: 0.9007 - val_loss: 1.8386e-07 - val_binary_accuracy: 0.9028 - lr: 0.0010 - 86s/epoch - 44ms/step
# Finished Training
# ./output_model_params_wjets/model_scaler.bin
# 1310/1310 - 1s - 1s/epoch - 862us/step
# 15990/15990 - 13s - 13s/epoch - 816us/step
# 5237/5237 - 4s - 4s/epoch - 796us/step
# 63958/63958 - 52s - 52s/epoch - 817us/step
# ttbar training data prediction (max) = 0.990088
# ttbar training data prediction (min) = 0.0023843085
# wjets training data prediction (max) = 0.99110824
# wjets training data prediction (min) = 0.0027201108
# ttbar training data prediction (max) = 0.9908606
# ttbar training data prediction (min) = 0.0028071709
# wjets training data prediction (max) = 0.99096596
# wjets training data prediction (min) = 0.0030275169

# %%
NN_training_channels_dict['wjets'].make_overfit_plots()

# %%
num_bins_cal = 50
NN_training_channels_dict['wjets'].make_calib_plots(nbins=num_bins_cal, observable='score')
# Out:
# observable not recognized

# %%
num_bins_cal = 50
NN_training_channels_dict['wjets'].make_calib_plots(nbins=num_bins_cal, observable='llr')
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:162: RuntimeWarning: divide by zero encountered in log
#   h_log_holdout = np.log(hist_num_holdout/hist_den_holdout)
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:163: RuntimeWarning: invalid value encountered in divide
#   h_log_holdout_err = np.sqrt((hist_num_holdout_err/hist_num_holdout**2)+(hist_den_holdout_err/hist_den_holdout**2))

# %%
variables_to_plot=['lepton_pt']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['wjets'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['lepton_phi']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['wjets'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['lepton_eta']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['wjets'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['H_T']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['wjets'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:281: RuntimeWarning: invalid value encountered in divide
#   hep.histplot(rat, edges, yerr = np.abs(rat*np.sqrt((np.sqrt(hist_den_err)/hist_den)**2+(np.sqrt(hist_num_err)/hist_num)**2)), linewidth=2.0)
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:281: RuntimeWarning: invalid value encountered in divide
#   hep.histplot(rat, edges, yerr = np.abs(rat*np.sqrt((np.sqrt(hist_den_err)/hist_den)**2+(np.sqrt(hist_num_err)/hist_num)**2)), linewidth=2.0)

# %%
NN_training_channels_dict['wjets'].evaluate_and_save_ratios(dataset)
# Out:
# 99564/99564 - 82s - 82s/epoch - 820us/step

# %%
# Choose ttbar as the reference hypothesis
dataset_ch_single_top_t_chan_ref = pd.concat([dataset[dataset['type']=='single_top_t_chan'], 
                                  dataset[dataset['type']=='ttbar']])

dataset_ch_single_top_t_chan_ref['train_labels'] = 0
dataset_ch_single_top_t_chan_ref.loc[dataset_ch_single_top_t_chan_ref['type']=='ttbar', 'train_labels'] = 1

# %%
rnd_seed_traintestsplit = 42
channel_names = ['single_top_t_chan', 'ttbar']

# Save paths
output_dir = './output_general_singletop/'
output_name = 'first_training_singletop'
path_to_ratios = './output_ratios_singletop/'
path_to_figures = './output_figures_singletop/'
path_to_models = './output_model_params_singletop/'



importlib.reload(sys.modules['common_utils.training'])
from common_utils.training import TrainEvaluate_NN

# Initialize the training class
NN_training_channels_dict['singletop'] = TrainEvaluate_NN(dataset_ch_single_top_t_chan_ref, 
                               dataset_ch_single_top_t_chan_ref['weights_normed'],
                               dataset_ch_single_top_t_chan_ref['train_labels'],
                               columns, 
                               columns_scaling, rnd_seed_traintestsplit, 
                               channel_names, output_dir, output_name, 
                                path_to_figures=path_to_figures,
                                path_to_ratios=path_to_ratios, 
                                path_to_models=path_to_models)

# %%
# Train the density ratio NN
NN_training_channels_dict['singletop'].train(hidden_layers=2, 
                        neurons=1000, 
                        number_of_epochs=50, 
                        batch_size=1024, 
                        learning_rate=0.1, 
                        scalerType='MinMax', 
                        calibration=False, 
                        num_bins_cal = 10, 
                        callback=True, 
                        callback_patience=30, 
                        callback_factor=0.01)
# Out:
# Sum of weights of class 0: 0.7999999999999995
# Sum of weights of class 1: 0.8000034386786885
# Using swish activation function
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 1000)              5000
#
#  dense_4 (Dense)             (None, 1000)              1001000
#
#  dense_5 (Dense)             (None, 1)                 1001
#
# =================================================================
# Total params: 1007001 (3.84 MB)
# Trainable params: 1007001 (3.84 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Using Callbacks
# Epoch 1/50
# 2093/2093 - 97s - loss: 3.6461e-07 - binary_accuracy: 0.7442 - val_loss: 3.6002e-07 - val_binary_accuracy: 0.7482 - lr: 0.1000 - 97s/epoch - 47ms/step
# Epoch 2/50
# 2093/2093 - 95s - loss: 3.5989e-07 - binary_accuracy: 0.7489 - val_loss: 3.5862e-07 - val_binary_accuracy: 0.7495 - lr: 0.1000 - 95s/epoch - 45ms/step
# Epoch 3/50
# 2093/2093 - 94s - loss: 3.5858e-07 - binary_accuracy: 0.7499 - val_loss: 3.5710e-07 - val_binary_accuracy: 0.7496 - lr: 0.1000 - 94s/epoch - 45ms/step
# Epoch 4/50
# 2093/2093 - 95s - loss: 3.5726e-07 - binary_accuracy: 0.7501 - val_loss: 3.5593e-07 - val_binary_accuracy: 0.7497 - lr: 0.1000 - 95s/epoch - 45ms/step
# Epoch 5/50
# 2093/2093 - 94s - loss: 3.5615e-07 - binary_accuracy: 0.7502 - val_loss: 3.5501e-07 - val_binary_accuracy: 0.7504 - lr: 0.1000 - 94s/epoch - 45ms/step
# Epoch 6/50
# 2093/2093 - 94s - loss: 3.5565e-07 - binary_accuracy: 0.7498 - val_loss: 3.5495e-07 - val_binary_accuracy: 0.7493 - lr: 0.1000 - 94s/epoch - 45ms/step
# Epoch 7/50
# 2093/2093 - 94s - loss: 3.5544e-07 - binary_accuracy: 0.7500 - val_loss: 3.5465e-07 - val_binary_accuracy: 0.7501 - lr: 0.1000 - 94s/epoch - 45ms/step
# Epoch 8/50
# 2093/2093 - 93s - loss: 3.5524e-07 - binary_accuracy: 0.7501 - val_loss: 3.5449e-07 - val_binary_accuracy: 0.7498 - lr: 0.1000 - 93s/epoch - 45ms/step
# Epoch 9/50
# 2093/2093 - 93s - loss: 3.5511e-07 - binary_accuracy: 0.7501 - val_loss: 3.5445e-07 - val_binary_accuracy: 0.7495 - lr: 0.1000 - 93s/epoch - 44ms/step
# Epoch 10/50
# 2093/2093 - 93s - loss: 3.5471e-07 - binary_accuracy: 0.7499 - val_loss: 3.5414e-07 - val_binary_accuracy: 0.7492 - lr: 0.1000 - 93s/epoch - 45ms/step
# Epoch 11/50
# 2093/2093 - 95s - loss: 3.5406e-07 - binary_accuracy: 0.7499 - val_loss: 3.5357e-07 - val_binary_accuracy: 0.7501 - lr: 0.1000 - 95s/epoch - 45ms/step
# Epoch 12/50
# 2093/2093 - 95s - loss: 3.5386e-07 - binary_accuracy: 0.7502 - val_loss: 3.5341e-07 - val_binary_accuracy: 0.7502 - lr: 0.1000 - 95s/epoch - 45ms/step
# Epoch 13/50
# 2093/2093 - 95s - loss: 3.5367e-07 - binary_accuracy: 0.7501 - val_loss: 3.5321e-07 - val_binary_accuracy: 0.7507 - lr: 0.1000 - 95s/epoch - 45ms/step
# Epoch 14/50
# 2093/2093 - 95s - loss: 3.5361e-07 - binary_accuracy: 0.7501 - val_loss: 3.5412e-07 - val_binary_accuracy: 0.7502 - lr: 0.1000 - 95s/epoch - 45ms/step
# Epoch 15/50
# 2093/2093 - 94s - loss: 3.5356e-07 - binary_accuracy: 0.7501 - val_loss: 3.5314e-07 - val_binary_accuracy: 0.7501 - lr: 0.1000 - 94s/epoch - 45ms/step
# Epoch 16/50
# 2093/2093 - 95s - loss: 3.5353e-07 - binary_accuracy: 0.7503 - val_loss: 3.5295e-07 - val_binary_accuracy: 0.7501 - lr: 0.1000 - 95s/epoch - 46ms/step
# Epoch 17/50
# 2093/2093 - 94s - loss: 3.5352e-07 - binary_accuracy: 0.7503 - val_loss: 3.5381e-07 - val_binary_accuracy: 0.7488 - lr: 0.1000 - 94s/epoch - 45ms/step
# Epoch 18/50
# 2093/2093 - 94s - loss: 3.5352e-07 - binary_accuracy: 0.7504 - val_loss: 3.5336e-07 - val_binary_accuracy: 0.7501 - lr: 0.1000 - 94s/epoch - 45ms/step
# Epoch 19/50
# 2093/2093 - 94s - loss: 3.5352e-07 - binary_accuracy: 0.7502 - val_loss: 3.5300e-07 - val_binary_accuracy: 0.7498 - lr: 0.1000 - 94s/epoch - 45ms/step
# Epoch 20/50
# 2093/2093 - 95s - loss: 3.5345e-07 - binary_accuracy: 0.7502 - val_loss: 3.5308e-07 - val_binary_accuracy: 0.7505 - lr: 0.1000 - 95s/epoch - 45ms/step
# Epoch 21/50
# 2093/2093 - 95s - loss: 3.5347e-07 - binary_accuracy: 0.7503 - val_loss: 3.5290e-07 - val_binary_accuracy: 0.7504 - lr: 0.1000 - 95s/epoch - 45ms/step
# Epoch 22/50
# 2093/2093 - 95s - loss: 3.5347e-07 - binary_accuracy: 0.7503 - val_loss: 3.5305e-07 - val_binary_accuracy: 0.7503 - lr: 0.1000 - 95s/epoch - 45ms/step
# Epoch 23/50
# 2093/2093 - 95s - loss: 3.5344e-07 - binary_accuracy: 0.7503 - val_loss: 3.5302e-07 - val_binary_accuracy: 0.7508 - lr: 0.1000 - 95s/epoch - 45ms/step
# Epoch 24/50
# 2093/2093 - 95s - loss: 3.5344e-07 - binary_accuracy: 0.7504 - val_loss: 3.5314e-07 - val_binary_accuracy: 0.7497 - lr: 0.1000 - 95s/epoch - 45ms/step
# Epoch 25/50
# 2093/2093 - 95s - loss: 3.5344e-07 - binary_accuracy: 0.7505 - val_loss: 3.5296e-07 - val_binary_accuracy: 0.7502 - lr: 0.1000 - 95s/epoch - 45ms/step
# Epoch 26/50
# 2093/2093 - 95s - loss: 3.5340e-07 - binary_accuracy: 0.7504 - val_loss: 3.5313e-07 - val_binary_accuracy: 0.7506 - lr: 0.1000 - 95s/epoch - 45ms/step
# Epoch 27/50
# 2093/2093 - 94s - loss: 3.5340e-07 - binary_accuracy: 0.7504 - val_loss: 3.5316e-07 - val_binary_accuracy: 0.7505 - lr: 0.1000 - 94s/epoch - 45ms/step
# Epoch 28/50
# 2093/2093 - 94s - loss: 3.5342e-07 - binary_accuracy: 0.7504 - val_loss: 3.5313e-07 - val_binary_accuracy: 0.7506 - lr: 0.1000 - 94s/epoch - 45ms/step
# Epoch 29/50
# 2093/2093 - 96s - loss: 3.5342e-07 - binary_accuracy: 0.7505 - val_loss: 3.5308e-07 - val_binary_accuracy: 0.7502 - lr: 0.1000 - 96s/epoch - 46ms/step
# Epoch 30/50
# 2093/2093 - 94s - loss: 3.5340e-07 - binary_accuracy: 0.7504 - val_loss: 3.5332e-07 - val_binary_accuracy: 0.7494 - lr: 0.1000 - 94s/epoch - 45ms/step
# Epoch 31/50
# 2093/2093 - 94s - loss: 3.5339e-07 - binary_accuracy: 0.7503 - val_loss: 3.5297e-07 - val_binary_accuracy: 0.7506 - lr: 0.1000 - 94s/epoch - 45ms/step
# Epoch 32/50
# 2093/2093 - 94s - loss: 3.5314e-07 - binary_accuracy: 0.7506 - val_loss: 3.5280e-07 - val_binary_accuracy: 0.7505 - lr: 0.0010 - 94s/epoch - 45ms/step
# Epoch 33/50
# 2093/2093 - 94s - loss: 3.5312e-07 - binary_accuracy: 0.7507 - val_loss: 3.5280e-07 - val_binary_accuracy: 0.7504 - lr: 0.0010 - 94s/epoch - 45ms/step
# Epoch 34/50
# 2093/2093 - 94s - loss: 3.5311e-07 - binary_accuracy: 0.7507 - val_loss: 3.5280e-07 - val_binary_accuracy: 0.7504 - lr: 0.0010 - 94s/epoch - 45ms/step
# Epoch 35/50
# 2093/2093 - 95s - loss: 3.5311e-07 - binary_accuracy: 0.7507 - val_loss: 3.5280e-07 - val_binary_accuracy: 0.7505 - lr: 0.0010 - 95s/epoch - 45ms/step
# Epoch 36/50
# 2093/2093 - 95s - loss: 3.5311e-07 - binary_accuracy: 0.7507 - val_loss: 3.5280e-07 - val_binary_accuracy: 0.7504 - lr: 0.0010 - 95s/epoch - 45ms/step
# Epoch 37/50
# 2093/2093 - 94s - loss: 3.5311e-07 - binary_accuracy: 0.7507 - val_loss: 3.5280e-07 - val_binary_accuracy: 0.7504 - lr: 0.0010 - 94s/epoch - 45ms/step
# Epoch 38/50
# 2093/2093 - 93s - loss: 3.5311e-07 - binary_accuracy: 0.7507 - val_loss: 3.5280e-07 - val_binary_accuracy: 0.7504 - lr: 0.0010 - 93s/epoch - 44ms/step
# Epoch 39/50
# 2093/2093 - 93s - loss: 3.5311e-07 - binary_accuracy: 0.7507 - val_loss: 3.5280e-07 - val_binary_accuracy: 0.7504 - lr: 0.0010 - 93s/epoch - 45ms/step
# Epoch 40/50
# 2093/2093 - 94s - loss: 3.5311e-07 - binary_accuracy: 0.7507 - val_loss: 3.5280e-07 - val_binary_accuracy: 0.7504 - lr: 0.0010 - 94s/epoch - 45ms/step
# Epoch 41/50
# 2093/2093 - 94s - loss: 3.5311e-07 - binary_accuracy: 0.7507 - val_loss: 3.5280e-07 - val_binary_accuracy: 0.7504 - lr: 0.0010 - 94s/epoch - 45ms/step
# Epoch 42/50
# 2093/2093 - 94s - loss: 3.5311e-07 - binary_accuracy: 0.7507 - val_loss: 3.5280e-07 - val_binary_accuracy: 0.7505 - lr: 0.0010 - 94s/epoch - 45ms/step
# Epoch 43/50
# 2093/2093 - 94s - loss: 3.5311e-07 - binary_accuracy: 0.7507 - val_loss: 3.5281e-07 - val_binary_accuracy: 0.7504 - lr: 0.0010 - 94s/epoch - 45ms/step
# Epoch 44/50
# 2093/2093 - 93s - loss: 3.5311e-07 - binary_accuracy: 0.7507 - val_loss: 3.5280e-07 - val_binary_accuracy: 0.7505 - lr: 0.0010 - 93s/epoch - 45ms/step
# Epoch 45/50
# 2093/2093 - 94s - loss: 3.5311e-07 - binary_accuracy: 0.7507 - val_loss: 3.5280e-07 - val_binary_accuracy: 0.7504 - lr: 0.0010 - 94s/epoch - 45ms/step
# Epoch 46/50
# 2093/2093 - 94s - loss: 3.5311e-07 - binary_accuracy: 0.7506 - val_loss: 3.5280e-07 - val_binary_accuracy: 0.7505 - lr: 0.0010 - 94s/epoch - 45ms/step
# Epoch 47/50
# 2093/2093 - 95s - loss: 3.5311e-07 - binary_accuracy: 0.7506 - val_loss: 3.5280e-07 - val_binary_accuracy: 0.7504 - lr: 0.0010 - 95s/epoch - 45ms/step
# Epoch 48/50
# 2093/2093 - 95s - loss: 3.5311e-07 - binary_accuracy: 0.7507 - val_loss: 3.5280e-07 - val_binary_accuracy: 0.7504 - lr: 0.0010 - 95s/epoch - 45ms/step
# Epoch 49/50
# 2093/2093 - 95s - loss: 3.5311e-07 - binary_accuracy: 0.7507 - val_loss: 3.5280e-07 - val_binary_accuracy: 0.7504 - lr: 0.0010 - 95s/epoch - 45ms/step
# Epoch 50/50
# 2093/2093 - 95s - loss: 3.5311e-07 - binary_accuracy: 0.7506 - val_loss: 3.5280e-07 - val_binary_accuracy: 0.7504 - lr: 0.0010 - 95s/epoch - 45ms/step
# Finished Training
# ./output_model_params_singletop/model_scaler.bin
# 2615/2615 - 2s - 2s/epoch - 832us/step
# 15990/15990 - 12s - 12s/epoch - 772us/step
# 10458/10458 - 8s - 8s/epoch - 805us/step
# 63958/63958 - 51s - 51s/epoch - 794us/step
# ttbar training data prediction (max) = 0.8833996
# ttbar training data prediction (min) = 0.02313281
# single_top_t_chan training data prediction (max) = 0.8845178
# single_top_t_chan training data prediction (min) = 0.02904207
# ttbar training data prediction (max) = 0.883335
# ttbar training data prediction (min) = 0.030681023
# single_top_t_chan training data prediction (max) = 0.883717
# single_top_t_chan training data prediction (min) = 0.030592555

# %%
NN_training_channels_dict['singletop'].make_overfit_plots()

# %%
num_bins_cal = 50
NN_training_channels_dict['singletop'].make_calib_plots(nbins=num_bins_cal, observable='score')
# Out:
# observable not recognized

# %%
NN_training_channels_dict['singletop'].make_calib_plots(nbins=num_bins_cal, observable='llr')
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:156: RuntimeWarning: divide by zero encountered in log
#   h_log = np.log(hist_num/hist_den)
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:157: RuntimeWarning: invalid value encountered in divide
#   h_log_err = np.sqrt((hist_num_err/hist_num**2)+(hist_den_err/hist_den**2))
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:162: RuntimeWarning: invalid value encountered in divide
#   h_log_holdout = np.log(hist_num_holdout/hist_den_holdout)
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:162: RuntimeWarning: divide by zero encountered in log
#   h_log_holdout = np.log(hist_num_holdout/hist_den_holdout)
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:163: RuntimeWarning: invalid value encountered in divide
#   h_log_holdout_err = np.sqrt((hist_num_holdout_err/hist_num_holdout**2)+(hist_den_holdout_err/hist_den_holdout**2))

# %%
variables_to_plot=['lepton_pt']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['singletop'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['lepton_phi']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['singletop'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['lepton_eta']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['singletop'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['H_T']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['singletop'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
NN_training_channels_dict['singletop'].evaluate_and_save_ratios(dataset)
# Out:
# 99564/99564 - 80s - 80s/epoch - 806us/step

# %%
# backup code for updating class methods 
importlib.reload(sys.modules['common_utils.training'])
from common_utils.training import TrainEvaluate_NN
import types

NN_training_channels_dict['wjets'].make_reweighted_plots = types.MethodType(TrainEvaluate_NN.make_reweighted_plots, NN_training_channels_dict['wjets'])
NN_training_channels_dict['wjets'].make_calib_plots = types.MethodType(TrainEvaluate_NN.make_calib_plots, NN_training_channels_dict['wjets'])
NN_training_channels_dict['wjets'].evaluate_and_save_ratios = types.MethodType(TrainEvaluate_NN.evaluate_and_save_ratios, NN_training_channels_dict['wjets'])
NN_training_channels_dict['wjets'].make_overfit_plots = types.MethodType(TrainEvaluate_NN.make_overfit_plots, NN_training_channels_dict['wjets'])
