# %% [markdown]
# Train Neural Networks to estimate Likelihood Ratios
# ===
#
# In this notebook we will setup the neural networks that train unbiased and low-variance density ratios to be then used for inference. The statistical model we have is:
#
# $$p(x|\mu, \alpha) = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot p_c\left(x|\alpha\right)$$

# %%
import os, sys, importlib
sys.path.append('../')

import common_utils
from common_utils import plotting, training
from common_utils.training import TrainEvaluate_NN
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt
hep.style.use(hep.style.ATLAS)

# %%
# Load the datasets from pre-processed input
saved_data='./cached_data/'

training_features = np.load(f"{saved_data}features.npy")
train_labels = np.load(f"{saved_data}train_labels.npy")
preselection_score = np.load(f"{saved_data}preselection_score.npy")
weights = np.load(f"{saved_data}weights.npy")

# %%
# labels_dict = {"ttbar": 0,
#                "single_top_s_chan":1,
#               "single_top_t_chan":2,
#               "single_top_tW":3,
#               "wjets":4}

# Keep only a subset of the background for illustration
labels_dict = {"ttbar": 0,
              "single_top_t_chan":1,
              "wjets":2}

# %%
min_pred = np.amin(preselection_score)
max_pred = np.amax(preselection_score)

bins = np.linspace(min_pred, max_pred, num=150)

hist_NN_output = {}

for key in labels_dict: 
    hist_NN_output[key], _ = np.histogram(preselection_score[train_labels==labels_dict[key]], weights = weights[train_labels==labels_dict[key]], bins=bins)

# %% [markdown]
# Make a selection cut for performing the NSBI analysis, balancing the number of signal events that go into the signal region (increasing sensitivity) and the feasibility of training accurate and precise NNs over a large phase space (need bigger models and more statistics).
#
# As a first cut, we choose a loose preselection and see if it works.

# %%
preselection_cut = -21 # Lets start with a very loose cut

for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins=bins, 
             alpha=0.6, label=key, 
             density=True, linewidth=2.0)

plt.xlabel("Preselection Score", size=18)
plt.axvline(preselection_cut, ymax=0.9, linestyle='--', label=f'preselection cut ({preselection_cut})')
plt.ylabel("Density", size=18)
plt.legend()
plt.yscale('log')
plt.show()

# %%
# Make the preselections

training_features = training_features[preselection_score>=preselection_cut].copy()
train_labels = train_labels[preselection_score>=preselection_cut].copy()
weights = weights[preselection_score>=preselection_cut].copy()

preselection_score_selected = preselection_score[preselection_score>=preselection_cut].copy()

# %%
type_vec = np.array(train_labels, dtype='object')

for key in labels_dict:
    type_vec[type_vec==labels_dict[key]] = key

# %%
# Build a pandas dataframe from the arrays for density ratio training and validation
columns = ['lepton_pt', 'lepton_eta', 'lepton_phi', 'H_T']
dataset = pd.DataFrame(training_features, columns=columns)

dataset['log_lepton_pt'] = np.log(dataset['lepton_pt'].ravel())
dataset['log_H_T'] = np.log(dataset['H_T'].ravel()+1.0)

dataset['presel_score'] = preselection_score_selected
dataset['train_labels'] = train_labels
dataset['type'] = type_vec
dataset['weights'] = weights

# %%
# Normalizing the training weights - only discriminating shapes, not norms

weights_normed = weights.copy()

for key in labels_dict:

    weights_normed[train_labels==labels_dict[key]] /= weights[train_labels==labels_dict[key]].sum()

dataset['weights_normed'] = weights_normed

# %%
# Save the preselected dataframe for inference use later on
dataset.to_hdf(f"{saved_data}dataset_preselected_ttbar.h5", key="dataset", mode='w')

# %%
columns = ['lepton_pt', 'lepton_eta', 'lepton_phi']
columns_scaling = ['lepton_pt', 'lepton_eta', 'lepton_phi']

columns = ['log_lepton_pt', 'lepton_eta', 'lepton_phi']
columns_scaling = ['log_lepton_pt', 'lepton_eta', 'lepton_phi']

columns = ['log_lepton_pt', 'log_H_T', 'lepton_eta', 'lepton_phi']
columns_scaling = ['log_lepton_pt', 'log_H_T', 'lepton_eta', 'lepton_phi']

# %%
# Choose ttbar as the reference hypothesis
dataset_ch_wjets_ref = pd.concat([dataset[dataset['type']=='wjets'], 
                                  dataset[dataset['type']=='ttbar']])

dataset_ch_wjets_ref['train_labels'] = 0
dataset_ch_wjets_ref.loc[dataset_ch_wjets_ref['type']=='ttbar', 'train_labels'] = 1

# %%
NN_training_channels_dict = {}

# %%
rnd_seed_traintestsplit = 42
channel_names = ['wjets', 'ttbar']

# Save paths
output_dir = './output_general_wjets/'
output_name = 'first_training_wjets'
path_to_ratios = './output_ratios_wjets/'
path_to_figures = './output_figures_wjets/'
path_to_models = './output_model_params_wjets/'

importlib.reload(sys.modules['common_utils.training'])
from common_utils.training import TrainEvaluate_NN

# Initialize the training class
NN_training_channels_dict['wjets'] = TrainEvaluate_NN(dataset_ch_wjets_ref, 
                                                       dataset_ch_wjets_ref['weights_normed'],
                                                       dataset_ch_wjets_ref['train_labels'],
                                                       columns, 
                                                       columns_scaling, rnd_seed_traintestsplit, 
                                                       channel_names, output_dir, output_name, 
                                                        path_to_figures=path_to_figures,
                                                        path_to_ratios=path_to_ratios, 
                                                        path_to_models=path_to_models)

# %%
# Train the density ratio NN
NN_training_channels_dict['wjets'].train(hidden_layers=2, 
                        neurons=1000, 
                        number_of_epochs=50, 
                        batch_size=1024, 
                        learning_rate=0.1, 
                        scalerType='MinMax', 
                        calibration=False, 
                        num_bins_cal = 10, 
                        callback=True, 
                        callback_patience=30, 
                        callback_factor=0.01)
# Out:
# Sum of weights of class 0: 0.7999991948599847
# Sum of weights of class 1: 0.8000020585246567
# Using swish activation function
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 1000)              5000
#
#  dense_19 (Dense)            (None, 1000)              1001000
#
#  dense_20 (Dense)            (None, 1)                 1001
#
# =================================================================
# Total params: 1007001 (3.84 MB)
# Trainable params: 1007001 (3.84 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Using Callbacks
# Epoch 1/50
# 2153/2153 - 89s - loss: 1.1909e-07 - binary_accuracy: 0.9351 - val_loss: 1.1411e-07 - val_binary_accuracy: 0.9365 - lr: 0.1000 - 89s/epoch - 42ms/step
# Epoch 2/50
# 2153/2153 - 89s - loss: 1.1409e-07 - binary_accuracy: 0.9370 - val_loss: 1.1347e-07 - val_binary_accuracy: 0.9370 - lr: 0.1000 - 89s/epoch - 41ms/step
# Epoch 3/50
# 2153/2153 - 89s - loss: 1.1388e-07 - binary_accuracy: 0.9372 - val_loss: 1.1348e-07 - val_binary_accuracy: 0.9372 - lr: 0.1000 - 89s/epoch - 41ms/step
# Epoch 4/50
# 2153/2153 - 89s - loss: 1.1378e-07 - binary_accuracy: 0.9372 - val_loss: 1.1332e-07 - val_binary_accuracy: 0.9370 - lr: 0.1000 - 89s/epoch - 41ms/step
# Epoch 5/50
# 2153/2153 - 93s - loss: 1.1371e-07 - binary_accuracy: 0.9373 - val_loss: 1.1372e-07 - val_binary_accuracy: 0.9368 - lr: 0.1000 - 93s/epoch - 43ms/step
# Epoch 6/50
# 2153/2153 - 95s - loss: 1.1364e-07 - binary_accuracy: 0.9373 - val_loss: 1.1434e-07 - val_binary_accuracy: 0.9365 - lr: 0.1000 - 95s/epoch - 44ms/step
# Epoch 7/50
# 2153/2153 - 99s - loss: 1.1352e-07 - binary_accuracy: 0.9372 - val_loss: 1.1317e-07 - val_binary_accuracy: 0.9369 - lr: 0.1000 - 99s/epoch - 46ms/step
# Epoch 8/50
# 2153/2153 - 105s - loss: 1.1336e-07 - binary_accuracy: 0.9373 - val_loss: 1.1329e-07 - val_binary_accuracy: 0.9372 - lr: 0.1000 - 105s/epoch - 49ms/step
# Epoch 9/50
# 2153/2153 - 104s - loss: 1.1318e-07 - binary_accuracy: 0.9372 - val_loss: 1.1300e-07 - val_binary_accuracy: 0.9368 - lr: 0.1000 - 104s/epoch - 48ms/step
# Epoch 10/50
# 2153/2153 - 110s - loss: 1.1291e-07 - binary_accuracy: 0.9373 - val_loss: 1.1289e-07 - val_binary_accuracy: 0.9367 - lr: 0.1000 - 110s/epoch - 51ms/step
# Epoch 11/50
# 2153/2153 - 110s - loss: 1.1241e-07 - binary_accuracy: 0.9373 - val_loss: 1.1245e-07 - val_binary_accuracy: 0.9368 - lr: 0.1000 - 110s/epoch - 51ms/step
# Epoch 12/50
# 2153/2153 - 114s - loss: 1.1167e-07 - binary_accuracy: 0.9372 - val_loss: 1.1141e-07 - val_binary_accuracy: 0.9369 - lr: 0.1000 - 114s/epoch - 53ms/step
# Epoch 13/50
# 2153/2153 - 113s - loss: 1.1107e-07 - binary_accuracy: 0.9371 - val_loss: 1.1103e-07 - val_binary_accuracy: 0.9368 - lr: 0.1000 - 113s/epoch - 52ms/step
# Epoch 14/50
# 2153/2153 - 117s - loss: 1.1085e-07 - binary_accuracy: 0.9370 - val_loss: 1.1078e-07 - val_binary_accuracy: 0.9369 - lr: 0.1000 - 117s/epoch - 54ms/step
# Epoch 15/50
# 2153/2153 - 117s - loss: 1.1067e-07 - binary_accuracy: 0.9371 - val_loss: 1.1111e-07 - val_binary_accuracy: 0.9366 - lr: 0.1000 - 117s/epoch - 55ms/step
# Epoch 16/50
# 2153/2153 - 117s - loss: 1.1055e-07 - binary_accuracy: 0.9371 - val_loss: 1.1059e-07 - val_binary_accuracy: 0.9366 - lr: 0.1000 - 117s/epoch - 55ms/step
# Epoch 17/50
# 2153/2153 - 117s - loss: 1.1051e-07 - binary_accuracy: 0.9372 - val_loss: 1.1040e-07 - val_binary_accuracy: 0.9370 - lr: 0.1000 - 117s/epoch - 54ms/step
# Epoch 18/50
# 2153/2153 - 116s - loss: 1.1042e-07 - binary_accuracy: 0.9372 - val_loss: 1.1049e-07 - val_binary_accuracy: 0.9370 - lr: 0.1000 - 116s/epoch - 54ms/step
# Epoch 19/50
# 2153/2153 - 118s - loss: 1.1039e-07 - binary_accuracy: 0.9372 - val_loss: 1.1043e-07 - val_binary_accuracy: 0.9367 - lr: 0.1000 - 118s/epoch - 55ms/step
# Epoch 20/50
# 2153/2153 - 119s - loss: 1.1033e-07 - binary_accuracy: 0.9371 - val_loss: 1.1050e-07 - val_binary_accuracy: 0.9370 - lr: 0.1000 - 119s/epoch - 55ms/step
# Epoch 21/50
# 2153/2153 - 119s - loss: 1.1027e-07 - binary_accuracy: 0.9372 - val_loss: 1.1027e-07 - val_binary_accuracy: 0.9369 - lr: 0.1000 - 119s/epoch - 55ms/step
# Epoch 22/50
# 2153/2153 - 117s - loss: 1.1019e-07 - binary_accuracy: 0.9373 - val_loss: 1.1060e-07 - val_binary_accuracy: 0.9371 - lr: 0.1000 - 117s/epoch - 54ms/step
# Epoch 23/50
# 2153/2153 - 116s - loss: 1.1013e-07 - binary_accuracy: 0.9373 - val_loss: 1.1028e-07 - val_binary_accuracy: 0.9369 - lr: 0.1000 - 116s/epoch - 54ms/step
# Epoch 24/50
# 2153/2153 - 118s - loss: 1.1007e-07 - binary_accuracy: 0.9373 - val_loss: 1.1080e-07 - val_binary_accuracy: 0.9368 - lr: 0.1000 - 118s/epoch - 55ms/step
# Epoch 25/50
# 2153/2153 - 116s - loss: 1.1001e-07 - binary_accuracy: 0.9374 - val_loss: 1.1006e-07 - val_binary_accuracy: 0.9370 - lr: 0.1000 - 116s/epoch - 54ms/step
# Epoch 26/50
# 2153/2153 - 117s - loss: 1.0995e-07 - binary_accuracy: 0.9375 - val_loss: 1.1023e-07 - val_binary_accuracy: 0.9370 - lr: 0.1000 - 117s/epoch - 54ms/step
# Epoch 27/50
# 2153/2153 - 118s - loss: 1.0992e-07 - binary_accuracy: 0.9375 - val_loss: 1.1001e-07 - val_binary_accuracy: 0.9371 - lr: 0.1000 - 118s/epoch - 55ms/step
# Epoch 28/50
# 2153/2153 - 117s - loss: 1.0988e-07 - binary_accuracy: 0.9373 - val_loss: 1.0991e-07 - val_binary_accuracy: 0.9369 - lr: 0.1000 - 117s/epoch - 54ms/step
# Epoch 29/50
# 2153/2153 - 117s - loss: 1.0986e-07 - binary_accuracy: 0.9375 - val_loss: 1.1020e-07 - val_binary_accuracy: 0.9374 - lr: 0.1000 - 117s/epoch - 54ms/step
# Epoch 30/50
# 2153/2153 - 117s - loss: 1.0983e-07 - binary_accuracy: 0.9375 - val_loss: 1.1067e-07 - val_binary_accuracy: 0.9369 - lr: 0.1000 - 117s/epoch - 54ms/step
# Epoch 31/50
# 2153/2153 - 117s - loss: 1.0979e-07 - binary_accuracy: 0.9374 - val_loss: 1.1017e-07 - val_binary_accuracy: 0.9370 - lr: 0.1000 - 117s/epoch - 54ms/step
# Epoch 32/50
# 2153/2153 - 119s - loss: 1.0966e-07 - binary_accuracy: 0.9376 - val_loss: 1.0979e-07 - val_binary_accuracy: 0.9370 - lr: 0.0010 - 119s/epoch - 55ms/step
# Epoch 33/50
# 2153/2153 - 119s - loss: 1.0958e-07 - binary_accuracy: 0.9376 - val_loss: 1.0977e-07 - val_binary_accuracy: 0.9371 - lr: 0.0010 - 119s/epoch - 55ms/step
# Epoch 34/50
# 2153/2153 - 118s - loss: 1.0957e-07 - binary_accuracy: 0.9376 - val_loss: 1.0977e-07 - val_binary_accuracy: 0.9372 - lr: 0.0010 - 118s/epoch - 55ms/step
# Epoch 35/50
# 2153/2153 - 118s - loss: 1.0957e-07 - binary_accuracy: 0.9376 - val_loss: 1.0977e-07 - val_binary_accuracy: 0.9371 - lr: 0.0010 - 118s/epoch - 55ms/step
# Epoch 36/50
# 2153/2153 - 118s - loss: 1.0957e-07 - binary_accuracy: 0.9376 - val_loss: 1.0976e-07 - val_binary_accuracy: 0.9370 - lr: 0.0010 - 118s/epoch - 55ms/step
# Epoch 37/50
# 2153/2153 - 118s - loss: 1.0957e-07 - binary_accuracy: 0.9376 - val_loss: 1.0976e-07 - val_binary_accuracy: 0.9371 - lr: 0.0010 - 118s/epoch - 55ms/step
# Epoch 38/50
# 2153/2153 - 118s - loss: 1.0957e-07 - binary_accuracy: 0.9376 - val_loss: 1.0976e-07 - val_binary_accuracy: 0.9371 - lr: 0.0010 - 118s/epoch - 55ms/step
# Epoch 39/50
# 2153/2153 - 115s - loss: 1.0957e-07 - binary_accuracy: 0.9376 - val_loss: 1.0976e-07 - val_binary_accuracy: 0.9371 - lr: 0.0010 - 115s/epoch - 54ms/step
# Epoch 40/50
# 2153/2153 - 116s - loss: 1.0956e-07 - binary_accuracy: 0.9376 - val_loss: 1.0975e-07 - val_binary_accuracy: 0.9371 - lr: 0.0010 - 116s/epoch - 54ms/step
# Epoch 41/50
# 2153/2153 - 114s - loss: 1.0956e-07 - binary_accuracy: 0.9376 - val_loss: 1.0975e-07 - val_binary_accuracy: 0.9371 - lr: 0.0010 - 114s/epoch - 53ms/step
# Epoch 42/50
# 2153/2153 - 113s - loss: 1.0956e-07 - binary_accuracy: 0.9376 - val_loss: 1.0975e-07 - val_binary_accuracy: 0.9371 - lr: 0.0010 - 113s/epoch - 53ms/step
# Epoch 43/50
# 2153/2153 - 114s - loss: 1.0956e-07 - binary_accuracy: 0.9376 - val_loss: 1.0975e-07 - val_binary_accuracy: 0.9371 - lr: 0.0010 - 114s/epoch - 53ms/step
# Epoch 44/50
# 2153/2153 - 113s - loss: 1.0956e-07 - binary_accuracy: 0.9376 - val_loss: 1.0975e-07 - val_binary_accuracy: 0.9371 - lr: 0.0010 - 113s/epoch - 52ms/step
# Epoch 45/50
# 2153/2153 - 112s - loss: 1.0956e-07 - binary_accuracy: 0.9376 - val_loss: 1.0975e-07 - val_binary_accuracy: 0.9371 - lr: 0.0010 - 112s/epoch - 52ms/step
# Epoch 46/50
# 2153/2153 - 113s - loss: 1.0956e-07 - binary_accuracy: 0.9376 - val_loss: 1.0975e-07 - val_binary_accuracy: 0.9371 - lr: 0.0010 - 113s/epoch - 52ms/step
# Epoch 47/50
# 2153/2153 - 112s - loss: 1.0956e-07 - binary_accuracy: 0.9376 - val_loss: 1.0975e-07 - val_binary_accuracy: 0.9371 - lr: 0.0010 - 112s/epoch - 52ms/step
# Epoch 48/50
# 2153/2153 - 112s - loss: 1.0956e-07 - binary_accuracy: 0.9376 - val_loss: 1.0975e-07 - val_binary_accuracy: 0.9370 - lr: 0.0010 - 112s/epoch - 52ms/step
# Epoch 49/50
# 2153/2153 - 114s - loss: 1.0956e-07 - binary_accuracy: 0.9376 - val_loss: 1.0975e-07 - val_binary_accuracy: 0.9371 - lr: 0.0010 - 114s/epoch - 53ms/step
# Epoch 50/50
# 2153/2153 - 119s - loss: 1.0956e-07 - binary_accuracy: 0.9376 - val_loss: 1.0975e-07 - val_binary_accuracy: 0.9370 - lr: 0.0010 - 119s/epoch - 55ms/step
# Finished Training
# ./output_model_params_wjets/model_scaler.bin
# 3106/3106 - 3s - 3s/epoch - 870us/step
# 16027/16027 - 13s - 13s/epoch - 799us/step
# 12421/12421 - 10s - 10s/epoch - 827us/step
# 64106/64106 - 52s - 52s/epoch - 812us/step
# ttbar training data prediction (max) = 0.9960005
# ttbar training data prediction (min) = 0.000598749
# wjets training data prediction (max) = 0.99613214
# wjets training data prediction (min) = 0.0006529811
# ttbar training data prediction (max) = 0.9960734
# ttbar training data prediction (min) = 0.0006341569
# wjets training data prediction (max) = 0.9961273
# wjets training data prediction (min) = 0.0007306743

# %%
NN_training_channels_dict['wjets'].make_overfit_plots()

# %%
num_bins_cal = 50
NN_training_channels_dict['wjets'].make_calib_plots(nbins=num_bins_cal, observable='score')
# Out:
# observable not recognized

# %%
num_bins_cal = 50
NN_training_channels_dict['wjets'].make_calib_plots(nbins=num_bins_cal, observable='llr')

# %%
variables_to_plot=['lepton_pt']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['wjets'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['lepton_phi']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['wjets'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['lepton_eta']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['wjets'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['H_T']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['wjets'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:281: RuntimeWarning: invalid value encountered in divide
#   hep.histplot(rat, edges, yerr = np.abs(rat*np.sqrt((np.sqrt(hist_den_err)/hist_den)**2+(np.sqrt(hist_num_err)/hist_num)**2)), linewidth=2.0)
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:281: RuntimeWarning: invalid value encountered in divide
#   hep.histplot(rat, edges, yerr = np.abs(rat*np.sqrt((np.sqrt(hist_den_err)/hist_den)**2+(np.sqrt(hist_num_err)/hist_num)**2)), linewidth=2.0)

# %%
NN_training_channels_dict['wjets'].evaluate_and_save_ratios(dataset)
# Out:
# 109260/109260 - 84s - 84s/epoch - 767us/step

# %%
# Choose ttbar as the reference hypothesis
dataset_ch_single_top_t_chan_ref = pd.concat([dataset[dataset['type']=='single_top_t_chan'], 
                                  dataset[dataset['type']=='ttbar']])

dataset_ch_single_top_t_chan_ref['train_labels'] = 0
dataset_ch_single_top_t_chan_ref.loc[dataset_ch_single_top_t_chan_ref['type']=='ttbar', 'train_labels'] = 1

# %%
rnd_seed_traintestsplit = 42
channel_names = ['single_top_t_chan', 'ttbar']

# Save paths
output_dir = './output_general_singletop/'
output_name = 'first_training_singletop'
path_to_ratios = './output_ratios_singletop/'
path_to_figures = './output_figures_singletop/'
path_to_models = './output_model_params_singletop/'



importlib.reload(sys.modules['common_utils.training'])
from common_utils.training import TrainEvaluate_NN

# Initialize the training class
NN_training_channels_dict['singletop'] = TrainEvaluate_NN(dataset_ch_single_top_t_chan_ref, 
                               dataset_ch_single_top_t_chan_ref['weights_normed'],
                               dataset_ch_single_top_t_chan_ref['train_labels'],
                               columns, 
                               columns_scaling, rnd_seed_traintestsplit, 
                               channel_names, output_dir, output_name, 
                                path_to_figures=path_to_figures,
                                path_to_ratios=path_to_ratios, 
                                path_to_models=path_to_models)

# %%
# Train the density ratio NN
NN_training_channels_dict['singletop'].train(hidden_layers=2, 
                        neurons=1000, 
                        number_of_epochs=50, 
                        batch_size=1024, 
                        learning_rate=0.1, 
                        scalerType='MinMax', 
                        calibration=False, 
                        num_bins_cal = 10, 
                        callback=True, 
                        callback_patience=30, 
                        callback_factor=0.01)

# %%
NN_training_channels_dict['singletop'].make_overfit_plots()

# %%
num_bins_cal = 50
NN_training_channels_dict['singletop'].make_calib_plots(nbins=num_bins_cal, observable='score')

# %%
NN_training_channels_dict['singletop'].make_calib_plots(nbins=num_bins_cal, observable='llr')

# %%
variables_to_plot=['lepton_pt']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['singletop'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['lepton_phi']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['singletop'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['lepton_eta']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['singletop'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['H_T']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['singletop'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
NN_training_channels_dict['singletop'].evaluate_and_save_ratios(dataset)

# %%
# backup code for updating class methods 
importlib.reload(sys.modules['common_utils.training'])
from common_utils.training import TrainEvaluate_NN
import types

NN_training_channels_dict['wjets'].make_reweighted_plots = types.MethodType(TrainEvaluate_NN.make_reweighted_plots, NN_training_channels_dict['wjets'])
NN_training_channels_dict['wjets'].make_calib_plots = types.MethodType(TrainEvaluate_NN.make_calib_plots, NN_training_channels_dict['wjets'])
NN_training_channels_dict['wjets'].evaluate_and_save_ratios = types.MethodType(TrainEvaluate_NN.evaluate_and_save_ratios, NN_training_channels_dict['wjets'])
NN_training_channels_dict['wjets'].make_overfit_plots = types.MethodType(TrainEvaluate_NN.make_overfit_plots, NN_training_channels_dict['wjets'])
