# %% [markdown]
# Train Neural Networks to estimate Likelihood Ratios
# ===
#
# In this notebook we will setup the neural networks that train unbiased and low-variance density ratios to be then used for inference. The statistical model we have is:
#
# $$p(x|\mu, \alpha) = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot p_c\left(x|\alpha\right)$$
#
# where $c$ stands for the various physics channels that contribute to the final state $x$, $\mu$ is the signal-strength parameter and $\alpha$ is the vector of nuisance parameters associated with the various systematic uncertainties in the model. Note that we are assuming that the parameter $\mu$-dependence is known analytically and that we have simulation models for each of the channels $p_c(x)$.
#
# The objective is to build the test statistic for composite hypothesis testing:
#
# $$t_\mu = -2 \ln \frac{p(x|\mu, \hat{\hat{\alpha}})}{p(x|\hat{\mu}, \hat{\alpha})}$$
#
# A direct approach would then be to model the probability density $p(x|\mu, \alpha)$ using NNs. But that is a more difficult task than training probability density ratios. We use a simple trick:
#
# $$t_\mu = -2 \ln \frac{p(x|\mu, \hat{\hat{\alpha}})/p_{ref}(x)}{p(x|\hat{\mu}, \hat{\alpha})/p_{ref}(x)}$$
#
# to turn this into a density ratio estimation problem:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot \frac{p_c\left(x|\alpha\right)}{p_{ref}(x)}$$
#
# Factorizing out the $\alpha$-dependence in the density ratios:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\sum_c G_c(\alpha) \cdot f_c(\mu) \cdot \nu_c} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot g_c(x|\alpha) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}$$
#
# Furthermore, instead of training NNs parameterized on $\mu$ and $\alpha$, we use analytical parameterizations to simplify the problem to training only parameter-independent density ratios.
#
# Let's set this up for the ttbar dataset!

# %%
import os, sys, importlib
sys.path.append('../')

import common_utils
from common_utils import plotting, training
from common_utils.training import TrainEvaluate_NN, TrainEvaluatePreselNN
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt

hep.style.use(hep.style.ATLAS)
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:10: FutureWarning: ``set_style`` is deprecated: Naming convention is changing to match mpl. Use ``mplhep.style.use()``.
#   hep.set_style("ATLAS")
# 2025-02-12 20:58:33.531681: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-12 20:58:34.215524: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load the datasets from pre-processed input
saved_data='./cached_data/'

training_features = np.load(f"{saved_data}features.npy")
train_labels = np.load(f"{saved_data}train_labels.npy")
weights = np.load(f"{saved_data}weights.npy")

# %%
# labels_dict = {"ttbar": 0,
#                "single_top_s_chan":1,
#               "single_top_t_chan":2,
#               "single_top_tW":3,
#               "wjets":4}

# Keep only a subset of the background for illustration
labels_dict = {"ttbar": 0,
              "single_top_t_chan":1,
              "wjets":2}

# %%
type_vec = np.array(train_labels, dtype='object')

for key in labels_dict:
    type_vec[type_vec==labels_dict[key]] = key

# %%
# Build a pandas dataframe from the arrays for density ratio training and validation
columns = ['lepton_pt', 'lepton_eta', 'lepton_phi', 'H_T']
dataset_incl = pd.DataFrame(training_features, columns=columns)

# Some scaling to reduce the spread of pt distributions 
dataset_incl['log_lepton_pt'] = np.log(dataset_incl['lepton_pt'].ravel())
dataset_incl['log_H_T'] = np.log(dataset_incl['H_T'].ravel()+1.0) # Add the one to compensate to avoid log of 0

# Some scaling to reduce the spread of pt distributions 
dataset_incl['train_labels_presel'] = train_labels
dataset_incl['type'] = type_vec
dataset_incl['weights'] = weights

# %%
# Normalizing the training weights - only discriminating shapes, not norms

weights_normed = weights.copy()

for key in labels_dict:

    weights_normed[train_labels==labels_dict[key]] /= weights[train_labels==labels_dict[key]].sum()

dataset_incl['weights_normed'] = weights_normed

# %% [markdown]
# The density ratios need to be trained on phase space regions with support for the reference hypothesis $p_{ref}(x) > 0$.
#
# To ensure this, we make a selection that selects events in the phase space regions with $p_{ref}(x) > 0$, and only perform the NSBI fit in this selected analysis region. A natural choice for the reference hypothesis is then a mix of signal hypotheses $p_{ref}(x) = \frac{1}{\sum_S \nu_S} \sum_S \frac{d\sigma_S}{dx}$.
#
# A multi-class classification NN, with softmax output, is trained to output a score:
#
# $$ \text{NN}_\text{presel} = \log \left[\frac{\sum_S P_S (x)}{\sum_B P_B(x)} \right]$$
#
# where $P_X$ are the probability scores outputted from the softmax layer of the trained NN.

# %% [markdown]
# Training the Preselection NN
# ===

# %%
# Only use lepton kinematics
columns = ['lepton_pt', 'lepton_eta', 'lepton_phi']
columns_scaling = ['lepton_pt', 'lepton_eta', 'lepton_phi']

# Only use lepton kinematics - use log pT for reduced spread
columns = ['log_lepton_pt', 'lepton_eta', 'lepton_phi']
columns_scaling = ['log_lepton_pt', 'lepton_eta', 'lepton_phi']

# Use lepton kinematics and the sum of jet pT observable 
columns = ['log_lepton_pt', 'log_H_T', 'lepton_eta', 'lepton_phi']
columns_scaling = ['log_lepton_pt', 'log_H_T', 'lepton_eta', 'lepton_phi'] # Subset of features which need scaling

# %%
USE_SAVED_MODEL_PRESEL=False

importlib.reload(sys.modules['common_utils.training'])
from common_utils.training import TrainEvaluatePreselNN

preselectionTraining = TrainEvaluatePreselNN(dataset_incl, columns, columns_scaling)

# %%
path_to_saved_presel_model = './preselection_saved_NN/'

if not USE_SAVED_MODEL_PRESEL:
    preselectionTraining.train(test_size=0.15, random_state=42, path_to_save=path_to_saved_presel_model)

else:
    preselectionTraining.get_trained_model(path_to_saved_presel_model)
# Out:
# 2025-02-12 20:58:36.902188: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3234 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB MIG 1g.5gb, pci bus id: 0000:81:00.0, compute capability: 8.0
# Epoch 1/20
# 2025-02-12 20:58:37.916584: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-02-12 20:58:37.945251: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f1100f650c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-02-12 20:58:37.945307: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA A100-SXM4-40GB MIG 1g.5gb, Compute Capability 8.0
# 2025-02-12 20:58:37.951025: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-02-12 20:58:37.964054: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8906
# 2025-02-12 20:58:38.018919: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2025-02-12 20:58:38.080442: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2935/2935 [==============================] - 9s 2ms/step - loss: 6.2645e-07 - accuracy: 0.6883 - val_loss: 5.4853e-07 - val_accuracy: 0.7244
# Epoch 2/20
# 2935/2935 [==============================] - 7s 2ms/step - loss: 5.4756e-07 - accuracy: 0.7227 - val_loss: 5.4448e-07 - val_accuracy: 0.7244
# Epoch 3/20
# 2935/2935 [==============================] - 7s 2ms/step - loss: 5.4467e-07 - accuracy: 0.7225 - val_loss: 5.4231e-07 - val_accuracy: 0.7242
# Epoch 4/20
# 2935/2935 [==============================] - 7s 2ms/step - loss: 5.4269e-07 - accuracy: 0.7224 - val_loss: 5.4055e-07 - val_accuracy: 0.7241
# Epoch 5/20
# 2935/2935 [==============================] - 7s 2ms/step - loss: 5.4099e-07 - accuracy: 0.7224 - val_loss: 5.3898e-07 - val_accuracy: 0.7241
# Epoch 6/20
# 2935/2935 [==============================] - 6s 2ms/step - loss: 5.3942e-07 - accuracy: 0.7225 - val_loss: 5.3749e-07 - val_accuracy: 0.7243
# Epoch 7/20
# 2935/2935 [==============================] - 6s 2ms/step - loss: 5.3790e-07 - accuracy: 0.7227 - val_loss: 5.3592e-07 - val_accuracy: 0.7243
# Epoch 8/20
# 2935/2935 [==============================] - 6s 2ms/step - loss: 5.3643e-07 - accuracy: 0.7227 - val_loss: 5.3452e-07 - val_accuracy: 0.7244
# Epoch 9/20
# 2935/2935 [==============================] - 6s 2ms/step - loss: 5.3514e-07 - accuracy: 0.7229 - val_loss: 5.3335e-07 - val_accuracy: 0.7246
# Epoch 10/20
# 2935/2935 [==============================] - 6s 2ms/step - loss: 5.3429e-07 - accuracy: 0.7232 - val_loss: 5.3271e-07 - val_accuracy: 0.7249
# Epoch 11/20
# 2935/2935 [==============================] - 6s 2ms/step - loss: 5.3377e-07 - accuracy: 0.7234 - val_loss: 5.3227e-07 - val_accuracy: 0.7249
# Epoch 12/20
# 2935/2935 [==============================] - 6s 2ms/step - loss: 5.3340e-07 - accuracy: 0.7236 - val_loss: 5.3193e-07 - val_accuracy: 0.7250
# Epoch 13/20
# 2935/2935 [==============================] - 6s 2ms/step - loss: 5.3311e-07 - accuracy: 0.7235 - val_loss: 5.3175e-07 - val_accuracy: 0.7249
# Epoch 14/20
# 2935/2935 [==============================] - 6s 2ms/step - loss: 5.3286e-07 - accuracy: 0.7236 - val_loss: 5.3157e-07 - val_accuracy: 0.7250
# Epoch 15/20
# 2935/2935 [==============================] - 6s 2ms/step - loss: 5.3268e-07 - accuracy: 0.7236 - val_loss: 5.3142e-07 - val_accuracy: 0.7249
# Epoch 16/20
# 2935/2935 [==============================] - 6s 2ms/step - loss: 5.3252e-07 - accuracy: 0.7235 - val_loss: 5.3120e-07 - val_accuracy: 0.7249
# Epoch 17/20
# 2935/2935 [==============================] - 6s 2ms/step - loss: 5.3239e-07 - accuracy: 0.7236 - val_loss: 5.3109e-07 - val_accuracy: 0.7249
# Epoch 18/20
# 2935/2935 [==============================] - 6s 2ms/step - loss: 5.3227e-07 - accuracy: 0.7236 - val_loss: 5.3099e-07 - val_accuracy: 0.7249
# Epoch 19/20
# 2935/2935 [==============================] - 6s 2ms/step - loss: 5.3217e-07 - accuracy: 0.7236 - val_loss: 5.3096e-07 - val_accuracy: 0.7249
# Epoch 20/20
# 2935/2935 [==============================] - 6s 2ms/step - loss: 5.3208e-07 - accuracy: 0.7237 - val_loss: 5.3086e-07 - val_accuracy: 0.7250

# %%
# Get predictions (softmax outputs)
pred_NN = preselectionTraining.predict(dataset_incl)
# Out:
# 110475/110475 [==============================] - 66s 598us/step

# %%
# the preselection score as defined above - log(P_S/P_B)
presel_score = np.log(pred_NN[:, labels_dict["ttbar"]]/(pred_NN[:, labels_dict["single_top_t_chan"]] + pred_NN[:, labels_dict["wjets"]]))

min_pred = np.amin(presel_score)
max_pred = np.amax(presel_score)

bins = np.linspace(min_pred, max_pred, num=150)

hist_NN_output = {}
for key in labels_dict: 
    hist_NN_output[key], _ = np.histogram(presel_score[train_labels==labels_dict[key]], weights = weights[train_labels==labels_dict[key]], bins=bins)


for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins=bins, 
             alpha=0.6, label=key, 
             density=True, linewidth=2.0)

plt.xlabel("Preselection Score", size=18)
plt.ylabel("Density", size=18)
plt.legend()
plt.yscale('log')
plt.show()

# %% [markdown]
# Make a selection cut for performing the NSBI analysis, balancing the number of signal events that go into the signal region (increasing sensitivity) and the feasibility of training accurate and precise NNs over a large phase space (need bigger models and more statistics).
#
# As a first cut, we choose a loose preselection and see if it works.

# %%
preselection_cut = -3

for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins=bins, 
             alpha=0.6, label=key, 
             density=True, linewidth=2.0)

plt.xlabel("Preselection Score", size=18)
plt.axvline(preselection_cut, ymax=0.9, linestyle='--', label=f'preselection cut ({preselection_cut})')
plt.ylabel("Density", size=18)
plt.legend(loc='upper left')
plt.yscale('log')
plt.show()

# %%
# Make the preselections

dataset_incl['presel_score'] = presel_score

dataset = dataset_incl[dataset_incl.presel_score>=preselection_cut].copy()

# %%
# Normalizing the training weights post preselection - only discriminating shapes, not norms

weights_normed = dataset['weights'].ravel().copy()
weights = dataset['weights'].ravel().copy()

for key in labels_dict:

    weights_normed[dataset['train_labels_presel']==labels_dict[key]] /= weights[dataset['train_labels_presel']==labels_dict[key]].sum()

dataset['weights_normed'] = weights_normed

print(dataset['weights_normed'].sum())
print(dataset['weights'].sum())
# Out:
# 3.000000000000001
# 9031736.266763749

# %%
# Save the preselected dataframe for inference use later on
dataset.to_hdf(f"{saved_data}dataset_preselected_ttbar.h5", key="dataset", mode='w')

# %% [markdown]
# Density ratio training
# ===
#
# Now we train the NNs for $\frac{p_c}{p_{ref}}(x)$ density ratios to build the full model. Since we chose $p_{t\bar{t}}$ as the reference hypothesis, this leaves us with the estimation of:
#
# $$\frac{p_\text{single top}}{p_{t\bar{t}}}(x) \, , \frac{p_\text{wjets}}{p_{t\bar{t}}}(x)$$
#
# Starting with $\frac{p_\text{wjets}}{p_{t\bar{t}}}(x)$:

# %%
# Choose ttbar as the reference hypothesis
dataset_ch_wjets_ref = pd.concat([dataset[dataset['type']=='wjets'], 
                                  dataset[dataset['type']=='ttbar']])

dataset_ch_wjets_ref['train_labels'] = 0
dataset_ch_wjets_ref.loc[dataset_ch_wjets_ref['type']=='ttbar', 'train_labels'] = 1

# %%
NN_training_channels_dict = {}

# %%
rnd_seed_traintestsplit = 42
channel_names = ['wjets', 'ttbar']

# Save paths
output_dir = './output_general_wjets/'
output_name = 'first_training_wjets'
path_to_ratios = './output_ratios_wjets/'
path_to_figures = './output_figures_wjets/'
path_to_models = './output_model_params_wjets/'

importlib.reload(sys.modules['common_utils.training'])
from common_utils.training import TrainEvaluate_NN

# Initialize the training class
NN_training_channels_dict['wjets'] = TrainEvaluate_NN(dataset_ch_wjets_ref, 
                                                       dataset_ch_wjets_ref['weights_normed'],
                                                       dataset_ch_wjets_ref['train_labels'],
                                                       columns, 
                                                       columns_scaling, rnd_seed_traintestsplit, 
                                                       channel_names, output_dir, output_name, 
                                                        path_to_figures=path_to_figures,
                                                        path_to_ratios=path_to_ratios, 
                                                        path_to_models=path_to_models)

# %% [markdown]
# Here we will start with a multi-layer perceptron (simple feed-forward Neural Network with fully-connected layers). This can be supplemented with more complex architectures like transformers.
#
# After detailed tuning during the off-shell Higgs boson analysis effort, we found that a network with very wide layers ($\geq 1000$) and a depth of less than 10 works best - alongside batch size of a few hundreds and a gradually declining learning rate that starts with a value just large enough to not blow up.

# %%
# Train the density ratio NN
NN_training_channels_dict['wjets'].train(hidden_layers=4, 
                        neurons=1000, 
                        number_of_epochs=70, 
                        batch_size=1024, 
                        learning_rate=0.1, 
                        scalerType='MinMax', 
                        calibration=False, 
                        num_bins_cal = 10, 
                        callback=True, 
                        callback_patience=30, 
                        callback_factor=0.01)
# Out:
# Sum of weights of class 0: 0.8000000000000003
# Sum of weights of class 1: 0.799988001126427
# Using swish activation function
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 1000)              5000
#
#  dense_5 (Dense)             (None, 1000)              1001000
#
#  dense_6 (Dense)             (None, 1000)              1001000
#
#  dense_7 (Dense)             (None, 1000)              1001000
#
#  dense_8 (Dense)             (None, 1)                 1001
#
# =================================================================
# Total params: 3009001 (11.48 MB)
# Trainable params: 3009001 (11.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Using Callbacks
# Epoch 1/70
# 1848/1848 - 14s - loss: 2.9079e-07 - binary_accuracy: 0.8411 - val_loss: 2.7405e-07 - val_binary_accuracy: 0.8544 - lr: 0.1000 - 14s/epoch - 8ms/step
# Epoch 2/70
# 1848/1848 - 12s - loss: 2.7001e-07 - binary_accuracy: 0.8546 - val_loss: 2.7262e-07 - val_binary_accuracy: 0.8564 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 3/70
# 1848/1848 - 12s - loss: 2.6904e-07 - binary_accuracy: 0.8555 - val_loss: 2.7269e-07 - val_binary_accuracy: 0.8548 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 4/70
# 1848/1848 - 12s - loss: 2.6850e-07 - binary_accuracy: 0.8553 - val_loss: 2.7118e-07 - val_binary_accuracy: 0.8562 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 5/70
# 1848/1848 - 12s - loss: 2.6797e-07 - binary_accuracy: 0.8556 - val_loss: 2.7112e-07 - val_binary_accuracy: 0.8567 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 6/70
# 1848/1848 - 12s - loss: 2.6739e-07 - binary_accuracy: 0.8560 - val_loss: 2.6980e-07 - val_binary_accuracy: 0.8565 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 7/70
# 1848/1848 - 12s - loss: 2.6717e-07 - binary_accuracy: 0.8561 - val_loss: 2.6917e-07 - val_binary_accuracy: 0.8579 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 8/70
# 1848/1848 - 12s - loss: 2.6692e-07 - binary_accuracy: 0.8562 - val_loss: 2.7342e-07 - val_binary_accuracy: 0.8542 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 9/70
# 1848/1848 - 12s - loss: 2.6673e-07 - binary_accuracy: 0.8565 - val_loss: 2.6912e-07 - val_binary_accuracy: 0.8577 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 10/70
# 1848/1848 - 12s - loss: 2.6657e-07 - binary_accuracy: 0.8564 - val_loss: 2.7146e-07 - val_binary_accuracy: 0.8563 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 11/70
# 1848/1848 - 12s - loss: 2.6637e-07 - binary_accuracy: 0.8566 - val_loss: 2.6957e-07 - val_binary_accuracy: 0.8578 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 12/70
# 1848/1848 - 12s - loss: 2.6643e-07 - binary_accuracy: 0.8564 - val_loss: 2.7341e-07 - val_binary_accuracy: 0.8556 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 13/70
# 1848/1848 - 12s - loss: 2.6609e-07 - binary_accuracy: 0.8565 - val_loss: 2.7056e-07 - val_binary_accuracy: 0.8567 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 14/70
# 1848/1848 - 12s - loss: 2.6615e-07 - binary_accuracy: 0.8570 - val_loss: 2.7172e-07 - val_binary_accuracy: 0.8556 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 15/70
# 1848/1848 - 12s - loss: 2.6601e-07 - binary_accuracy: 0.8569 - val_loss: 2.6966e-07 - val_binary_accuracy: 0.8570 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 16/70
# 1848/1848 - 12s - loss: 2.6611e-07 - binary_accuracy: 0.8565 - val_loss: 2.7037e-07 - val_binary_accuracy: 0.8569 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 17/70
# 1848/1848 - 12s - loss: 2.6603e-07 - binary_accuracy: 0.8564 - val_loss: 2.6984e-07 - val_binary_accuracy: 0.8573 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 18/70
# 1848/1848 - 12s - loss: 2.6591e-07 - binary_accuracy: 0.8568 - val_loss: 2.6902e-07 - val_binary_accuracy: 0.8571 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 19/70
# 1848/1848 - 12s - loss: 2.6585e-07 - binary_accuracy: 0.8567 - val_loss: 2.6961e-07 - val_binary_accuracy: 0.8573 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 20/70
# 1848/1848 - 12s - loss: 2.6582e-07 - binary_accuracy: 0.8566 - val_loss: 2.7007e-07 - val_binary_accuracy: 0.8574 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 21/70
# 1848/1848 - 12s - loss: 2.6579e-07 - binary_accuracy: 0.8568 - val_loss: 2.6914e-07 - val_binary_accuracy: 0.8567 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 22/70
# 1848/1848 - 12s - loss: 2.6566e-07 - binary_accuracy: 0.8568 - val_loss: 2.7071e-07 - val_binary_accuracy: 0.8565 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 23/70
# 1848/1848 - 12s - loss: 2.6562e-07 - binary_accuracy: 0.8569 - val_loss: 2.7020e-07 - val_binary_accuracy: 0.8578 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 24/70
# 1848/1848 - 12s - loss: 2.6570e-07 - binary_accuracy: 0.8569 - val_loss: 2.6913e-07 - val_binary_accuracy: 0.8576 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 25/70
# 1848/1848 - 12s - loss: 2.6558e-07 - binary_accuracy: 0.8572 - val_loss: 2.6937e-07 - val_binary_accuracy: 0.8560 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 26/70
# 1848/1848 - 12s - loss: 2.6566e-07 - binary_accuracy: 0.8568 - val_loss: 2.6917e-07 - val_binary_accuracy: 0.8577 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 27/70
# 1848/1848 - 12s - loss: 2.6557e-07 - binary_accuracy: 0.8572 - val_loss: 2.6947e-07 - val_binary_accuracy: 0.8572 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 28/70
# 1848/1848 - 12s - loss: 2.6555e-07 - binary_accuracy: 0.8571 - val_loss: 2.6907e-07 - val_binary_accuracy: 0.8571 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 29/70
# 1848/1848 - 12s - loss: 2.6547e-07 - binary_accuracy: 0.8570 - val_loss: 2.6896e-07 - val_binary_accuracy: 0.8579 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 30/70
# 1848/1848 - 12s - loss: 2.6544e-07 - binary_accuracy: 0.8569 - val_loss: 2.6959e-07 - val_binary_accuracy: 0.8575 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 31/70
# 1848/1848 - 12s - loss: 2.6539e-07 - binary_accuracy: 0.8568 - val_loss: 2.6988e-07 - val_binary_accuracy: 0.8577 - lr: 0.1000 - 12s/epoch - 6ms/step
# Epoch 32/70
# 1848/1848 - 12s - loss: 2.6459e-07 - binary_accuracy: 0.8576 - val_loss: 2.6851e-07 - val_binary_accuracy: 0.8577 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 33/70
# 1848/1848 - 12s - loss: 2.6437e-07 - binary_accuracy: 0.8575 - val_loss: 2.6845e-07 - val_binary_accuracy: 0.8578 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 34/70
# 1848/1848 - 12s - loss: 2.6436e-07 - binary_accuracy: 0.8575 - val_loss: 2.6844e-07 - val_binary_accuracy: 0.8579 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 35/70
# 1848/1848 - 12s - loss: 2.6435e-07 - binary_accuracy: 0.8575 - val_loss: 2.6844e-07 - val_binary_accuracy: 0.8578 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 36/70
# 1848/1848 - 12s - loss: 2.6434e-07 - binary_accuracy: 0.8575 - val_loss: 2.6841e-07 - val_binary_accuracy: 0.8579 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 37/70
# 1848/1848 - 12s - loss: 2.6433e-07 - binary_accuracy: 0.8576 - val_loss: 2.6842e-07 - val_binary_accuracy: 0.8578 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 38/70
# 1848/1848 - 12s - loss: 2.6432e-07 - binary_accuracy: 0.8576 - val_loss: 2.6843e-07 - val_binary_accuracy: 0.8578 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 39/70
# 1848/1848 - 12s - loss: 2.6432e-07 - binary_accuracy: 0.8576 - val_loss: 2.6840e-07 - val_binary_accuracy: 0.8578 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 40/70
# 1848/1848 - 12s - loss: 2.6431e-07 - binary_accuracy: 0.8575 - val_loss: 2.6840e-07 - val_binary_accuracy: 0.8578 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 41/70
# 1848/1848 - 12s - loss: 2.6431e-07 - binary_accuracy: 0.8575 - val_loss: 2.6840e-07 - val_binary_accuracy: 0.8579 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 42/70
# 1848/1848 - 12s - loss: 2.6431e-07 - binary_accuracy: 0.8576 - val_loss: 2.6839e-07 - val_binary_accuracy: 0.8577 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 43/70
# 1848/1848 - 12s - loss: 2.6431e-07 - binary_accuracy: 0.8576 - val_loss: 2.6840e-07 - val_binary_accuracy: 0.8577 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 44/70
# 1848/1848 - 12s - loss: 2.6430e-07 - binary_accuracy: 0.8576 - val_loss: 2.6840e-07 - val_binary_accuracy: 0.8578 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 45/70
# 1848/1848 - 12s - loss: 2.6430e-07 - binary_accuracy: 0.8576 - val_loss: 2.6839e-07 - val_binary_accuracy: 0.8578 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 46/70
# 1848/1848 - 12s - loss: 2.6431e-07 - binary_accuracy: 0.8576 - val_loss: 2.6839e-07 - val_binary_accuracy: 0.8576 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 47/70
# 1848/1848 - 12s - loss: 2.6430e-07 - binary_accuracy: 0.8575 - val_loss: 2.6840e-07 - val_binary_accuracy: 0.8578 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 48/70
# 1848/1848 - 12s - loss: 2.6430e-07 - binary_accuracy: 0.8576 - val_loss: 2.6838e-07 - val_binary_accuracy: 0.8578 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 49/70
# 1848/1848 - 12s - loss: 2.6430e-07 - binary_accuracy: 0.8577 - val_loss: 2.6840e-07 - val_binary_accuracy: 0.8576 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 50/70
# 1848/1848 - 12s - loss: 2.6430e-07 - binary_accuracy: 0.8576 - val_loss: 2.6838e-07 - val_binary_accuracy: 0.8577 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 51/70
# 1848/1848 - 12s - loss: 2.6429e-07 - binary_accuracy: 0.8575 - val_loss: 2.6838e-07 - val_binary_accuracy: 0.8578 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 52/70
# 1848/1848 - 12s - loss: 2.6430e-07 - binary_accuracy: 0.8576 - val_loss: 2.6838e-07 - val_binary_accuracy: 0.8575 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 53/70
# 1848/1848 - 12s - loss: 2.6429e-07 - binary_accuracy: 0.8575 - val_loss: 2.6840e-07 - val_binary_accuracy: 0.8578 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 54/70
# 1848/1848 - 12s - loss: 2.6429e-07 - binary_accuracy: 0.8576 - val_loss: 2.6838e-07 - val_binary_accuracy: 0.8579 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 55/70
# 1848/1848 - 12s - loss: 2.6429e-07 - binary_accuracy: 0.8576 - val_loss: 2.6842e-07 - val_binary_accuracy: 0.8576 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 56/70
# 1848/1848 - 12s - loss: 2.6430e-07 - binary_accuracy: 0.8576 - val_loss: 2.6839e-07 - val_binary_accuracy: 0.8577 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 57/70
# 1848/1848 - 12s - loss: 2.6429e-07 - binary_accuracy: 0.8576 - val_loss: 2.6839e-07 - val_binary_accuracy: 0.8576 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 58/70
# 1848/1848 - 12s - loss: 2.6429e-07 - binary_accuracy: 0.8576 - val_loss: 2.6839e-07 - val_binary_accuracy: 0.8576 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 59/70
# 1848/1848 - 12s - loss: 2.6428e-07 - binary_accuracy: 0.8576 - val_loss: 2.6841e-07 - val_binary_accuracy: 0.8579 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 60/70
# 1848/1848 - 12s - loss: 2.6429e-07 - binary_accuracy: 0.8576 - val_loss: 2.6837e-07 - val_binary_accuracy: 0.8578 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 61/70
# 1848/1848 - 12s - loss: 2.6429e-07 - binary_accuracy: 0.8576 - val_loss: 2.6839e-07 - val_binary_accuracy: 0.8576 - lr: 0.0010 - 12s/epoch - 6ms/step
# Epoch 62/70
# 1848/1848 - 12s - loss: 2.6427e-07 - binary_accuracy: 0.8577 - val_loss: 2.6839e-07 - val_binary_accuracy: 0.8576 - lr: 1.0000e-05 - 12s/epoch - 7ms/step
# Epoch 63/70
# 1848/1848 - 12s - loss: 2.6427e-07 - binary_accuracy: 0.8576 - val_loss: 2.6839e-07 - val_binary_accuracy: 0.8576 - lr: 1.0000e-05 - 12s/epoch - 6ms/step
# Epoch 64/70
# 1848/1848 - 12s - loss: 2.6427e-07 - binary_accuracy: 0.8576 - val_loss: 2.6839e-07 - val_binary_accuracy: 0.8576 - lr: 1.0000e-05 - 12s/epoch - 6ms/step
# Epoch 65/70
# 1848/1848 - 12s - loss: 2.6427e-07 - binary_accuracy: 0.8576 - val_loss: 2.6839e-07 - val_binary_accuracy: 0.8576 - lr: 1.0000e-05 - 12s/epoch - 6ms/step
# Epoch 66/70
# 1848/1848 - 12s - loss: 2.6427e-07 - binary_accuracy: 0.8576 - val_loss: 2.6839e-07 - val_binary_accuracy: 0.8577 - lr: 1.0000e-05 - 12s/epoch - 6ms/step
# Epoch 67/70
# 1848/1848 - 12s - loss: 2.6427e-07 - binary_accuracy: 0.8576 - val_loss: 2.6839e-07 - val_binary_accuracy: 0.8577 - lr: 1.0000e-05 - 12s/epoch - 6ms/step
# Epoch 68/70
# 1848/1848 - 12s - loss: 2.6427e-07 - binary_accuracy: 0.8576 - val_loss: 2.6839e-07 - val_binary_accuracy: 0.8577 - lr: 1.0000e-05 - 12s/epoch - 6ms/step
# Epoch 69/70
# 1848/1848 - 12s - loss: 2.6427e-07 - binary_accuracy: 0.8576 - val_loss: 2.6839e-07 - val_binary_accuracy: 0.8577 - lr: 1.0000e-05 - 12s/epoch - 6ms/step
# Epoch 70/70
# 1848/1848 - 12s - loss: 2.6427e-07 - binary_accuracy: 0.8576 - val_loss: 2.6839e-07 - val_binary_accuracy: 0.8577 - lr: 1.0000e-05 - 12s/epoch - 6ms/step
# Finished Training
# ./output_model_params_wjets/model_scaler.bin
# 601/601 - 0s - 457ms/epoch - 760us/step
# 15820/15820 - 9s - 9s/epoch - 598us/step
# 2403/2403 - 1s - 1s/epoch - 575us/step
# 63277/63277 - 38s - 38s/epoch - 594us/step
# ttbar training data prediction (max) = 0.9798695
# ttbar training data prediction (min) = 0.0029774804
# wjets training data prediction (max) = 0.9801994
# wjets training data prediction (min) = 0.003031875
# ttbar training data prediction (max) = 0.9797006
# ttbar training data prediction (min) = 0.0030746916
# wjets training data prediction (max) = 0.98020387
# wjets training data prediction (min) = 0.0032559065

# %% [markdown]
# Check for overtraining - the holdout dataset

# %%
NN_training_channels_dict['wjets'].make_overfit_plots()

# %% [markdown]
# Diagnostic Checks
# ===
#
# While traditionally, a NN observable is judged on the basis of its accuracy - for NSBI we are interested in the quality of the density ratios more than the discrimination power. The latter comes from the perfect modelling of the multi-dimensional likelihood ratios.
#
# To ensure correct modelling, we run two main checks on the training:
#
# - Calibration closure test
# - Density ratio reweighting test

# %%
num_bins_cal = 50
NN_training_channels_dict['wjets'].make_calib_plots(nbins=num_bins_cal, observable='score')
# Out:
# observable not recognized

# %%
num_bins_cal = 50
NN_training_channels_dict['wjets'].make_calib_plots(nbins=num_bins_cal, observable='llr')

# %%
variables_to_plot=['lepton_pt']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['wjets'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['lepton_phi']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['wjets'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['lepton_eta']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['wjets'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['H_T']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['wjets'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:281: RuntimeWarning: invalid value encountered in divide
#   hep.histplot(rat, edges, yerr = np.abs(rat*np.sqrt((np.sqrt(hist_den_err)/hist_den)**2+(np.sqrt(hist_num_err)/hist_num)**2)), linewidth=2.0)

# %%
variables_to_plot=['presel_score']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['wjets'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
NN_training_channels_dict['wjets'].evaluate_and_save_ratios(dataset)
# Out:
# 93318/93318 - 55s - 55s/epoch - 588us/step

# %%
# Choose ttbar as the reference hypothesis
dataset_ch_single_top_t_chan_ref = pd.concat([dataset[dataset['type']=='single_top_t_chan'], 
                                  dataset[dataset['type']=='ttbar']])

dataset_ch_single_top_t_chan_ref['train_labels'] = 0
dataset_ch_single_top_t_chan_ref.loc[dataset_ch_single_top_t_chan_ref['type']=='ttbar', 'train_labels'] = 1

# %%
rnd_seed_traintestsplit = 42
channel_names = ['single_top_t_chan', 'ttbar']

# Save paths
output_dir = './output_general_singletop/'
output_name = 'first_training_singletop'
path_to_ratios = './output_ratios_singletop/'
path_to_figures = './output_figures_singletop/'
path_to_models = './output_model_params_singletop/'



importlib.reload(sys.modules['common_utils.training'])
from common_utils.training import TrainEvaluate_NN

# Initialize the training class
NN_training_channels_dict['singletop'] = TrainEvaluate_NN(dataset_ch_single_top_t_chan_ref, 
                               dataset_ch_single_top_t_chan_ref['weights_normed'],
                               dataset_ch_single_top_t_chan_ref['train_labels'],
                               columns, 
                               columns_scaling, rnd_seed_traintestsplit, 
                               channel_names, output_dir, output_name, 
                                path_to_figures=path_to_figures,
                                path_to_ratios=path_to_ratios, 
                                path_to_models=path_to_models)

# %%
# Train the density ratio NN
NN_training_channels_dict['singletop'].train(hidden_layers=4, 
                        neurons=1000, 
                        number_of_epochs=70, 
                        batch_size=512, 
                        learning_rate=0.2, 
                        scalerType='MinMax', 
                        calibration=False, 
                        num_bins_cal = 10, 
                        callback=True, 
                        callback_patience=30, 
                        callback_factor=0.01)
# Out:
# Sum of weights of class 0: 0.8000000000000006
# Sum of weights of class 1: 0.7999960048573898
# Using swish activation function
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 1000)              5000
#
#  dense_10 (Dense)            (None, 1000)              1001000
#
#  dense_11 (Dense)            (None, 1000)              1001000
#
#  dense_12 (Dense)            (None, 1000)              1001000
#
#  dense_13 (Dense)            (None, 1)                 1001
#
# =================================================================
# Total params: 3009001 (11.48 MB)
# Trainable params: 3009001 (11.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Using Callbacks
# Epoch 1/70
# 4065/4065 - 18s - loss: 3.8758e-07 - binary_accuracy: 0.7254 - val_loss: 3.8184e-07 - val_binary_accuracy: 0.7316 - lr: 0.2000 - 18s/epoch - 4ms/step
# Epoch 2/70
# 4065/4065 - 16s - loss: 3.8290e-07 - binary_accuracy: 0.7289 - val_loss: 3.8168e-07 - val_binary_accuracy: 0.7314 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 3/70
# 4065/4065 - 16s - loss: 3.8270e-07 - binary_accuracy: 0.7293 - val_loss: 3.8187e-07 - val_binary_accuracy: 0.7309 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 4/70
# 4065/4065 - 16s - loss: 3.8254e-07 - binary_accuracy: 0.7297 - val_loss: 3.8289e-07 - val_binary_accuracy: 0.7312 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 5/70
# 4065/4065 - 16s - loss: 3.8246e-07 - binary_accuracy: 0.7297 - val_loss: 3.8530e-07 - val_binary_accuracy: 0.7287 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 6/70
# 4065/4065 - 16s - loss: 3.8216e-07 - binary_accuracy: 0.7299 - val_loss: 3.8177e-07 - val_binary_accuracy: 0.7305 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 7/70
# 4065/4065 - 16s - loss: 3.8209e-07 - binary_accuracy: 0.7299 - val_loss: 3.8162e-07 - val_binary_accuracy: 0.7306 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 8/70
# 4065/4065 - 16s - loss: 3.8197e-07 - binary_accuracy: 0.7299 - val_loss: 3.8177e-07 - val_binary_accuracy: 0.7307 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 9/70
# 4065/4065 - 16s - loss: 3.8200e-07 - binary_accuracy: 0.7300 - val_loss: 3.8097e-07 - val_binary_accuracy: 0.7317 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 10/70
# 4065/4065 - 16s - loss: 3.8194e-07 - binary_accuracy: 0.7299 - val_loss: 3.8126e-07 - val_binary_accuracy: 0.7318 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 11/70
# 4065/4065 - 16s - loss: 3.8188e-07 - binary_accuracy: 0.7301 - val_loss: 3.8208e-07 - val_binary_accuracy: 0.7303 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 12/70
# 4065/4065 - 16s - loss: 3.8185e-07 - binary_accuracy: 0.7302 - val_loss: 3.8184e-07 - val_binary_accuracy: 0.7306 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 13/70
# 4065/4065 - 16s - loss: 3.8183e-07 - binary_accuracy: 0.7301 - val_loss: 3.8167e-07 - val_binary_accuracy: 0.7315 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 14/70
# 4065/4065 - 16s - loss: 3.8179e-07 - binary_accuracy: 0.7302 - val_loss: 3.8098e-07 - val_binary_accuracy: 0.7315 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 15/70
# 4065/4065 - 16s - loss: 3.8176e-07 - binary_accuracy: 0.7301 - val_loss: 3.8119e-07 - val_binary_accuracy: 0.7311 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 16/70
# 4065/4065 - 16s - loss: 3.8174e-07 - binary_accuracy: 0.7303 - val_loss: 3.8103e-07 - val_binary_accuracy: 0.7316 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 17/70
# 4065/4065 - 16s - loss: 3.8171e-07 - binary_accuracy: 0.7300 - val_loss: 3.8189e-07 - val_binary_accuracy: 0.7314 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 18/70
# 4065/4065 - 16s - loss: 3.8167e-07 - binary_accuracy: 0.7302 - val_loss: 3.8117e-07 - val_binary_accuracy: 0.7316 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 19/70
# 4065/4065 - 16s - loss: 3.8169e-07 - binary_accuracy: 0.7302 - val_loss: 3.8267e-07 - val_binary_accuracy: 0.7294 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 20/70
# 4065/4065 - 16s - loss: 3.8166e-07 - binary_accuracy: 0.7301 - val_loss: 3.8128e-07 - val_binary_accuracy: 0.7313 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 21/70
# 4065/4065 - 16s - loss: 3.8163e-07 - binary_accuracy: 0.7301 - val_loss: 3.8175e-07 - val_binary_accuracy: 0.7319 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 22/70
# 4065/4065 - 16s - loss: 3.8157e-07 - binary_accuracy: 0.7302 - val_loss: 3.8145e-07 - val_binary_accuracy: 0.7317 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 23/70
# 4065/4065 - 16s - loss: 3.8158e-07 - binary_accuracy: 0.7303 - val_loss: 3.8277e-07 - val_binary_accuracy: 0.7291 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 24/70
# 4065/4065 - 16s - loss: 3.8156e-07 - binary_accuracy: 0.7300 - val_loss: 3.8202e-07 - val_binary_accuracy: 0.7307 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 25/70
# 4065/4065 - 16s - loss: 3.8153e-07 - binary_accuracy: 0.7303 - val_loss: 3.8110e-07 - val_binary_accuracy: 0.7313 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 26/70
# 4065/4065 - 16s - loss: 3.8155e-07 - binary_accuracy: 0.7300 - val_loss: 3.8062e-07 - val_binary_accuracy: 0.7315 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 27/70
# 4065/4065 - 16s - loss: 3.8157e-07 - binary_accuracy: 0.7302 - val_loss: 3.8160e-07 - val_binary_accuracy: 0.7315 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 28/70
# 4065/4065 - 16s - loss: 3.8152e-07 - binary_accuracy: 0.7303 - val_loss: 3.8154e-07 - val_binary_accuracy: 0.7314 - lr: 0.2000 - 16s/epoch - 4ms/step
# Epoch 29/70
# 4065/4065 - 17s - loss: 3.8155e-07 - binary_accuracy: 0.7301 - val_loss: 3.8162e-07 - val_binary_accuracy: 0.7313 - lr: 0.2000 - 17s/epoch - 4ms/step
# Epoch 30/70
# 4065/4065 - 17s - loss: 3.8154e-07 - binary_accuracy: 0.7301 - val_loss: 3.8179e-07 - val_binary_accuracy: 0.7317 - lr: 0.2000 - 17s/epoch - 4ms/step
# Epoch 31/70
# 4065/4065 - 17s - loss: 3.8152e-07 - binary_accuracy: 0.7302 - val_loss: 3.8204e-07 - val_binary_accuracy: 0.7319 - lr: 0.2000 - 17s/epoch - 4ms/step
# Epoch 32/70
# 4065/4065 - 16s - loss: 3.8093e-07 - binary_accuracy: 0.7305 - val_loss: 3.8054e-07 - val_binary_accuracy: 0.7317 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 33/70
# 4065/4065 - 16s - loss: 3.8085e-07 - binary_accuracy: 0.7307 - val_loss: 3.8051e-07 - val_binary_accuracy: 0.7313 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 34/70
# 4065/4065 - 16s - loss: 3.8084e-07 - binary_accuracy: 0.7307 - val_loss: 3.8050e-07 - val_binary_accuracy: 0.7316 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 35/70
# 4065/4065 - 16s - loss: 3.8083e-07 - binary_accuracy: 0.7307 - val_loss: 3.8049e-07 - val_binary_accuracy: 0.7316 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 36/70
# 4065/4065 - 16s - loss: 3.8083e-07 - binary_accuracy: 0.7307 - val_loss: 3.8049e-07 - val_binary_accuracy: 0.7317 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 37/70
# 4065/4065 - 16s - loss: 3.8083e-07 - binary_accuracy: 0.7306 - val_loss: 3.8049e-07 - val_binary_accuracy: 0.7317 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 38/70
# 4065/4065 - 16s - loss: 3.8083e-07 - binary_accuracy: 0.7307 - val_loss: 3.8048e-07 - val_binary_accuracy: 0.7316 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 39/70
# 4065/4065 - 16s - loss: 3.8083e-07 - binary_accuracy: 0.7306 - val_loss: 3.8049e-07 - val_binary_accuracy: 0.7317 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 40/70
# 4065/4065 - 16s - loss: 3.8082e-07 - binary_accuracy: 0.7306 - val_loss: 3.8048e-07 - val_binary_accuracy: 0.7316 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 41/70
# 4065/4065 - 16s - loss: 3.8082e-07 - binary_accuracy: 0.7307 - val_loss: 3.8048e-07 - val_binary_accuracy: 0.7315 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 42/70
# 4065/4065 - 17s - loss: 3.8082e-07 - binary_accuracy: 0.7306 - val_loss: 3.8048e-07 - val_binary_accuracy: 0.7315 - lr: 0.0020 - 17s/epoch - 4ms/step
# Epoch 43/70
# 4065/4065 - 16s - loss: 3.8082e-07 - binary_accuracy: 0.7306 - val_loss: 3.8047e-07 - val_binary_accuracy: 0.7315 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 44/70
# 4065/4065 - 16s - loss: 3.8082e-07 - binary_accuracy: 0.7306 - val_loss: 3.8048e-07 - val_binary_accuracy: 0.7315 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 45/70
# 4065/4065 - 16s - loss: 3.8082e-07 - binary_accuracy: 0.7307 - val_loss: 3.8049e-07 - val_binary_accuracy: 0.7314 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 46/70
# 4065/4065 - 17s - loss: 3.8082e-07 - binary_accuracy: 0.7307 - val_loss: 3.8049e-07 - val_binary_accuracy: 0.7317 - lr: 0.0020 - 17s/epoch - 4ms/step
# Epoch 47/70
# 4065/4065 - 16s - loss: 3.8082e-07 - binary_accuracy: 0.7306 - val_loss: 3.8049e-07 - val_binary_accuracy: 0.7317 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 48/70
# 4065/4065 - 16s - loss: 3.8082e-07 - binary_accuracy: 0.7306 - val_loss: 3.8048e-07 - val_binary_accuracy: 0.7315 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 49/70
# 4065/4065 - 16s - loss: 3.8082e-07 - binary_accuracy: 0.7307 - val_loss: 3.8049e-07 - val_binary_accuracy: 0.7316 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 50/70
# 4065/4065 - 16s - loss: 3.8082e-07 - binary_accuracy: 0.7306 - val_loss: 3.8048e-07 - val_binary_accuracy: 0.7316 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 51/70
# 4065/4065 - 16s - loss: 3.8082e-07 - binary_accuracy: 0.7307 - val_loss: 3.8047e-07 - val_binary_accuracy: 0.7315 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 52/70
# 4065/4065 - 16s - loss: 3.8082e-07 - binary_accuracy: 0.7306 - val_loss: 3.8050e-07 - val_binary_accuracy: 0.7317 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 53/70
# 4065/4065 - 16s - loss: 3.8082e-07 - binary_accuracy: 0.7307 - val_loss: 3.8049e-07 - val_binary_accuracy: 0.7317 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 54/70
# 4065/4065 - 17s - loss: 3.8082e-07 - binary_accuracy: 0.7306 - val_loss: 3.8048e-07 - val_binary_accuracy: 0.7315 - lr: 0.0020 - 17s/epoch - 4ms/step
# Epoch 55/70
# 4065/4065 - 16s - loss: 3.8082e-07 - binary_accuracy: 0.7307 - val_loss: 3.8049e-07 - val_binary_accuracy: 0.7315 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 56/70
# 4065/4065 - 16s - loss: 3.8082e-07 - binary_accuracy: 0.7306 - val_loss: 3.8048e-07 - val_binary_accuracy: 0.7316 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 57/70
# 4065/4065 - 17s - loss: 3.8082e-07 - binary_accuracy: 0.7306 - val_loss: 3.8047e-07 - val_binary_accuracy: 0.7316 - lr: 0.0020 - 17s/epoch - 4ms/step
# Epoch 58/70
# 4065/4065 - 17s - loss: 3.8082e-07 - binary_accuracy: 0.7307 - val_loss: 3.8049e-07 - val_binary_accuracy: 0.7317 - lr: 0.0020 - 17s/epoch - 4ms/step
# Epoch 59/70
# 4065/4065 - 17s - loss: 3.8082e-07 - binary_accuracy: 0.7306 - val_loss: 3.8048e-07 - val_binary_accuracy: 0.7316 - lr: 0.0020 - 17s/epoch - 4ms/step
# Epoch 60/70
# 4065/4065 - 16s - loss: 3.8082e-07 - binary_accuracy: 0.7306 - val_loss: 3.8048e-07 - val_binary_accuracy: 0.7316 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 61/70
# 4065/4065 - 16s - loss: 3.8082e-07 - binary_accuracy: 0.7307 - val_loss: 3.8049e-07 - val_binary_accuracy: 0.7316 - lr: 0.0020 - 16s/epoch - 4ms/step
# Epoch 62/70
# 4065/4065 - 16s - loss: 3.8081e-07 - binary_accuracy: 0.7307 - val_loss: 3.8049e-07 - val_binary_accuracy: 0.7317 - lr: 2.0000e-05 - 16s/epoch - 4ms/step
# Epoch 63/70
# 4065/4065 - 16s - loss: 3.8081e-07 - binary_accuracy: 0.7307 - val_loss: 3.8048e-07 - val_binary_accuracy: 0.7315 - lr: 2.0000e-05 - 16s/epoch - 4ms/step
# Epoch 64/70
# 4065/4065 - 16s - loss: 3.8081e-07 - binary_accuracy: 0.7306 - val_loss: 3.8048e-07 - val_binary_accuracy: 0.7315 - lr: 2.0000e-05 - 16s/epoch - 4ms/step
# Epoch 65/70
# 4065/4065 - 16s - loss: 3.8081e-07 - binary_accuracy: 0.7307 - val_loss: 3.8048e-07 - val_binary_accuracy: 0.7315 - lr: 2.0000e-05 - 16s/epoch - 4ms/step
# Epoch 66/70
# 4065/4065 - 16s - loss: 3.8081e-07 - binary_accuracy: 0.7306 - val_loss: 3.8048e-07 - val_binary_accuracy: 0.7315 - lr: 2.0000e-05 - 16s/epoch - 4ms/step
# Epoch 67/70
# 4065/4065 - 16s - loss: 3.8081e-07 - binary_accuracy: 0.7306 - val_loss: 3.8048e-07 - val_binary_accuracy: 0.7315 - lr: 2.0000e-05 - 16s/epoch - 4ms/step
# Epoch 68/70
# 4065/4065 - 16s - loss: 3.8081e-07 - binary_accuracy: 0.7306 - val_loss: 3.8048e-07 - val_binary_accuracy: 0.7315 - lr: 2.0000e-05 - 16s/epoch - 4ms/step
# Epoch 69/70
# 4065/4065 - 16s - loss: 3.8081e-07 - binary_accuracy: 0.7306 - val_loss: 3.8047e-07 - val_binary_accuracy: 0.7315 - lr: 2.0000e-05 - 16s/epoch - 4ms/step
# Epoch 70/70
# 4065/4065 - 16s - loss: 3.8081e-07 - binary_accuracy: 0.7306 - val_loss: 3.8047e-07 - val_binary_accuracy: 0.7315 - lr: 2.0000e-05 - 16s/epoch - 4ms/step
# Finished Training
# ./output_model_params_singletop/model_scaler.bin
# 2244/2244 - 1s - 1s/epoch - 620us/step
# 15820/15820 - 9s - 9s/epoch - 595us/step
# 8975/8975 - 5s - 5s/epoch - 591us/step
# 63277/63277 - 38s - 38s/epoch - 596us/step
# ttbar training data prediction (max) = 0.8514484
# ttbar training data prediction (min) = 0.06522921
# single_top_t_chan training data prediction (max) = 0.8560052
# single_top_t_chan training data prediction (min) = 0.065176114
# ttbar training data prediction (max) = 0.8548657
# ttbar training data prediction (min) = 0.06566688
# single_top_t_chan training data prediction (max) = 0.85542804
# single_top_t_chan training data prediction (min) = 0.06594942

# %%
NN_training_channels_dict['singletop'].make_overfit_plots()

# %%
num_bins_cal = 50
NN_training_channels_dict['singletop'].make_calib_plots(nbins=num_bins_cal, observable='score')
# Out:
# observable not recognized

# %%
NN_training_channels_dict['singletop'].make_calib_plots(nbins=num_bins_cal, observable='llr')

# %%
variables_to_plot=['lepton_pt']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['singletop'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['lepton_phi']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['singletop'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['lepton_eta']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['singletop'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['H_T']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['singletop'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['presel_score']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['singletop'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
NN_training_channels_dict['singletop'].evaluate_and_save_ratios(dataset)
# Out:
# 93318/93318 - 56s - 56s/epoch - 596us/step

# %%
# backup code for updating class methods - only for debugging phase
importlib.reload(sys.modules['common_utils.training'])
from common_utils.training import TrainEvaluate_NN
import types

NN_training_channels_dict['wjets'].make_reweighted_plots = types.MethodType(TrainEvaluate_NN.make_reweighted_plots, NN_training_channels_dict['wjets'])
NN_training_channels_dict['wjets'].make_calib_plots = types.MethodType(TrainEvaluate_NN.make_calib_plots, NN_training_channels_dict['wjets'])
NN_training_channels_dict['wjets'].evaluate_and_save_ratios = types.MethodType(TrainEvaluate_NN.evaluate_and_save_ratios, NN_training_channels_dict['wjets'])
NN_training_channels_dict['wjets'].make_overfit_plots = types.MethodType(TrainEvaluate_NN.make_overfit_plots, NN_training_channels_dict['wjets'])
