# %% [markdown]
# Train Neural Networks to estimate Likelihood Ratios
# ===
#
# In this notebook we will setup the neural networks that train unbiased and low-variance density ratios to be then used for inference. The statistical model we have is:
#
# $$p(x|\mu, \alpha) = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot p_c\left(x|\alpha\right)$$

# %%
import os, sys, importlib
sys.path.append('../')

import common_utils
from common_utils import plotting, training
from common_utils.training import TrainEvaluate_NN
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt
hep.style.use(hep.style.ATLAS)
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:10: FutureWarning: ``set_style`` is deprecated: Naming convention is changing to match mpl. Use ``mplhep.style.use()``.
#   hep.set_style("ATLAS")
# 2025-02-09 17:03:24.706195: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-09 17:03:25.492694: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load the datasets from pre-processed input
saved_data='./cached_data/'

training_features = np.load(f"{saved_data}features.npy")
train_labels = np.load(f"{saved_data}train_labels.npy")
preselection_score = np.load(f"{saved_data}preselection_score.npy")
weights = np.load(f"{saved_data}weights.npy")

# %%
# labels_dict = {"ttbar": 0,
#                "single_top_s_chan":1,
#               "single_top_t_chan":2,
#               "single_top_tW":3,
#               "wjets":4}

# Keep only a subset of the background for illustration
labels_dict = {"ttbar": 0,
              "single_top_t_chan":1,
              "wjets":2}

# %%
min_pred = np.amin(preselection_score)
max_pred = np.amax(preselection_score)

bins = np.linspace(min_pred, max_pred, num=150)

hist_NN_output = {}

for key in labels_dict: 
    hist_NN_output[key], _ = np.histogram(preselection_score[train_labels==labels_dict[key]], weights = weights[train_labels==labels_dict[key]], bins=bins)

# %% [markdown]
# Make a selection cut for performing the NSBI analysis, balancing the number of signal events that go into the signal region (increasing sensitivity) and the feasibility of training accurate and precise NNs over a large phase space (need bigger models and more statistics).
#
# As a first cut, we choose a loose preselection and see if it works.

# %%
preselection_cut = -16.5 # Lets start with a very loose cut

for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins=bins, 
             alpha=0.6, label=key, 
             density=True, linewidth=2.0)

plt.xlabel("Preselection Score", size=18)
plt.axvline(preselection_cut, ymax=0.9, linestyle='--', label=f'preselection cut ({preselection_cut})')
plt.ylabel("Density", size=18)
plt.legend()
plt.yscale('log')
plt.show()

# %%
# Make the preselections

training_features = training_features[preselection_score>=preselection_cut].copy()
train_labels = train_labels[preselection_score>=preselection_cut].copy()
weights = weights[preselection_score>=preselection_cut].copy()

preselection_score_selected = preselection_score[preselection_score>=preselection_cut].copy()

# %%
type_vec = np.array(train_labels, dtype='object')

for key in labels_dict:
    type_vec[type_vec==labels_dict[key]] = key

# %%
# Build a pandas dataframe from the arrays for density ratio training and validation
columns = ['lepton_pt', 'lepton_eta', 'lepton_phi']
dataset = pd.DataFrame(training_features, columns=columns)

dataset['log_lepton_pt'] = np.log(dataset['lepton_pt'].ravel())

dataset['presel_score'] = preselection_score_selected
dataset['train_labels'] = train_labels
dataset['type'] = type_vec
dataset['weights'] = weights

# %%
# Normalizing the training weights - only discriminating shapes, not norms

weights_normed = weights.copy()

for key in labels_dict:

    weights_normed[train_labels==labels_dict[key]] /= weights[train_labels==labels_dict[key]].sum()

dataset['weights_normed'] = weights_normed

# %%
# Choose ttbar as the reference hypothesis
dataset_ch_wjets_ref = pd.concat([dataset[dataset['type']=='wjets'], 
                                  dataset[dataset['type']=='ttbar']])

dataset_ch_wjets_ref['train_labels'] = 0
dataset_ch_wjets_ref.loc[dataset_ch_wjets_ref['type']=='ttbar', 'train_labels'] = 1

# %%
columns = ['lepton_pt', 'lepton_eta', 'lepton_phi']
columns_scaling = ['lepton_pt', 'lepton_eta', 'lepton_phi']

columns = ['log_lepton_pt', 'lepton_eta', 'lepton_phi']
columns_scaling = ['log_lepton_pt', 'lepton_eta', 'lepton_phi']

# %%
rnd_seed_traintestsplit = 42
channel_names = ['wjets', 'ttbar']

# Save paths
output_dir = './output_general/'
output_name = 'first_training_wjets'
path_to_ratios = './output_ratios/'
path_to_figures = './output_figures/'
path_to_models = './output_model_params/'

importlib.reload(sys.modules['common_utils.training'])
from common_utils.training import TrainEvaluate_NN

# Initialize the training class
NN_training = TrainEvaluate_NN(dataset_ch_wjets_ref, 
                               dataset_ch_wjets_ref['weights_normed'],
                               dataset_ch_wjets_ref['train_labels'],
                               columns, 
                               columns_scaling, rnd_seed_traintestsplit, 
                               channel_names, output_dir, output_name, 
                                path_to_figures=path_to_figures,
                                path_to_ratios=path_to_ratios, 
                                path_to_models=path_to_models)

# %%
# Train the density ratio NN
NN_training.train(hidden_layers=2, 
                        neurons=1000, 
                        number_of_epochs=70, 
                        batch_size=2096, 
                        learning_rate=0.1, 
                        scalerType='MinMax', 
                        calibration=False, 
                        num_bins_cal = 10, 
                        callback=True, 
                        callback_patience=30, 
                        callback_factor=0.01)
# Out:
# Sum of weights of class 0: 0.8000007526266657
# Sum of weights of class 1: 0.7999985571390978
# Using swish activation function
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_25 (Dense)            (None, 1000)              4000
#
#  dense_26 (Dense)            (None, 1000)              1001000
#
#  dense_27 (Dense)            (None, 1)                 1001
#
# =================================================================
# Total params: 1006001 (3.84 MB)
# Trainable params: 1006001 (3.84 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Using Callbacks
# Epoch 1/70
# 1064/1064 - 41s - loss: 4.4695e-07 - binary_accuracy: 0.5284 - val_loss: 4.4430e-07 - val_binary_accuracy: 0.5387 - lr: 0.1000 - 41s/epoch - 38ms/step
# Epoch 2/70
# 1064/1064 - 39s - loss: 4.2984e-07 - binary_accuracy: 0.5946 - val_loss: 4.2042e-07 - val_binary_accuracy: 0.6277 - lr: 0.1000 - 39s/epoch - 37ms/step
# Epoch 3/70
# 1064/1064 - 39s - loss: 4.1795e-07 - binary_accuracy: 0.6303 - val_loss: 4.1656e-07 - val_binary_accuracy: 0.6305 - lr: 0.1000 - 39s/epoch - 37ms/step
# Epoch 4/70
# 1064/1064 - 39s - loss: 4.1487e-07 - binary_accuracy: 0.6325 - val_loss: 4.1541e-07 - val_binary_accuracy: 0.6303 - lr: 0.1000 - 39s/epoch - 37ms/step
# Epoch 5/70
# 1064/1064 - 39s - loss: 4.1435e-07 - binary_accuracy: 0.6328 - val_loss: 4.1487e-07 - val_binary_accuracy: 0.6314 - lr: 0.1000 - 39s/epoch - 37ms/step
# Epoch 6/70
# 1064/1064 - 38s - loss: 4.1433e-07 - binary_accuracy: 0.6329 - val_loss: 4.1494e-07 - val_binary_accuracy: 0.6310 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 7/70
# 1064/1064 - 38s - loss: 4.1429e-07 - binary_accuracy: 0.6329 - val_loss: 4.1486e-07 - val_binary_accuracy: 0.6309 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 8/70
# 1064/1064 - 38s - loss: 4.1428e-07 - binary_accuracy: 0.6329 - val_loss: 4.1510e-07 - val_binary_accuracy: 0.6310 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 9/70
# 1064/1064 - 39s - loss: 4.1425e-07 - binary_accuracy: 0.6329 - val_loss: 4.1499e-07 - val_binary_accuracy: 0.6318 - lr: 0.1000 - 39s/epoch - 36ms/step
# Epoch 10/70
# 1064/1064 - 38s - loss: 4.1423e-07 - binary_accuracy: 0.6331 - val_loss: 4.1489e-07 - val_binary_accuracy: 0.6312 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 11/70
# 1064/1064 - 38s - loss: 4.1427e-07 - binary_accuracy: 0.6330 - val_loss: 4.1500e-07 - val_binary_accuracy: 0.6314 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 12/70
# 1064/1064 - 39s - loss: 4.1423e-07 - binary_accuracy: 0.6329 - val_loss: 4.1505e-07 - val_binary_accuracy: 0.6303 - lr: 0.1000 - 39s/epoch - 36ms/step
# Epoch 13/70
# 1064/1064 - 38s - loss: 4.1422e-07 - binary_accuracy: 0.6329 - val_loss: 4.1492e-07 - val_binary_accuracy: 0.6310 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 14/70
# 1064/1064 - 38s - loss: 4.1422e-07 - binary_accuracy: 0.6331 - val_loss: 4.1484e-07 - val_binary_accuracy: 0.6307 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 15/70
# 1064/1064 - 38s - loss: 4.1421e-07 - binary_accuracy: 0.6332 - val_loss: 4.1506e-07 - val_binary_accuracy: 0.6311 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 16/70
# 1064/1064 - 38s - loss: 4.1422e-07 - binary_accuracy: 0.6331 - val_loss: 4.1490e-07 - val_binary_accuracy: 0.6317 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 17/70
# 1064/1064 - 38s - loss: 4.1419e-07 - binary_accuracy: 0.6330 - val_loss: 4.1493e-07 - val_binary_accuracy: 0.6308 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 18/70
# 1064/1064 - 38s - loss: 4.1418e-07 - binary_accuracy: 0.6331 - val_loss: 4.1510e-07 - val_binary_accuracy: 0.6304 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 19/70
# 1064/1064 - 38s - loss: 4.1418e-07 - binary_accuracy: 0.6330 - val_loss: 4.1494e-07 - val_binary_accuracy: 0.6304 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 20/70
# 1064/1064 - 38s - loss: 4.1420e-07 - binary_accuracy: 0.6332 - val_loss: 4.1481e-07 - val_binary_accuracy: 0.6308 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 21/70
# 1064/1064 - 38s - loss: 4.1417e-07 - binary_accuracy: 0.6330 - val_loss: 4.1484e-07 - val_binary_accuracy: 0.6308 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 22/70
# 1064/1064 - 38s - loss: 4.1417e-07 - binary_accuracy: 0.6330 - val_loss: 4.1482e-07 - val_binary_accuracy: 0.6307 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 23/70
# 1064/1064 - 38s - loss: 4.1416e-07 - binary_accuracy: 0.6330 - val_loss: 4.1486e-07 - val_binary_accuracy: 0.6310 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 24/70
# 1064/1064 - 38s - loss: 4.1416e-07 - binary_accuracy: 0.6333 - val_loss: 4.1498e-07 - val_binary_accuracy: 0.6316 - lr: 0.1000 - 38s/epoch - 35ms/step
# Epoch 25/70
# 1064/1064 - 38s - loss: 4.1416e-07 - binary_accuracy: 0.6330 - val_loss: 4.1476e-07 - val_binary_accuracy: 0.6314 - lr: 0.1000 - 38s/epoch - 35ms/step
# Epoch 26/70
# 1064/1064 - 38s - loss: 4.1413e-07 - binary_accuracy: 0.6331 - val_loss: 4.1480e-07 - val_binary_accuracy: 0.6313 - lr: 0.1000 - 38s/epoch - 35ms/step
# Epoch 27/70
# 1064/1064 - 38s - loss: 4.1414e-07 - binary_accuracy: 0.6331 - val_loss: 4.1492e-07 - val_binary_accuracy: 0.6309 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 28/70
# 1064/1064 - 37s - loss: 4.1415e-07 - binary_accuracy: 0.6331 - val_loss: 4.1492e-07 - val_binary_accuracy: 0.6312 - lr: 0.1000 - 37s/epoch - 35ms/step
# Epoch 29/70
# 1064/1064 - 37s - loss: 4.1414e-07 - binary_accuracy: 0.6330 - val_loss: 4.1494e-07 - val_binary_accuracy: 0.6309 - lr: 0.1000 - 37s/epoch - 35ms/step
# Epoch 30/70
# 1064/1064 - 37s - loss: 4.1414e-07 - binary_accuracy: 0.6330 - val_loss: 4.1475e-07 - val_binary_accuracy: 0.6307 - lr: 0.1000 - 37s/epoch - 35ms/step
# Epoch 31/70
# 1064/1064 - 37s - loss: 4.1413e-07 - binary_accuracy: 0.6330 - val_loss: 4.1478e-07 - val_binary_accuracy: 0.6314 - lr: 0.1000 - 37s/epoch - 35ms/step
# Epoch 32/70
# 1064/1064 - 37s - loss: 4.1401e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6313 - lr: 0.0010 - 37s/epoch - 35ms/step
# Epoch 33/70
# 1064/1064 - 37s - loss: 4.1399e-07 - binary_accuracy: 0.6333 - val_loss: 4.1468e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 37s/epoch - 35ms/step
# Epoch 34/70
# 1064/1064 - 37s - loss: 4.1399e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6313 - lr: 0.0010 - 37s/epoch - 35ms/step
# Epoch 35/70
# 1064/1064 - 37s - loss: 4.1399e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 37s/epoch - 35ms/step
# Epoch 36/70
# 1064/1064 - 38s - loss: 4.1399e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 38s/epoch - 35ms/step
# Epoch 37/70
# 1064/1064 - 37s - loss: 4.1399e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 37s/epoch - 35ms/step
# Epoch 38/70
# 1064/1064 - 37s - loss: 4.1399e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 37s/epoch - 35ms/step
# Epoch 39/70
# 1064/1064 - 37s - loss: 4.1399e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 37s/epoch - 35ms/step
# Epoch 40/70
# 1064/1064 - 37s - loss: 4.1399e-07 - binary_accuracy: 0.6332 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 37s/epoch - 35ms/step
# Epoch 41/70
# 1064/1064 - 37s - loss: 4.1399e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 37s/epoch - 35ms/step
# Epoch 42/70
# 1064/1064 - 37s - loss: 4.1399e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6313 - lr: 0.0010 - 37s/epoch - 35ms/step
# Epoch 43/70
# 1064/1064 - 37s - loss: 4.1399e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 37s/epoch - 35ms/step
# Epoch 44/70
# 1064/1064 - 38s - loss: 4.1399e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6311 - lr: 0.0010 - 38s/epoch - 35ms/step
# Epoch 45/70
# 1064/1064 - 38s - loss: 4.1399e-07 - binary_accuracy: 0.6332 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 38s/epoch - 35ms/step
# Epoch 46/70
# 1064/1064 - 38s - loss: 4.1398e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6313 - lr: 0.0010 - 38s/epoch - 35ms/step
# Epoch 47/70
# 1064/1064 - 38s - loss: 4.1399e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 38s/epoch - 36ms/step
# Epoch 48/70
# 1064/1064 - 37s - loss: 4.1398e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 37s/epoch - 35ms/step
# Epoch 49/70
# 1064/1064 - 38s - loss: 4.1399e-07 - binary_accuracy: 0.6332 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 38s/epoch - 36ms/step
# Epoch 50/70
# 1064/1064 - 38s - loss: 4.1398e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6313 - lr: 0.0010 - 38s/epoch - 36ms/step
# Epoch 51/70
# 1064/1064 - 38s - loss: 4.1399e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 38s/epoch - 35ms/step
# Epoch 52/70
# 1064/1064 - 37s - loss: 4.1399e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 37s/epoch - 35ms/step
# Epoch 53/70
# 1064/1064 - 38s - loss: 4.1399e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6313 - lr: 0.0010 - 38s/epoch - 36ms/step
# Epoch 54/70
# 1064/1064 - 38s - loss: 4.1398e-07 - binary_accuracy: 0.6332 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 38s/epoch - 35ms/step
# Epoch 55/70
# 1064/1064 - 38s - loss: 4.1398e-07 - binary_accuracy: 0.6332 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6313 - lr: 0.0010 - 38s/epoch - 35ms/step
# Epoch 56/70
# 1064/1064 - 37s - loss: 4.1398e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 37s/epoch - 35ms/step
# Epoch 57/70
# 1064/1064 - 38s - loss: 4.1398e-07 - binary_accuracy: 0.6332 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 38s/epoch - 35ms/step
# Epoch 58/70
# 1064/1064 - 38s - loss: 4.1398e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 38s/epoch - 35ms/step
# Epoch 59/70
# 1064/1064 - 38s - loss: 4.1398e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6313 - lr: 0.0010 - 38s/epoch - 35ms/step
# Epoch 60/70
# 1064/1064 - 37s - loss: 4.1398e-07 - binary_accuracy: 0.6332 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 37s/epoch - 35ms/step
# Epoch 61/70
# 1064/1064 - 37s - loss: 4.1398e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 37s/epoch - 35ms/step
# Epoch 62/70
# 1064/1064 - 37s - loss: 4.1398e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 1.0000e-05 - 37s/epoch - 35ms/step
# Epoch 63/70
# 1064/1064 - 37s - loss: 4.1398e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 1.0000e-05 - 37s/epoch - 35ms/step
# Epoch 64/70
# 1064/1064 - 37s - loss: 4.1398e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 1.0000e-05 - 37s/epoch - 35ms/step
# Epoch 65/70
# 1064/1064 - 37s - loss: 4.1398e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 1.0000e-05 - 37s/epoch - 35ms/step
# Epoch 66/70
# 1064/1064 - 38s - loss: 4.1398e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 1.0000e-05 - 38s/epoch - 36ms/step
# Epoch 67/70
# 1064/1064 - 38s - loss: 4.1398e-07 - binary_accuracy: 0.6333 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 1.0000e-05 - 38s/epoch - 36ms/step
# Epoch 68/70
# 1064/1064 - 38s - loss: 4.1398e-07 - binary_accuracy: 0.6332 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 1.0000e-05 - 38s/epoch - 35ms/step
# Epoch 69/70
# 1064/1064 - 38s - loss: 4.1398e-07 - binary_accuracy: 0.6332 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 1.0000e-05 - 38s/epoch - 35ms/step
# Epoch 70/70
# 1064/1064 - 37s - loss: 4.1398e-07 - binary_accuracy: 0.6332 - val_loss: 4.1469e-07 - val_binary_accuracy: 0.6312 - lr: 1.0000e-05 - 37s/epoch - 35ms/step
# Finished Training
# ./output_model_params/model_scaler.bin
# 3322/3322 - 3s - 3s/epoch - 835us/step
# 16025/16025 - 13s - 13s/epoch - 799us/step
# 13287/13287 - 10s - 10s/epoch - 747us/step
# 64098/64098 - 47s - 47s/epoch - 732us/step
# ttbar training data prediction (max) = 0.8488669
# ttbar training data prediction (min) = 0.17378968
# wjets training data prediction (max) = 0.848941
# wjets training data prediction (min) = 0.17423438
# ttbar training data prediction (max) = 0.84882075
# ttbar training data prediction (min) = 0.17382972
# wjets training data prediction (max) = 0.84890795
# wjets training data prediction (min) = 0.17428666

# %%
NN_training.make_overfit_plots()

# %%
num_bins_cal = 50
NN_training.make_calib_plots(nbins=num_bins_cal, observable='score')

# %%
NN_training.make_calib_plots(nbins=num_bins_cal, observable='llr')

# %%
variables_to_plot=['lepton_pt', 'lepton_phi', 'lepton_eta']
yscale_type='log'
num_bins_plotting=21

NN_training.make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 5
#       2 yscale_type='log'
#       3 num_bins_plotting=21
# ----> 5 NN_training.make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)
#
# File /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/training.py:290, in TrainEvaluate_NN.make_reweighted_plots(self, variables, scale, num_bins)
#     282 def make_reweighted_plots(self, variables, scale, num_bins):
#     284     plot_reweighted(self.train_data_eval, self.label_0_tpred,
#     285                     self.w_train_label_0, self.label_1_tpred, self.w_train_label_1,
#     286                     variables=variables, num=num_bins,
#     287                     sample_name=self.sample_name, scale=scale,
#     288                     path_to_figures=self.path_to_figures)
# --> 290     plot_reweighted(self.holdout_data_eval, self.label_0_hpred, self.w_0_holdout,self.label_1_hpred, self.w_1_holdout,
#     291                     variables=variables, num=num_bins,
#     292                     sample_name=self.sample_name, scale=scale, path_to_figures=self.path_to_figures)
#
# AttributeError: 'TrainEvaluate_NN' object has no attribute 'w_0_holdout'
