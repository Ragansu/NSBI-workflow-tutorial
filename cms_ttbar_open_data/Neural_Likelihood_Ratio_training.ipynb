# %% [markdown]
# Train Neural Networks to estimate Likelihood Ratios
# ===
#
# In this notebook we will setup the neural networks that train unbiased and low-variance density ratios to be then used for inference. The statistical model we have is:
#
# $$p(x|\mu, \alpha) = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot p_c\left(x|\alpha\right)$$

# %%
import os, sys, importlib
sys.path.append('../')

import common_utils
from common_utils import plotting, training
from common_utils.training import TrainEvaluate_NN
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt
hep.style.use(hep.style.ATLAS)
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:10: FutureWarning: ``set_style`` is deprecated: Naming convention is changing to match mpl. Use ``mplhep.style.use()``.
#   hep.set_style("ATLAS")
# 2025-02-09 17:03:24.706195: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-02-09 17:03:25.492694: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Load the datasets from pre-processed input
saved_data='./cached_data/'

training_features = np.load(f"{saved_data}features.npy")
train_labels = np.load(f"{saved_data}train_labels.npy")
preselection_score = np.load(f"{saved_data}preselection_score.npy")
weights = np.load(f"{saved_data}weights.npy")

# %%
# labels_dict = {"ttbar": 0,
#                "single_top_s_chan":1,
#               "single_top_t_chan":2,
#               "single_top_tW":3,
#               "wjets":4}

# Keep only a subset of the background for illustration
labels_dict = {"ttbar": 0,
              "single_top_t_chan":1,
              "wjets":2}

# %%
min_pred = np.amin(preselection_score)
max_pred = np.amax(preselection_score)

bins = np.linspace(min_pred, max_pred, num=150)

hist_NN_output = {}

for key in labels_dict: 
    hist_NN_output[key], _ = np.histogram(preselection_score[train_labels==labels_dict[key]], weights = weights[train_labels==labels_dict[key]], bins=bins)

# %% [markdown]
# Make a selection cut for performing the NSBI analysis, balancing the number of signal events that go into the signal region (increasing sensitivity) and the feasibility of training accurate and precise NNs over a large phase space (need bigger models and more statistics).
#
# As a first cut, we choose a loose preselection and see if it works.

# %%
preselection_cut = -16.5 # Lets start with a very loose cut

for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins=bins, 
             alpha=0.6, label=key, 
             density=True, linewidth=2.0)

plt.xlabel("Preselection Score", size=18)
plt.axvline(preselection_cut, ymax=0.9, linestyle='--', label=f'preselection cut ({preselection_cut})')
plt.ylabel("Density", size=18)
plt.legend()
plt.yscale('log')
plt.show()

# %%
# Make the preselections

training_features = training_features[preselection_score>=preselection_cut].copy()
train_labels = train_labels[preselection_score>=preselection_cut].copy()
weights = weights[preselection_score>=preselection_cut].copy()

preselection_score_selected = preselection_score[preselection_score>=preselection_cut].copy()

# %%
type_vec = np.array(train_labels, dtype='object')

for key in labels_dict:
    type_vec[type_vec==labels_dict[key]] = key

# %%
# Build a pandas dataframe from the arrays for density ratio training and validation
columns = ['lepton_pt', 'lepton_eta', 'lepton_phi']
dataset = pd.DataFrame(training_features, columns=columns)

dataset['log_lepton_pt'] = np.log(dataset['lepton_pt'].ravel())

dataset['presel_score'] = preselection_score_selected
dataset['train_labels'] = train_labels
dataset['type'] = type_vec
dataset['weights'] = weights

# %%
# Normalizing the training weights - only discriminating shapes, not norms

weights_normed = weights.copy()

for key in labels_dict:

    weights_normed[train_labels==labels_dict[key]] /= weights[train_labels==labels_dict[key]].sum()

dataset['weights_normed'] = weights_normed

# %%
# Save the preselected dataframe for inference use later on
dataset.to_hdf(f"{saved_data}dataset_preselected_ttbar.h5", key="dataset", mode='w')

# %%
columns = ['lepton_pt', 'lepton_eta', 'lepton_phi']
columns_scaling = ['lepton_pt', 'lepton_eta', 'lepton_phi']

columns = ['log_lepton_pt', 'lepton_eta', 'lepton_phi']
columns_scaling = ['log_lepton_pt', 'lepton_eta', 'lepton_phi']

# %%
# Choose ttbar as the reference hypothesis
dataset_ch_wjets_ref = pd.concat([dataset[dataset['type']=='wjets'], 
                                  dataset[dataset['type']=='ttbar']])

dataset_ch_wjets_ref['train_labels'] = 0
dataset_ch_wjets_ref.loc[dataset_ch_wjets_ref['type']=='ttbar', 'train_labels'] = 1

# %%
rnd_seed_traintestsplit = 42
channel_names = ['wjets', 'ttbar']

# Save paths
output_dir = './output_general_wjets/'
output_name = 'first_training_wjets'
path_to_ratios = './output_ratios_wjets/'
path_to_figures = './output_figures_wjets/'
path_to_models = './output_model_params_wjets/'

importlib.reload(sys.modules['common_utils.training'])
from common_utils.training import TrainEvaluate_NN

# Initialize the training class
NN_training = TrainEvaluate_NN(dataset_ch_wjets_ref, 
                               dataset_ch_wjets_ref['weights_normed'],
                               dataset_ch_wjets_ref['train_labels'],
                               columns, 
                               columns_scaling, rnd_seed_traintestsplit, 
                               channel_names, output_dir, output_name, 
                                path_to_figures=path_to_figures,
                                path_to_ratios=path_to_ratios, 
                                path_to_models=path_to_models)

# %%
# Train the density ratio NN
NN_training.train(hidden_layers=2, 
                        neurons=1000, 
                        number_of_epochs=70, 
                        batch_size=2096, 
                        learning_rate=0.1, 
                        scalerType='MinMax', 
                        calibration=False, 
                        num_bins_cal = 10, 
                        callback=True, 
                        callback_patience=30, 
                        callback_factor=0.01)
# Out:
# Sum of weights of class 0: 0.8000007526266657
# Sum of weights of class 1: 0.7999985571390978
# Using swish activation function
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_31 (Dense)            (None, 1000)              4000
#
#  dense_32 (Dense)            (None, 1000)              1001000
#
#  dense_33 (Dense)            (None, 1)                 1001
#
# =================================================================
# Total params: 1006001 (3.84 MB)
# Trainable params: 1006001 (3.84 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Using Callbacks
# Epoch 1/70
# 1064/1064 - 42s - loss: 4.4700e-07 - binary_accuracy: 0.5296 - val_loss: 4.4466e-07 - val_binary_accuracy: 0.5482 - lr: 0.1000 - 42s/epoch - 39ms/step
# Epoch 2/70
# 1064/1064 - 40s - loss: 4.2775e-07 - binary_accuracy: 0.6024 - val_loss: 4.1963e-07 - val_binary_accuracy: 0.6273 - lr: 0.1000 - 40s/epoch - 38ms/step
# Epoch 3/70
# 1064/1064 - 39s - loss: 4.1795e-07 - binary_accuracy: 0.6300 - val_loss: 4.1743e-07 - val_binary_accuracy: 0.6291 - lr: 0.1000 - 39s/epoch - 37ms/step
# Epoch 4/70
# 1064/1064 - 40s - loss: 4.1592e-07 - binary_accuracy: 0.6322 - val_loss: 4.1570e-07 - val_binary_accuracy: 0.6307 - lr: 0.1000 - 40s/epoch - 38ms/step
# Epoch 5/70
# 1064/1064 - 40s - loss: 4.1495e-07 - binary_accuracy: 0.6325 - val_loss: 4.1572e-07 - val_binary_accuracy: 0.6301 - lr: 0.1000 - 40s/epoch - 38ms/step
# Epoch 6/70
# 1064/1064 - 41s - loss: 4.1466e-07 - binary_accuracy: 0.6327 - val_loss: 4.1493e-07 - val_binary_accuracy: 0.6312 - lr: 0.1000 - 41s/epoch - 38ms/step
# Epoch 7/70
# 1064/1064 - 40s - loss: 4.1456e-07 - binary_accuracy: 0.6328 - val_loss: 4.1789e-07 - val_binary_accuracy: 0.6282 - lr: 0.1000 - 40s/epoch - 38ms/step
# Epoch 8/70
# 1064/1064 - 41s - loss: 4.1454e-07 - binary_accuracy: 0.6326 - val_loss: 4.1598e-07 - val_binary_accuracy: 0.6303 - lr: 0.1000 - 41s/epoch - 38ms/step
# Epoch 9/70
# 1064/1064 - 40s - loss: 4.1450e-07 - binary_accuracy: 0.6327 - val_loss: 4.1504e-07 - val_binary_accuracy: 0.6310 - lr: 0.1000 - 40s/epoch - 38ms/step
# Epoch 10/70
# 1064/1064 - 40s - loss: 4.1450e-07 - binary_accuracy: 0.6327 - val_loss: 4.1532e-07 - val_binary_accuracy: 0.6302 - lr: 0.1000 - 40s/epoch - 38ms/step
# Epoch 11/70
# 1064/1064 - 40s - loss: 4.1448e-07 - binary_accuracy: 0.6326 - val_loss: 4.1509e-07 - val_binary_accuracy: 0.6314 - lr: 0.1000 - 40s/epoch - 37ms/step
# Epoch 12/70
# 1064/1064 - 39s - loss: 4.1445e-07 - binary_accuracy: 0.6327 - val_loss: 4.1543e-07 - val_binary_accuracy: 0.6304 - lr: 0.1000 - 39s/epoch - 37ms/step
# Epoch 13/70
# 1064/1064 - 39s - loss: 4.1445e-07 - binary_accuracy: 0.6326 - val_loss: 4.1725e-07 - val_binary_accuracy: 0.6297 - lr: 0.1000 - 39s/epoch - 37ms/step
# Epoch 14/70
# 1064/1064 - 40s - loss: 4.1440e-07 - binary_accuracy: 0.6328 - val_loss: 4.1484e-07 - val_binary_accuracy: 0.6310 - lr: 0.1000 - 40s/epoch - 37ms/step
# Epoch 15/70
# 1064/1064 - 40s - loss: 4.1442e-07 - binary_accuracy: 0.6325 - val_loss: 4.1505e-07 - val_binary_accuracy: 0.6309 - lr: 0.1000 - 40s/epoch - 38ms/step
# Epoch 16/70
# 1064/1064 - 40s - loss: 4.1437e-07 - binary_accuracy: 0.6327 - val_loss: 4.1655e-07 - val_binary_accuracy: 0.6288 - lr: 0.1000 - 40s/epoch - 37ms/step
# Epoch 17/70
# 1064/1064 - 40s - loss: 4.1439e-07 - binary_accuracy: 0.6327 - val_loss: 4.1534e-07 - val_binary_accuracy: 0.6305 - lr: 0.1000 - 40s/epoch - 38ms/step
# Epoch 18/70
# 1064/1064 - 40s - loss: 4.1437e-07 - binary_accuracy: 0.6327 - val_loss: 4.1541e-07 - val_binary_accuracy: 0.6306 - lr: 0.1000 - 40s/epoch - 38ms/step
# Epoch 19/70
# 1064/1064 - 40s - loss: 4.1438e-07 - binary_accuracy: 0.6328 - val_loss: 4.1511e-07 - val_binary_accuracy: 0.6313 - lr: 0.1000 - 40s/epoch - 37ms/step
# Epoch 20/70
# 1064/1064 - 40s - loss: 4.1435e-07 - binary_accuracy: 0.6329 - val_loss: 4.1649e-07 - val_binary_accuracy: 0.6295 - lr: 0.1000 - 40s/epoch - 37ms/step
# Epoch 21/70
# 1064/1064 - 40s - loss: 4.1435e-07 - binary_accuracy: 0.6329 - val_loss: 4.1616e-07 - val_binary_accuracy: 0.6289 - lr: 0.1000 - 40s/epoch - 37ms/step
# Epoch 22/70
# 1064/1064 - 39s - loss: 4.1436e-07 - binary_accuracy: 0.6325 - val_loss: 4.1548e-07 - val_binary_accuracy: 0.6306 - lr: 0.1000 - 39s/epoch - 37ms/step
# Epoch 23/70
# 1064/1064 - 40s - loss: 4.1435e-07 - binary_accuracy: 0.6326 - val_loss: 4.1506e-07 - val_binary_accuracy: 0.6312 - lr: 0.1000 - 40s/epoch - 37ms/step
# Epoch 24/70
# 1064/1064 - 40s - loss: 4.1433e-07 - binary_accuracy: 0.6327 - val_loss: 4.1477e-07 - val_binary_accuracy: 0.6312 - lr: 0.1000 - 40s/epoch - 37ms/step
# Epoch 25/70
# 1064/1064 - 40s - loss: 4.1432e-07 - binary_accuracy: 0.6329 - val_loss: 4.1511e-07 - val_binary_accuracy: 0.6307 - lr: 0.1000 - 40s/epoch - 37ms/step
# Epoch 26/70
# 1064/1064 - 40s - loss: 4.1432e-07 - binary_accuracy: 0.6329 - val_loss: 4.1684e-07 - val_binary_accuracy: 0.6284 - lr: 0.1000 - 40s/epoch - 37ms/step
# Epoch 30/70
# 1064/1064 - 40s - loss: 4.1431e-07 - binary_accuracy: 0.6327 - val_loss: 4.1478e-07 - val_binary_accuracy: 0.6316 - lr: 0.1000 - 40s/epoch - 38ms/step
# Epoch 31/70
# 1064/1064 - 40s - loss: 4.1434e-07 - binary_accuracy: 0.6329 - val_loss: 4.1484e-07 - val_binary_accuracy: 0.6313 - lr: 0.1000 - 40s/epoch - 38ms/step
# Epoch 32/70
# 1064/1064 - 40s - loss: 4.1397e-07 - binary_accuracy: 0.6333 - val_loss: 4.1465e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 40s/epoch - 38ms/step
# Epoch 33/70
# 1064/1064 - 40s - loss: 4.1394e-07 - binary_accuracy: 0.6333 - val_loss: 4.1465e-07 - val_binary_accuracy: 0.6313 - lr: 0.0010 - 40s/epoch - 38ms/step
# Epoch 34/70
# 1064/1064 - 40s - loss: 4.1394e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6313 - lr: 0.0010 - 40s/epoch - 37ms/step
# Epoch 35/70
# 1064/1064 - 40s - loss: 4.1394e-07 - binary_accuracy: 0.6334 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6311 - lr: 0.0010 - 40s/epoch - 38ms/step
# Epoch 36/70
# 1064/1064 - 40s - loss: 4.1394e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 40s/epoch - 38ms/step
# Epoch 37/70
# 1064/1064 - 40s - loss: 4.1394e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6314 - lr: 0.0010 - 40s/epoch - 38ms/step
# Epoch 38/70
# 1064/1064 - 40s - loss: 4.1394e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 40s/epoch - 38ms/step
# Epoch 39/70
# 1064/1064 - 41s - loss: 4.1394e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6313 - lr: 0.0010 - 41s/epoch - 38ms/step
# Epoch 40/70
# 1064/1064 - 40s - loss: 4.1394e-07 - binary_accuracy: 0.6333 - val_loss: 4.1465e-07 - val_binary_accuracy: 0.6315 - lr: 0.0010 - 40s/epoch - 38ms/step
# Epoch 41/70
# 1064/1064 - 40s - loss: 4.1394e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6313 - lr: 0.0010 - 40s/epoch - 38ms/step
# Epoch 42/70
# 1064/1064 - 41s - loss: 4.1394e-07 - binary_accuracy: 0.6334 - val_loss: 4.1467e-07 - val_binary_accuracy: 0.6313 - lr: 0.0010 - 41s/epoch - 38ms/step
# Epoch 43/70
# 1064/1064 - 41s - loss: 4.1394e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6313 - lr: 0.0010 - 41s/epoch - 38ms/step
# Epoch 44/70
# 1064/1064 - 40s - loss: 4.1393e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6314 - lr: 0.0010 - 40s/epoch - 38ms/step
# Epoch 45/70
# 1064/1064 - 40s - loss: 4.1393e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6310 - lr: 0.0010 - 40s/epoch - 38ms/step
# Epoch 46/70
# 1064/1064 - 40s - loss: 4.1393e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 40s/epoch - 38ms/step
# Epoch 47/70
# 1064/1064 - 40s - loss: 4.1393e-07 - binary_accuracy: 0.6334 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 40s/epoch - 38ms/step
# Epoch 48/70
# 1064/1064 - 40s - loss: 4.1393e-07 - binary_accuracy: 0.6334 - val_loss: 4.1467e-07 - val_binary_accuracy: 0.6314 - lr: 0.0010 - 40s/epoch - 38ms/step
# Epoch 49/70
# 1064/1064 - 40s - loss: 4.1394e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6314 - lr: 0.0010 - 40s/epoch - 37ms/step
# Epoch 50/70
# 1064/1064 - 40s - loss: 4.1394e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 40s/epoch - 38ms/step
# Epoch 51/70
# 1064/1064 - 40s - loss: 4.1393e-07 - binary_accuracy: 0.6334 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 40s/epoch - 38ms/step
# Epoch 52/70
# 1064/1064 - 40s - loss: 4.1393e-07 - binary_accuracy: 0.6332 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6314 - lr: 0.0010 - 40s/epoch - 37ms/step
# Epoch 53/70
# 1064/1064 - 40s - loss: 4.1393e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6315 - lr: 0.0010 - 40s/epoch - 37ms/step
# Epoch 54/70
# 1064/1064 - 39s - loss: 4.1393e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6315 - lr: 0.0010 - 39s/epoch - 37ms/step
# Epoch 55/70
# 1064/1064 - 40s - loss: 4.1393e-07 - binary_accuracy: 0.6333 - val_loss: 4.1467e-07 - val_binary_accuracy: 0.6314 - lr: 0.0010 - 40s/epoch - 37ms/step
# Epoch 56/70
# 1064/1064 - 39s - loss: 4.1393e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 39s/epoch - 37ms/step
# Epoch 57/70
# 1064/1064 - 40s - loss: 4.1393e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6311 - lr: 0.0010 - 40s/epoch - 37ms/step
# Epoch 58/70
# 1064/1064 - 40s - loss: 4.1393e-07 - binary_accuracy: 0.6334 - val_loss: 4.1468e-07 - val_binary_accuracy: 0.6315 - lr: 0.0010 - 40s/epoch - 37ms/step
# Epoch 59/70
# 1064/1064 - 40s - loss: 4.1393e-07 - binary_accuracy: 0.6333 - val_loss: 4.1465e-07 - val_binary_accuracy: 0.6313 - lr: 0.0010 - 40s/epoch - 37ms/step
# Epoch 60/70
# 1064/1064 - 39s - loss: 4.1393e-07 - binary_accuracy: 0.6332 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6313 - lr: 0.0010 - 39s/epoch - 37ms/step
# Epoch 61/70
# 1064/1064 - 39s - loss: 4.1393e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6312 - lr: 0.0010 - 39s/epoch - 37ms/step
# Epoch 62/70
# 1064/1064 - 40s - loss: 4.1392e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6312 - lr: 1.0000e-05 - 40s/epoch - 38ms/step
# Epoch 63/70
# 1064/1064 - 40s - loss: 4.1392e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6312 - lr: 1.0000e-05 - 40s/epoch - 38ms/step
# Epoch 64/70
# 1064/1064 - 40s - loss: 4.1392e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6312 - lr: 1.0000e-05 - 40s/epoch - 37ms/step
# Epoch 65/70
# 1064/1064 - 40s - loss: 4.1392e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6312 - lr: 1.0000e-05 - 40s/epoch - 38ms/step
# Epoch 66/70
# 1064/1064 - 40s - loss: 4.1392e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6312 - lr: 1.0000e-05 - 40s/epoch - 38ms/step
# Epoch 67/70
# 1064/1064 - 39s - loss: 4.1392e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6312 - lr: 1.0000e-05 - 39s/epoch - 37ms/step
# Epoch 68/70
# 1064/1064 - 39s - loss: 4.1392e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6313 - lr: 1.0000e-05 - 39s/epoch - 37ms/step
# Epoch 69/70
# 1064/1064 - 39s - loss: 4.1392e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6313 - lr: 1.0000e-05 - 39s/epoch - 37ms/step
# Epoch 70/70
# 1064/1064 - 39s - loss: 4.1392e-07 - binary_accuracy: 0.6333 - val_loss: 4.1466e-07 - val_binary_accuracy: 0.6313 - lr: 1.0000e-05 - 39s/epoch - 37ms/step
# Finished Training
# ./output_model_params/model_scaler.bin
# 3322/3322 - 3s - 3s/epoch - 771us/step
# 16025/16025 - 12s - 12s/epoch - 731us/step
# 13287/13287 - 10s - 10s/epoch - 749us/step
# 64098/64098 - 48s - 48s/epoch - 743us/step
# ttbar training data prediction (max) = 0.86004597
# ttbar training data prediction (min) = 0.17496192
# wjets training data prediction (max) = 0.86014795
# wjets training data prediction (min) = 0.17489286
# ttbar training data prediction (max) = 0.8600507
# ttbar training data prediction (min) = 0.17582329
# wjets training data prediction (max) = 0.86013067
# wjets training data prediction (min) = 0.17631122

# %%
NN_training.make_overfit_plots()

# %%
num_bins_cal = 50
NN_training.make_calib_plots(nbins=num_bins_cal, observable='score')
# Out:
# observable not recognized

# %%
NN_training.make_calib_plots(nbins=num_bins_cal, observable='llr')

# %%
variables_to_plot=['lepton_pt', 'lepton_phi', 'lepton_eta']
yscale_type='log'
num_bins_plotting=21

NN_training.make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
NN_training.evaluate_and_save_ratios(dataset)
# Out:
# 110353/110353 - 80s - 80s/epoch - 729us/step

# %%
# Choose ttbar as the reference hypothesis
dataset_ch_single_top_t_chan_ref = pd.concat([dataset[dataset['type']=='single_top_t_chan'], 
                                  dataset[dataset['type']=='ttbar']])

dataset_ch_single_top_t_chan_ref['train_labels'] = 0
dataset_ch_single_top_t_chan_ref.loc[dataset_ch_single_top_t_chan_ref['type']=='ttbar', 'train_labels'] = 1

# %%
rnd_seed_traintestsplit = 42
channel_names = ['single_top_t_chan', 'ttbar']

# Save paths
output_dir = './output_general_singletop/'
output_name = 'first_training_singletop'
path_to_ratios = './output_ratios_singletop/'
path_to_figures = './output_figures_singletop/'
path_to_models = './output_model_params_singletop/'



importlib.reload(sys.modules['common_utils.training'])
from common_utils.training import TrainEvaluate_NN

# Initialize the training class
NN_training = TrainEvaluate_NN(dataset_ch_single_top_t_chan_ref, 
                               dataset_ch_single_top_t_chan_ref['weights_normed'],
                               dataset_ch_single_top_t_chan_ref['train_labels'],
                               columns, 
                               columns_scaling, rnd_seed_traintestsplit, 
                               channel_names, output_dir, output_name, 
                                path_to_figures=path_to_figures,
                                path_to_ratios=path_to_ratios, 
                                path_to_models=path_to_models)

# %%
# Train the density ratio NN
NN_training.train(hidden_layers=2, 
                        neurons=1000, 
                        number_of_epochs=70, 
                        batch_size=2096, 
                        learning_rate=0.1, 
                        scalerType='MinMax', 
                        calibration=False, 
                        num_bins_cal = 10, 
                        callback=True, 
                        callback_patience=30, 
                        callback_factor=0.01)
# Out:
# Sum of weights of class 0: 0.8
# Sum of weights of class 1: 0.7999986595597879
# Using swish activation function
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_28 (Dense)            (None, 1000)              4000
#
#  dense_29 (Dense)            (None, 1000)              1001000
#
#  dense_30 (Dense)            (None, 1)                 1001
#
# =================================================================
# Total params: 1006001 (3.84 MB)
# Trainable params: 1006001 (3.84 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Using Callbacks
# Epoch 1/70
# 1031/1031 - 38s - loss: 4.5890e-07 - binary_accuracy: 0.5347 - val_loss: 4.5812e-07 - val_binary_accuracy: 0.5329 - lr: 0.1000 - 38s/epoch - 37ms/step
# Epoch 2/70
# 1031/1031 - 38s - loss: 4.5844e-07 - binary_accuracy: 0.5367 - val_loss: 4.5741e-07 - val_binary_accuracy: 0.5400 - lr: 0.1000 - 38s/epoch - 37ms/step
# Epoch 3/70
# 1031/1031 - 38s - loss: 4.5768e-07 - binary_accuracy: 0.5409 - val_loss: 4.5702e-07 - val_binary_accuracy: 0.5431 - lr: 0.1000 - 38s/epoch - 37ms/step
# Epoch 4/70
# 1031/1031 - 38s - loss: 4.5751e-07 - binary_accuracy: 0.5418 - val_loss: 4.5694e-07 - val_binary_accuracy: 0.5414 - lr: 0.1000 - 38s/epoch - 37ms/step
# Epoch 5/70
# 1031/1031 - 39s - loss: 4.5738e-07 - binary_accuracy: 0.5419 - val_loss: 4.5700e-07 - val_binary_accuracy: 0.5431 - lr: 0.1000 - 39s/epoch - 37ms/step
# Epoch 6/70
# 1031/1031 - 38s - loss: 4.5717e-07 - binary_accuracy: 0.5423 - val_loss: 4.5643e-07 - val_binary_accuracy: 0.5436 - lr: 0.1000 - 38s/epoch - 37ms/step
# Epoch 7/70
# 1031/1031 - 39s - loss: 4.5687e-07 - binary_accuracy: 0.5430 - val_loss: 4.5672e-07 - val_binary_accuracy: 0.5419 - lr: 0.1000 - 39s/epoch - 37ms/step
# Epoch 8/70
# 1031/1031 - 38s - loss: 4.5683e-07 - binary_accuracy: 0.5431 - val_loss: 4.5636e-07 - val_binary_accuracy: 0.5390 - lr: 0.1000 - 38s/epoch - 37ms/step
# Epoch 9/70
# 1031/1031 - 39s - loss: 4.5680e-07 - binary_accuracy: 0.5433 - val_loss: 4.5626e-07 - val_binary_accuracy: 0.5442 - lr: 0.1000 - 39s/epoch - 37ms/step
# Epoch 10/70
# 1031/1031 - 39s - loss: 4.5681e-07 - binary_accuracy: 0.5430 - val_loss: 4.5651e-07 - val_binary_accuracy: 0.5421 - lr: 0.1000 - 39s/epoch - 38ms/step
# Epoch 11/70
# 1031/1031 - 38s - loss: 4.5679e-07 - binary_accuracy: 0.5432 - val_loss: 4.5627e-07 - val_binary_accuracy: 0.5437 - lr: 0.1000 - 38s/epoch - 37ms/step
# Epoch 12/70
# 1031/1031 - 38s - loss: 4.5676e-07 - binary_accuracy: 0.5432 - val_loss: 4.5647e-07 - val_binary_accuracy: 0.5384 - lr: 0.1000 - 38s/epoch - 37ms/step
# Epoch 13/70
# 1031/1031 - 38s - loss: 4.5675e-07 - binary_accuracy: 0.5431 - val_loss: 4.5626e-07 - val_binary_accuracy: 0.5432 - lr: 0.1000 - 38s/epoch - 37ms/step
# Epoch 14/70
# 1031/1031 - 39s - loss: 4.5674e-07 - binary_accuracy: 0.5430 - val_loss: 4.5626e-07 - val_binary_accuracy: 0.5434 - lr: 0.1000 - 39s/epoch - 38ms/step
# Epoch 15/70
# 1031/1031 - 39s - loss: 4.5673e-07 - binary_accuracy: 0.5431 - val_loss: 4.5622e-07 - val_binary_accuracy: 0.5428 - lr: 0.1000 - 39s/epoch - 38ms/step
# Epoch 16/70
# 1031/1031 - 39s - loss: 4.5672e-07 - binary_accuracy: 0.5434 - val_loss: 4.5640e-07 - val_binary_accuracy: 0.5391 - lr: 0.1000 - 39s/epoch - 38ms/step
# Epoch 17/70
# 1031/1031 - 39s - loss: 4.5671e-07 - binary_accuracy: 0.5434 - val_loss: 4.5619e-07 - val_binary_accuracy: 0.5437 - lr: 0.1000 - 39s/epoch - 38ms/step
# Epoch 18/70
# 1031/1031 - 39s - loss: 4.5670e-07 - binary_accuracy: 0.5433 - val_loss: 4.5619e-07 - val_binary_accuracy: 0.5441 - lr: 0.1000 - 39s/epoch - 38ms/step
# Epoch 19/70
# 1031/1031 - 38s - loss: 4.5668e-07 - binary_accuracy: 0.5433 - val_loss: 4.5617e-07 - val_binary_accuracy: 0.5438 - lr: 0.1000 - 38s/epoch - 37ms/step
# Epoch 20/70
# 1031/1031 - 38s - loss: 4.5668e-07 - binary_accuracy: 0.5433 - val_loss: 4.5615e-07 - val_binary_accuracy: 0.5443 - lr: 0.1000 - 38s/epoch - 37ms/step
# Epoch 21/70
# 1031/1031 - 39s - loss: 4.5666e-07 - binary_accuracy: 0.5432 - val_loss: 4.5622e-07 - val_binary_accuracy: 0.5436 - lr: 0.1000 - 39s/epoch - 38ms/step
# Epoch 22/70
# 1031/1031 - 39s - loss: 4.5666e-07 - binary_accuracy: 0.5433 - val_loss: 4.5666e-07 - val_binary_accuracy: 0.5409 - lr: 0.1000 - 39s/epoch - 37ms/step
# Epoch 23/70
# 1031/1031 - 38s - loss: 4.5664e-07 - binary_accuracy: 0.5436 - val_loss: 4.5616e-07 - val_binary_accuracy: 0.5437 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 24/70
# 1031/1031 - 38s - loss: 4.5663e-07 - binary_accuracy: 0.5435 - val_loss: 4.5613e-07 - val_binary_accuracy: 0.5432 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 25/70
# 1031/1031 - 38s - loss: 4.5662e-07 - binary_accuracy: 0.5436 - val_loss: 4.5625e-07 - val_binary_accuracy: 0.5383 - lr: 0.1000 - 38s/epoch - 36ms/step
# Epoch 26/70
# 1031/1031 - 38s - loss: 4.5661e-07 - binary_accuracy: 0.5438 - val_loss: 4.5610e-07 - val_binary_accuracy: 0.5436 - lr: 0.1000 - 38s/epoch - 37ms/step
# Epoch 27/70
# 1031/1031 - 38s - loss: 4.5661e-07 - binary_accuracy: 0.5432 - val_loss: 4.5609e-07 - val_binary_accuracy: 0.5439 - lr: 0.1000 - 38s/epoch - 37ms/step
# Epoch 28/70
# 1031/1031 - 38s - loss: 4.5658e-07 - binary_accuracy: 0.5435 - val_loss: 4.5605e-07 - val_binary_accuracy: 0.5429 - lr: 0.1000 - 38s/epoch - 37ms/step
# Epoch 29/70
# 1031/1031 - 38s - loss: 4.5658e-07 - binary_accuracy: 0.5439 - val_loss: 4.5609e-07 - val_binary_accuracy: 0.5441 - lr: 0.1000 - 38s/epoch - 37ms/step
# Epoch 30/70
# 1031/1031 - 37s - loss: 4.5657e-07 - binary_accuracy: 0.5435 - val_loss: 4.5604e-07 - val_binary_accuracy: 0.5439 - lr: 0.1000 - 37s/epoch - 36ms/step
# Epoch 31/70
# 1031/1031 - 37s - loss: 4.5655e-07 - binary_accuracy: 0.5434 - val_loss: 4.5603e-07 - val_binary_accuracy: 0.5426 - lr: 0.1000 - 37s/epoch - 36ms/step
# Epoch 32/70
# 1031/1031 - 37s - loss: 4.5650e-07 - binary_accuracy: 0.5439 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5443 - lr: 0.0010 - 37s/epoch - 36ms/step
# Epoch 33/70
# 1031/1031 - 37s - loss: 4.5648e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5442 - lr: 0.0010 - 37s/epoch - 36ms/step
# Epoch 34/70
# 1031/1031 - 37s - loss: 4.5647e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5441 - lr: 0.0010 - 37s/epoch - 36ms/step
# Epoch 35/70
# 1031/1031 - 37s - loss: 4.5647e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5440 - lr: 0.0010 - 37s/epoch - 36ms/step
# Epoch 36/70
# 1031/1031 - 37s - loss: 4.5647e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5443 - lr: 0.0010 - 37s/epoch - 36ms/step
# Epoch 37/70
# 1031/1031 - 37s - loss: 4.5647e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5444 - lr: 0.0010 - 37s/epoch - 36ms/step
# Epoch 38/70
# 1031/1031 - 37s - loss: 4.5647e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5441 - lr: 0.0010 - 37s/epoch - 36ms/step
# Epoch 39/70
# 1031/1031 - 38s - loss: 4.5647e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5441 - lr: 0.0010 - 38s/epoch - 37ms/step
# Epoch 40/70
# 1031/1031 - 37s - loss: 4.5647e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5442 - lr: 0.0010 - 37s/epoch - 36ms/step
# Epoch 41/70
# 1031/1031 - 38s - loss: 4.5647e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5443 - lr: 0.0010 - 38s/epoch - 37ms/step
# Epoch 42/70
# 1031/1031 - 38s - loss: 4.5647e-07 - binary_accuracy: 0.5439 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5441 - lr: 0.0010 - 38s/epoch - 36ms/step
# Epoch 43/70
# 1031/1031 - 38s - loss: 4.5647e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5441 - lr: 0.0010 - 38s/epoch - 37ms/step
# Epoch 44/70
# 1031/1031 - 38s - loss: 4.5647e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5443 - lr: 0.0010 - 38s/epoch - 37ms/step
# Epoch 45/70
# 1031/1031 - 38s - loss: 4.5647e-07 - binary_accuracy: 0.5439 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5442 - lr: 0.0010 - 38s/epoch - 37ms/step
# Epoch 46/70
# 1031/1031 - 37s - loss: 4.5646e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5442 - lr: 0.0010 - 37s/epoch - 36ms/step
# Epoch 47/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5443 - lr: 0.0010 - 38s/epoch - 37ms/step
# Epoch 48/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5439 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5442 - lr: 0.0010 - 38s/epoch - 36ms/step
# Epoch 49/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5439 - lr: 0.0010 - 38s/epoch - 37ms/step
# Epoch 50/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5443 - lr: 0.0010 - 38s/epoch - 36ms/step
# Epoch 51/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5439 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5442 - lr: 0.0010 - 38s/epoch - 36ms/step
# Epoch 52/70
# 1031/1031 - 37s - loss: 4.5646e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5441 - lr: 0.0010 - 37s/epoch - 36ms/step
# Epoch 53/70
# 1031/1031 - 37s - loss: 4.5646e-07 - binary_accuracy: 0.5439 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5442 - lr: 0.0010 - 37s/epoch - 36ms/step
# Epoch 54/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5441 - lr: 0.0010 - 38s/epoch - 37ms/step
# Epoch 55/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5439 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5441 - lr: 0.0010 - 38s/epoch - 37ms/step
# Epoch 56/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5439 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5441 - lr: 0.0010 - 38s/epoch - 37ms/step
# Epoch 57/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5443 - lr: 0.0010 - 38s/epoch - 37ms/step
# Epoch 58/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5440 - val_loss: 4.5596e-07 - val_binary_accuracy: 0.5442 - lr: 0.0010 - 38s/epoch - 37ms/step
# Epoch 59/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5440 - val_loss: 4.5596e-07 - val_binary_accuracy: 0.5443 - lr: 0.0010 - 38s/epoch - 37ms/step
# Epoch 60/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5439 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5439 - lr: 0.0010 - 38s/epoch - 37ms/step
# Epoch 61/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5439 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5442 - lr: 0.0010 - 38s/epoch - 37ms/step
# Epoch 62/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5441 - lr: 1.0000e-05 - 38s/epoch - 37ms/step
# Epoch 63/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5441 - lr: 1.0000e-05 - 38s/epoch - 37ms/step
# Epoch 64/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5441 - lr: 1.0000e-05 - 38s/epoch - 37ms/step
# Epoch 65/70
# 1031/1031 - 39s - loss: 4.5646e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5441 - lr: 1.0000e-05 - 39s/epoch - 37ms/step
# Epoch 66/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5441 - lr: 1.0000e-05 - 38s/epoch - 37ms/step
# Epoch 67/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5441 - lr: 1.0000e-05 - 38s/epoch - 37ms/step
# Epoch 68/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5441 - lr: 1.0000e-05 - 38s/epoch - 37ms/step
# Epoch 69/70
# 1031/1031 - 38s - loss: 4.5646e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5441 - lr: 1.0000e-05 - 38s/epoch - 36ms/step
# Epoch 70/70
# 1031/1031 - 37s - loss: 4.5646e-07 - binary_accuracy: 0.5440 - val_loss: 4.5597e-07 - val_binary_accuracy: 0.5441 - lr: 1.0000e-05 - 37s/epoch - 36ms/step
# Finished Training
# ./output_model_params_singletop/model_scaler.bin
# 2725/2725 - 2s - 2s/epoch - 764us/step
# 16025/16025 - 12s - 12s/epoch - 737us/step
# 10898/10898 - 8s - 8s/epoch - 743us/step
# 64098/64098 - 47s - 47s/epoch - 741us/step
# ttbar training data prediction (max) = 0.87017566
# ttbar training data prediction (min) = 0.3935488
# single_top_t_chan training data prediction (max) = 0.86999136
# single_top_t_chan training data prediction (min) = 0.3934948
# ttbar training data prediction (max) = 0.8665903
# ttbar training data prediction (min) = 0.39382154
# single_top_t_chan training data prediction (max) = 0.86899453
# single_top_t_chan training data prediction (min) = 0.39369223

# %%
NN_training.make_overfit_plots()

# %%
num_bins_cal = 50
NN_training.make_calib_plots(nbins=num_bins_cal, observable='score')
# Out:
# observable not recognized

# %%
NN_training.make_calib_plots(nbins=num_bins_cal, observable='llr')

# %%
variables_to_plot=['lepton_pt', 'lepton_phi', 'lepton_eta']
yscale_type='log'
num_bins_plotting=21

NN_training.make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
importlib.reload(sys.modules['common_utils.training'])
from common_utils.training import TrainEvaluate_NN
import types

NN_training.make_reweighted_plots = types.MethodType(TrainEvaluate_NN.make_reweighted_plots, NN_training)
NN_training.make_calib_plots = types.MethodType(TrainEvaluate_NN.make_calib_plots, NN_training)
NN_training.evaluate_and_save_ratios = types.MethodType(TrainEvaluate_NN.evaluate_and_save_ratios, NN_training)

# %%
NN_training.evaluate_and_save_ratios(dataset)
# Out:
# 110353/110353 - 80s - 80s/epoch - 725us/step
