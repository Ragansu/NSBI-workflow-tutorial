# %% [markdown]
# Train Neural Networks to estimate Likelihood Ratios
# ===
#
# In this notebook we will setup the neural networks that train unbiased and low-variance density ratios to be then used for inference. The statistical model we have is:
#
# $$p(x|\mu, \alpha) = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot p_c\left(x|\alpha\right)$$

# %%
import os, sys, importlib
sys.path.append('../')

import common_utils
from common_utils import plotting, training
from common_utils.training import TrainEvaluate_NN
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt
hep.style.use(hep.style.ATLAS)

# %%
# Load the datasets from pre-processed input
saved_data='./cached_data/'

training_features = np.load(f"{saved_data}features.npy")
train_labels = np.load(f"{saved_data}train_labels.npy")
preselection_score = np.load(f"{saved_data}preselection_score.npy")
weights = np.load(f"{saved_data}weights.npy")

# %%
# labels_dict = {"ttbar": 0,
#                "single_top_s_chan":1,
#               "single_top_t_chan":2,
#               "single_top_tW":3,
#               "wjets":4}

# Keep only a subset of the background for illustration
labels_dict = {"ttbar": 0,
              "single_top_t_chan":1,
              "wjets":2}

# %%
min_pred = np.amin(preselection_score)
max_pred = np.amax(preselection_score)

bins = np.linspace(min_pred, max_pred, num=150)

hist_NN_output = {}

for key in labels_dict: 
    hist_NN_output[key], _ = np.histogram(preselection_score[train_labels==labels_dict[key]], weights = weights[train_labels==labels_dict[key]], bins=bins)

# %% [markdown]
# Make a selection cut for performing the NSBI analysis, balancing the number of signal events that go into the signal region (increasing sensitivity) and the feasibility of training accurate and precise NNs over a large phase space (need bigger models and more statistics).
#
# As a first cut, we choose a loose preselection and see if it works.

# %%
preselection_cut = -20.1 # Lets start with a very loose cut

for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins=bins, 
             alpha=0.6, label=key, 
             density=True, linewidth=2.0)

plt.xlabel("Preselection Score", size=18)
plt.axvline(preselection_cut, ymax=0.9, linestyle='--', label=f'preselection cut ({preselection_cut})')
plt.ylabel("Density", size=18)
plt.legend()
plt.yscale('log')
plt.show()

# %%
# Make the preselections

training_features = training_features[preselection_score>=preselection_cut].copy()
train_labels = train_labels[preselection_score>=preselection_cut].copy()
weights = weights[preselection_score>=preselection_cut].copy()

preselection_score_selected = preselection_score[preselection_score>=preselection_cut].copy()

# %%
type_vec = np.array(train_labels, dtype='object')

for key in labels_dict:
    type_vec[type_vec==labels_dict[key]] = key

# %%
# Build a pandas dataframe from the arrays for density ratio training and validation
columns = ['lepton_pt', 'lepton_eta', 'lepton_phi', 'H_T']
dataset = pd.DataFrame(training_features, columns=columns)

dataset['log_lepton_pt'] = np.log(dataset['lepton_pt'].ravel())

dataset['presel_score'] = preselection_score_selected
dataset['train_labels'] = train_labels
dataset['type'] = type_vec
dataset['weights'] = weights

# %%
# Normalizing the training weights - only discriminating shapes, not norms

weights_normed = weights.copy()

for key in labels_dict:

    weights_normed[train_labels==labels_dict[key]] /= weights[train_labels==labels_dict[key]].sum()

dataset['weights_normed'] = weights_normed

# %%
# Save the preselected dataframe for inference use later on
dataset.to_hdf(f"{saved_data}dataset_preselected_ttbar.h5", key="dataset", mode='w')

# %%
columns = ['lepton_pt', 'lepton_eta', 'lepton_phi']
columns_scaling = ['lepton_pt', 'lepton_eta', 'lepton_phi']

columns = ['log_lepton_pt', 'lepton_eta', 'lepton_phi']
columns_scaling = ['log_lepton_pt', 'lepton_eta', 'lepton_phi']

# %%
# Choose ttbar as the reference hypothesis
dataset_ch_wjets_ref = pd.concat([dataset[dataset['type']=='wjets'], 
                                  dataset[dataset['type']=='ttbar']])

dataset_ch_wjets_ref['train_labels'] = 0
dataset_ch_wjets_ref.loc[dataset_ch_wjets_ref['type']=='ttbar', 'train_labels'] = 1

# %%
NN_training_channels_dict = {}

# %%
rnd_seed_traintestsplit = 42
channel_names = ['wjets', 'ttbar']

# Save paths
output_dir = './output_general_wjets/'
output_name = 'first_training_wjets'
path_to_ratios = './output_ratios_wjets/'
path_to_figures = './output_figures_wjets/'
path_to_models = './output_model_params_wjets/'

importlib.reload(sys.modules['common_utils.training'])
from common_utils.training import TrainEvaluate_NN

# Initialize the training class
NN_training_channels_dict['wjets'] = TrainEvaluate_NN(dataset_ch_wjets_ref, 
                                                       dataset_ch_wjets_ref['weights_normed'],
                                                       dataset_ch_wjets_ref['train_labels'],
                                                       columns, 
                                                       columns_scaling, rnd_seed_traintestsplit, 
                                                       channel_names, output_dir, output_name, 
                                                        path_to_figures=path_to_figures,
                                                        path_to_ratios=path_to_ratios, 
                                                        path_to_models=path_to_models)

# %%
# Train the density ratio NN
NN_training_channels_dict['wjets'].train(hidden_layers=2, 
                        neurons=1000, 
                        number_of_epochs=50, 
                        batch_size=512, 
                        learning_rate=0.1, 
                        scalerType='MinMax', 
                        calibration=False, 
                        num_bins_cal = 10, 
                        callback=True, 
                        callback_patience=30, 
                        callback_factor=0.01)
# Out:
# Sum of weights of class 0: 0.8000011719825841
# Sum of weights of class 1: 0.7999958746059221
# Using swish activation function
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 1000)              4000
#
#  dense_13 (Dense)            (None, 1000)              1001000
#
#  dense_14 (Dense)            (None, 1)                 1001
#
# =================================================================
# Total params: 1006001 (3.84 MB)
# Trainable params: 1006001 (3.84 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Using Callbacks
# Epoch 1/50
# 4086/4086 - 125s - loss: 4.6289e-07 - binary_accuracy: 0.5792 - val_loss: 4.5233e-07 - val_binary_accuracy: 0.6123 - lr: 0.1000 - 125s/epoch - 31ms/step
# Epoch 2/50
# 4086/4086 - 121s - loss: 4.5169e-07 - binary_accuracy: 0.6107 - val_loss: 4.5148e-07 - val_binary_accuracy: 0.6126 - lr: 0.1000 - 121s/epoch - 30ms/step
# Epoch 3/50
# 4086/4086 - 121s - loss: 4.5145e-07 - binary_accuracy: 0.6108 - val_loss: 4.5096e-07 - val_binary_accuracy: 0.6130 - lr: 0.1000 - 121s/epoch - 30ms/step
# Epoch 4/50
# 4086/4086 - 119s - loss: 4.5141e-07 - binary_accuracy: 0.6109 - val_loss: 4.5103e-07 - val_binary_accuracy: 0.6130 - lr: 0.1000 - 119s/epoch - 29ms/step
# Epoch 5/50
# 4086/4086 - 119s - loss: 4.5139e-07 - binary_accuracy: 0.6111 - val_loss: 4.5119e-07 - val_binary_accuracy: 0.6128 - lr: 0.1000 - 119s/epoch - 29ms/step
# Epoch 6/50
# 4086/4086 - 119s - loss: 4.5135e-07 - binary_accuracy: 0.6112 - val_loss: 4.5193e-07 - val_binary_accuracy: 0.6118 - lr: 0.1000 - 119s/epoch - 29ms/step
# Epoch 7/50
# 4086/4086 - 119s - loss: 4.5133e-07 - binary_accuracy: 0.6109 - val_loss: 4.5164e-07 - val_binary_accuracy: 0.6105 - lr: 0.1000 - 119s/epoch - 29ms/step
# Epoch 8/50
# 4086/4086 - 117s - loss: 4.5130e-07 - binary_accuracy: 0.6113 - val_loss: 4.5119e-07 - val_binary_accuracy: 0.6130 - lr: 0.1000 - 117s/epoch - 29ms/step
# Epoch 9/50
# 4086/4086 - 115s - loss: 4.5126e-07 - binary_accuracy: 0.6116 - val_loss: 4.5122e-07 - val_binary_accuracy: 0.6132 - lr: 0.1000 - 115s/epoch - 28ms/step
# Epoch 10/50
# 4086/4086 - 115s - loss: 4.5129e-07 - binary_accuracy: 0.6112 - val_loss: 4.5113e-07 - val_binary_accuracy: 0.6126 - lr: 0.1000 - 115s/epoch - 28ms/step
# Epoch 11/50
# 4086/4086 - 114s - loss: 4.5124e-07 - binary_accuracy: 0.6112 - val_loss: 4.5149e-07 - val_binary_accuracy: 0.6122 - lr: 0.1000 - 114s/epoch - 28ms/step
# Epoch 12/50
# 4086/4086 - 117s - loss: 4.5123e-07 - binary_accuracy: 0.6112 - val_loss: 4.5113e-07 - val_binary_accuracy: 0.6125 - lr: 0.1000 - 117s/epoch - 29ms/step
# Epoch 13/50
# 4086/4086 - 114s - loss: 4.5121e-07 - binary_accuracy: 0.6112 - val_loss: 4.5112e-07 - val_binary_accuracy: 0.6132 - lr: 0.1000 - 114s/epoch - 28ms/step
# Epoch 14/50
# 4086/4086 - 120s - loss: 4.5120e-07 - binary_accuracy: 0.6115 - val_loss: 4.5096e-07 - val_binary_accuracy: 0.6136 - lr: 0.1000 - 120s/epoch - 29ms/step
# Epoch 15/50
# 4086/4086 - 118s - loss: 4.5118e-07 - binary_accuracy: 0.6110 - val_loss: 4.5117e-07 - val_binary_accuracy: 0.6124 - lr: 0.1000 - 118s/epoch - 29ms/step
# Epoch 16/50
# 4086/4086 - 116s - loss: 4.5120e-07 - binary_accuracy: 0.6114 - val_loss: 4.5207e-07 - val_binary_accuracy: 0.6120 - lr: 0.1000 - 116s/epoch - 28ms/step
# Epoch 17/50
# 4086/4086 - 115s - loss: 4.5120e-07 - binary_accuracy: 0.6113 - val_loss: 4.5179e-07 - val_binary_accuracy: 0.6113 - lr: 0.1000 - 115s/epoch - 28ms/step
# Epoch 18/50
# 4086/4086 - 118s - loss: 4.5115e-07 - binary_accuracy: 0.6115 - val_loss: 4.5106e-07 - val_binary_accuracy: 0.6124 - lr: 0.1000 - 118s/epoch - 29ms/step
# Epoch 19/50
# 4086/4086 - 119s - loss: 4.5117e-07 - binary_accuracy: 0.6112 - val_loss: 4.5096e-07 - val_binary_accuracy: 0.6136 - lr: 0.1000 - 119s/epoch - 29ms/step
# Epoch 20/50
# 4086/4086 - 120s - loss: 4.5115e-07 - binary_accuracy: 0.6113 - val_loss: 4.5110e-07 - val_binary_accuracy: 0.6125 - lr: 0.1000 - 120s/epoch - 29ms/step
# Epoch 21/50
# 4086/4086 - 120s - loss: 4.5114e-07 - binary_accuracy: 0.6116 - val_loss: 4.5139e-07 - val_binary_accuracy: 0.6116 - lr: 0.1000 - 120s/epoch - 29ms/step
# Epoch 22/50
# 4086/4086 - 119s - loss: 4.5115e-07 - binary_accuracy: 0.6113 - val_loss: 4.5201e-07 - val_binary_accuracy: 0.6109 - lr: 0.1000 - 119s/epoch - 29ms/step
# Epoch 23/50
# 4086/4086 - 119s - loss: 4.5116e-07 - binary_accuracy: 0.6113 - val_loss: 4.5092e-07 - val_binary_accuracy: 0.6135 - lr: 0.1000 - 119s/epoch - 29ms/step
# Epoch 24/50
# 4086/4086 - 119s - loss: 4.5113e-07 - binary_accuracy: 0.6115 - val_loss: 4.5096e-07 - val_binary_accuracy: 0.6134 - lr: 0.1000 - 119s/epoch - 29ms/step
# Epoch 25/50
# 4086/4086 - 118s - loss: 4.5113e-07 - binary_accuracy: 0.6113 - val_loss: 4.5084e-07 - val_binary_accuracy: 0.6135 - lr: 0.1000 - 118s/epoch - 29ms/step
# Epoch 26/50
# 4086/4086 - 120s - loss: 4.5112e-07 - binary_accuracy: 0.6112 - val_loss: 4.5139e-07 - val_binary_accuracy: 0.6125 - lr: 0.1000 - 120s/epoch - 29ms/step
# Epoch 27/50
# 4086/4086 - 125s - loss: 4.5114e-07 - binary_accuracy: 0.6111 - val_loss: 4.5115e-07 - val_binary_accuracy: 0.6131 - lr: 0.1000 - 125s/epoch - 30ms/step
# Epoch 28/50
# 4086/4086 - 122s - loss: 4.5111e-07 - binary_accuracy: 0.6115 - val_loss: 4.5082e-07 - val_binary_accuracy: 0.6140 - lr: 0.1000 - 122s/epoch - 30ms/step
# Epoch 29/50
# 4086/4086 - 123s - loss: 4.5114e-07 - binary_accuracy: 0.6113 - val_loss: 4.5134e-07 - val_binary_accuracy: 0.6120 - lr: 0.1000 - 123s/epoch - 30ms/step
# Epoch 30/50
# 4086/4086 - 121s - loss: 4.5110e-07 - binary_accuracy: 0.6114 - val_loss: 4.5111e-07 - val_binary_accuracy: 0.6129 - lr: 0.1000 - 121s/epoch - 30ms/step
# Epoch 31/50
# 4086/4086 - 123s - loss: 4.5110e-07 - binary_accuracy: 0.6112 - val_loss: 4.5097e-07 - val_binary_accuracy: 0.6139 - lr: 0.1000 - 123s/epoch - 30ms/step
# Epoch 32/50
# 4086/4086 - 123s - loss: 4.5081e-07 - binary_accuracy: 0.6120 - val_loss: 4.5072e-07 - val_binary_accuracy: 0.6139 - lr: 0.0010 - 123s/epoch - 30ms/step
# Epoch 33/50
# 4086/4086 - 123s - loss: 4.5072e-07 - binary_accuracy: 0.6120 - val_loss: 4.5070e-07 - val_binary_accuracy: 0.6138 - lr: 0.0010 - 123s/epoch - 30ms/step
# Epoch 34/50
# 4086/4086 - 125s - loss: 4.5070e-07 - binary_accuracy: 0.6120 - val_loss: 4.5070e-07 - val_binary_accuracy: 0.6137 - lr: 0.0010 - 125s/epoch - 31ms/step
# Epoch 35/50
# 4086/4086 - 127s - loss: 4.5070e-07 - binary_accuracy: 0.6119 - val_loss: 4.5069e-07 - val_binary_accuracy: 0.6137 - lr: 0.0010 - 127s/epoch - 31ms/step
# Epoch 36/50
# 4086/4086 - 129s - loss: 4.5069e-07 - binary_accuracy: 0.6119 - val_loss: 4.5069e-07 - val_binary_accuracy: 0.6137 - lr: 0.0010 - 129s/epoch - 32ms/step
# Epoch 37/50
# 4086/4086 - 128s - loss: 4.5069e-07 - binary_accuracy: 0.6119 - val_loss: 4.5068e-07 - val_binary_accuracy: 0.6137 - lr: 0.0010 - 128s/epoch - 31ms/step
# Epoch 38/50
# 4086/4086 - 127s - loss: 4.5069e-07 - binary_accuracy: 0.6119 - val_loss: 4.5069e-07 - val_binary_accuracy: 0.6137 - lr: 0.0010 - 127s/epoch - 31ms/step
# Epoch 39/50
# 4086/4086 - 126s - loss: 4.5069e-07 - binary_accuracy: 0.6119 - val_loss: 4.5069e-07 - val_binary_accuracy: 0.6137 - lr: 0.0010 - 126s/epoch - 31ms/step
# Epoch 40/50
# 4086/4086 - 124s - loss: 4.5069e-07 - binary_accuracy: 0.6118 - val_loss: 4.5069e-07 - val_binary_accuracy: 0.6135 - lr: 0.0010 - 124s/epoch - 30ms/step
# Epoch 41/50
# 4086/4086 - 124s - loss: 4.5069e-07 - binary_accuracy: 0.6119 - val_loss: 4.5069e-07 - val_binary_accuracy: 0.6135 - lr: 0.0010 - 124s/epoch - 30ms/step
# Epoch 42/50
# 4086/4086 - 124s - loss: 4.5069e-07 - binary_accuracy: 0.6119 - val_loss: 4.5069e-07 - val_binary_accuracy: 0.6137 - lr: 0.0010 - 124s/epoch - 30ms/step
# Epoch 43/50
# 4086/4086 - 124s - loss: 4.5068e-07 - binary_accuracy: 0.6120 - val_loss: 4.5068e-07 - val_binary_accuracy: 0.6136 - lr: 0.0010 - 124s/epoch - 30ms/step
# Epoch 44/50
# 4086/4086 - 125s - loss: 4.5069e-07 - binary_accuracy: 0.6119 - val_loss: 4.5068e-07 - val_binary_accuracy: 0.6137 - lr: 0.0010 - 125s/epoch - 31ms/step
# Epoch 45/50
# 4086/4086 - 126s - loss: 4.5069e-07 - binary_accuracy: 0.6119 - val_loss: 4.5068e-07 - val_binary_accuracy: 0.6137 - lr: 0.0010 - 126s/epoch - 31ms/step
# Epoch 46/50
# 4086/4086 - 125s - loss: 4.5068e-07 - binary_accuracy: 0.6119 - val_loss: 4.5069e-07 - val_binary_accuracy: 0.6136 - lr: 0.0010 - 125s/epoch - 31ms/step
# Epoch 47/50
# 4086/4086 - 126s - loss: 4.5069e-07 - binary_accuracy: 0.6118 - val_loss: 4.5069e-07 - val_binary_accuracy: 0.6137 - lr: 0.0010 - 126s/epoch - 31ms/step
# Epoch 48/50
# 4086/4086 - 127s - loss: 4.5069e-07 - binary_accuracy: 0.6120 - val_loss: 4.5068e-07 - val_binary_accuracy: 0.6138 - lr: 0.0010 - 127s/epoch - 31ms/step
# Epoch 49/50
# 4086/4086 - 125s - loss: 4.5069e-07 - binary_accuracy: 0.6119 - val_loss: 4.5069e-07 - val_binary_accuracy: 0.6138 - lr: 0.0010 - 125s/epoch - 31ms/step
# Epoch 50/50
# 4086/4086 - 126s - loss: 4.5068e-07 - binary_accuracy: 0.6119 - val_loss: 4.5069e-07 - val_binary_accuracy: 0.6136 - lr: 0.0010 - 126s/epoch - 31ms/step
# Finished Training
# ./output_model_params_wjets/model_scaler.bin
# 2134/2134 - 2s - 2s/epoch - 1ms/step
# 16026/16026 - 13s - 13s/epoch - 796us/step
# 8533/8533 - 7s - 7s/epoch - 829us/step
# 64102/64102 - 50s - 50s/epoch - 777us/step
# ttbar training data prediction (max) = 0.8065508
# ttbar training data prediction (min) = 0.17967784
# wjets training data prediction (max) = 0.8069022
# wjets training data prediction (min) = 0.17896076
# ttbar training data prediction (max) = 0.806039
# ttbar training data prediction (min) = 0.18041562
# wjets training data prediction (max) = 0.80690473
# wjets training data prediction (min) = 0.17906642

# %%
NN_training_channels_dict['wjets'].make_overfit_plots()

# %%
num_bins_cal = 50
NN_training_channels_dict['wjets'].make_calib_plots(nbins=num_bins_cal, observable='score')
# Out:
# observable not recognized

# %%
NN_training_channels_dict['wjets'].make_calib_plots(nbins=num_bins_cal, observable='llr')

# %%
variables_to_plot=['lepton_pt', 'lepton_phi', 'lepton_eta']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['wjets'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
NN_training_channels_dict['wjets'].evaluate_and_save_ratios(dataset)
# Out:
# 104270/104270 - 81s - 81s/epoch - 779us/step

# %%
# Choose ttbar as the reference hypothesis
dataset_ch_single_top_t_chan_ref = pd.concat([dataset[dataset['type']=='single_top_t_chan'], 
                                  dataset[dataset['type']=='ttbar']])

dataset_ch_single_top_t_chan_ref['train_labels'] = 0
dataset_ch_single_top_t_chan_ref.loc[dataset_ch_single_top_t_chan_ref['type']=='ttbar', 'train_labels'] = 1

# %%
rnd_seed_traintestsplit = 42
channel_names = ['single_top_t_chan', 'ttbar']

# Save paths
output_dir = './output_general_singletop/'
output_name = 'first_training_singletop'
path_to_ratios = './output_ratios_singletop/'
path_to_figures = './output_figures_singletop/'
path_to_models = './output_model_params_singletop/'



importlib.reload(sys.modules['common_utils.training'])
from common_utils.training import TrainEvaluate_NN

# Initialize the training class
NN_training_channels_dict['singletop'] = TrainEvaluate_NN(dataset_ch_single_top_t_chan_ref, 
                               dataset_ch_single_top_t_chan_ref['weights_normed'],
                               dataset_ch_single_top_t_chan_ref['train_labels'],
                               columns, 
                               columns_scaling, rnd_seed_traintestsplit, 
                               channel_names, output_dir, output_name, 
                                path_to_figures=path_to_figures,
                                path_to_ratios=path_to_ratios, 
                                path_to_models=path_to_models)

# %%
# Train the density ratio NN
NN_training_channels_dict['singletop'].train(hidden_layers=2, 
                        neurons=1000, 
                        number_of_epochs=50, 
                        batch_size=512, 
                        learning_rate=0.1, 
                        scalerType='MinMax', 
                        calibration=False, 
                        num_bins_cal = 10, 
                        callback=True, 
                        callback_patience=30, 
                        callback_factor=0.01)
# Out:
# Sum of weights of class 0: 0.8000004637777945
# Sum of weights of class 1: 0.800001380821888
# Using swish activation function
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 1000)              4000
#
#  dense_16 (Dense)            (None, 1000)              1001000
#
#  dense_17 (Dense)            (None, 1)                 1001
#
# =================================================================
# Total params: 1006001 (3.84 MB)
# Trainable params: 1006001 (3.84 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Using Callbacks
# Epoch 1/50
# 4213/4213 - 125s - loss: 4.5932e-07 - binary_accuracy: 0.5357 - val_loss: 4.5780e-07 - val_binary_accuracy: 0.5398 - lr: 0.1000 - 125s/epoch - 30ms/step
# Epoch 2/50
# 4213/4213 - 123s - loss: 4.5833e-07 - binary_accuracy: 0.5411 - val_loss: 4.5719e-07 - val_binary_accuracy: 0.5419 - lr: 0.1000 - 123s/epoch - 29ms/step
# Epoch 3/50
# 4213/4213 - 123s - loss: 4.5779e-07 - binary_accuracy: 0.5421 - val_loss: 4.5724e-07 - val_binary_accuracy: 0.5376 - lr: 0.1000 - 123s/epoch - 29ms/step
# Epoch 4/50
# 4213/4213 - 122s - loss: 4.5771e-07 - binary_accuracy: 0.5420 - val_loss: 4.5701e-07 - val_binary_accuracy: 0.5415 - lr: 0.1000 - 122s/epoch - 29ms/step
# Epoch 5/50
# 4213/4213 - 120s - loss: 4.5765e-07 - binary_accuracy: 0.5421 - val_loss: 4.5731e-07 - val_binary_accuracy: 0.5403 - lr: 0.1000 - 120s/epoch - 29ms/step
# Epoch 6/50
# 4213/4213 - 120s - loss: 4.5762e-07 - binary_accuracy: 0.5425 - val_loss: 4.5687e-07 - val_binary_accuracy: 0.5418 - lr: 0.1000 - 120s/epoch - 29ms/step
# Epoch 7/50
# 4213/4213 - 119s - loss: 4.5759e-07 - binary_accuracy: 0.5426 - val_loss: 4.5694e-07 - val_binary_accuracy: 0.5409 - lr: 0.1000 - 119s/epoch - 28ms/step
# Epoch 8/50
# 4213/4213 - 120s - loss: 4.5757e-07 - binary_accuracy: 0.5424 - val_loss: 4.5682e-07 - val_binary_accuracy: 0.5416 - lr: 0.1000 - 120s/epoch - 28ms/step
# Epoch 9/50
# 4213/4213 - 120s - loss: 4.5755e-07 - binary_accuracy: 0.5423 - val_loss: 4.5686e-07 - val_binary_accuracy: 0.5415 - lr: 0.1000 - 120s/epoch - 28ms/step
# Epoch 10/50
# 4213/4213 - 120s - loss: 4.5753e-07 - binary_accuracy: 0.5425 - val_loss: 4.5688e-07 - val_binary_accuracy: 0.5427 - lr: 0.1000 - 120s/epoch - 28ms/step
# Epoch 11/50
# 4213/4213 - 120s - loss: 4.5749e-07 - binary_accuracy: 0.5425 - val_loss: 4.5660e-07 - val_binary_accuracy: 0.5417 - lr: 0.1000 - 120s/epoch - 29ms/step
# Epoch 12/50
# 4213/4213 - 122s - loss: 4.5740e-07 - binary_accuracy: 0.5421 - val_loss: 4.5670e-07 - val_binary_accuracy: 0.5400 - lr: 0.1000 - 122s/epoch - 29ms/step
# Epoch 13/50
# 4213/4213 - 122s - loss: 4.5729e-07 - binary_accuracy: 0.5422 - val_loss: 4.5648e-07 - val_binary_accuracy: 0.5420 - lr: 0.1000 - 122s/epoch - 29ms/step
# Epoch 14/50
# 4213/4213 - 123s - loss: 4.5725e-07 - binary_accuracy: 0.5424 - val_loss: 4.5646e-07 - val_binary_accuracy: 0.5420 - lr: 0.1000 - 123s/epoch - 29ms/step
# Epoch 15/50
# 4213/4213 - 121s - loss: 4.5722e-07 - binary_accuracy: 0.5424 - val_loss: 4.5670e-07 - val_binary_accuracy: 0.5411 - lr: 0.1000 - 121s/epoch - 29ms/step
# Epoch 16/50
# 4213/4213 - 123s - loss: 4.5722e-07 - binary_accuracy: 0.5428 - val_loss: 4.5646e-07 - val_binary_accuracy: 0.5420 - lr: 0.1000 - 123s/epoch - 29ms/step
# Epoch 17/50
# 4213/4213 - 122s - loss: 4.5720e-07 - binary_accuracy: 0.5424 - val_loss: 4.5649e-07 - val_binary_accuracy: 0.5410 - lr: 0.1000 - 122s/epoch - 29ms/step
# Epoch 18/50
# 4213/4213 - 124s - loss: 4.5720e-07 - binary_accuracy: 0.5430 - val_loss: 4.5652e-07 - val_binary_accuracy: 0.5420 - lr: 0.1000 - 124s/epoch - 29ms/step
# Epoch 19/50

# %%
NN_training_channels_dict['singletop'].make_overfit_plots()

# %%
num_bins_cal = 50
NN_training_channels_dict['singletop'].make_calib_plots(nbins=num_bins_cal, observable='score')
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:83: RuntimeWarning: invalid value encountered in divide
#   +(hist_den_err/(hist_den)**2))
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:91: RuntimeWarning: invalid value encountered in divide
#   hist_ratio_holdout = hist_num_holdout / ( hist_den_holdout + hist_num_holdout )
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:93: RuntimeWarning: divide by zero encountered in divide
#   err_holdout = hist_ratio_holdout**2 * np.abs(hist_den_holdout/hist_num_holdout) * np.sqrt((hist_num_holdout_err/(hist_num_holdout)**2)\
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:93: RuntimeWarning: invalid value encountered in divide
#   err_holdout = hist_ratio_holdout**2 * np.abs(hist_den_holdout/hist_num_holdout) * np.sqrt((hist_num_holdout_err/(hist_num_holdout)**2)\
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:93: RuntimeWarning: invalid value encountered in multiply
#   err_holdout = hist_ratio_holdout**2 * np.abs(hist_den_holdout/hist_num_holdout) * np.sqrt((hist_num_holdout_err/(hist_num_holdout)**2)\
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:94: RuntimeWarning: invalid value encountered in divide
#   +(hist_den_holdout_err/(hist_den_holdout)**2))
# observable not recognized

# %%
NN_training_channels_dict['singletop'].make_calib_plots(nbins=num_bins_cal, observable='llr')
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:156: RuntimeWarning: divide by zero encountered in divide
#   h_log = np.log(hist_num/hist_den)
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:157: RuntimeWarning: invalid value encountered in divide
#   h_log_err = np.sqrt((hist_num_err/hist_num**2)+(hist_den_err/hist_den**2))
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:162: RuntimeWarning: divide by zero encountered in divide
#   h_log_holdout = np.log(hist_num_holdout/hist_den_holdout)
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:162: RuntimeWarning: invalid value encountered in divide
#   h_log_holdout = np.log(hist_num_holdout/hist_den_holdout)
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:162: RuntimeWarning: divide by zero encountered in log
#   h_log_holdout = np.log(hist_num_holdout/hist_den_holdout)
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:163: RuntimeWarning: invalid value encountered in divide
#   h_log_holdout_err = np.sqrt((hist_num_holdout_err/hist_num_holdout**2)+(hist_den_holdout_err/hist_den_holdout**2))

# %%
variables_to_plot=['lepton_pt', 'lepton_phi', 'lepton_eta']
yscale_type='log'
num_bins_plotting=21

NN_training_channels_dict['singletop'].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/cms_ttbar_open_data/../common_utils/plotting.py:281: RuntimeWarning: invalid value encountered in divide
#   hep.histplot(rat, edges, yerr = np.abs(rat*np.sqrt((np.sqrt(hist_den_err)/hist_den)**2+(np.sqrt(hist_num_err)/hist_num)**2)), linewidth=2.0)

# %%
NN_training_channels_dict['singletop'].evaluate_and_save_ratios(dataset)
# Out:
# 104270/104270 - 83s - 83s/epoch - 793us/step

# %%
# backup code for updating class methods 
importlib.reload(sys.modules['common_utils.training'])
from common_utils.training import TrainEvaluate_NN
import types

NN_training.make_reweighted_plots = types.MethodType(TrainEvaluate_NN.make_reweighted_plots, NN_training)
NN_training.make_calib_plots = types.MethodType(TrainEvaluate_NN.make_calib_plots, NN_training)
NN_training.evaluate_and_save_ratios = types.MethodType(TrainEvaluate_NN.evaluate_and_save_ratios, NN_training)
