# %% [markdown]
# Systematic Uncertainty Modelling
# ===
#
# In the `Neural_Likelihood_Ratio_Estimation.ipynb` notebook, we left out the nuisance parameter piece of the parameterized density ratio decomposition:
#
# $$g_c(x|\alpha) = \frac{p_c(x|\alpha)}{p_c(x)} = \prod_m \frac{p_c(x|\alpha_m^{eval})}{p_c(x)}$$
#
# where the second equality assumes that **the effect of various sources of uncertainty in the model can be factorized**. This is another density ratio estimation problem, but instead of training m $\alpha-$parameterized NNs, we use a HistFactory-style interpolation generalized to a per-event formulation:
#
# $$\frac{p_c(x|\alpha_m^{eval})}{p_c(x)} = \begin{cases}
#     \left(\frac{p_c(x|\alpha_m^+)}{p_c(x)}\right)^{\alpha_m^\text{eval}}& \alpha_m^\text{eval}>1\\
#     1+\sum_{n=1}^6c_n\cdot (\alpha_m^\text{eval})^n& -1\leq\alpha_m^\text{eval}\leq 1\\
#     \left(\frac{p_c(x|\alpha_m^-)}{p_c(x)}\right)^{-\alpha_m^\text{eval}}& \alpha_m^\text{eval}<-1\\
#     \end{cases}$$
#
# where $\alpha=\{\alpha_m^{eval}\}$ and for each nuisance parameter $m$, we have three simulation models - $p_c(x), p_c(x|\alpha_m^+), p_c(x|\alpha_m^-)$. Naturally, this still requires NNs to estimate the density ratios:
#
# $$\frac{p_c(x|\alpha_m^+)}{p_c(x)} \, , \frac{p_c(x|\alpha_m^-)}{p_c(x)}$$
#
# **These are the density ratios that we will estimate using NNs in this notebook.**
# Two ratios corresponding to each $\alpha_m^\pm$ will be trained for each systematic uncertainty indexed by $m$ and for each channel $c$ to build the final parameterized model,
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\sum_c G_c(\alpha) \cdot f_c(\mu) \cdot \nu_c} \sum_c f_c(\mu) \cdot G_c(\alpha) \cdot \nu_c \cdot g_c(x|\alpha) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}$$
#
# The full workflow for building $\mu, \alpha-$parameterized density ratios is represented in the flowchart below:
#
# ![NSBI_highlevel_overview.001.png](attachment:b9ab250c-7514-4848-bdf4-5b7db16ed023.png)

# %%
import os, sys, importlib
# sys.path.append('/home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/')

import nsbi_common_utils
from nsbi_common_utils import plotting, training, datasets, configuration
from nsbi_common_utils.training import TrainEvaluate_NN, TrainEvaluatePreselNN

from utils import calculate_preselection_observable, preselection_using_score

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, MinMaxScaler
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt
import pickle
import yaml
import random
import numpy as np

from coffea.analysis_tools import PackedSelection

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

hep.style.use(hep.style.ATLAS)
# Out:
# /home/jsandesara_umass_edu/NSBI-workflow-tutorial/src/nsbi_common_utils/plotting.py:11: FutureWarning: ``set_style`` is deprecated: Naming convention is changing to match mpl. Use ``mplhep.style.use()``.
#   hep.set_style("ATLAS")
# 2025-10-23 01:20:05.277184: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-23 01:20:05.297437: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-23 01:20:05.303859: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-23 01:20:05.319221: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
importlib.reload(sys.modules['nsbi_common_utils.configuration'])
from nsbi_common_utils import configuration

config = nsbi_common_utils.configuration.ConfigManager(file_path_string = './config.yml')

# %%
config.config["Regions"][2]["Variable"]

# %%
# Input features for training
features, features_scaling = config.get_training_features()

# %%
importlib.reload(sys.modules['nsbi_common_utils.datasets'])
from nsbi_common_utils import datasets

branches_to_load = features + ['presel_score']

Datasets = nsbi_common_utils.datasets.datasets(config_path = './config.yml',
                                                branches_to_load =  branches_to_load)

dataset_incl_dict = Datasets.load_datasets_from_config(load_systematics = True)

# %%
dataset_SR_dict = Datasets.filter_region_by_type(dataset_incl_dict, region = "SR")

# %% [markdown]
# Density ratio training
# ===
#
# Now we train the NNs to predict two ratios,
#
# $$\frac{p_c(x|\alpha_m^+)}{p_c(x)} \, , \frac{p_c(x|\alpha_m^-)}{p_c(x)}$$
#
# for each nuisance parameter $\alpha_m$, for each process $p_c$ that is affected by the corresponding nuisance parameter.
#
# Here is a major computational bottleneck of this workflow - for $N_{syst}$ systematics affecting each of the $N_{proc}$ processes, we would need a total of
#
# $$N_{syst} \times N_{proc} \times 2$$
#
# well-trained NNs. In our example with $N_{syst}=2$ and $N_{proc}=3$, this corresponds to a total of 12 NNs. Typically in LHC experiments $N_{syst}\approx O(10^2)$! This type of approach thus requires a GPU infrastructure for efficient optimizations.

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import TrainEvaluate_NN

PATH_TO_SAVED_DATA = './saved_data/'

NN_training_syst_process  = {}
path_to_ratios            = {}
path_to_figures           = {}
path_to_models            = {}

# rnd_seed_traintestsplit = 42 # can also be randomized, fixed for now
rnd_seed_traintestsplit = random.randint(0, 2**32 - 1)

# DELETE_EXISTING_MODELS = True
DELETE_EXISTING_MODELS = False


for process in config.get_basis_samples():
    
    NN_training_syst_process[process]   = {}
    path_to_ratios[process]             = {}
    path_to_figures[process]            = {}
    path_to_models[process]             = {}

    _train_label_sample_dict = {process        : 0}

    dataset_den             = Datasets.merge_dataframe_dict_for_training(dataset_SR_dict["Nominal"], 
                                                                _train_label_sample_dict, 
                                                                samples_to_merge = [process])
    
    
    for dict_syst in config.config["Systematics"]:
        
        syst = dict_syst["Name"]

        NN_training_syst_process[process][syst] = {}
        path_to_ratios[process][syst]           = {}
        path_to_figures[process][syst]          = {}
        path_to_models[process][syst]           = {}

        for direction in ["Up", "Dn"]:
            
            samples_to_train = config.get_samples_in_syst_for_training(syst, direction)
            
            if (process not in samples_to_train):
                print(f"Nothing to train for {process} in {syst+direction} uncertainty")
                del NN_training_syst_process[process][syst], path_to_ratios[process][syst], path_to_figures[process][syst], path_to_models[process][syst]
                continue

            syst_key_name = syst + '_' + direction
            
            _train_label_sample_dict = {process        : 1}

            dataset_num             = Datasets.merge_dataframe_dict_for_training(dataset_SR_dict[syst_key_name], 
                                                                                _train_label_sample_dict, 
                                                                                samples_to_merge = [process])

            # Save paths
            top_path                                    = f'{PATH_TO_SAVED_DATA}output_training_systematics/'
            output_name                                 = f'{process}_{syst}_{direction}'
            output_dir                                  = f'{top_path}general_output_{output_name}'
            path_to_ratios[process][syst][direction]    = f'{top_path}output_ratios_{output_name}/'
            path_to_figures[process][syst][direction]   = f'{top_path}output_figures_{output_name}/'
            path_to_models[process][syst][direction]    = f'{top_path}output_model_params_{output_name}/'
            
            # Build a training dataset for the training of p_<process_type>/p_<REF_PROCESSES> density ratio
            dataset_syst_nom = pd.concat([dataset_num, dataset_den])
            
            NN_training_syst_process[process][syst][direction] = TrainEvaluate_NN(dataset_syst_nom, 
                                                                                   dataset_syst_nom['weights_normed'].to_numpy(),
                                                                                   dataset_syst_nom['train_labels'].to_numpy(),
                                                                                   features, 
                                                                                   features_scaling,
                                                                                   [syst+'_'+direction, process], 
                                                                                  output_dir, output_name, 
                                                                                    path_to_figures=path_to_figures[process][syst][direction],
                                                                                    path_to_ratios=path_to_ratios[process][syst][direction], 
                                                                                    path_to_models=path_to_models[process][syst][direction],
                                                                                    delete_existing_models = DELETE_EXISTING_MODELS)

# %%
# For systematic uncertainty variations, we can use a calibration layer to regularize the small fluctuations in density ratio output
doCalibration = True
num_bins_cal = 50

USE_SAVED_MODELS = True
RECALIBRATE = True
num_ensemble_members = 1

plot_scaled_features = False

verbose_output = 1

scalerType = 'MinMax'
hidden_layers = 4
num_neurons = 1000
num_epochs = 100
batch_size = 10_000
initial_lr = 0.1

for process, process_dict in NN_training_syst_process.items():

    for syst, syst_dict in process_dict.items():
        
        for direction in syst_dict.keys():

            NN_training_syst_process[process][syst][direction].train_ensemble (  hidden_layers        = hidden_layers, 
                                                                                 neurons              = num_neurons, 
                                                                                 number_of_epochs     = num_epochs, 
                                                                                 batch_size           = batch_size, 
                                                                                 learning_rate        = initial_lr, 
                                                                                 scalerType           = scalerType, 
                                                                                 calibration          = doCalibration, 
                                                                                 num_bins_cal         = num_bins_cal, 
                                                                                 callback             = True, 
                                                                                 callback_patience    = 30, 
                                                                                 callback_factor      = 0.01,
                                                                                 verbose              = verbose_output,
                                                                                 plot_scaled_features = plot_scaled_features,
                                                                                 load_trained_models  = USE_SAVED_MODELS,
                                                                                 recalibrate_output   = RECALIBRATE,
                                                                                 num_ensemble_members = num_ensemble_members
                                                                            )    
            
            NN_training_syst_process[process][syst][direction].test_normalization ( )
# Out:
# starting ensemble training
# Sum of weights of class 0: 0.7000005421809687
# Sum of weights of class 1: 0.6999987136413167
# Using swish activation function
# /home/jsandesara_umass_edu/NSBI-workflow-tutorial/.pixi/envs/nsbi-env-gpu/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-10-23 01:20:43.975927: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9615 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:88:00.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │         9,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,013,001 (11.49 MB)
#  Trainable params: 3,013,001 (11.49 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# 2025-10-23 01:20:51.137617: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-10-23 01:20:51.968207: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 13s 39ms/step - binary_accuracy: 0.5028 - loss: 5.5270e-07 - val_binary_accuracy: 0.4995 - val_loss: 5.5274e-07 - learning_rate: 0.1000
# Epoch 2/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.5043 - loss: 5.5269e-07 - val_binary_accuracy: 0.5007 - val_loss: 5.5271e-07 - learning_rate: 0.1000
# Epoch 3/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.5053 - loss: 5.5267e-07 - val_binary_accuracy: 0.4991 - val_loss: 5.5278e-07 - learning_rate: 0.1000
# Epoch 4/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.5054 - loss: 5.5267e-07 - val_binary_accuracy: 0.5000 - val_loss: 5.5272e-07 - learning_rate: 0.1000
# Epoch 5/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.5057 - loss: 5.5266e-07 - val_binary_accuracy: 0.5066 - val_loss: 5.5269e-07 - learning_rate: 0.1000
# Epoch 6/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.5066 - loss: 5.5265e-07 - val_binary_accuracy: 0.5035 - val_loss: 5.5269e-07 - learning_rate: 0.1000
# Epoch 7/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.5063 - loss: 5.5264e-07 - val_binary_accuracy: 0.4981 - val_loss: 5.5281e-07 - learning_rate: 0.1000
# Epoch 8/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.5068 - loss: 5.5265e-07 - val_binary_accuracy: 0.5013 - val_loss: 5.5270e-07 - learning_rate: 0.1000
# Epoch 9/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.5076 - loss: 5.5263e-07 - val_binary_accuracy: 0.4982 - val_loss: 5.5282e-07 - learning_rate: 0.1000
# Epoch 10/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.5065 - loss: 5.5264e-07 - val_binary_accuracy: 0.5045 - val_loss: 5.5267e-07 - learning_rate: 0.1000
# Epoch 11/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.5075 - loss: 5.5262e-07 - val_binary_accuracy: 0.5046 - val_loss: 5.5267e-07 - learning_rate: 0.1000
# Epoch 12/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.5078 - loss: 5.5262e-07 - val_binary_accuracy: 0.5056 - val_loss: 5.5269e-07 - learning_rate: 0.1000
# Epoch 13/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.5080 - loss: 5.5262e-07 - val_binary_accuracy: 0.5064 - val_loss: 5.5266e-07 - learning_rate: 0.1000
# Epoch 14/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.5077 - loss: 5.5262e-07 - val_binary_accuracy: 0.5045 - val_loss: 5.5269e-07 - learning_rate: 0.1000
# Epoch 15/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5072 - loss: 5.5263e-07 - val_binary_accuracy: 0.5006 - val_loss: 5.5274e-07 - learning_rate: 0.1000
# Epoch 16/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.5081 - loss: 5.5262e-07 - val_binary_accuracy: 0.5072 - val_loss: 5.5265e-07 - learning_rate: 0.1000
# Epoch 17/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.5080 - loss: 5.5261e-07 - val_binary_accuracy: 0.5024 - val_loss: 5.5271e-07 - learning_rate: 0.1000
# Epoch 18/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - binary_accuracy: 0.5081 - loss: 5.5261e-07 - val_binary_accuracy: 0.5068 - val_loss: 5.5265e-07 - learning_rate: 0.1000
# Epoch 19/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5082 - loss: 5.5260e-07 - val_binary_accuracy: 0.5047 - val_loss: 5.5268e-07 - learning_rate: 0.1000
# Epoch 20/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5088 - loss: 5.5260e-07 - val_binary_accuracy: 0.5005 - val_loss: 5.5277e-07 - learning_rate: 0.1000
# Epoch 21/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5081 - loss: 5.5260e-07 - val_binary_accuracy: 0.5031 - val_loss: 5.5271e-07 - learning_rate: 0.1000
# Epoch 22/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5081 - loss: 5.5260e-07 - val_binary_accuracy: 0.5031 - val_loss: 5.5270e-07 - learning_rate: 0.1000
# Epoch 23/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5084 - loss: 5.5260e-07 - val_binary_accuracy: 0.5047 - val_loss: 5.5270e-07 - learning_rate: 0.1000
# Epoch 24/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5080 - loss: 5.5261e-07 - val_binary_accuracy: 0.5051 - val_loss: 5.5265e-07 - learning_rate: 0.1000
# Epoch 25/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5087 - loss: 5.5260e-07 - val_binary_accuracy: 0.5048 - val_loss: 5.5267e-07 - learning_rate: 0.1000
# Epoch 26/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5083 - loss: 5.5260e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 0.1000
# Epoch 27/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5086 - loss: 5.5259e-07 - val_binary_accuracy: 0.5015 - val_loss: 5.5276e-07 - learning_rate: 0.1000
# Epoch 28/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5074 - loss: 5.5260e-07 - val_binary_accuracy: 0.5068 - val_loss: 5.5264e-07 - learning_rate: 0.1000
# Epoch 29/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5088 - loss: 5.5259e-07 - val_binary_accuracy: 0.5068 - val_loss: 5.5265e-07 - learning_rate: 0.1000
# Epoch 30/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5088 - loss: 5.5259e-07 - val_binary_accuracy: 0.5062 - val_loss: 5.5263e-07 - learning_rate: 0.1000
# Epoch 31/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5085 - loss: 5.5259e-07 - val_binary_accuracy: 0.5065 - val_loss: 5.5264e-07 - learning_rate: 0.1000
# Epoch 32/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5091 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 33/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5091 - loss: 5.5258e-07 - val_binary_accuracy: 0.5066 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 34/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5091 - loss: 5.5258e-07 - val_binary_accuracy: 0.5065 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 35/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5091 - loss: 5.5258e-07 - val_binary_accuracy: 0.5064 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 36/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5066 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 37/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5065 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 38/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5065 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 39/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5066 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 40/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5091 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 41/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5090 - loss: 5.5258e-07 - val_binary_accuracy: 0.5068 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 42/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5091 - loss: 5.5258e-07 - val_binary_accuracy: 0.5066 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 43/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5064 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 44/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5066 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 45/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5065 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 46/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5065 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 47/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 48/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5090 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 49/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5091 - loss: 5.5258e-07 - val_binary_accuracy: 0.5066 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 50/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5066 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 51/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5091 - loss: 5.5258e-07 - val_binary_accuracy: 0.5068 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 52/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 53/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 54/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5066 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 55/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 56/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 57/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5066 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 58/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 59/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 60/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5093 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 61/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 0.0010
# Epoch 62/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 68/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 69/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 70/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 82/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 83/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 84/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 85/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 86/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 87/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 88/100
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5258e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5264e-07 - learning_rate: 1.0000e-05
# Epoch 89/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5081 - loss: 5.5313e-07 - val_binary_accuracy: 0.5096 - val_loss: 5.5310e-07 - learning_rate: 0.1000
# Epoch 13/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5079 - loss: 5.5313e-07 - val_binary_accuracy: 0.5090 - val_loss: 5.5309e-07 - learning_rate: 0.1000
# Epoch 14/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5080 - loss: 5.5312e-07 - val_binary_accuracy: 0.5097 - val_loss: 5.5309e-07 - learning_rate: 0.1000
# Epoch 15/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5081 - loss: 5.5312e-07 - val_binary_accuracy: 0.5087 - val_loss: 5.5309e-07 - learning_rate: 0.1000
# Epoch 16/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5080 - loss: 5.5312e-07 - val_binary_accuracy: 0.5102 - val_loss: 5.5308e-07 - learning_rate: 0.1000
# Epoch 17/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5080 - loss: 5.5312e-07 - val_binary_accuracy: 0.5105 - val_loss: 5.5308e-07 - learning_rate: 0.1000
# Epoch 18/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5087 - loss: 5.5311e-07 - val_binary_accuracy: 0.5095 - val_loss: 5.5308e-07 - learning_rate: 0.1000
# Epoch 19/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5084 - loss: 5.5311e-07 - val_binary_accuracy: 0.5063 - val_loss: 5.5310e-07 - learning_rate: 0.1000
# Epoch 20/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5084 - loss: 5.5311e-07 - val_binary_accuracy: 0.5093 - val_loss: 5.5307e-07 - learning_rate: 0.1000
# Epoch 21/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5084 - loss: 5.5311e-07 - val_binary_accuracy: 0.5086 - val_loss: 5.5307e-07 - learning_rate: 0.1000
# Epoch 22/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5084 - loss: 5.5310e-07 - val_binary_accuracy: 0.5067 - val_loss: 5.5311e-07 - learning_rate: 0.1000
# Epoch 23/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5086 - loss: 5.5311e-07 - val_binary_accuracy: 0.5104 - val_loss: 5.5306e-07 - learning_rate: 0.1000
# Epoch 24/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5086 - loss: 5.5310e-07 - val_binary_accuracy: 0.5082 - val_loss: 5.5307e-07 - learning_rate: 0.1000
# Epoch 25/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5085 - loss: 5.5311e-07 - val_binary_accuracy: 0.5112 - val_loss: 5.5305e-07 - learning_rate: 0.1000
# Epoch 26/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5088 - loss: 5.5310e-07 - val_binary_accuracy: 0.5107 - val_loss: 5.5305e-07 - learning_rate: 0.1000
# Epoch 27/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5086 - loss: 5.5310e-07 - val_binary_accuracy: 0.5097 - val_loss: 5.5306e-07 - learning_rate: 0.1000
# Epoch 28/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5088 - loss: 5.5310e-07 - val_binary_accuracy: 0.5107 - val_loss: 5.5305e-07 - learning_rate: 0.1000
# Epoch 29/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5085 - loss: 5.5310e-07 - val_binary_accuracy: 0.5096 - val_loss: 5.5305e-07 - learning_rate: 0.1000
# Epoch 30/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5088 - loss: 5.5310e-07 - val_binary_accuracy: 0.5116 - val_loss: 5.5304e-07 - learning_rate: 0.1000
# Epoch 31/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5088 - loss: 5.5309e-07 - val_binary_accuracy: 0.5094 - val_loss: 5.5305e-07 - learning_rate: 0.1000
# Epoch 32/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5093 - loss: 5.5309e-07 - val_binary_accuracy: 0.5106 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 33/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5094 - loss: 5.5308e-07 - val_binary_accuracy: 0.5109 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 34/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5093 - loss: 5.5308e-07 - val_binary_accuracy: 0.5114 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 35/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5112 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 36/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5091 - loss: 5.5308e-07 - val_binary_accuracy: 0.5112 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 37/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5091 - loss: 5.5308e-07 - val_binary_accuracy: 0.5114 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 38/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5093 - loss: 5.5308e-07 - val_binary_accuracy: 0.5114 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 39/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5091 - loss: 5.5308e-07 - val_binary_accuracy: 0.5114 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 40/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5093 - loss: 5.5308e-07 - val_binary_accuracy: 0.5114 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 41/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5114 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 42/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5115 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 43/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5115 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 44/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5113 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 45/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5114 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 46/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5113 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 47/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5114 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 48/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5091 - loss: 5.5308e-07 - val_binary_accuracy: 0.5113 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 49/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5115 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 50/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5113 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 51/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5093 - loss: 5.5308e-07 - val_binary_accuracy: 0.5113 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 52/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5091 - loss: 5.5308e-07 - val_binary_accuracy: 0.5113 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 53/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5113 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 54/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5113 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 55/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5093 - loss: 5.5308e-07 - val_binary_accuracy: 0.5114 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 56/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5114 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 57/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5113 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 58/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5113 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 59/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5091 - loss: 5.5308e-07 - val_binary_accuracy: 0.5115 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 60/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5114 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 61/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5091 - loss: 5.5308e-07 - val_binary_accuracy: 0.5115 - val_loss: 5.5304e-07 - learning_rate: 0.0010
# Epoch 62/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5115 - val_loss: 5.5304e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5115 - val_loss: 5.5304e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5115 - val_loss: 5.5304e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5115 - val_loss: 5.5304e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 158/158 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - binary_accuracy: 0.5092 - loss: 5.5308e-07 - val_binary_accuracy: 0.5115 - val_loss: 5.5304e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
#  37/158 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - binary_accuracy: 0.5097 - loss: 5.5305e-07
# IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5072 - loss: 1.4072e-06 - val_binary_accuracy: 0.5049 - val_loss: 1.4073e-06 - learning_rate: 0.1000
# Epoch 28/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5077 - loss: 1.4072e-06 - val_binary_accuracy: 0.5059 - val_loss: 1.4073e-06 - learning_rate: 0.1000
# Epoch 29/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5066 - loss: 1.4072e-06 - val_binary_accuracy: 0.5031 - val_loss: 1.4075e-06 - learning_rate: 0.1000
# Epoch 30/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5078 - loss: 1.4072e-06 - val_binary_accuracy: 0.5049 - val_loss: 1.4073e-06 - learning_rate: 0.1000
# Epoch 31/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5075 - loss: 1.4072e-06 - val_binary_accuracy: 0.5072 - val_loss: 1.4073e-06 - learning_rate: 0.1000
# Epoch 32/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5064 - loss: 1.4072e-06 - val_binary_accuracy: 0.5084 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 33/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5070 - loss: 1.4071e-06 - val_binary_accuracy: 0.5087 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 34/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5075 - loss: 1.4071e-06 - val_binary_accuracy: 0.5094 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 35/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5077 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 36/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - binary_accuracy: 0.5076 - loss: 1.4071e-06 - val_binary_accuracy: 0.5091 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 37/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5077 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 38/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5078 - loss: 1.4071e-06 - val_binary_accuracy: 0.5089 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 39/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5079 - loss: 1.4071e-06 - val_binary_accuracy: 0.5090 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 40/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5078 - loss: 1.4071e-06 - val_binary_accuracy: 0.5090 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 41/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5078 - loss: 1.4071e-06 - val_binary_accuracy: 0.5091 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 42/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5079 - loss: 1.4071e-06 - val_binary_accuracy: 0.5091 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 43/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5077 - loss: 1.4071e-06 - val_binary_accuracy: 0.5089 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 44/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5079 - loss: 1.4071e-06 - val_binary_accuracy: 0.5088 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 45/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5079 - loss: 1.4071e-06 - val_binary_accuracy: 0.5088 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 46/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5076 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 47/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5077 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 48/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5078 - loss: 1.4071e-06 - val_binary_accuracy: 0.5086 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 49/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5081 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 50/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5078 - loss: 1.4071e-06 - val_binary_accuracy: 0.5089 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 51/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5079 - loss: 1.4071e-06 - val_binary_accuracy: 0.5088 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 52/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5076 - loss: 1.4071e-06 - val_binary_accuracy: 0.5087 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 53/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5081 - loss: 1.4071e-06 - val_binary_accuracy: 0.5090 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 54/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5079 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 55/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5079 - loss: 1.4071e-06 - val_binary_accuracy: 0.5091 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 56/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5094 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 57/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 58/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5078 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 59/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5079 - loss: 1.4071e-06 - val_binary_accuracy: 0.5090 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 60/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 61/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5083 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 0.0010
# Epoch 62/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 63/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 64/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 65/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 66/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 67/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 68/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 69/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 70/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 71/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 72/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 73/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 74/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 75/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 76/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 77/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 78/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 79/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 80/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 81/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 82/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 83/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 84/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 85/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 86/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 87/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 88/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 89/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5093 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 90/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 91/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-05
# Epoch 92/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-07
# Epoch 93/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-07
# Epoch 94/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-07
# Epoch 95/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-07
# Epoch 96/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-07
# Epoch 97/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-07
# Epoch 98/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-07
# Epoch 99/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-07
# Epoch 100/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5080 - loss: 1.4071e-06 - val_binary_accuracy: 0.5092 - val_loss: 1.4072e-06 - learning_rate: 1.0000e-07
# Finished Training
# 2025-10-23 01:59:33.418858: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-10-23 01:59:33.466022: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9615 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:88:00.0, compute capability: 7.5
# 2025-10-23 01:59:33.658310: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9615 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:88:00.0, compute capability: 7.5
# 2025-10-23 01:59:33.685038: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-10-23 01:59:33.691052: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9615 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:88:00.0, compute capability: 7.5
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# The sum of PDFs in ensemble member 0 is 0.9999879597709435
#
#
# The sum of PDFs using the whole ensemble is 0.9999879597709435
#
#
#
# starting ensemble training
# Sum of weights of class 0: 0.7000015377998352
# Sum of weights of class 1: 0.6999998092651367
# Using swish activation function
# /home/jsandesara_umass_edu/NSBI-workflow-tutorial/.pixi/envs/nsbi-env-gpu/lib/python3.12/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │         9,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,013,001 (11.49 MB)
#  Trainable params: 3,013,001 (11.49 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - binary_accuracy: 0.5076 - loss: 1.3528e-06 - val_binary_accuracy: 0.5130 - val_loss: 1.3525e-06 - learning_rate: 0.1000
# Epoch 2/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5105 - loss: 1.3525e-06 - val_binary_accuracy: 0.5128 - val_loss: 1.3523e-06 - learning_rate: 0.1000
# Epoch 3/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5127 - loss: 1.3523e-06 - val_binary_accuracy: 0.5140 - val_loss: 1.3521e-06 - learning_rate: 0.1000
# Epoch 4/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5145 - loss: 1.3521e-06 - val_binary_accuracy: 0.5151 - val_loss: 1.3520e-06 - learning_rate: 0.1000
# Epoch 5/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5149 - loss: 1.3520e-06 - val_binary_accuracy: 0.5165 - val_loss: 1.3518e-06 - learning_rate: 0.1000
# Epoch 6/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5167 - loss: 1.3518e-06 - val_binary_accuracy: 0.5177 - val_loss: 1.3517e-06 - learning_rate: 0.1000
# Epoch 7/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5173 - loss: 1.3517e-06 - val_binary_accuracy: 0.5190 - val_loss: 1.3515e-06 - learning_rate: 0.1000
# Epoch 8/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - binary_accuracy: 0.5177 - loss: 1.3516e-06 - val_binary_accuracy: 0.5171 - val_loss: 1.3517e-06 - learning_rate: 0.1000
# Epoch 9/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5179 - loss: 1.3515e-06 - val_binary_accuracy: 0.5195 - val_loss: 1.3513e-06 - learning_rate: 0.1000
# Epoch 10/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5186 - loss: 1.3514e-06 - val_binary_accuracy: 0.5210 - val_loss: 1.3514e-06 - learning_rate: 0.1000
# Epoch 11/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5184 - loss: 1.3514e-06 - val_binary_accuracy: 0.5204 - val_loss: 1.3513e-06 - learning_rate: 0.1000
# Epoch 12/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5187 - loss: 1.3513e-06 - val_binary_accuracy: 0.5205 - val_loss: 1.3512e-06 - learning_rate: 0.1000
# Epoch 13/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5187 - loss: 1.3513e-06 - val_binary_accuracy: 0.5201 - val_loss: 1.3512e-06 - learning_rate: 0.1000
# Epoch 14/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5183 - loss: 1.3513e-06 - val_binary_accuracy: 0.5206 - val_loss: 1.3512e-06 - learning_rate: 0.1000
# Epoch 15/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5187 - loss: 1.3513e-06 - val_binary_accuracy: 0.5189 - val_loss: 1.3511e-06 - learning_rate: 0.1000
# Epoch 16/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5183 - loss: 1.3513e-06 - val_binary_accuracy: 0.5196 - val_loss: 1.3511e-06 - learning_rate: 0.1000
# Epoch 17/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5185 - loss: 1.3512e-06 - val_binary_accuracy: 0.5187 - val_loss: 1.3512e-06 - learning_rate: 0.1000
# Epoch 18/100
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5187 - loss: 1.3512e-06 - val_binary_accuracy: 0.5212 - val_loss: 1.3513e-06 - learning_rate: 0.1000
# Epoch 19/100
# ...
# Epoch 19/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5198 - loss: 1.4286e-06 - val_binary_accuracy: 0.5173 - val_loss: 1.4296e-06 - learning_rate: 0.1000
# Epoch 20/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5201 - loss: 1.4285e-06 - val_binary_accuracy: 0.5139 - val_loss: 1.4299e-06 - learning_rate: 0.1000
# Epoch 21/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5201 - loss: 1.4286e-06 - val_binary_accuracy: 0.5145 - val_loss: 1.4295e-06 - learning_rate: 0.1000
# Epoch 22/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5201 - loss: 1.4285e-06 - val_binary_accuracy: 0.5143 - val_loss: 1.4304e-06 - learning_rate: 0.1000
# Epoch 23/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5197 - loss: 1.4286e-06 - val_binary_accuracy: 0.5179 - val_loss: 1.4294e-06 - learning_rate: 0.1000
# Epoch 24/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5203 - loss: 1.4285e-06 - val_binary_accuracy: 0.5172 - val_loss: 1.4296e-06 - learning_rate: 0.1000
# Epoch 25/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5201 - loss: 1.4285e-06 - val_binary_accuracy: 0.5165 - val_loss: 1.4294e-06 - learning_rate: 0.1000
# Epoch 26/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5206 - loss: 1.4285e-06 - val_binary_accuracy: 0.5115 - val_loss: 1.4307e-06 - learning_rate: 0.1000
# Epoch 27/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5195 - loss: 1.4286e-06 - val_binary_accuracy: 0.5090 - val_loss: 1.4319e-06 - learning_rate: 0.1000
# Epoch 28/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5199 - loss: 1.4287e-06 - val_binary_accuracy: 0.5152 - val_loss: 1.4295e-06 - learning_rate: 0.1000
# Epoch 29/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5197 - loss: 1.4285e-06 - val_binary_accuracy: 0.5149 - val_loss: 1.4295e-06 - learning_rate: 0.1000
# Epoch 30/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5201 - loss: 1.4285e-06 - val_binary_accuracy: 0.5165 - val_loss: 1.4294e-06 - learning_rate: 0.1000
# Epoch 31/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5201 - loss: 1.4285e-06 - val_binary_accuracy: 0.5170 - val_loss: 1.4296e-06 - learning_rate: 0.1000
# Epoch 32/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5208 - loss: 1.4286e-06 - val_binary_accuracy: 0.5170 - val_loss: 1.4294e-06 - learning_rate: 0.0010
# Epoch 33/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5201 - loss: 1.4285e-06 - val_binary_accuracy: 0.5172 - val_loss: 1.4294e-06 - learning_rate: 0.0010
# Epoch 34/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5204 - loss: 1.4284e-06 - val_binary_accuracy: 0.5170 - val_loss: 1.4294e-06 - learning_rate: 0.0010
# Epoch 35/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5169 - val_loss: 1.4294e-06 - learning_rate: 0.0010
# Epoch 36/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4293e-06 - learning_rate: 0.0010
# Epoch 37/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4294e-06 - learning_rate: 0.0010
# Epoch 38/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5166 - val_loss: 1.4294e-06 - learning_rate: 0.0010
# Epoch 39/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4293e-06 - learning_rate: 0.0010
# Epoch 40/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5166 - val_loss: 1.4293e-06 - learning_rate: 0.0010
# Epoch 41/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4293e-06 - learning_rate: 0.0010
# Epoch 42/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5166 - val_loss: 1.4294e-06 - learning_rate: 0.0010
# Epoch 43/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5169 - val_loss: 1.4293e-06 - learning_rate: 0.0010
# Epoch 44/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5201 - loss: 1.4284e-06 - val_binary_accuracy: 0.5170 - val_loss: 1.4293e-06 - learning_rate: 0.0010
# Epoch 45/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5202 - loss: 1.4284e-06 - val_binary_accuracy: 0.5169 - val_loss: 1.4293e-06 - learning_rate: 0.0010
# Epoch 46/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5169 - val_loss: 1.4293e-06 - learning_rate: 0.0010
# Epoch 47/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5202 - loss: 1.4284e-06 - val_binary_accuracy: 0.5169 - val_loss: 1.4293e-06 - learning_rate: 0.0010
# Epoch 48/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4294e-06 - learning_rate: 0.0010
# Epoch 49/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4293e-06 - learning_rate: 0.0010
# Epoch 50/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5202 - loss: 1.4284e-06 - val_binary_accuracy: 0.5171 - val_loss: 1.4293e-06 - learning_rate: 0.0010
# Epoch 51/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5166 - val_loss: 1.4293e-06 - learning_rate: 0.0010
# Epoch 52/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4294e-06 - learning_rate: 0.0010
# Epoch 53/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 0.0010
# Epoch 54/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4293e-06 - learning_rate: 0.0010
# Epoch 55/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5202 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4293e-06 - learning_rate: 0.0010
# Epoch 56/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5202 - loss: 1.4284e-06 - val_binary_accuracy: 0.5166 - val_loss: 1.4294e-06 - learning_rate: 0.0010
# Epoch 57/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5202 - loss: 1.4284e-06 - val_binary_accuracy: 0.5166 - val_loss: 1.4294e-06 - learning_rate: 0.0010
# Epoch 58/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5202 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4294e-06 - learning_rate: 0.0010
# Epoch 59/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4293e-06 - learning_rate: 0.0010
# Epoch 60/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4294e-06 - learning_rate: 0.0010
# Epoch 61/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 0.0010
# Epoch 62/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5202 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 63/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5202 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 64/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5202 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 65/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5202 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 66/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5202 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 67/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5202 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 68/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5202 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 69/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5202 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 70/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 71/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 72/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 73/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 74/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 75/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 76/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 77/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5167 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 78/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 79/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 80/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 81/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 82/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 83/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 84/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 85/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 86/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 87/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 88/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 89/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 90/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 91/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-05
# Epoch 92/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-07
# Epoch 93/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-07
# Epoch 94/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-07
# Epoch 95/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-07
# Epoch 96/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-07
# Epoch 97/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-07
# Epoch 98/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-07
# Epoch 99/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-07
# Epoch 100/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - binary_accuracy: 0.5203 - loss: 1.4284e-06 - val_binary_accuracy: 0.5168 - val_loss: 1.4294e-06 - learning_rate: 1.0000e-07
# Finished Training
# 2025-10-23 02:05:33.861451: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-10-23 02:05:33.867292: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9615 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:88:00.0, compute capability: 7.5
# 2025-10-23 02:05:34.076245: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9615 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:88:00.0, compute capability: 7.5
# 2025-10-23 02:05:34.100341: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-10-23 02:05:34.106036: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9615 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:88:00.0, compute capability: 7.5
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# The sum of PDFs in ensemble member 0 is 1.000046074307079
#
#
# The sum of PDFs using the whole ensemble is 1.000046074307079

# %%
num_bins_cal = 50
NN_training_syst_process["htautau"]["JES"]["Up"].make_calib_plots(nbins=num_bins_cal, observable='score')

# %%
num_bins_cal = 50
NN_training_syst_process["htautau"]["JES"]["Dn"].make_calib_plots(nbins=num_bins_cal, observable='score')

# %%
num_bins_cal = 50
NN_training_syst_process["htautau"]["TES"]["Dn"].make_calib_plots(nbins=num_bins_cal, observable='score')

# %%
variables_to_plot=['log_DER_pt_h'] # The 1D variable for reweighting closure
yscale_type='log'
num_bins_plotting=21

NN_training_syst_process["htautau"]["TES"]["Up"].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
variables_to_plot=['log_DER_pt_h'] # The 1D variable for reweighting closure
yscale_type='log'
num_bins_plotting=21

NN_training_syst_process["htautau"]["TES"]["Dn"].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %% [markdown]
# Save the model output
# --
#
# Save the density ratios corresponding to each NP $\alpha_m$ and process $p_c(x)$ as a set of `numpy` arrays for use in the `Parameter_Fitting_with_Systematics.ipynb` notebook.
#
# The trained models are also saved automatically by the training class for direct use in inference, or for evaluating on real data.

# %%
ensemble_aggregation_type = 'mean_ratio'

path_to_load = "saved_datasets/dataset_Asimov.root"
dataset_Asimov_SR = nsbi_common_utils.datasets.load_dataframe_from_root(path_to_load     = path_to_load,
                                                                      tree_name        = "nominal",
                                                                      branches_to_load = branches_to_load)

path_to_saved_ratios = {}

for process in config.get_basis_samples():

    path_to_saved_ratios[process] = {}
    
    for dict_syst in config.config["Systematics"]:

        syst = dict_syst["Name"]
        
        if (process not in dict_syst["Samples"]) | (dict_syst["Type"] != "NormPlusShape"): continue

        path_to_saved_ratios[process][syst] = {}
        
        for direction in ["Up", "Dn"]:

            # Evaluate the density ratios p_alpha^\pm/p_nom for the nominal dataset
            path_to_saved_ratios[process][syst][direction] = NN_training_syst_process[process][syst][direction].evaluate_and_save_ratios(dataset_Asimov_SR, 
                                                                                        aggregation_type = ensemble_aggregation_type)
# Out:
# Evaluating density ratios
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
