# %% [markdown]
# Train Neural Networks to estimate Likelihood Ratios
# ===
#
# In this notebook we will setup the neural networks that train unbiased and low-variance density ratios to be then used for inference. The statistical model we have is:
#
# $$p(x|\mu, \alpha) = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot p_c\left(x|\alpha\right)$$
#
# where $c$ stands for the various physics channels that contribute to the final state $x$, $\mu$ is the signal-strength parameter and $\alpha$ is the vector of nuisance parameters associated with the various systematic uncertainties in the model. Note that we are assuming that the parameter $\mu$-dependence is known analytically and that we have simulation models for each of the channels $p_c(x)$.
#
# The objective is to build the test statistic for composite hypothesis testing:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})}{p(x_i|\hat{\mu}, \hat{\alpha})} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
# A direct approach would then be to model the probability density $p(x|\mu, \alpha)$ using NNs. But that is a more difficult task than training probability density ratios. We use a simple trick:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})/p_{ref}(x)}{p(x_i|\hat{\mu}, \hat{\alpha})/p_{ref}(x)} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
#
# to turn this into a density ratio estimation problem:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot \frac{p_c\left(x|\alpha\right)}{p_{ref}(x)}$$
#
# Factorizing out the $\alpha$-dependence in the density ratios:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\sum_c G_c(\alpha) \cdot f_c(\mu) \cdot \nu_c} \sum_c f_c(\mu) \cdot G_c(\alpha)\cdot \nu_c \cdot g_c(x|\alpha) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}$$
#
# **Factorized approach:**
#
# Instead of training NNs parameterized on $\mu$ and $\alpha$, we use analytical parameterizations to simplify the problem to training only parameter-independent density ratios.
#
# Let's set this up for the toy ttbar model we are using. Neglecting the nuisance parameter dependence for now,
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}\right] = \mu \cdot \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)} + \frac{p_{t\bar{t}}\left(x\right)}{p_{ref}(x)} + \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)}$$

# %%
import os, sys, importlib
sys.path.append('../')

import nsbi_common_utils
from nsbi_common_utils import plotting, training
from nsbi_common_utils.training import TrainEvaluate_NN, TrainEvaluatePreselNN
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt
import pickle

from utils import preselection_using_score, calculate_preselection_observable

from coffea.analysis_tools import PackedSelection

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

hep.style.use(hep.style.ATLAS)
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/src/nsbi_common_utils/plotting.py:10: FutureWarning: ``set_style`` is deprecated: Naming convention is changing to match mpl. Use ``mplhep.style.use()``.
#   hep.set_style("ATLAS")
# 2025-06-04 21:23:59.915378: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749072239.928419  277839 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749072239.932268  277839 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-04 21:23:59.946630: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# If the preselection NN has already been trained and saved, load from the saved model
USE_SAVED_MODEL_PRESEL=True
# If the preselection NN has already been trained and evaluated, load the numpy array of predictions
USE_SAVED_PRESEL_PREDICTIONS=True

path_prefix = '/home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/'

# Path for saving interemdiate objects, like NN predictions
saved_data = f'{path_prefix}cached_data/'

# Path for saving/loading preselection NN model
path_to_saved_presel_model = f'{path_prefix}preselection_saved_NN/'

# %%
# Load the nominal dataset saved from the pre-processing notebook
dataset_incl_nominal = pd.read_hdf(f"{saved_data}df_nominal.h5", key="dataset", mode='r')

# Load the MC/data weights and training labels identifying different processes
weights = dataset_incl_nominal.weights.to_numpy()
train_labels = dataset_incl_nominal.train_labels.to_numpy()

# %%
# Get the dictionary of labels to processes
labels_dict = np.load(f"{saved_data}labels_dictionary.npy", allow_pickle=True).item()

# %%
# Normalizing the training weights - only discriminating shapes, not norms
weights_normed = weights.copy()

for key in labels_dict:

    weights_normed[train_labels==labels_dict[key]] /= weights[train_labels==labels_dict[key]].sum()

dataset_incl_nominal['weights_normed'] = weights_normed

# %% [markdown]
# Training the Preselection NN
# ===

# %% [markdown]
# **Choice of reference sample**
#
# The density ratios need to be trained on phase space regions with support for the reference hypothesis $p_{ref}(x) > 0$.
#
# To ensure this, we make a selection that selects events in the phase space regions with $p_{ref}(x) > 0$, or $p_c(x) \gg p_{ref}(x)$, and only perform the NSBI fit in this selected analysis region. **A natural choice for the reference hypothesis is then the signal-rich hypotheses**. This is referred to in the ATLAS publications as the Search-Oriented Mixture Models approach:
#
# $$p_{ref}(x) = \frac{1}{\sum_S \nu_S} \sum_S \frac{d\sigma_S}{dx} = \frac{1}{\nu_{H \to \tau\tau}} \frac{d\sigma_{H \to \tau\tau}}{dx}$$
#
# where the sum runs over all signal hypothesis in the model and the second equality is due to the sole signal hypothesis in our toy model, $pp \to {t\bar{t}}$.
#
# **Selecting out regions with $p_{ref}\sim 0$**
#
# A multi-class classification NN, with softmax output, is trained to output a score:
#
# $$ \text{NN}_\text{presel} = \log \left[\frac{\sum_S P_S (x)}{\sum_B P_B(x)} \right]$$
#
# where $P_c$ are the probability scores outputted from the softmax layer of the trained NN.

# %%
dataset_incl_nominal.columns.unique()
# Out:
# Index(['PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi',
#        'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi', 'PRI_jet_all_pt',
#        'PRI_jet_leading_eta', 'PRI_n_jets', 'weights', 'detailed_labels',
#        'type', 'train_labels', 'weights_normed'],
#       dtype='object')

# %%
dataset_incl_nominal['has_jets'] = np.where(
    dataset_incl_nominal['PRI_n_jets'] > 0, 1, 0
)

# %%
# Features to use for training NNs
columns = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi']
columns_scaling = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi']

# columns = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi', 'PRI_jet_all_pt', 'PRI_n_jets', 'has_jets']
# columns_scaling = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi', 'PRI_jet_all_pt']

# columns = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi', 'PRI_jet_all_pt', 'PRI_jet_leading_pt', 'PRI_jet_leading_eta', 'has_jets']
# columns_scaling = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi', 'PRI_jet_all_pt', 'PRI_jet_leading_pt', 'PRI_jet_leading_eta']


np.save(f"{saved_data}columns.npy", columns)
np.save(f"{saved_data}columns_scaling.npy", columns_scaling)

# %%
signal_processes = ["htautau"]
background_processes = ["ttbar", "ztautau"]
# background_processes = ["ttbar", "ztautau", "diboson"]

pre_factor = {}

pre_factor['htautau'] = 1.0
pre_factor['ttbar'] = 1.0
pre_factor['ztautau'] = 1.0

np.save(f"{saved_data}signal_processes.npy", signal_processes)
np.save(f"{saved_data}background_processes.npy", background_processes)
np.save(f"{saved_data}pre_factor_preselection.npy", pre_factor)

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import TrainEvaluatePreselNN

num_classes = len(labels_dict)

preselectionTraining = TrainEvaluatePreselNN(dataset_incl_nominal, num_classes, columns, columns_scaling)

# %%
if USE_SAVED_PRESEL_PREDICTIONS:
    presel_score = np.load(f"{saved_data}presel_score.npy")


else:
    if not USE_SAVED_MODEL_PRESEL:
        preselectionTraining.train(test_size=0.2, 
                                   random_state=4242, 
                                   path_to_save=path_to_saved_presel_model,
                                  batch_size=4096,
                                  epochs=50, learning_rate=0.1)
    
    else:
        preselectionTraining.get_trained_model(path_to_saved_presel_model)

    # Get predictions (softmax outputs)
    pred_NN_incl = preselectionTraining.predict(dataset_incl_nominal)

    presel_score = calculate_preselection_observable(pred_NN_incl, labels_dict, signal_processes, background_processes, pre_factor_dict = pre_factor)

    np.save(f"{saved_data}presel_score.npy", presel_score)
    np.save(f"{saved_data}pred_NN_incl.npy", presel_score)

# %%
# mix_model_hypotheses = signal_processes + background_processes
mix_model_hypotheses = background_processes
ref_processes = signal_processes

np.save(f"{saved_data}mix_model_hypotheses.npy", mix_model_hypotheses)
np.save(f"{saved_data}ref_processes.npy", ref_processes)

# %%
min_pred = np.amin(presel_score)
max_pred = np.amax(presel_score)

bins = np.linspace(min_pred, max_pred, num=50)

hist_NN_output = {}
hist_NN_output_errs = {}

for key in labels_dict: 
    hist_NN_output[key], _ = np.histogram(presel_score[train_labels==labels_dict[key]], 
                                          weights = weights[train_labels==labels_dict[key]], bins=bins)
    
    hist_NN_output_errs[key], _ = np.histogram(presel_score[train_labels==labels_dict[key]], 
                                          weights = weights[train_labels==labels_dict[key]]**2, bins=bins)


for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins=bins, 
             alpha=0.6, label=key, 
             density=True, linewidth=2.0, yerr = np.sqrt(hist_NN_output_errs[key]))

plt.xlabel("Preselection Score", size=18)
plt.ylabel("Density", size=18)
plt.legend()
plt.yscale('log')
plt.show()

# %% [markdown]
# Making the cut
# ===
#
# Make a selection cut for regions with $p_{ref} \gg 0$ for performing the NSBI analysis. The remaining events - which by definition are background-dominated - can be used as a **Control Region** for data-driven background estimation, pre-unblinding validations, etc.
#
# Moreover, the preselections act as a tuning know for the tradeoff in selecting as many signal events as possible to go into the **Signal Region** (increasing sensitivity) and the feasibility of training accurate and precise NNs over a large phase space (need bigger models and more statistics). **The preselections can also weed out phase space regions with low background statistics to avoid poorly modelled regions.**
#
# Heres a first cut that you can optimize as much as you like to get the desired final results.

# %%
# Play around with these selections - decrease if estimators are unbiased but need more sensitivity and increase if the model is biased to reduce complexity
preselection_cuts = {'upper': 2.2, 'lower': -0.5}
np.save(f"{saved_data}preselection_cuts.npy", preselection_cuts)


for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins = bins, 
             alpha = 0.6, label = key, 
             density = True, linewidth = 2.0, 
                 yerr = np.sqrt(hist_NN_output_errs[key]))

plt.xlabel("Preselection Score", size=18)

for key in preselection_cuts:
    if preselection_cuts[key] != -999:
        plt.axvline(preselection_cuts[key], ymax=0.9, linestyle='--', label=f'preselection cut {key} = {preselection_cuts[key]}')

plt.ylabel("Density", size=18)
plt.legend(loc='upper left')
plt.yscale('log')
plt.show()

# %% [markdown]
# Signal and Control Regions
# ===
#
# The high signal over background phase space towards the right of the preselection cut shown above will be categorized as the **Signal Region** where the NSBI analysis is performed.
#
# The low signal phase space towards the left will be used as a **Control Region**, with typical uses such as background estimation, pre-unblinding data-MC checks, etc. In this phase space, we will use a binned summary observable like in any traditional analysis.

# %%
dataset_incl_nominal['presel_score'] = presel_score

dataset, dataset_CR = preselection_using_score(dataset_incl_nominal, preselection_cuts)

del dataset_incl_nominal

# %%
# Build a summary observable for Control Region
hist_CR = {}
num_bins = 10

CR_observable='PRI_had_pt'
np.save(f"{saved_data}observable_CR.npy", CR_observable)

kin_variable = dataset_CR[CR_observable].to_numpy()

min_kin = np.amin(kin_variable)
max_kin = np.amax(kin_variable)
min_kin = 30.0
max_kin = 80.0

bins = np.linspace(min_kin, max_kin, num=num_bins)

# Use the high-level preselection NN score as a summary observable for Control Region
for channel_ in labels_dict:
    dataset_CR_process = dataset_CR[dataset_CR.detailed_labels==channel_]
    hist_CR[channel_], bins = np.histogram(np.clip(dataset_CR_process[CR_observable].ravel(), min_kin, max_kin),
                                  weights = dataset_CR_process['weights'].ravel(),
                                  bins = bins)

# Save the Control Region observable
with open(f"{saved_data}hist_CR_ttbar.pkl", "wb") as fp:
    pickle.dump(hist_CR, fp)

np.save(f"{saved_data}CRbins.npy", bins)

# del dataset_CR

# %%
# Plot the Control Region observable

for channel_ in labels_dict:
    hep.histplot(hist_CR[channel_], bins=bins, label=channel_, density=1, linewidth=2.0)

plt.legend()
plt.xlabel('Control Region Observable')
# plt.yscale('log')
plt.ylabel('Density')
# Out:
# Text(0, 1, 'Density')

# %%
# Save the preselected Nominal dataframe for inference use later on
dataset.to_hdf(f"{saved_data}dataset_preselected_nominal_SR.h5", key="dataset", mode='w')

# %%
top_path = f'{path_prefix}output_training_nominal/'

# %% [markdown]
# Density ratio training
# ===
#
# Now we train the NNs for $\frac{p_c}{p_{ref}}(x)$ density ratios to build the full model. Our choice of reference hypothesis, motivated by the search-oriented mixture model described above, is:
#
# $$p_{ref}(x) = p_\text{higgs}(x) = \frac{1}{\nu_{H \to \tau\tau}} \frac{d\sigma_{H \to \tau\tau}}{dx} $$
#
# gives the POI $\mu-$parameterized model:
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} \right]= \mu + \frac{p_{t\bar{t}}\left(x\right)}{p_{H \to \tau\tau}(x)} + \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{H \to \tau\tau}(x)}$$
#
# The task of estimating the $\mu-$parameterized density ratio is thus reduced to estimating two $\mu-$independent density ratios $\frac{p_\text{single top}}{p_{t\bar{t}}}(x)$ and $\frac{p_\text{wjets}}{p_{t\bar{t}}}(x)$ mixed together with an analytical parameterization (hence the name mixture model).

# %%
 dataset['type'] =  dataset['detailed_labels'].to_numpy()

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import TrainEvaluate_NN

mask_ref = np.isin(dataset.detailed_labels, ref_processes)

NN_training_mix_model = {}

rnd_seed_traintestsplit = 42 # can also be randomized, fixed for now

for process_type in mix_model_hypotheses:
    
    mask_process = dataset['type']==process_type
    
    dataset_num = dataset[mask_process].copy()
    dataset_ref = dataset[mask_ref].copy()

    dataset_num['train_labels'] = 1
    dataset_ref['train_labels'] = 0

    dataset_num['weights_normed'] = dataset_num['weights'].to_numpy() / dataset_num['weights'].sum()
    dataset_ref['weights_normed'] = dataset_ref['weights'].to_numpy() / dataset_ref['weights'].sum()

    # Build a training dataset for the training of p_<process_type>/p_<ref_processes> density ratio
    dataset_mix_model = pd.concat([dataset_num, dataset_ref])

    del dataset_num, dataset_ref

    # Save paths
    output_name = f'{process_type}'
    output_dir = f'{top_path}general_output_{process_type}'
    path_to_ratios = f'{top_path}output_ratios_{process_type}/'
    path_to_figures = f'{top_path}output_figures_{process_type}/'
    path_to_models = f'{top_path}output_model_params_{process_type}/'

    NN_training_mix_model[process_type] = TrainEvaluate_NN(dataset_mix_model, 
                                                           dataset_mix_model['weights_normed'],
                                                           dataset_mix_model['train_labels'],
                                                           columns, 
                                                           columns_scaling, rnd_seed_traintestsplit,
                                                           [process_type, 'ref'], output_dir, output_name, 
                                                            path_to_figures=path_to_figures,
                                                            path_to_ratios=path_to_ratios, 
                                                            path_to_models=path_to_models)


    del dataset_mix_model

# %% [markdown]
# Neural Network architecture
# ===
#
# Here we will start with a multi-layer perceptron (simple feed-forward Neural Network with fully-connected layers). This can be supplemented with more complex architectures like transformers.
#
# After detailed tuning during the off-shell Higgs boson analysis effort, we found that a network with very wide layers ($\geq 1000$) and a depth of less than 10 works best - alongside batch size of a few hundreds and a gradually declining learning rate that starts with a value just large enough to not blow up.

# %% [markdown]
# Starting with the training and validation of the various density ratio:
#
# $$\frac{p_{t\bar{t}}(x)}{p_\text{ref}(x)}, \frac{p_{Z \to \tau\tau}(x)}{p_\text{ref}(x)}$$

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 1

# %%
mix_model_hypotheses
# Out:
# ['ttbar', 'ztautau']

# %%
# Define unique settings for each process type

training_settings = {
    'ttbar': {
        'hidden_layers':        2,
        'neurons':              1000,
        'number_of_epochs':     100,
        'batch_size':           512,
        'learning_rate':        0.1,
        'scalerType':           'StandardScaler',
        'calibration':          True,
        'num_bins_cal':         100,
        'callback':             True,
        'callback_patience':    30,
        'callback_factor':      0.01,
        'verbose':              2
    },
    
    'ztautau': {
        'hidden_layers':        2,
        'neurons':              1000,
        'number_of_epochs':     100,
        'batch_size':           512,
        'learning_rate':        1.0,
        'scalerType':           'StandardScaler',
        'calibration':          True,
        'num_bins_cal':         100,
        'callback':             True,
        'callback_patience':    30,
        'callback_factor':      0.01,
        'verbose':              2
    }
}

# %%
# Train the density ratio NN
for process_type in mix_model_hypotheses:
    
    settings = training_settings[process_type]

    NN_training_mix_model[process_type].train(**settings)
    NN_training_mix_model[process_type].test_normalization()
# Out:
# Sum of weights of class 0: 0.6999995708465576
# Sum of weights of class 1: 0.700005292892456
# Using swish activation function
# /home/jaySandesara/.conda/envs/NSBI/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1749072254.178780  277839 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1924 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB MIG 1g.5gb, pci bus id: 0000:c1:00.0, compute capability: 8.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,010,001 (3.85 MB)
#  Trainable params: 1,010,001 (3.85 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1749072255.648065  278271 service.cc:148] XLA service 0x7fcdfc0048f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1749072255.648097  278271 service.cc:156]   StreamExecutor device (0): NVIDIA A100-SXM4-40GB MIG 1g.5gb, Compute Capability 8.0
# 2025-06-04 21:24:15.695186: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1749072255.780801  278271 cuda_dnn.cc:529] Loaded cuDNN version 90501
# 2025-06-04 21:24:16.156444: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion_1', 8 bytes spill stores, 4 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion', 16 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1749072256.161544  278271 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1945/1945 - 6s - 3ms/step - binary_accuracy: 0.6732 - loss: 7.7968e-07 - val_binary_accuracy: 0.6779 - val_loss: 7.7563e-07 - learning_rate: 0.1000
# Epoch 2/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.6887 - loss: 7.5884e-07 - val_binary_accuracy: 0.6875 - val_loss: 7.4952e-07 - learning_rate: 0.1000
# Epoch 3/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.6928 - loss: 7.5306e-07 - val_binary_accuracy: 0.6856 - val_loss: 7.5215e-07 - learning_rate: 0.1000
# Epoch 4/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.6948 - loss: 7.4948e-07 - val_binary_accuracy: 0.6889 - val_loss: 7.4611e-07 - learning_rate: 0.1000
# Epoch 5/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.6958 - loss: 7.4797e-07 - val_binary_accuracy: 0.6921 - val_loss: 7.4263e-07 - learning_rate: 0.1000
# Epoch 6/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.6960 - loss: 7.4413e-07 - val_binary_accuracy: 0.6943 - val_loss: 7.3965e-07 - learning_rate: 0.1000
# Epoch 7/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.6974 - loss: 7.4147e-07 - val_binary_accuracy: 0.6913 - val_loss: 7.4177e-07 - learning_rate: 0.1000
# Epoch 8/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.6962 - loss: 7.4058e-07 - val_binary_accuracy: 0.6961 - val_loss: 7.3458e-07 - learning_rate: 0.1000
# Epoch 9/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.6980 - loss: 7.3956e-07 - val_binary_accuracy: 0.6962 - val_loss: 7.3209e-07 - learning_rate: 0.1000
# Epoch 10/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.6980 - loss: 7.3826e-07 - val_binary_accuracy: 0.6918 - val_loss: 7.4098e-07 - learning_rate: 0.1000
# Epoch 11/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.6992 - loss: 7.3726e-07 - val_binary_accuracy: 0.6955 - val_loss: 7.3458e-07 - learning_rate: 0.1000
# Epoch 12/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.6975 - loss: 7.3756e-07 - val_binary_accuracy: 0.6956 - val_loss: 7.3369e-07 - learning_rate: 0.1000
# Epoch 13/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.6998 - loss: 7.3669e-07 - val_binary_accuracy: 0.6942 - val_loss: 7.3525e-07 - learning_rate: 0.1000
# Epoch 14/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.6990 - loss: 7.3597e-07 - val_binary_accuracy: 0.6954 - val_loss: 7.2999e-07 - learning_rate: 0.1000
# Epoch 15/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.6997 - loss: 7.3503e-07 - val_binary_accuracy: 0.6930 - val_loss: 7.3115e-07 - learning_rate: 0.1000
# Epoch 16/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7003 - loss: 7.3425e-07 - val_binary_accuracy: 0.6968 - val_loss: 7.3823e-07 - learning_rate: 0.1000
# Epoch 17/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7011 - loss: 7.3456e-07 - val_binary_accuracy: 0.6991 - val_loss: 7.2988e-07 - learning_rate: 0.1000
# Epoch 18/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7007 - loss: 7.3369e-07 - val_binary_accuracy: 0.6929 - val_loss: 7.3655e-07 - learning_rate: 0.1000
# Epoch 19/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7003 - loss: 7.3417e-07 - val_binary_accuracy: 0.6966 - val_loss: 7.2852e-07 - learning_rate: 0.1000
# Epoch 20/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7007 - loss: 7.3391e-07 - val_binary_accuracy: 0.6931 - val_loss: 7.3463e-07 - learning_rate: 0.1000
# Epoch 21/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7017 - loss: 7.3336e-07 - val_binary_accuracy: 0.6972 - val_loss: 7.2863e-07 - learning_rate: 0.1000
# Epoch 22/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7009 - loss: 7.3345e-07 - val_binary_accuracy: 0.6972 - val_loss: 7.2713e-07 - learning_rate: 0.1000
# Epoch 23/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7003 - loss: 7.3284e-07 - val_binary_accuracy: 0.6982 - val_loss: 7.4030e-07 - learning_rate: 0.1000
# Epoch 24/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7009 - loss: 7.3292e-07 - val_binary_accuracy: 0.6988 - val_loss: 7.2992e-07 - learning_rate: 0.1000
# Epoch 25/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7016 - loss: 7.3252e-07 - val_binary_accuracy: 0.6981 - val_loss: 7.2727e-07 - learning_rate: 0.1000
# Epoch 26/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7011 - loss: 7.3291e-07 - val_binary_accuracy: 0.6988 - val_loss: 7.3055e-07 - learning_rate: 0.1000
# Epoch 27/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7003 - loss: 7.3235e-07 - val_binary_accuracy: 0.6973 - val_loss: 7.2791e-07 - learning_rate: 0.1000
# Epoch 28/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7016 - loss: 7.3235e-07 - val_binary_accuracy: 0.6957 - val_loss: 7.3462e-07 - learning_rate: 0.1000
# Epoch 29/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7015 - loss: 7.3251e-07 - val_binary_accuracy: 0.7002 - val_loss: 7.2989e-07 - learning_rate: 0.1000
# Epoch 30/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7007 - loss: 7.3277e-07 - val_binary_accuracy: 0.6975 - val_loss: 7.2500e-07 - learning_rate: 0.1000
# Epoch 31/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7015 - loss: 7.3212e-07 - val_binary_accuracy: 0.6936 - val_loss: 7.2910e-07 - learning_rate: 0.1000
# Epoch 32/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7044 - loss: 7.2565e-07 - val_binary_accuracy: 0.6986 - val_loss: 7.2199e-07 - learning_rate: 0.0010
# Epoch 33/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7062 - loss: 7.2243e-07 - val_binary_accuracy: 0.6997 - val_loss: 7.2092e-07 - learning_rate: 0.0010
# Epoch 34/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7067 - loss: 7.2131e-07 - val_binary_accuracy: 0.7003 - val_loss: 7.2050e-07 - learning_rate: 0.0010
# Epoch 35/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7074 - loss: 7.2075e-07 - val_binary_accuracy: 0.7017 - val_loss: 7.1991e-07 - learning_rate: 0.0010
# Epoch 36/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7077 - loss: 7.2034e-07 - val_binary_accuracy: 0.7007 - val_loss: 7.1965e-07 - learning_rate: 0.0010
# Epoch 37/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7075 - loss: 7.2006e-07 - val_binary_accuracy: 0.7020 - val_loss: 7.1919e-07 - learning_rate: 0.0010
# Epoch 38/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7079 - loss: 7.1979e-07 - val_binary_accuracy: 0.7033 - val_loss: 7.1885e-07 - learning_rate: 0.0010
# Epoch 39/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7078 - loss: 7.1965e-07 - val_binary_accuracy: 0.7030 - val_loss: 7.1852e-07 - learning_rate: 0.0010
# Epoch 40/100
# 1945/1945 - 3s - 2ms/step - binary_accuracy: 0.7078 - loss: 7.1948e-07 - val_binary_accuracy: 0.7036 - val_loss: 7.1841e-07 - learning_rate: 0.0010
# Epoch 41/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7076 - loss: 7.1935e-07 - val_binary_accuracy: 0.7036 - val_loss: 7.1822e-07 - learning_rate: 0.0010
# Epoch 42/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7076 - loss: 7.1923e-07 - val_binary_accuracy: 0.7035 - val_loss: 7.1810e-07 - learning_rate: 0.0010
# Epoch 43/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7076 - loss: 7.1915e-07 - val_binary_accuracy: 0.7031 - val_loss: 7.1812e-07 - learning_rate: 0.0010
# Epoch 44/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7077 - loss: 7.1902e-07 - val_binary_accuracy: 0.7030 - val_loss: 7.1803e-07 - learning_rate: 0.0010
# Epoch 45/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7078 - loss: 7.1897e-07 - val_binary_accuracy: 0.7044 - val_loss: 7.1783e-07 - learning_rate: 0.0010
# Epoch 46/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7075 - loss: 7.1890e-07 - val_binary_accuracy: 0.7034 - val_loss: 7.1786e-07 - learning_rate: 0.0010
# Epoch 47/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7077 - loss: 7.1884e-07 - val_binary_accuracy: 0.7035 - val_loss: 7.1801e-07 - learning_rate: 0.0010
# Epoch 48/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7079 - loss: 7.1876e-07 - val_binary_accuracy: 0.7031 - val_loss: 7.1790e-07 - learning_rate: 0.0010
# Epoch 49/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7077 - loss: 7.1866e-07 - val_binary_accuracy: 0.7033 - val_loss: 7.1762e-07 - learning_rate: 0.0010
# Epoch 50/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7077 - loss: 7.1864e-07 - val_binary_accuracy: 0.7033 - val_loss: 7.1767e-07 - learning_rate: 0.0010
# Epoch 51/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7077 - loss: 7.1861e-07 - val_binary_accuracy: 0.7030 - val_loss: 7.1766e-07 - learning_rate: 0.0010
# Epoch 52/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7079 - loss: 7.1854e-07 - val_binary_accuracy: 0.7032 - val_loss: 7.1760e-07 - learning_rate: 0.0010
# Epoch 53/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7080 - loss: 7.1849e-07 - val_binary_accuracy: 0.7033 - val_loss: 7.1771e-07 - learning_rate: 0.0010
# Epoch 54/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7077 - loss: 7.1844e-07 - val_binary_accuracy: 0.7036 - val_loss: 7.1751e-07 - learning_rate: 0.0010
# Epoch 55/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7078 - loss: 7.1843e-07 - val_binary_accuracy: 0.7039 - val_loss: 7.1733e-07 - learning_rate: 0.0010
# Epoch 56/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7081 - loss: 7.1838e-07 - val_binary_accuracy: 0.7036 - val_loss: 7.1739e-07 - learning_rate: 0.0010
# Epoch 57/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7081 - loss: 7.1834e-07 - val_binary_accuracy: 0.7036 - val_loss: 7.1755e-07 - learning_rate: 0.0010
# Epoch 58/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1829e-07 - val_binary_accuracy: 0.7033 - val_loss: 7.1742e-07 - learning_rate: 0.0010
# Epoch 59/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7081 - loss: 7.1826e-07 - val_binary_accuracy: 0.7034 - val_loss: 7.1729e-07 - learning_rate: 0.0010
# Epoch 60/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7080 - loss: 7.1820e-07 - val_binary_accuracy: 0.7025 - val_loss: 7.1743e-07 - learning_rate: 0.0010
# Epoch 61/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7085 - loss: 7.1821e-07 - val_binary_accuracy: 0.7030 - val_loss: 7.1729e-07 - learning_rate: 0.0010
# Epoch 62/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1795e-07 - val_binary_accuracy: 0.7033 - val_loss: 7.1729e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1794e-07 - val_binary_accuracy: 0.7031 - val_loss: 7.1729e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1793e-07 - val_binary_accuracy: 0.7031 - val_loss: 7.1730e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1793e-07 - val_binary_accuracy: 0.7029 - val_loss: 7.1730e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1793e-07 - val_binary_accuracy: 0.7029 - val_loss: 7.1731e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1793e-07 - val_binary_accuracy: 0.7028 - val_loss: 7.1731e-07 - learning_rate: 1.0000e-05
# Epoch 68/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7084 - loss: 7.1792e-07 - val_binary_accuracy: 0.7028 - val_loss: 7.1731e-07 - learning_rate: 1.0000e-05
# Epoch 69/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7084 - loss: 7.1792e-07 - val_binary_accuracy: 0.7028 - val_loss: 7.1732e-07 - learning_rate: 1.0000e-05
# Epoch 70/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7084 - loss: 7.1792e-07 - val_binary_accuracy: 0.7027 - val_loss: 7.1732e-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7084 - loss: 7.1792e-07 - val_binary_accuracy: 0.7031 - val_loss: 7.1732e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1792e-07 - val_binary_accuracy: 0.7030 - val_loss: 7.1732e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1791e-07 - val_binary_accuracy: 0.7030 - val_loss: 7.1732e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1791e-07 - val_binary_accuracy: 0.7029 - val_loss: 7.1732e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1791e-07 - val_binary_accuracy: 0.7029 - val_loss: 7.1733e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1791e-07 - val_binary_accuracy: 0.7029 - val_loss: 7.1733e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1791e-07 - val_binary_accuracy: 0.7029 - val_loss: 7.1733e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7084 - loss: 7.1791e-07 - val_binary_accuracy: 0.7029 - val_loss: 7.1733e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1791e-07 - val_binary_accuracy: 0.7029 - val_loss: 7.1733e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1791e-07 - val_binary_accuracy: 0.7029 - val_loss: 7.1733e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1791e-07 - val_binary_accuracy: 0.7029 - val_loss: 7.1733e-07 - learning_rate: 1.0000e-05
# Epoch 82/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1791e-07 - val_binary_accuracy: 0.7029 - val_loss: 7.1733e-07 - learning_rate: 1.0000e-05
# Epoch 83/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1791e-07 - val_binary_accuracy: 0.7027 - val_loss: 7.1734e-07 - learning_rate: 1.0000e-05
# Epoch 84/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1791e-07 - val_binary_accuracy: 0.7027 - val_loss: 7.1733e-07 - learning_rate: 1.0000e-05
# Epoch 85/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1791e-07 - val_binary_accuracy: 0.7027 - val_loss: 7.1734e-07 - learning_rate: 1.0000e-05
# Epoch 86/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1791e-07 - val_binary_accuracy: 0.7027 - val_loss: 7.1734e-07 - learning_rate: 1.0000e-05
# Epoch 87/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1791e-07 - val_binary_accuracy: 0.7027 - val_loss: 7.1734e-07 - learning_rate: 1.0000e-05
# Epoch 88/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1791e-07 - val_binary_accuracy: 0.7027 - val_loss: 7.1734e-07 - learning_rate: 1.0000e-05
# Epoch 89/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1791e-07 - val_binary_accuracy: 0.7029 - val_loss: 7.1734e-07 - learning_rate: 1.0000e-05
# Epoch 90/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1791e-07 - val_binary_accuracy: 0.7028 - val_loss: 7.1734e-07 - learning_rate: 1.0000e-05
# Epoch 91/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1791e-07 - val_binary_accuracy: 0.7028 - val_loss: 7.1734e-07 - learning_rate: 1.0000e-05
# Epoch 92/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1790e-07 - val_binary_accuracy: 0.7028 - val_loss: 7.1734e-07 - learning_rate: 1.0000e-07
# Epoch 93/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1790e-07 - val_binary_accuracy: 0.7028 - val_loss: 7.1734e-07 - learning_rate: 1.0000e-07
# Epoch 94/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1790e-07 - val_binary_accuracy: 0.7028 - val_loss: 7.1734e-07 - learning_rate: 1.0000e-07
# Epoch 95/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1790e-07 - val_binary_accuracy: 0.7028 - val_loss: 7.1734e-07 - learning_rate: 1.0000e-07
# Epoch 96/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1790e-07 - val_binary_accuracy: 0.7028 - val_loss: 7.1734e-07 - learning_rate: 1.0000e-07
# Epoch 97/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1790e-07 - val_binary_accuracy: 0.7028 - val_loss: 7.1734e-07 - learning_rate: 1.0000e-07
# Epoch 98/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1790e-07 - val_binary_accuracy: 0.7028 - val_loss: 7.1734e-07 - learning_rate: 1.0000e-07
# Epoch 99/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1790e-07 - val_binary_accuracy: 0.7028 - val_loss: 7.1734e-07 - learning_rate: 1.0000e-07
# Epoch 100/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1790e-07 - val_binary_accuracy: 0.7028 - val_loss: 7.1734e-07 - learning_rate: 1.0000e-07
# Finished Training
# /home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/output_training_nominal/output_model_params_ttbar/model_scaler.bin
# 34567/34567 - 38s - 1ms/step
# 0.011841331
# 0.95069826
# 34567/34567 - 38s - 1ms/step
# 14814/14814 - 17s - 1ms/step
# 49381/49381 - 27s - 545us/step
# The sum of PDFs is 0.9998522996902466
# Sum of weights of class 0: 0.6999996304512024
# Sum of weights of class 1: 0.700001060962677
# Using swish activation function
# /home/jaySandesara/.conda/envs/NSBI/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 1000)           │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,010,001 (3.85 MB)
#  Trainable params: 1,010,001 (3.85 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# 2025-06-04 21:33:53.769596: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion_1', 8 bytes spill stores, 4 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion', 16 bytes spill stores, 20 bytes spill loads
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6691 - loss: 4.9006e-07 - val_binary_accuracy: 0.6783 - val_loss: 4.7955e-07 - learning_rate: 0.1000
# Epoch 2/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6819 - loss: 4.7610e-07 - val_binary_accuracy: 0.6806 - val_loss: 4.7653e-07 - learning_rate: 0.1000
# Epoch 3/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6824 - loss: 4.7506e-07 - val_binary_accuracy: 0.6813 - val_loss: 4.7602e-07 - learning_rate: 0.1000
# Epoch 4/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6835 - loss: 4.7411e-07 - val_binary_accuracy: 0.6815 - val_loss: 4.7497e-07 - learning_rate: 0.1000
# Epoch 5/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6849 - loss: 4.7278e-07 - val_binary_accuracy: 0.6825 - val_loss: 4.7455e-07 - learning_rate: 0.1000
# Epoch 6/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6859 - loss: 4.7152e-07 - val_binary_accuracy: 0.6823 - val_loss: 4.7295e-07 - learning_rate: 0.1000
# Epoch 7/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6862 - loss: 4.7060e-07 - val_binary_accuracy: 0.6845 - val_loss: 4.7228e-07 - learning_rate: 0.1000
# Epoch 8/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6868 - loss: 4.6994e-07 - val_binary_accuracy: 0.6856 - val_loss: 4.7109e-07 - learning_rate: 0.1000
# Epoch 9/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6873 - loss: 4.6922e-07 - val_binary_accuracy: 0.6854 - val_loss: 4.7068e-07 - learning_rate: 0.1000
# Epoch 10/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6875 - loss: 4.6872e-07 - val_binary_accuracy: 0.6856 - val_loss: 4.7074e-07 - learning_rate: 0.1000
# Epoch 11/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6880 - loss: 4.6808e-07 - val_binary_accuracy: 0.6867 - val_loss: 4.6904e-07 - learning_rate: 0.1000
# Epoch 12/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6891 - loss: 4.6717e-07 - val_binary_accuracy: 0.6869 - val_loss: 4.6935e-07 - learning_rate: 0.1000
# Epoch 13/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6906 - loss: 4.6594e-07 - val_binary_accuracy: 0.6884 - val_loss: 4.6758e-07 - learning_rate: 0.1000
# Epoch 14/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6916 - loss: 4.6518e-07 - val_binary_accuracy: 0.6890 - val_loss: 4.6659e-07 - learning_rate: 0.1000
# Epoch 15/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6919 - loss: 4.6472e-07 - val_binary_accuracy: 0.6901 - val_loss: 4.6605e-07 - learning_rate: 0.1000
# Epoch 16/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6923 - loss: 4.6444e-07 - val_binary_accuracy: 0.6890 - val_loss: 4.6741e-07 - learning_rate: 0.1000
# Epoch 17/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6922 - loss: 4.6430e-07 - val_binary_accuracy: 0.6898 - val_loss: 4.6631e-07 - learning_rate: 0.1000
# Epoch 18/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6923 - loss: 4.6413e-07 - val_binary_accuracy: 0.6903 - val_loss: 4.6549e-07 - learning_rate: 0.1000
# Epoch 19/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6927 - loss: 4.6397e-07 - val_binary_accuracy: 0.6895 - val_loss: 4.6613e-07 - learning_rate: 0.1000
# Epoch 20/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6927 - loss: 4.6385e-07 - val_binary_accuracy: 0.6899 - val_loss: 4.6626e-07 - learning_rate: 0.1000
# Epoch 21/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6928 - loss: 4.6377e-07 - val_binary_accuracy: 0.6900 - val_loss: 4.6548e-07 - learning_rate: 0.1000
# Epoch 22/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6929 - loss: 4.6359e-07 - val_binary_accuracy: 0.6895 - val_loss: 4.6600e-07 - learning_rate: 0.1000
# Epoch 23/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6932 - loss: 4.6349e-07 - val_binary_accuracy: 0.6907 - val_loss: 4.6543e-07 - learning_rate: 0.1000
# Epoch 24/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6932 - loss: 4.6336e-07 - val_binary_accuracy: 0.6903 - val_loss: 4.6540e-07 - learning_rate: 0.1000
# Epoch 25/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6933 - loss: 4.6326e-07 - val_binary_accuracy: 0.6907 - val_loss: 4.6536e-07 - learning_rate: 0.1000
# Epoch 26/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6933 - loss: 4.6322e-07 - val_binary_accuracy: 0.6912 - val_loss: 4.6533e-07 - learning_rate: 0.1000
# Epoch 27/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6935 - loss: 4.6303e-07 - val_binary_accuracy: 0.6905 - val_loss: 4.6545e-07 - learning_rate: 0.1000
# Epoch 28/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6934 - loss: 4.6300e-07 - val_binary_accuracy: 0.6918 - val_loss: 4.6458e-07 - learning_rate: 0.1000
# Epoch 29/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6936 - loss: 4.6294e-07 - val_binary_accuracy: 0.6907 - val_loss: 4.6566e-07 - learning_rate: 0.1000
# Epoch 30/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6936 - loss: 4.6282e-07 - val_binary_accuracy: 0.6906 - val_loss: 4.6486e-07 - learning_rate: 0.1000
# Epoch 31/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6938 - loss: 4.6277e-07 - val_binary_accuracy: 0.6908 - val_loss: 4.6525e-07 - learning_rate: 0.1000
# Epoch 32/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6157e-07 - val_binary_accuracy: 0.6923 - val_loss: 4.6368e-07 - learning_rate: 0.0010
# Epoch 33/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6951 - loss: 4.6127e-07 - val_binary_accuracy: 0.6925 - val_loss: 4.6361e-07 - learning_rate: 0.0010
# Epoch 34/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6951 - loss: 4.6121e-07 - val_binary_accuracy: 0.6926 - val_loss: 4.6358e-07 - learning_rate: 0.0010
# Epoch 35/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6951 - loss: 4.6118e-07 - val_binary_accuracy: 0.6929 - val_loss: 4.6358e-07 - learning_rate: 0.0010
# Epoch 36/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6952 - loss: 4.6116e-07 - val_binary_accuracy: 0.6928 - val_loss: 4.6356e-07 - learning_rate: 0.0010
# Epoch 37/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6952 - loss: 4.6114e-07 - val_binary_accuracy: 0.6929 - val_loss: 4.6354e-07 - learning_rate: 0.0010
# Epoch 38/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6952 - loss: 4.6113e-07 - val_binary_accuracy: 0.6928 - val_loss: 4.6353e-07 - learning_rate: 0.0010
# Epoch 39/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6952 - loss: 4.6112e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6354e-07 - learning_rate: 0.0010
# Epoch 40/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6953 - loss: 4.6111e-07 - val_binary_accuracy: 0.6926 - val_loss: 4.6351e-07 - learning_rate: 0.0010
# Epoch 41/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6952 - loss: 4.6110e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6352e-07 - learning_rate: 0.0010
# Epoch 42/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6953 - loss: 4.6109e-07 - val_binary_accuracy: 0.6923 - val_loss: 4.6351e-07 - learning_rate: 0.0010
# Epoch 43/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6953 - loss: 4.6109e-07 - val_binary_accuracy: 0.6926 - val_loss: 4.6352e-07 - learning_rate: 0.0010
# Epoch 44/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6952 - loss: 4.6108e-07 - val_binary_accuracy: 0.6925 - val_loss: 4.6350e-07 - learning_rate: 0.0010
# Epoch 45/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6953 - loss: 4.6108e-07 - val_binary_accuracy: 0.6928 - val_loss: 4.6351e-07 - learning_rate: 0.0010
# Epoch 46/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6953 - loss: 4.6107e-07 - val_binary_accuracy: 0.6926 - val_loss: 4.6349e-07 - learning_rate: 0.0010
# Epoch 47/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6953 - loss: 4.6106e-07 - val_binary_accuracy: 0.6925 - val_loss: 4.6348e-07 - learning_rate: 0.0010
# Epoch 48/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6953 - loss: 4.6106e-07 - val_binary_accuracy: 0.6924 - val_loss: 4.6350e-07 - learning_rate: 0.0010
# Epoch 49/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6953 - loss: 4.6106e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6349e-07 - learning_rate: 0.0010
# Epoch 50/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6953 - loss: 4.6105e-07 - val_binary_accuracy: 0.6926 - val_loss: 4.6350e-07 - learning_rate: 0.0010
# Epoch 51/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6953 - loss: 4.6105e-07 - val_binary_accuracy: 0.6926 - val_loss: 4.6351e-07 - learning_rate: 0.0010
# Epoch 52/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6953 - loss: 4.6105e-07 - val_binary_accuracy: 0.6926 - val_loss: 4.6348e-07 - learning_rate: 0.0010
# Epoch 53/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6953 - loss: 4.6104e-07 - val_binary_accuracy: 0.6926 - val_loss: 4.6348e-07 - learning_rate: 0.0010
# Epoch 54/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6953 - loss: 4.6104e-07 - val_binary_accuracy: 0.6926 - val_loss: 4.6347e-07 - learning_rate: 0.0010
# Epoch 55/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6953 - loss: 4.6103e-07 - val_binary_accuracy: 0.6926 - val_loss: 4.6349e-07 - learning_rate: 0.0010
# Epoch 56/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6953 - loss: 4.6104e-07 - val_binary_accuracy: 0.6926 - val_loss: 4.6346e-07 - learning_rate: 0.0010
# Epoch 57/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6953 - loss: 4.6103e-07 - val_binary_accuracy: 0.6926 - val_loss: 4.6346e-07 - learning_rate: 0.0010
# Epoch 58/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6103e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6347e-07 - learning_rate: 0.0010
# Epoch 59/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6102e-07 - val_binary_accuracy: 0.6926 - val_loss: 4.6346e-07 - learning_rate: 0.0010
# Epoch 60/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6102e-07 - val_binary_accuracy: 0.6925 - val_loss: 4.6345e-07 - learning_rate: 0.0010
# Epoch 61/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6953 - loss: 4.6102e-07 - val_binary_accuracy: 0.6926 - val_loss: 4.6346e-07 - learning_rate: 0.0010
# Epoch 62/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6926 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6926 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6926 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6926 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 68/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 69/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 70/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 82/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 83/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 84/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6346e-07 - learning_rate: 1.0000e-05
# Epoch 85/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6345e-07 - learning_rate: 1.0000e-05
# Epoch 86/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6345e-07 - learning_rate: 1.0000e-05
# Epoch 87/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6345e-07 - learning_rate: 1.0000e-05
# Epoch 88/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6345e-07 - learning_rate: 1.0000e-05
# Epoch 89/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6345e-07 - learning_rate: 1.0000e-05
# Epoch 90/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6345e-07 - learning_rate: 1.0000e-05
# Epoch 91/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6345e-07 - learning_rate: 1.0000e-05
# Epoch 92/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6345e-07 - learning_rate: 1.0000e-07
# Epoch 93/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6345e-07 - learning_rate: 1.0000e-07
# Epoch 94/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6345e-07 - learning_rate: 1.0000e-07
# Epoch 95/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6345e-07 - learning_rate: 1.0000e-07
# Epoch 96/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6345e-07 - learning_rate: 1.0000e-07
# Epoch 97/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6345e-07 - learning_rate: 1.0000e-07
# Epoch 98/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6345e-07 - learning_rate: 1.0000e-07
# Epoch 99/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6345e-07 - learning_rate: 1.0000e-07
# Epoch 100/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6954 - loss: 4.6099e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6345e-07 - learning_rate: 1.0000e-07
# Finished Training
# /home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/output_training_nominal/output_model_params_ztautau/model_scaler.bin
# 55914/55914 - 64s - 1ms/step
# 4.121473e-06
# 0.928463
# 55914/55914 - 59s - 1ms/step
# 23963/23963 - 23s - 959us/step
# 79877/79877 - 57s - 712us/step
# The sum of PDFs is 0.9993261694908142

# %% [markdown]
# Check for overtraining by comparing the NN output distributions between training and holdout datasets. The holdout dataset is the subset of events not used during training.

# %%
for process_type in mix_model_hypotheses:
    NN_training_mix_model[process_type].make_overfit_plots()

# %% [markdown]
# Diagnostic Checks
# ===
#
# While traditionally, a NN observable is judged on the basis of its accuracy - for NSBI we are interested in the quality of the density ratios more than the discrimination power. The latter comes from the perfect modelling of the multi-dimensional likelihood ratios.
#
# To ensure correct modelling, we run two main checks on the training:
#
# - **Calibration closure test**
#
#   The NNs are trained using the binary cross-entropy loss, which under ideal conditions leads to the NN converging to the score function:
#
#   $$\hat{s}_\text{pred} = \frac{p_\text{ref}(x)}{p_\text{ref}(x)+p_\text{c}(x)}$$
#
#   that can be converted into the probability ratio we desire (likelihood ratio trick):
#
#   $$\frac{p_\text{c}(x)}{p_\text{ref}(x)} = \frac{\hat{s}_\text{pred}(x)}{1-\hat{s}_\text{pred}(x)}$$
#
#   For the NNs to be well-calibrated, we use the Monte Carlo samples to verify the equality:
#
#
#   $$\left[\frac{p_c(x)}{p_c(x)+p_{ref}(x)}\right]_\text{NN} \sim \left[\frac{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}}{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}+\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}}\right]_\text{MC}$$
#
#   where we bin the events from $p_c$ and $p_\text{ref}$ MC samples, denoted by $\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}$ and $\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}$ respectively where $I(x|\hat{s}_\text{pred})$ returns the index of the $\hat{s}_\text{pred}$ bin in which an event $x$ falls.

# %%
num_bins_cal = 50

for process_type in mix_model_hypotheses:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='score')
# Out:
# observable not recognized
# observable not recognized

# %%
num_bins_cal = 50

for process_type in mix_model_hypotheses:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='llr')

# %% [markdown]
# - **Density ratio reweighting closure tests**
#
#   Despite having a well-calibrated output and thus a robust probabilistic interpretation, the trained density ratios might not capture the full multi-dimensional event information $x$. In other words, the NNs might still be biased estimators of the optimal score function, as defined in the CARL paper (link).
#
#   The next diagnostic involves verifying the following equality using 1D projections of $x$:
#
#   $$\frac{p_c(x)}{p_{ref}(x)} \times p_{ref}(x) \sim p_c(x)$$
#
#   We can do this one-by-one for all the observables used to model the density ratios, and also possibly the observables not used directly in the training but can still be well-estimated due to the NN learning the right physics.

# %%
variables_to_plot=['PRI_lep_pt'] # The 1D variable for reweighting closure
yscale_type='log'
num_bins_plotting=21

for process_type in mix_model_hypotheses:

    NN_training_mix_model[process_type].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
for process_type in mix_model_hypotheses:
    # Evaluate the density ratios p_c/p_ref for the full dataset and save for the inference step
    NN_training_mix_model[process_type].evaluate_and_save_ratios(dataset)

# %% [markdown]
# Systematic Uncertainty Modelling
# ===
#
# So far we have left out the nuisance parameter piece of the parameterized density ratio decomposition shown before:
#
# $$g_c(x|\alpha) = \frac{p_c(x|\alpha)}{p_c(x)}$$
#
# which will be estimated in the `Systematic_Uncertainty_Estimation.ipynb` notebook.

# %% [markdown]
# Training an Ensemble of NNs
# ===
#
# In a realistic analysis, a large ensemble of NNs are trained to estimate density ratios, for *each* of the channels. **This reduces not only the variance but has also been found to reduce biases in the final fits.**
#
# In the off-shell Higgs boson analysis, we used k-fold cross-validation, with k=10, to train an ensemble $N_{ens}\sim 250$ of NNs per density ratio $p_c(x)/p_{ref}(x)$. The density ratios used in the final fit are always evaluated on the holdout dataset and by using each of the folds as holdout once, the entire model for $p_c(x)/p_{ref}(x)$ consists of $N_{ens}\times k \sim 2500$ NNs. Each NN in the ensemble is trained by resampling data without replacement from the k-1 folds used for training.
