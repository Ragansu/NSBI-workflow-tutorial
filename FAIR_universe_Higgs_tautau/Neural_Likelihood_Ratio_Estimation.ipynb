# %% [markdown]
# Train Neural Networks to estimate Likelihood Ratios
# ===
#
# In this notebook we will setup the neural networks that train unbiased and low-variance density ratios to be then used for inference. The statistical model we have is:
#
# $$p(x|\mu, \alpha) = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot p_c\left(x|\alpha\right)$$
#
# where $c$ stands for the various physics channels that contribute to the final state $x$, $\mu$ is the signal-strength parameter and $\alpha$ is the vector of nuisance parameters associated with the various systematic uncertainties in the model. Note that we are assuming that the parameter $\mu$-dependence is known analytically and that we have simulation models for each of the channels $p_c(x)$.
#
# The objective is to build the test statistic for composite hypothesis testing:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})}{p(x_i|\hat{\mu}, \hat{\alpha})} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
# A direct approach would then be to model the probability density $p(x|\mu, \alpha)$ using NNs. But that is a more difficult task than training probability density ratios. We use a simple trick:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})/p_{ref}(x)}{p(x_i|\hat{\mu}, \hat{\alpha})/p_{ref}(x)} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
#
# to turn this into a density ratio estimation problem:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot \frac{p_c\left(x|\alpha\right)}{p_{ref}(x)}$$
#
# Factorizing out the $\alpha$-dependence in the density ratios:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\sum_c G_c(\alpha) \cdot f_c(\mu) \cdot \nu_c} \sum_c f_c(\mu) \cdot G_c(\alpha)\cdot \nu_c \cdot g_c(x|\alpha) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}$$
#
# **Factorized approach:**
#
# Instead of training NNs parameterized on $\mu$ and $\alpha$, we use analytical parameterizations to simplify the problem to training only parameter-independent density ratios.
#
# Let's set this up for the toy ttbar model we are using. Neglecting the nuisance parameter dependence for now,
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}\right] = \mu \cdot \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)} + \frac{p_{t\bar{t}}\left(x\right)}{p_{ref}(x)} + \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)}$$

# %%
import os, sys, importlib
sys.path.append('../')

import nsbi_common_utils
from nsbi_common_utils import plotting, training
from nsbi_common_utils.training import TrainEvaluate_NN, TrainEvaluatePreselNN
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt
import pickle

from coffea.analysis_tools import PackedSelection

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

hep.style.use(hep.style.ATLAS)
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/src/nsbi_common_utils/plotting.py:10: FutureWarning: ``set_style`` is deprecated: Naming convention is changing to match mpl. Use ``mplhep.style.use()``.
#   hep.set_style("ATLAS")
# 2025-06-03 10:09:27.200952: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748945367.214968     247 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748945367.219523     247 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-03 10:09:27.237148: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# If the preselection NN has already been trained and saved, load from the saved model
USE_SAVED_MODEL_PRESEL=True
# If the preselection NN has already been trained and evaluated, load the numpy array of predictions
USE_SAVED_PRESEL_PREDICTIONS=True

path_prefix = '/home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/'

# Path for saving interemdiate objects, like NN predictions
saved_data = f'{path_prefix}cached_data/'

# Path for saving/loading preselection NN model
path_to_saved_presel_model = f'{path_prefix}preselection_saved_NN/'

# %%
# Load the inclusive dataset saved from the pre-processing notebook
dataset_incl_nominal = pd.read_hdf(f"{saved_data}df_inclusive.h5", key="dataset", mode='r')

# Isolate the nominal dataset, ignore systematics in this notebook
# mask_nominal = dataset_incl.syst_labels=='nominal'
# dataset_incl_nominal = dataset_incl[mask_nominal].copy()

# Load the MC/data weights and training labels identifying different processes
weights = dataset_incl_nominal.weights.to_numpy()
train_labels = dataset_incl_nominal.train_labels.to_numpy()

# %%
# Get the dictionary of labels to processes
labels_dict = np.load(f"{saved_data}labels_dictionary.npy", allow_pickle=True).item()

# %%
# Normalizing the training weights - only discriminating shapes, not norms
weights_normed = weights.copy()

for key in labels_dict:

    weights_normed[train_labels==labels_dict[key]] /= weights[train_labels==labels_dict[key]].sum()

dataset_incl_nominal['weights_normed'] = weights_normed

# %% [markdown]
# Training the Preselection NN
# ===

# %% [markdown]
# **Choice of reference sample**
#
# The density ratios need to be trained on phase space regions with support for the reference hypothesis $p_{ref}(x) > 0$.
#
# To ensure this, we make a selection that selects events in the phase space regions with $p_{ref}(x) > 0$, or $p_c(x) \gg p_{ref}(x)$, and only perform the NSBI fit in this selected analysis region. **A natural choice for the reference hypothesis is then the signal-rich hypotheses**. This is referred to in the ATLAS publications as the Search-Oriented Mixture Models approach:
#
# $$p_{ref}(x) = \frac{1}{\sum_S \nu_S} \sum_S \frac{d\sigma_S}{dx} = \frac{1}{\nu_{H \to \tau\tau}} \frac{d\sigma_{H \to \tau\tau}}{dx}$$
#
# where the sum runs over all signal hypothesis in the model and the second equality is due to the sole signal hypothesis in our toy model, $pp \to {t\bar{t}}$.
#
# **Selecting out regions with $p_{ref}\sim 0$**
#
# A multi-class classification NN, with softmax output, is trained to output a score:
#
# $$ \text{NN}_\text{presel} = \log \left[\frac{\sum_S P_S (x)}{\sum_B P_B(x)} \right]$$
#
# where $P_c$ are the probability scores outputted from the softmax layer of the trained NN.

# %%
dataset_incl_nominal.columns.unique()
# Out:
# Index(['PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_had_pt', 'PRI_had_eta',
#        'PRI_had_phi', 'PRI_jet_leading_pt', 'PRI_jet_leading_eta',
#        'PRI_jet_leading_phi', 'PRI_jet_subleading_pt',
#        'PRI_jet_subleading_eta', 'PRI_jet_subleading_phi', 'PRI_n_jets',
#        'PRI_jet_all_pt', 'PRI_met', 'PRI_met_phi', 'weights',
#        'detailed_labels', 'labels', 'DER_mass_transverse_met_lep',
#        'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet',
#        'DER_prodeta_jet_jet', 'DER_deltar_had_lep', 'DER_pt_tot', 'DER_sum_pt',
#        'DER_pt_ratio_lep_had', 'DER_met_phi_centrality',
#        'DER_lep_eta_centrality', 'train_labels', 'weights_normed'],
#       dtype='object')

# %%
# Features to use for training NNs
columns = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi']
columns_scaling = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi']

np.save(f"{saved_data}columns.npy", columns)
np.save(f"{saved_data}columns_scaling.npy", columns_scaling)

# %%
print(labels_dict)
# Out:
# {'htautau': 0, 'ztautau': 1, 'ttbar': 2}

# %%
signal_processes = ["htautau"]
background_processes = ["ttbar", "ztautau"]
# background_processes = ["ttbar", "ztautau", "diboson"]

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import TrainEvaluatePreselNN

num_classes = len(labels_dict)

preselectionTraining = TrainEvaluatePreselNN(dataset_incl_nominal, num_classes, columns, columns_scaling)

# %%
if USE_SAVED_PRESEL_PREDICTIONS:
    presel_score_incl = np.load(f"{saved_data}presel_score_incl.npy")


else:
    if not USE_SAVED_MODEL_PRESEL:
        preselectionTraining.train(test_size=0.25, 
                                   random_state=42, 
                                   path_to_save=path_to_saved_presel_model,
                                  batch_size=4096,
                                  epochs=50)
    
    else:
        preselectionTraining.get_trained_model(path_to_saved_presel_model)

    # Get predictions (softmax outputs)
    pred_NN_incl = preselectionTraining.predict(dataset_incl_nominal)

# %%
if not USE_SAVED_PRESEL_PREDICTIONS:

    signal_sum = np.sum(
        [pred_NN_incl[:, labels_dict[signal]] for signal in signal_processes], axis=0
    )

    background_sum = np.sum(
        [pred_NN_incl[:, labels_dict[background]] for background in background_processes], axis=0
    )
    # the preselection score as defined above - log(P_S/P_B)
    presel_score_incl = np.log(signal_sum/background_sum)
    # presel_score_incl = (signal_sum/background_sum)
    np.save(f"{saved_data}presel_score_incl.npy", presel_score_incl)

# %%
presel_score = presel_score_incl.copy()

# %%
min_pred = np.amin(presel_score)
max_pred = np.amax(presel_score)

bins = np.linspace(min_pred, max_pred, num=50)

hist_NN_output = {}
hist_NN_output_errs = {}

for key in labels_dict: 
    hist_NN_output[key], _ = np.histogram(presel_score[train_labels==labels_dict[key]], 
                                          weights = weights[train_labels==labels_dict[key]], bins=bins)
    
    hist_NN_output_errs[key], _ = np.histogram(presel_score[train_labels==labels_dict[key]], 
                                          weights = weights[train_labels==labels_dict[key]]**2, bins=bins)


for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins=bins, 
             alpha=0.6, label=key, 
             density=True, linewidth=2.0, yerr = np.sqrt(hist_NN_output_errs[key]))

plt.xlabel("Preselection Score", size=18)
plt.ylabel("Density", size=18)
plt.legend()
plt.yscale('log')
plt.show()

# %% [markdown]
# Making the cut
# ===
#
# Make a selection cut for regions with $p_{ref} \gg 0$ for performing the NSBI analysis. The remaining events - which by definition are background-dominated - can be used as a **Control Region** for data-driven background estimation, pre-unblinding validations, etc.
#
# Moreover, the preselections act as a tuning know for the tradeoff in selecting as many signal events as possible to go into the **Signal Region** (increasing sensitivity) and the feasibility of training accurate and precise NNs over a large phase space (need bigger models and more statistics). **The preselections can also weed out phase space regions with low background statistics to avoid poorly modelled regions.**
#
# Heres a first cut that you can optimize as much as you like to get the desired final results.

# %%
# Play around with these selections - decrease if estimators are unbiased but need more sensitivity and increase if the model is biased to reduce complexity
preselection_cuts = {'upper': 2.5, 'lower': -1}
np.save(f"{saved_data}preselection_cuts.npy", preselection_cuts)


for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins = bins, 
             alpha = 0.6, label = key, 
             density = True, linewidth = 2.0, 
                 yerr = np.sqrt(hist_NN_output_errs[key]))

plt.xlabel("Preselection Score", size=18)

for key in preselection_cuts:
    if preselection_cuts[key] != -999:
        plt.axvline(preselection_cuts[key], ymax=0.9, linestyle='--', label=f'preselection cut {key} = {preselection_cuts[key]}')

plt.ylabel("Density", size=18)
plt.legend(loc='upper left')
plt.yscale('log')
plt.show()

# %% [markdown]
# Signal and Control Regions
# ===
#
# The high signal over background phase space towards the right of the preselection cut shown above will be categorized as the **Signal Region** where the NSBI analysis is performed.
#
# The low signal phase space towards the left will be used as a **Control Region**, with typical uses such as background estimation, pre-unblinding data-MC checks, etc. In this phase space, we will use a binned summary observable like in any traditional analysis.

# %%
dataset_incl_nominal['presel_score'] = presel_score

lower_cut = preselection_cuts.get('lower')
upper_cut = preselection_cuts.get('upper')

masks = {
    'SR': pd.Series(True, index=dataset_incl_nominal.index),
    'CR': pd.Series(False, index=dataset_incl_nominal.index)
}

# CASE A: both lower and upper exist (and are “active”, i.e. not -999)
if (lower_cut != -999) and (upper_cut != -999):
    masks['SR'] = (
        (dataset_incl_nominal.presel_score >= lower_cut) &
        (dataset_incl_nominal.presel_score <= upper_cut)
    )
    masks['CR'] = ~masks['SR']  

# CASE B: only a lower‐side cut is active
elif (lower_cut != -999):
    masks['SR'] = (dataset_incl_nominal.presel_score >= lower_cut)
    masks['CR'] = (dataset_incl_nominal.presel_score <  lower_cut)

# CASE C: only an upper‐side cut is active
elif (upper_cut != -999):
    masks['SR'] = (dataset_incl_nominal.presel_score <= upper_cut)
    masks['CR'] = (dataset_incl_nominal.presel_score >  upper_cut)


dataset   = dataset_incl_nominal[masks['SR']].copy()
dataset_CR = dataset_incl_nominal[masks['CR']].copy()

del dataset_incl_nominal

# %%
# Build a summary observable for Control Region
hist_CR = {}
num_bins = 10

CR_observable='PRI_lep_pt'

kin_variable = dataset_CR[CR_observable].to_numpy()

min_kin = np.amin(kin_variable)
max_kin = np.amax(kin_variable)
max_kin = 80.0

bins = np.linspace(min_kin, max_kin, num=num_bins)

# Use the high-level preselection NN score as a summary observable for Control Region
for channel_ in labels_dict:
    dataset_CR_process = dataset_CR[dataset_CR.detailed_labels==channel_]
    hist_CR[channel_], bins = np.histogram(dataset_CR_process[CR_observable].ravel(), 
                                  weights = dataset_CR_process['weights'].ravel(),
                                  bins = bins)

# Save the Control Region observable
with open(f"{saved_data}hist_CR_ttbar.pkl", "wb") as fp:
    pickle.dump(hist_CR, fp)

np.save(f"{saved_data}CRbins.npy", bins)

del dataset_CR

# %%
# Plot the Control Region observable

for channel_ in labels_dict:
    hep.histplot(hist_CR[channel_], bins=bins, label=channel_, density=1, linewidth=2.0)

plt.legend()
plt.xlabel('Control Region Observable')
# plt.yscale('log')
plt.ylabel('Density')
# Out:
# Text(0, 1, 'Density')

# %%
# Save the preselected Nominal dataframe for inference use later on
dataset.to_hdf(f"{saved_data}dataset_preselected_nominal_SR.h5", key="dataset", mode='w')

# %%
top_path = f'{path_prefix}output_training_nominal/'

# %% [markdown]
# Density ratio training
# ===
#
# Now we train the NNs for $\frac{p_c}{p_{ref}}(x)$ density ratios to build the full model. Our choice of reference hypothesis, motivated by the search-oriented mixture model described above, is:
#
# $$p_{ref}(x) = p_\text{higgs}(x) = \frac{1}{\nu_{H \to \tau\tau}} \frac{d\sigma_{H \to \tau\tau}}{dx} $$
#
# gives the POI $\mu-$parameterized model:
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} \right]= \mu + \frac{p_{t\bar{t}}\left(x\right)}{p_{H \to \tau\tau}(x)} + \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{H \to \tau\tau}(x)}$$
#
# The task of estimating the $\mu-$parameterized density ratio is thus reduced to estimating two $\mu-$independent density ratios $\frac{p_\text{single top}}{p_{t\bar{t}}}(x)$ and $\frac{p_\text{wjets}}{p_{t\bar{t}}}(x)$ mixed together with an analytical parameterization (hence the name mixture model).

# %%
 dataset['type'] =  dataset['detailed_labels'].to_numpy()

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import TrainEvaluate_NN

mix_model_hypotheses = signal_processes + background_processes
mix_model_hypotheses = background_processes
ref_processes = signal_processes

np.save(f"{saved_data}mix_model_hypotheses.npy", mix_model_hypotheses)
np.save(f"{saved_data}ref_processes.npy", ref_processes)

mask_ref = np.isin(dataset.detailed_labels, ref_processes)

dataset_mix_model = {}
NN_training_mix_model = {}

rnd_seed_traintestsplit = 42 # can also be randomized, fixed for now

for process_type in mix_model_hypotheses:
    
    mask_process = dataset['type']==process_type
    
    dataset_num = dataset[mask_process].copy()
    dataset_ref = dataset[mask_ref].copy()

    dataset_num['train_labels'] = 1
    dataset_ref['train_labels'] = 0

    dataset_num['weights_normed'] = dataset_num['weights'].to_numpy() / dataset_num['weights'].sum()
    dataset_ref['weights_normed'] = dataset_ref['weights'].to_numpy() / dataset_ref['weights'].sum()

    # Build a training dataset for the training of p_<process_type>/p_<ref_processes> density ratio
    dataset_mix_model[process_type] = pd.concat([dataset_num, dataset_ref])

    del dataset_num, dataset_ref

    # Save paths
    output_name = f'{process_type}'
    output_dir = f'{top_path}general_output_{process_type}'
    path_to_ratios = f'{top_path}output_ratios_{process_type}/'
    path_to_figures = f'{top_path}output_figures_{process_type}/'
    path_to_models = f'{top_path}output_model_params_{process_type}/'

    NN_training_mix_model[process_type] = TrainEvaluate_NN(dataset_mix_model[process_type], 
                                                           dataset_mix_model[process_type]['weights_normed'],
                                                           dataset_mix_model[process_type]['train_labels'],
                                                           columns, 
                                                           columns_scaling, rnd_seed_traintestsplit,
                                                           [process_type, 'ref'], output_dir, output_name, 
                                                            path_to_figures=path_to_figures,
                                                            path_to_ratios=path_to_ratios, 
                                                            path_to_models=path_to_models)

# %% [markdown]
# Neural Network architecture
# ===
#
# Here we will start with a multi-layer perceptron (simple feed-forward Neural Network with fully-connected layers). This can be supplemented with more complex architectures like transformers.
#
# After detailed tuning during the off-shell Higgs boson analysis effort, we found that a network with very wide layers ($\geq 1000$) and a depth of less than 10 works best - alongside batch size of a few hundreds and a gradually declining learning rate that starts with a value just large enough to not blow up.

# %% [markdown]
# Starting with the training and validation of the various density ratio:
#
# $$\frac{p_{t\bar{t}}(x)}{p_\text{ref}(x)}, \frac{p_{Z \to \tau\tau}(x)}{p_\text{ref}(x)}$$

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 1

# %%
for process_type in mix_model_hypotheses:

    # Train the density ratio NN
    NN_training_mix_model[process_type].train (   hidden_layers        = 2, 
                                                    neurons              = 1000, 
                                                    number_of_epochs     = 100, 
                                                    batch_size           = 128, 
                                                    learning_rate        = 0.1, 
                                                    scalerType           = 'StandardScaler', 
                                                    calibration          = False, 
                                                    num_bins_cal         = 100, 
                                                    callback             = True, 
                                                    callback_patience    = 30, 
                                                    callback_factor      = 0.01,
                                                    verbose              = 2     )    
    
    NN_training_mix_model[process_type].test_normalization()
# Out:
# Sum of weights of class 0: 0.6999988436316287
# Sum of weights of class 1: 0.7000033148586146
# Using swish activation function
# /home/jaySandesara/.conda/envs/NSBI/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 1000)           │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,010,001 (3.85 MB)
#  Trainable params: 1,010,001 (3.85 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# 2025-06-03 11:04:56.137436: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion', 4 bytes spill stores, 4 bytes spill loads
# 10386/10386 - 17s - 2ms/step - binary_accuracy: 0.7087 - loss: 5.4859e-07 - val_binary_accuracy: 0.7188 - val_loss: 5.3800e-07 - learning_rate: 0.1000
# Epoch 2/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7148 - loss: 5.4063e-07 - val_binary_accuracy: 0.7230 - val_loss: 5.3609e-07 - learning_rate: 0.1000
# Epoch 3/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7149 - loss: 5.4006e-07 - val_binary_accuracy: 0.7124 - val_loss: 5.5010e-07 - learning_rate: 0.1000
# Epoch 4/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7153 - loss: 5.4032e-07 - val_binary_accuracy: 0.7225 - val_loss: 5.4125e-07 - learning_rate: 0.1000
# Epoch 5/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7152 - loss: 5.4039e-07 - val_binary_accuracy: 0.7215 - val_loss: 5.4773e-07 - learning_rate: 0.1000
# Epoch 6/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7146 - loss: 5.3998e-07 - val_binary_accuracy: 0.7171 - val_loss: 5.4297e-07 - learning_rate: 0.1000
# Epoch 7/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7156 - loss: 5.3949e-07 - val_binary_accuracy: 0.7144 - val_loss: 5.4153e-07 - learning_rate: 0.1000
# Epoch 8/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7165 - loss: 5.3696e-07 - val_binary_accuracy: 0.7215 - val_loss: 5.4760e-07 - learning_rate: 0.1000
# Epoch 9/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7157 - loss: 5.3613e-07 - val_binary_accuracy: 0.7213 - val_loss: 5.3269e-07 - learning_rate: 0.1000
# Epoch 10/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7182 - loss: 5.3426e-07 - val_binary_accuracy: 0.7166 - val_loss: 5.3468e-07 - learning_rate: 0.1000
# Epoch 11/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7162 - loss: 5.3390e-07 - val_binary_accuracy: 0.7215 - val_loss: 5.3066e-07 - learning_rate: 0.1000
# Epoch 12/100
# 10386/10386 - 15s - 1ms/step - binary_accuracy: 0.7178 - loss: 5.3362e-07 - val_binary_accuracy: 0.7235 - val_loss: 5.2855e-07 - learning_rate: 0.1000
# Epoch 13/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7175 - loss: 5.3339e-07 - val_binary_accuracy: 0.7220 - val_loss: 5.3481e-07 - learning_rate: 0.1000
# Epoch 14/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7176 - loss: 5.3285e-07 - val_binary_accuracy: 0.7065 - val_loss: 5.5369e-07 - learning_rate: 0.1000
# Epoch 15/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7175 - loss: 5.3275e-07 - val_binary_accuracy: 0.7199 - val_loss: 5.2818e-07 - learning_rate: 0.1000
# Epoch 16/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7169 - loss: 5.3244e-07 - val_binary_accuracy: 0.7256 - val_loss: 5.2910e-07 - learning_rate: 0.1000
# Epoch 17/100
# 10386/10386 - 15s - 1ms/step - binary_accuracy: 0.7177 - loss: 5.3249e-07 - val_binary_accuracy: 0.7162 - val_loss: 5.4305e-07 - learning_rate: 0.1000
# Epoch 18/100
# 10386/10386 - 15s - 1ms/step - binary_accuracy: 0.7178 - loss: 5.3204e-07 - val_binary_accuracy: 0.7235 - val_loss: 5.2682e-07 - learning_rate: 0.1000
# Epoch 19/100
# 10386/10386 - 15s - 1ms/step - binary_accuracy: 0.7175 - loss: 5.3195e-07 - val_binary_accuracy: 0.7236 - val_loss: 5.2615e-07 - learning_rate: 0.1000
# Epoch 20/100
# 10386/10386 - 15s - 1ms/step - binary_accuracy: 0.7179 - loss: 5.3188e-07 - val_binary_accuracy: 0.7256 - val_loss: 5.4141e-07 - learning_rate: 0.1000
# Epoch 21/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7174 - loss: 5.3189e-07 - val_binary_accuracy: 0.7237 - val_loss: 5.3110e-07 - learning_rate: 0.1000
# Epoch 22/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7178 - loss: 5.3146e-07 - val_binary_accuracy: 0.7237 - val_loss: 5.2920e-07 - learning_rate: 0.1000
# Epoch 23/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7180 - loss: 5.3205e-07 - val_binary_accuracy: 0.7042 - val_loss: 5.4730e-07 - learning_rate: 0.1000
# Epoch 24/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7181 - loss: 5.3156e-07 - val_binary_accuracy: 0.7240 - val_loss: 5.3224e-07 - learning_rate: 0.1000
# Epoch 25/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7175 - loss: 5.3134e-07 - val_binary_accuracy: 0.7206 - val_loss: 5.3854e-07 - learning_rate: 0.1000
# Epoch 26/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7177 - loss: 5.3116e-07 - val_binary_accuracy: 0.7238 - val_loss: 5.3715e-07 - learning_rate: 0.1000
# Epoch 27/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7180 - loss: 5.3149e-07 - val_binary_accuracy: 0.7242 - val_loss: 5.2889e-07 - learning_rate: 0.1000
# Epoch 28/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7171 - loss: 5.3118e-07 - val_binary_accuracy: 0.7234 - val_loss: 5.3028e-07 - learning_rate: 0.1000
# Epoch 29/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7182 - loss: 5.3140e-07 - val_binary_accuracy: 0.7262 - val_loss: 5.2624e-07 - learning_rate: 0.1000
# Epoch 30/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7189 - loss: 5.3142e-07 - val_binary_accuracy: 0.7208 - val_loss: 5.3727e-07 - learning_rate: 0.1000
# Epoch 31/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7167 - loss: 5.3179e-07 - val_binary_accuracy: 0.7186 - val_loss: 5.3013e-07 - learning_rate: 0.1000
# Epoch 32/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7250 - loss: 5.1979e-07 - val_binary_accuracy: 0.7273 - val_loss: 5.2114e-07 - learning_rate: 0.0010
# Epoch 33/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7270 - loss: 5.1744e-07 - val_binary_accuracy: 0.7293 - val_loss: 5.1987e-07 - learning_rate: 0.0010
# Epoch 34/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7274 - loss: 5.1673e-07 - val_binary_accuracy: 0.7293 - val_loss: 5.1938e-07 - learning_rate: 0.0010
# Epoch 35/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7280 - loss: 5.1630e-07 - val_binary_accuracy: 0.7293 - val_loss: 5.1883e-07 - learning_rate: 0.0010
# Epoch 36/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7283 - loss: 5.1603e-07 - val_binary_accuracy: 0.7304 - val_loss: 5.1855e-07 - learning_rate: 0.0010
# Epoch 37/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7283 - loss: 5.1580e-07 - val_binary_accuracy: 0.7300 - val_loss: 5.1840e-07 - learning_rate: 0.0010
# Epoch 38/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7284 - loss: 5.1560e-07 - val_binary_accuracy: 0.7300 - val_loss: 5.1812e-07 - learning_rate: 0.0010
# Epoch 39/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7285 - loss: 5.1544e-07 - val_binary_accuracy: 0.7309 - val_loss: 5.1806e-07 - learning_rate: 0.0010
# Epoch 40/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7284 - loss: 5.1530e-07 - val_binary_accuracy: 0.7306 - val_loss: 5.1804e-07 - learning_rate: 0.0010
# Epoch 41/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7288 - loss: 5.1520e-07 - val_binary_accuracy: 0.7307 - val_loss: 5.1788e-07 - learning_rate: 0.0010
# Epoch 42/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7289 - loss: 5.1510e-07 - val_binary_accuracy: 0.7309 - val_loss: 5.1800e-07 - learning_rate: 0.0010
# Epoch 43/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7289 - loss: 5.1500e-07 - val_binary_accuracy: 0.7297 - val_loss: 5.1771e-07 - learning_rate: 0.0010
# Epoch 44/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7291 - loss: 5.1494e-07 - val_binary_accuracy: 0.7304 - val_loss: 5.1761e-07 - learning_rate: 0.0010
# Epoch 45/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7290 - loss: 5.1485e-07 - val_binary_accuracy: 0.7297 - val_loss: 5.1766e-07 - learning_rate: 0.0010
# Epoch 46/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7293 - loss: 5.1476e-07 - val_binary_accuracy: 0.7303 - val_loss: 5.1785e-07 - learning_rate: 0.0010
# Epoch 47/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7292 - loss: 5.1472e-07 - val_binary_accuracy: 0.7302 - val_loss: 5.1760e-07 - learning_rate: 0.0010
# Epoch 48/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7292 - loss: 5.1467e-07 - val_binary_accuracy: 0.7302 - val_loss: 5.1749e-07 - learning_rate: 0.0010
# Epoch 49/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7294 - loss: 5.1458e-07 - val_binary_accuracy: 0.7301 - val_loss: 5.1752e-07 - learning_rate: 0.0010
# Epoch 50/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7295 - loss: 5.1456e-07 - val_binary_accuracy: 0.7300 - val_loss: 5.1755e-07 - learning_rate: 0.0010
# Epoch 51/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7295 - loss: 5.1449e-07 - val_binary_accuracy: 0.7299 - val_loss: 5.1745e-07 - learning_rate: 0.0010
# Epoch 52/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7295 - loss: 5.1445e-07 - val_binary_accuracy: 0.7301 - val_loss: 5.1746e-07 - learning_rate: 0.0010
# Epoch 53/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7292 - loss: 5.1441e-07 - val_binary_accuracy: 0.7295 - val_loss: 5.1773e-07 - learning_rate: 0.0010
# Epoch 54/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7300 - loss: 5.1435e-07 - val_binary_accuracy: 0.7304 - val_loss: 5.1740e-07 - learning_rate: 0.0010
# Epoch 55/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7295 - loss: 5.1432e-07 - val_binary_accuracy: 0.7299 - val_loss: 5.1732e-07 - learning_rate: 0.0010
# Epoch 56/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7299 - loss: 5.1429e-07 - val_binary_accuracy: 0.7300 - val_loss: 5.1727e-07 - learning_rate: 0.0010
# Epoch 57/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7297 - loss: 5.1425e-07 - val_binary_accuracy: 0.7304 - val_loss: 5.1735e-07 - learning_rate: 0.0010
# Epoch 58/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1421e-07 - val_binary_accuracy: 0.7309 - val_loss: 5.1726e-07 - learning_rate: 0.0010
# Epoch 59/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7298 - loss: 5.1414e-07 - val_binary_accuracy: 0.7301 - val_loss: 5.1723e-07 - learning_rate: 0.0010
# Epoch 60/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7296 - loss: 5.1414e-07 - val_binary_accuracy: 0.7306 - val_loss: 5.1730e-07 - learning_rate: 0.0010
# Epoch 61/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7299 - loss: 5.1410e-07 - val_binary_accuracy: 0.7298 - val_loss: 5.1709e-07 - learning_rate: 0.0010
# Epoch 62/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1383e-07 - val_binary_accuracy: 0.7299 - val_loss: 5.1711e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1380e-07 - val_binary_accuracy: 0.7299 - val_loss: 5.1713e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1379e-07 - val_binary_accuracy: 0.7298 - val_loss: 5.1714e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1378e-07 - val_binary_accuracy: 0.7297 - val_loss: 5.1715e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7302 - loss: 5.1378e-07 - val_binary_accuracy: 0.7300 - val_loss: 5.1716e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1377e-07 - val_binary_accuracy: 0.7299 - val_loss: 5.1716e-07 - learning_rate: 1.0000e-05
# Epoch 68/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7302 - loss: 5.1377e-07 - val_binary_accuracy: 0.7299 - val_loss: 5.1717e-07 - learning_rate: 1.0000e-05
# Epoch 69/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1377e-07 - val_binary_accuracy: 0.7298 - val_loss: 5.1717e-07 - learning_rate: 1.0000e-05
# Epoch 70/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1377e-07 - val_binary_accuracy: 0.7298 - val_loss: 5.1718e-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1377e-07 - val_binary_accuracy: 0.7299 - val_loss: 5.1718e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1376e-07 - val_binary_accuracy: 0.7299 - val_loss: 5.1718e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1376e-07 - val_binary_accuracy: 0.7299 - val_loss: 5.1718e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1376e-07 - val_binary_accuracy: 0.7300 - val_loss: 5.1718e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7302 - loss: 5.1376e-07 - val_binary_accuracy: 0.7299 - val_loss: 5.1718e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7302 - loss: 5.1376e-07 - val_binary_accuracy: 0.7298 - val_loss: 5.1718e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7302 - loss: 5.1376e-07 - val_binary_accuracy: 0.7298 - val_loss: 5.1719e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7302 - loss: 5.1376e-07 - val_binary_accuracy: 0.7300 - val_loss: 5.1719e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1376e-07 - val_binary_accuracy: 0.7300 - val_loss: 5.1719e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7302 - loss: 5.1376e-07 - val_binary_accuracy: 0.7300 - val_loss: 5.1719e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1375e-07 - val_binary_accuracy: 0.7300 - val_loss: 5.1719e-07 - learning_rate: 1.0000e-05
# Epoch 82/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1375e-07 - val_binary_accuracy: 0.7299 - val_loss: 5.1719e-07 - learning_rate: 1.0000e-05
# Epoch 83/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1375e-07 - val_binary_accuracy: 0.7301 - val_loss: 5.1719e-07 - learning_rate: 1.0000e-05
# Epoch 84/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7300 - loss: 5.1375e-07 - val_binary_accuracy: 0.7300 - val_loss: 5.1719e-07 - learning_rate: 1.0000e-05
# Epoch 85/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1375e-07 - val_binary_accuracy: 0.7301 - val_loss: 5.1719e-07 - learning_rate: 1.0000e-05
# Epoch 86/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1375e-07 - val_binary_accuracy: 0.7301 - val_loss: 5.1719e-07 - learning_rate: 1.0000e-05
# Epoch 87/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1375e-07 - val_binary_accuracy: 0.7302 - val_loss: 5.1720e-07 - learning_rate: 1.0000e-05
# Epoch 88/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1375e-07 - val_binary_accuracy: 0.7302 - val_loss: 5.1719e-07 - learning_rate: 1.0000e-05
# Epoch 89/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1375e-07 - val_binary_accuracy: 0.7302 - val_loss: 5.1720e-07 - learning_rate: 1.0000e-05
# Epoch 90/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1375e-07 - val_binary_accuracy: 0.7302 - val_loss: 5.1720e-07 - learning_rate: 1.0000e-05
# Epoch 91/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1375e-07 - val_binary_accuracy: 0.7303 - val_loss: 5.1720e-07 - learning_rate: 1.0000e-05
# Epoch 92/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1374e-07 - val_binary_accuracy: 0.7303 - val_loss: 5.1720e-07 - learning_rate: 1.0000e-07
# Epoch 93/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1374e-07 - val_binary_accuracy: 0.7303 - val_loss: 5.1720e-07 - learning_rate: 1.0000e-07
# Epoch 94/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1374e-07 - val_binary_accuracy: 0.7303 - val_loss: 5.1720e-07 - learning_rate: 1.0000e-07
# Epoch 95/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1374e-07 - val_binary_accuracy: 0.7303 - val_loss: 5.1720e-07 - learning_rate: 1.0000e-07
# Epoch 96/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1374e-07 - val_binary_accuracy: 0.7303 - val_loss: 5.1720e-07 - learning_rate: 1.0000e-07
# Epoch 97/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1374e-07 - val_binary_accuracy: 0.7303 - val_loss: 5.1720e-07 - learning_rate: 1.0000e-07
# Epoch 98/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1374e-07 - val_binary_accuracy: 0.7303 - val_loss: 5.1720e-07 - learning_rate: 1.0000e-07
# Epoch 99/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1374e-07 - val_binary_accuracy: 0.7303 - val_loss: 5.1720e-07 - learning_rate: 1.0000e-07
# Epoch 100/100
# 10386/10386 - 14s - 1ms/step - binary_accuracy: 0.7301 - loss: 5.1374e-07 - val_binary_accuracy: 0.7303 - val_loss: 5.1720e-07 - learning_rate: 1.0000e-07
# Finished Training
# /home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/output_training_nominal/output_model_params_ttbar/model_scaler.bin
# 19783/19783 - 11s - 575us/step
# 46160/46160 - 24s - 525us/step
# 65943/65943 - 35s - 535us/step
# The sum of PDFs is 0.9974640846882113
# Sum of weights of class 0: 0.6999988436316285
# Sum of weights of class 1: 0.7000003545687923
# Using swish activation function
# /home/jaySandesara/.conda/envs/NSBI/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                │ (None, 1000)           │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,010,001 (3.85 MB)
#  Trainable params: 1,010,001 (3.85 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# 2025-06-03 11:30:02.577033: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion', 4 bytes spill stores, 4 bytes spill loads
# 19690/19690 - 28s - 1ms/step - binary_accuracy: 0.7201 - loss: 2.8638e-07 - val_binary_accuracy: 0.7246 - val_loss: 2.8258e-07 - learning_rate: 0.1000
# Epoch 2/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7245 - loss: 2.8222e-07 - val_binary_accuracy: 0.7258 - val_loss: 2.8151e-07 - learning_rate: 0.1000
# Epoch 3/100
# 19690/19690 - 27s - 1ms/step - binary_accuracy: 0.7252 - loss: 2.8087e-07 - val_binary_accuracy: 0.7263 - val_loss: 2.8030e-07 - learning_rate: 0.1000
# Epoch 4/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7253 - loss: 2.7979e-07 - val_binary_accuracy: 0.7259 - val_loss: 2.7895e-07 - learning_rate: 0.1000
# Epoch 5/100
# 19690/19690 - 28s - 1ms/step - binary_accuracy: 0.7257 - loss: 2.7920e-07 - val_binary_accuracy: 0.7260 - val_loss: 2.7954e-07 - learning_rate: 0.1000
# Epoch 6/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7260 - loss: 2.7870e-07 - val_binary_accuracy: 0.7253 - val_loss: 2.7926e-07 - learning_rate: 0.1000
# Epoch 7/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7263 - loss: 2.7812e-07 - val_binary_accuracy: 0.7275 - val_loss: 2.7799e-07 - learning_rate: 0.1000
# Epoch 8/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7267 - loss: 2.7766e-07 - val_binary_accuracy: 0.7275 - val_loss: 2.7695e-07 - learning_rate: 0.1000
# Epoch 9/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7270 - loss: 2.7732e-07 - val_binary_accuracy: 0.7274 - val_loss: 2.7743e-07 - learning_rate: 0.1000
# Epoch 10/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7272 - loss: 2.7704e-07 - val_binary_accuracy: 0.7283 - val_loss: 2.7637e-07 - learning_rate: 0.1000
# Epoch 11/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7275 - loss: 2.7686e-07 - val_binary_accuracy: 0.7276 - val_loss: 2.7700e-07 - learning_rate: 0.1000
# Epoch 12/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7277 - loss: 2.7669e-07 - val_binary_accuracy: 0.7269 - val_loss: 2.7684e-07 - learning_rate: 0.1000
# Epoch 13/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7278 - loss: 2.7646e-07 - val_binary_accuracy: 0.7286 - val_loss: 2.7603e-07 - learning_rate: 0.1000
# Epoch 14/100
# 19690/19690 - 27s - 1ms/step - binary_accuracy: 0.7281 - loss: 2.7633e-07 - val_binary_accuracy: 0.7283 - val_loss: 2.7668e-07 - learning_rate: 0.1000
# Epoch 15/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7282 - loss: 2.7616e-07 - val_binary_accuracy: 0.7279 - val_loss: 2.7712e-07 - learning_rate: 0.1000
# Epoch 16/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7285 - loss: 2.7604e-07 - val_binary_accuracy: 0.7295 - val_loss: 2.7536e-07 - learning_rate: 0.1000
# Epoch 17/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7286 - loss: 2.7592e-07 - val_binary_accuracy: 0.7291 - val_loss: 2.7523e-07 - learning_rate: 0.1000
# Epoch 18/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7287 - loss: 2.7577e-07 - val_binary_accuracy: 0.7292 - val_loss: 2.7531e-07 - learning_rate: 0.1000
# Epoch 19/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7288 - loss: 2.7569e-07 - val_binary_accuracy: 0.7291 - val_loss: 2.7559e-07 - learning_rate: 0.1000
# Epoch 20/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7289 - loss: 2.7563e-07 - val_binary_accuracy: 0.7293 - val_loss: 2.7562e-07 - learning_rate: 0.1000
# Epoch 21/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7290 - loss: 2.7554e-07 - val_binary_accuracy: 0.7288 - val_loss: 2.7527e-07 - learning_rate: 0.1000
# Epoch 22/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7291 - loss: 2.7550e-07 - val_binary_accuracy: 0.7300 - val_loss: 2.7543e-07 - learning_rate: 0.1000
# Epoch 23/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7292 - loss: 2.7540e-07 - val_binary_accuracy: 0.7298 - val_loss: 2.7509e-07 - learning_rate: 0.1000
# Epoch 24/100
# 19690/19690 - 27s - 1ms/step - binary_accuracy: 0.7290 - loss: 2.7532e-07 - val_binary_accuracy: 0.7295 - val_loss: 2.7575e-07 - learning_rate: 0.1000
# Epoch 25/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7293 - loss: 2.7528e-07 - val_binary_accuracy: 0.7296 - val_loss: 2.7512e-07 - learning_rate: 0.1000
# Epoch 26/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7293 - loss: 2.7520e-07 - val_binary_accuracy: 0.7297 - val_loss: 2.7490e-07 - learning_rate: 0.1000
# Epoch 27/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7293 - loss: 2.7512e-07 - val_binary_accuracy: 0.7297 - val_loss: 2.7513e-07 - learning_rate: 0.1000
# Epoch 28/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7295 - loss: 2.7508e-07 - val_binary_accuracy: 0.7293 - val_loss: 2.7622e-07 - learning_rate: 0.1000
# Epoch 29/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7295 - loss: 2.7500e-07 - val_binary_accuracy: 0.7300 - val_loss: 2.7465e-07 - learning_rate: 0.1000
# Epoch 30/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7295 - loss: 2.7495e-07 - val_binary_accuracy: 0.7296 - val_loss: 2.7469e-07 - learning_rate: 0.1000
# Epoch 31/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7296 - loss: 2.7489e-07 - val_binary_accuracy: 0.7295 - val_loss: 2.7489e-07 - learning_rate: 0.1000
# Epoch 32/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7307 - loss: 2.7365e-07 - val_binary_accuracy: 0.7310 - val_loss: 2.7357e-07 - learning_rate: 0.0010
# Epoch 33/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7311 - loss: 2.7339e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7346e-07 - learning_rate: 0.0010
# Epoch 34/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7311 - loss: 2.7332e-07 - val_binary_accuracy: 0.7310 - val_loss: 2.7342e-07 - learning_rate: 0.0010
# Epoch 35/100
# 19690/19690 - 27s - 1ms/step - binary_accuracy: 0.7311 - loss: 2.7329e-07 - val_binary_accuracy: 0.7310 - val_loss: 2.7339e-07 - learning_rate: 0.0010
# Epoch 36/100
# 19690/19690 - 28s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7326e-07 - val_binary_accuracy: 0.7312 - val_loss: 2.7337e-07 - learning_rate: 0.0010
# Epoch 37/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7311 - loss: 2.7325e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7336e-07 - learning_rate: 0.0010
# Epoch 38/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7323e-07 - val_binary_accuracy: 0.7312 - val_loss: 2.7335e-07 - learning_rate: 0.0010
# Epoch 39/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7311 - loss: 2.7322e-07 - val_binary_accuracy: 0.7312 - val_loss: 2.7333e-07 - learning_rate: 0.0010
# Epoch 40/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7311 - loss: 2.7321e-07 - val_binary_accuracy: 0.7310 - val_loss: 2.7331e-07 - learning_rate: 0.0010
# Epoch 41/100
# 19690/19690 - 27s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7321e-07 - val_binary_accuracy: 0.7313 - val_loss: 2.7333e-07 - learning_rate: 0.0010
# Epoch 42/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7320e-07 - val_binary_accuracy: 0.7313 - val_loss: 2.7330e-07 - learning_rate: 0.0010
# Epoch 43/100
# 19690/19690 - 27s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7319e-07 - val_binary_accuracy: 0.7312 - val_loss: 2.7329e-07 - learning_rate: 0.0010
# Epoch 44/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7318e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7330e-07 - learning_rate: 0.0010
# Epoch 45/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7318e-07 - val_binary_accuracy: 0.7312 - val_loss: 2.7329e-07 - learning_rate: 0.0010
# Epoch 46/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7317e-07 - val_binary_accuracy: 0.7312 - val_loss: 2.7329e-07 - learning_rate: 0.0010
# Epoch 47/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7317e-07 - val_binary_accuracy: 0.7312 - val_loss: 2.7327e-07 - learning_rate: 0.0010
# Epoch 48/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7316e-07 - val_binary_accuracy: 0.7312 - val_loss: 2.7327e-07 - learning_rate: 0.0010
# Epoch 49/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7316e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7326e-07 - learning_rate: 0.0010
# Epoch 50/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7315e-07 - val_binary_accuracy: 0.7310 - val_loss: 2.7326e-07 - learning_rate: 0.0010
# Epoch 51/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7315e-07 - val_binary_accuracy: 0.7310 - val_loss: 2.7325e-07 - learning_rate: 0.0010
# Epoch 52/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7315e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7326e-07 - learning_rate: 0.0010
# Epoch 53/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7314e-07 - val_binary_accuracy: 0.7312 - val_loss: 2.7325e-07 - learning_rate: 0.0010
# Epoch 54/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7314e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7325e-07 - learning_rate: 0.0010
# Epoch 55/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7314e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7324e-07 - learning_rate: 0.0010
# Epoch 56/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7313e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7324e-07 - learning_rate: 0.0010
# Epoch 57/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7313e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7324e-07 - learning_rate: 0.0010
# Epoch 58/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7313e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7324e-07 - learning_rate: 0.0010
# Epoch 59/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7312e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7322e-07 - learning_rate: 0.0010
# Epoch 60/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7312e-07 - val_binary_accuracy: 0.7312 - val_loss: 2.7323e-07 - learning_rate: 0.0010
# Epoch 61/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7313 - loss: 2.7312e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7322e-07 - learning_rate: 0.0010
# Epoch 62/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7310e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7322e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7309e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7322e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7309e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7322e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 19690/19690 - 25s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7309e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7322e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7309e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7322e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7309e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7322e-07 - learning_rate: 1.0000e-05
# Epoch 68/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7309e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7322e-07 - learning_rate: 1.0000e-05
# Epoch 69/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7309e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7322e-07 - learning_rate: 1.0000e-05
# Epoch 70/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7309e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7322e-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7309e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7322e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7309e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7322e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7309e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7322e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7309e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7321e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7309e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7321e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7309e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7321e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7313 - loss: 2.7309e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7321e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7309e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7321e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7309e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7321e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 19690/19690 - 25s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7309e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7321e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 19690/19690 - 26s - 1ms/step - binary_accuracy: 0.7312 - loss: 2.7309e-07 - val_binary_accuracy: 0.7311 - val_loss: 2.7321e-07 - learning_rate: 1.0000e-05
# Epoch 82/100

# %% [markdown]
# Check for overtraining by comparing the NN output distributions between training and holdout datasets. The holdout dataset is the subset of events not used during training.

# %%
for process_type in mix_model_hypotheses:
    NN_training_mix_model[process_type].make_overfit_plots()

# %% [markdown]
# Diagnostic Checks
# ===
#
# While traditionally, a NN observable is judged on the basis of its accuracy - for NSBI we are interested in the quality of the density ratios more than the discrimination power. The latter comes from the perfect modelling of the multi-dimensional likelihood ratios.
#
# To ensure correct modelling, we run two main checks on the training:
#
# - **Calibration closure test**
#
#   The NNs are trained using the binary cross-entropy loss, which under ideal conditions leads to the NN converging to the score function:
#
#   $$\hat{s}_\text{pred} = \frac{p_\text{ref}(x)}{p_\text{ref}(x)+p_\text{c}(x)}$$
#
#   that can be converted into the probability ratio we desire (likelihood ratio trick):
#
#   $$\frac{p_\text{c}(x)}{p_\text{ref}(x)} = \frac{\hat{s}_\text{pred}(x)}{1-\hat{s}_\text{pred}(x)}$$
#
#   For the NNs to be well-calibrated, we use the Monte Carlo samples to verify the equality:
#
#
#   $$\left[\frac{p_c(x)}{p_c(x)+p_{ref}(x)}\right]_\text{NN} \sim \left[\frac{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}}{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}+\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}}\right]_\text{MC}$$
#
#   where we bin the events from $p_c$ and $p_\text{ref}$ MC samples, denoted by $\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}$ and $\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}$ respectively where $I(x|\hat{s}_\text{pred})$ returns the index of the $\hat{s}_\text{pred}$ bin in which an event $x$ falls.

# %%
num_bins_cal = 50

for process_type in mix_model_hypotheses:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='score')

# %%
num_bins_cal = 50

for process_type in mix_model_hypotheses:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='llr')

# %% [markdown]
# - **Density ratio reweighting closure tests**
#
#   Despite having a well-calibrated output and thus a robust probabilistic interpretation, the trained density ratios might not capture the full multi-dimensional event information $x$. In other words, the NNs might still be biased estimators of the optimal score function, as defined in the CARL paper (link).
#
#   The next diagnostic involves verifying the following equality using 1D projections of $x$:
#
#   $$\frac{p_c(x)}{p_{ref}(x)} \times p_{ref}(x) \sim p_c(x)$$
#
#   We can do this one-by-one for all the observables used to model the density ratios, and also possibly the observables not used directly in the training but can still be well-estimated due to the NN learning the right physics.

# %%
variables_to_plot=['PRI_lep_pt'] # The 1D variable for reweighting closure
yscale_type='log'
num_bins_plotting=21

for process_type in mix_model_hypotheses:

    NN_training_mix_model[process_type].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
for process_type in mix_model_hypotheses:
    # Evaluate the density ratios p_c/p_ref for the full dataset and save for the inference step
    NN_training_mix_model[process_type].evaluate_and_save_ratios(dataset)

# %% [markdown]
# Systematic Uncertainty Modelling
# ===
#
# So far we have left out the nuisance parameter piece of the parameterized density ratio decomposition shown before:
#
# $$g_c(x|\alpha) = \frac{p_c(x|\alpha)}{p_c(x)}$$
#
# which will be estimated in the `Systematic_Uncertainty_Estimation.ipynb` notebook.

# %% [markdown]
# Training an Ensemble of NNs
# ===
#
# In a realistic analysis, a large ensemble of NNs are trained to estimate density ratios, for *each* of the channels. **This reduces not only the variance but has also been found to reduce biases in the final fits.**
#
# In the off-shell Higgs boson analysis, we used k-fold cross-validation, with k=10, to train an ensemble $N_{ens}\sim 250$ of NNs per density ratio $p_c(x)/p_{ref}(x)$. The density ratios used in the final fit are always evaluated on the holdout dataset and by using each of the folds as holdout once, the entire model for $p_c(x)/p_{ref}(x)$ consists of $N_{ens}\times k \sim 2500$ NNs. Each NN in the ensemble is trained by resampling data without replacement from the k-1 folds used for training.
