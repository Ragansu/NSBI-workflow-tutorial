# %% [markdown]
# Train Neural Networks to estimate Likelihood Ratios
# ===
#
# In this notebook we will setup the neural networks that train unbiased and low-variance density ratios to be then used for inference. The statistical model we have is:
#
# $$p(x|\mu, \alpha) = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot p_c\left(x|\alpha\right)$$
#
# where $c$ stands for the various physics channels that contribute to the final state $x$, $\mu$ is the signal-strength parameter and $\alpha$ is the vector of nuisance parameters associated with the various systematic uncertainties in the model. Note that we are assuming that the parameter $\mu$-dependence is known analytically and that we have simulation models for each of the channels $p_c(x)$.
#
# The objective is to build the test statistic for composite hypothesis testing:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})}{p(x_i|\hat{\mu}, \hat{\alpha})} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
# A direct approach would then be to model the probability density $p(x|\mu, \alpha)$ using NNs. But that is a more difficult task than training probability density ratios. We use a simple trick:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})/p_{ref}(x)}{p(x_i|\hat{\mu}, \hat{\alpha})/p_{ref}(x)} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
#
# to turn this into a density ratio estimation problem:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot \frac{p_c\left(x|\alpha\right)}{p_{ref}(x)}$$
#
# Factorizing out the $\alpha$-dependence in the density ratios:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\sum_c G_c(\alpha) \cdot f_c(\mu) \cdot \nu_c} \sum_c f_c(\mu) \cdot G_c(\alpha)\cdot \nu_c \cdot g_c(x|\alpha) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}$$
#
# **Factorized approach:**
#
# Instead of training NNs parameterized on $\mu$ and $\alpha$, we use analytical parameterizations to simplify the problem to training only parameter-independent density ratios.
#
# Let's set this up for the toy ttbar model we are using. Neglecting the nuisance parameter dependence for now,
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}\right] = \mu \cdot \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)} + \frac{p_{t\bar{t}}\left(x\right)}{p_{ref}(x)} + \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)}$$

# %%
import os, sys, importlib
sys.path.append('../')

import nsbi_common_utils
from nsbi_common_utils import plotting, training
from nsbi_common_utils.training import TrainEvaluate_NN, TrainEvaluatePreselNN
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt
import pickle

from utils import preselection_using_score, calculate_preselection_observable

from coffea.analysis_tools import PackedSelection

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

hep.style.use(hep.style.ATLAS)
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/src/nsbi_common_utils/plotting.py:10: FutureWarning: ``set_style`` is deprecated: Naming convention is changing to match mpl. Use ``mplhep.style.use()``.
#   hep.set_style("ATLAS")
# 2025-06-04 21:56:08.728737: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749074168.741782  482920 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749074168.745662  482920 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-04 21:56:08.760595: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
path_prefix = '/home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/'

# Path for saving interemdiate objects, like NN predictions
saved_data = f'{path_prefix}cached_data/'

# Path for saving/loading preselection NN model
path_to_saved_presel_model = f'{path_prefix}preselection_saved_NN/'

# Load the nominal dataset saved from the pre-processing notebook
dataset_incl_nominal = pd.read_hdf(f"{saved_data}df_nominal.h5", key="dataset", mode='r')

# %%
# If the preselection NN has already been trained and saved, load from the saved model
USE_SAVED_MODEL_PRESEL=True
# If the preselection NN has already been trained and evaluated, load the numpy array of predictions
USE_SAVED_PRESEL_PREDICTIONS=True

# Get the dictionary of labels to processes
labels_dict = np.load(f"{saved_data}labels_dictionary.npy", allow_pickle=True).item()

# Features to use for training NNs
columns = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi']
columns_scaling = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi']

# columns = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi', 'PRI_jet_all_pt', 'PRI_n_jets', 'has_jets']
# columns_scaling = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi', 'PRI_jet_all_pt']

# columns = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi', 'PRI_jet_all_pt', 'PRI_jet_leading_pt', 'PRI_jet_leading_eta', 'has_jets']
# columns_scaling = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi', 'PRI_jet_all_pt', 'PRI_jet_leading_pt', 'PRI_jet_leading_eta']


np.save(f"{saved_data}columns.npy", columns)
np.save(f"{saved_data}columns_scaling.npy", columns_scaling)


signal_processes = ["htautau"]
background_processes = ["ttbar", "ztautau"]
# background_processes = ["ttbar", "ztautau", "diboson"]

# mix_model_hypotheses = signal_processes + background_processes
mix_model_hypotheses = background_processes
ref_processes = signal_processes

np.save(f"{saved_data}mix_model_hypotheses.npy", mix_model_hypotheses)
np.save(f"{saved_data}ref_processes.npy", ref_processes)

pre_factor_preselection_score = {}

pre_factor_preselection_score['htautau'] = 1.0
pre_factor_preselection_score['ttbar'] = 1.0
pre_factor_preselection_score['ztautau'] = 1.0

np.save(f"{saved_data}signal_processes.npy", signal_processes)
np.save(f"{saved_data}background_processes.npy", background_processes)
np.save(f"{saved_data}pre_factor_preselection.npy", pre_factor_preselection_score)

# %%
# Load the MC/data weights and training labels identifying different processes
weights = dataset_incl_nominal.weights.to_numpy()
train_labels = dataset_incl_nominal.train_labels.to_numpy()

# %%
# Normalizing the training weights - only discriminating shapes, not norms
weights_normed = weights.copy()

for key in labels_dict:

    weights_normed[train_labels==labels_dict[key]] /= weights[train_labels==labels_dict[key]].sum()

dataset_incl_nominal['weights_normed'] = weights_normed

# %% [markdown]
# Training the Preselection NN
# ===

# %% [markdown]
# **Choice of reference sample**
#
# The density ratios need to be trained on phase space regions with support for the reference hypothesis $p_{ref}(x) > 0$.
#
# To ensure this, we make a selection that selects events in the phase space regions with $p_{ref}(x) > 0$, or $p_c(x) \gg p_{ref}(x)$, and only perform the NSBI fit in this selected analysis region. **A natural choice for the reference hypothesis is then the signal-rich hypotheses**. This is referred to in the ATLAS publications as the Search-Oriented Mixture Models approach:
#
# $$p_{ref}(x) = \frac{1}{\sum_S \nu_S} \sum_S \frac{d\sigma_S}{dx} = \frac{1}{\nu_{H \to \tau\tau}} \frac{d\sigma_{H \to \tau\tau}}{dx}$$
#
# where the sum runs over all signal hypothesis in the model and the second equality is due to the sole signal hypothesis in our toy model, $pp \to {t\bar{t}}$.
#
# **Selecting out regions with $p_{ref}\sim 0$**
#
# A multi-class classification NN, with softmax output, is trained to output a score:
#
# $$ \text{NN}_\text{presel} = \log \left[\frac{\sum_S P_S (x)}{\sum_B P_B(x)} \right]$$
#
# where $P_c$ are the probability scores outputted from the softmax layer of the trained NN.

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import TrainEvaluatePreselNN

num_classes = len(labels_dict)

preselectionTraining = TrainEvaluatePreselNN(dataset_incl_nominal, num_classes, columns, columns_scaling)

# %%
if USE_SAVED_PRESEL_PREDICTIONS:
    presel_score = np.load(f"{saved_data}presel_score.npy")


else:
    if not USE_SAVED_MODEL_PRESEL:
        preselectionTraining.train(test_size=0.2, 
                                   random_state=4242, 
                                   path_to_save=path_to_saved_presel_model,
                                  batch_size=4096,
                                  epochs=50, learning_rate=0.1)
    
    else:
        preselectionTraining.get_trained_model(path_to_saved_presel_model)

    # Get predictions (softmax outputs)
    pred_NN_incl = preselectionTraining.predict(dataset_incl_nominal)

    presel_score = calculate_preselection_observable(pred_NN_incl, labels_dict, signal_processes, background_processes, pre_factor_dict = pre_factor_preselection_score)

    np.save(f"{saved_data}presel_score.npy", presel_score)
    np.save(f"{saved_data}pred_NN_incl.npy", presel_score)

# %%
min_pred = np.amin(presel_score)
max_pred = np.amax(presel_score)

bins = np.linspace(min_pred, max_pred, num=50)

hist_NN_output = {}
hist_NN_output_errs = {}

for key in labels_dict: 
    hist_NN_output[key], _ = np.histogram(presel_score[train_labels==labels_dict[key]], 
                                          weights = weights[train_labels==labels_dict[key]], bins=bins)
    
    hist_NN_output_errs[key], _ = np.histogram(presel_score[train_labels==labels_dict[key]], 
                                          weights = weights[train_labels==labels_dict[key]]**2, bins=bins)


for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins=bins, 
             alpha=0.6, label=key, 
             density=True, linewidth=2.0, yerr = np.sqrt(hist_NN_output_errs[key]))

plt.xlabel("Preselection Score", size=18)
plt.ylabel("Density", size=18)
plt.legend()
plt.yscale('log')
plt.show()

# %% [markdown]
# Making the cut
# ===
#
# Make a selection cut for regions with $p_{ref} \gg 0$ for performing the NSBI analysis. The remaining events - which by definition are background-dominated - can be used as a **Control Region** for data-driven background estimation, pre-unblinding validations, etc.
#
# Moreover, the preselections act as a tuning know for the tradeoff in selecting as many signal events as possible to go into the **Signal Region** (increasing sensitivity) and the feasibility of training accurate and precise NNs over a large phase space (need bigger models and more statistics). **The preselections can also weed out phase space regions with low background statistics to avoid poorly modelled regions.**
#
# Heres a first cut that you can optimize as much as you like to get the desired final results.

# %%
# Play around with these selections - decrease if estimators are unbiased but need more sensitivity and increase if the model is biased to reduce complexity
preselection_cuts = {'upper': 2.2, 'lower': -0.5}
np.save(f"{saved_data}preselection_cuts.npy", preselection_cuts)


for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins = bins, 
             alpha = 0.6, label = key, 
             density = True, linewidth = 2.0, 
                 yerr = np.sqrt(hist_NN_output_errs[key]))

plt.xlabel("Preselection Score", size=18)

for key in preselection_cuts:
    if preselection_cuts[key] != -999:
        plt.axvline(preselection_cuts[key], ymax=0.9, linestyle='--', label=f'preselection cut {key} = {preselection_cuts[key]}')

plt.ylabel("Density", size=18)
plt.legend(loc='upper left')
plt.yscale('log')
plt.show()

# %% [markdown]
# Signal and Control Regions
# ===
#
# The high signal over background phase space towards the right of the preselection cut shown above will be categorized as the **Signal Region** where the NSBI analysis is performed.
#
# The low signal phase space towards the left will be used as a **Control Region**, with typical uses such as background estimation, pre-unblinding data-MC checks, etc. In this phase space, we will use a binned summary observable like in any traditional analysis.

# %%
dataset_incl_nominal['presel_score'] = presel_score

dataset, dataset_CR = preselection_using_score(dataset_incl_nominal, preselection_cuts)

del dataset_incl_nominal

# %%
# Build a summary observable for Control Region
hist_CR = {}
num_bins = 10

CR_observable='PRI_had_pt'
np.save(f"{saved_data}observable_CR.npy", CR_observable)

kin_variable = dataset_CR[CR_observable].to_numpy()

min_kin = np.amin(kin_variable)
max_kin = np.amax(kin_variable)
min_kin = 30.0
max_kin = 80.0

bins = np.linspace(min_kin, max_kin, num=num_bins)

# Use the high-level preselection NN score as a summary observable for Control Region
for channel_ in labels_dict:
    dataset_CR_process = dataset_CR[dataset_CR.detailed_labels==channel_]
    hist_CR[channel_], bins = np.histogram(np.clip(dataset_CR_process[CR_observable].ravel(), min_kin, max_kin),
                                  weights = dataset_CR_process['weights'].ravel(),
                                  bins = bins)

# Save the Control Region observable
with open(f"{saved_data}hist_CR_ttbar.pkl", "wb") as fp:
    pickle.dump(hist_CR, fp)

np.save(f"{saved_data}CRbins.npy", bins)

# del dataset_CR

# %%
# Plot the Control Region observable

for channel_ in labels_dict:
    hep.histplot(hist_CR[channel_], bins=bins, label=channel_, density=1, linewidth=2.0)

plt.legend()
plt.xlabel('Control Region Observable')
# plt.yscale('log')
plt.ylabel('Density')
# Out:
# Text(0, 1, 'Density')

# %%
# Save the preselected Nominal dataframe for inference use later on
dataset.to_hdf(f"{saved_data}dataset_preselected_nominal_SR.h5", key="dataset", mode='w')

# %%
top_path = f'{path_prefix}output_training_nominal/'

# %% [markdown]
# Density ratio training
# ===
#
# Now we train the NNs for $\frac{p_c}{p_{ref}}(x)$ density ratios to build the full model. Our choice of reference hypothesis, motivated by the search-oriented mixture model described above, is:
#
# $$p_{ref}(x) = p_\text{higgs}(x) = \frac{1}{\nu_{H \to \tau\tau}} \frac{d\sigma_{H \to \tau\tau}}{dx} $$
#
# gives the POI $\mu-$parameterized model:
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} \right]= \mu + \frac{p_{t\bar{t}}\left(x\right)}{p_{H \to \tau\tau}(x)} + \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{H \to \tau\tau}(x)}$$
#
# The task of estimating the $\mu-$parameterized density ratio is thus reduced to estimating two $\mu-$independent density ratios $\frac{p_\text{single top}}{p_{t\bar{t}}}(x)$ and $\frac{p_\text{wjets}}{p_{t\bar{t}}}(x)$ mixed together with an analytical parameterization (hence the name mixture model).

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import TrainEvaluate_NN

mask_ref = np.isin(dataset.detailed_labels, ref_processes)

NN_training_mix_model = {}

rnd_seed_traintestsplit = 42 # can also be randomized, fixed for now

for process_type in mix_model_hypotheses:
    
    mask_process = dataset['type']==process_type
    
    dataset_num = dataset[mask_process].copy()
    dataset_ref = dataset[mask_ref].copy()

    dataset_num['train_labels'] = 1
    dataset_ref['train_labels'] = 0

    dataset_num['weights_normed'] = dataset_num['weights'].to_numpy() / dataset_num['weights'].sum()
    dataset_ref['weights_normed'] = dataset_ref['weights'].to_numpy() / dataset_ref['weights'].sum()

    # Build a training dataset for the training of p_<process_type>/p_<ref_processes> density ratio
    dataset_mix_model = pd.concat([dataset_num, dataset_ref])

    del dataset_num, dataset_ref

    # Save paths
    output_name = f'{process_type}'
    output_dir = f'{top_path}general_output_{process_type}'
    path_to_ratios = f'{top_path}output_ratios_{process_type}/'
    path_to_figures = f'{top_path}output_figures_{process_type}/'
    path_to_models = f'{top_path}output_model_params_{process_type}/'

    NN_training_mix_model[process_type] = TrainEvaluate_NN(dataset_mix_model, 
                                                           dataset_mix_model['weights_normed'],
                                                           dataset_mix_model['train_labels'],
                                                           columns, 
                                                           columns_scaling, rnd_seed_traintestsplit,
                                                           [process_type, 'ref'], output_dir, output_name, 
                                                            path_to_figures=path_to_figures,
                                                            path_to_ratios=path_to_ratios, 
                                                            path_to_models=path_to_models)


    del dataset_mix_model

# %% [markdown]
# Neural Network architecture
# ===
#
# Here we will start with a multi-layer perceptron (simple feed-forward Neural Network with fully-connected layers). This can be supplemented with more complex architectures like transformers.
#
# After detailed tuning during the off-shell Higgs boson analysis effort, we found that a network with very wide layers ($\geq 1000$) and a depth of less than 10 works best - alongside batch size of a few hundreds and a gradually declining learning rate that starts with a value just large enough to not blow up.

# %% [markdown]
# Starting with the training and validation of the various density ratio:
#
# $$\frac{p_{t\bar{t}}(x)}{p_\text{ref}(x)}, \frac{p_{Z \to \tau\tau}(x)}{p_\text{ref}(x)}$$

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 1

# %%
mix_model_hypotheses
# Out:
# ['ttbar', 'ztautau']

# %%
# Define unique settings for each process type

training_settings = {
    'ttbar': {
        'hidden_layers':        2,
        'neurons':              1000,
        'number_of_epochs':     100,
        'batch_size':           512,
        'learning_rate':        0.1,
        'scalerType':           'StandardScaler',
        'calibration':          True,
        'num_bins_cal':         100,
        'callback':             True,
        'callback_patience':    30,
        'callback_factor':      0.01,
        'verbose':              2
    },
    
    'ztautau': {
        'hidden_layers':        2,
        'neurons':              1000,
        'number_of_epochs':     100,
        'batch_size':           512,
        'learning_rate':        1.0,
        'scalerType':           'StandardScaler',
        'calibration':          True,
        'num_bins_cal':         100,
        'callback':             True,
        'callback_patience':    30,
        'callback_factor':      0.01,
        'verbose':              2
    }
}

# %%
# Train the density ratio NN
for process_type in mix_model_hypotheses:
    
    settings = training_settings[process_type]

    NN_training_mix_model[process_type].train(**settings)
    NN_training_mix_model[process_type].test_normalization()
# Out:
# Sum of weights of class 0: 0.6999995708465576
# Sum of weights of class 1: 0.700005292892456
# Using swish activation function
# /home/jaySandesara/.conda/envs/NSBI/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1749074181.559737  482920 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1922 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB MIG 1g.5gb, pci bus id: 0000:c1:00.0, compute capability: 8.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,010,001 (3.85 MB)
#  Trainable params: 1,010,001 (3.85 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1749074183.038361  484913 service.cc:148] XLA service 0x7f6284008a80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1749074183.038393  484913 service.cc:156]   StreamExecutor device (0): NVIDIA A100-SXM4-40GB MIG 1g.5gb, Compute Capability 8.0
# 2025-06-04 21:56:23.082141: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1749074183.165633  484913 cuda_dnn.cc:529] Loaded cuDNN version 90501
# 2025-06-04 21:56:23.552198: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion_1', 8 bytes spill stores, 4 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion', 16 bytes spill stores, 20 bytes spill loads
#
# I0000 00:00:1749074183.557253  484913 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1945/1945 - 7s - 3ms/step - binary_accuracy: 0.6719 - loss: 7.8185e-07 - val_binary_accuracy: 0.6725 - val_loss: 7.7132e-07 - learning_rate: 0.1000
# Epoch 2/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.6881 - loss: 7.6003e-07 - val_binary_accuracy: 0.6874 - val_loss: 7.5027e-07 - learning_rate: 0.1000
# Epoch 3/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.6933 - loss: 7.5317e-07 - val_binary_accuracy: 0.6882 - val_loss: 7.4887e-07 - learning_rate: 0.1000
# Epoch 4/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.6936 - loss: 7.5037e-07 - val_binary_accuracy: 0.6890 - val_loss: 7.4868e-07 - learning_rate: 0.1000
# Epoch 5/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.6950 - loss: 7.4833e-07 - val_binary_accuracy: 0.6876 - val_loss: 7.5234e-07 - learning_rate: 0.1000
# Epoch 6/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.6954 - loss: 7.4558e-07 - val_binary_accuracy: 0.6909 - val_loss: 7.4403e-07 - learning_rate: 0.1000
# Epoch 7/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.6973 - loss: 7.4138e-07 - val_binary_accuracy: 0.6906 - val_loss: 7.3614e-07 - learning_rate: 0.1000
# Epoch 8/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.6970 - loss: 7.4024e-07 - val_binary_accuracy: 0.6906 - val_loss: 7.4178e-07 - learning_rate: 0.1000
# Epoch 9/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.6976 - loss: 7.3917e-07 - val_binary_accuracy: 0.6940 - val_loss: 7.3327e-07 - learning_rate: 0.1000
# Epoch 10/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.6997 - loss: 7.3685e-07 - val_binary_accuracy: 0.6893 - val_loss: 7.4163e-07 - learning_rate: 0.1000
# Epoch 11/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.6988 - loss: 7.3598e-07 - val_binary_accuracy: 0.6962 - val_loss: 7.3373e-07 - learning_rate: 0.1000
# Epoch 12/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.6991 - loss: 7.3619e-07 - val_binary_accuracy: 0.6959 - val_loss: 7.3790e-07 - learning_rate: 0.1000
# Epoch 13/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.6997 - loss: 7.3532e-07 - val_binary_accuracy: 0.6978 - val_loss: 7.2851e-07 - learning_rate: 0.1000
# Epoch 14/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.6997 - loss: 7.3486e-07 - val_binary_accuracy: 0.6949 - val_loss: 7.3655e-07 - learning_rate: 0.1000
# Epoch 15/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7006 - loss: 7.3495e-07 - val_binary_accuracy: 0.6974 - val_loss: 7.3159e-07 - learning_rate: 0.1000
# Epoch 16/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.6996 - loss: 7.3487e-07 - val_binary_accuracy: 0.6939 - val_loss: 7.2873e-07 - learning_rate: 0.1000
# Epoch 17/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.6987 - loss: 7.3463e-07 - val_binary_accuracy: 0.6988 - val_loss: 7.2752e-07 - learning_rate: 0.1000
# Epoch 18/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.6993 - loss: 7.3427e-07 - val_binary_accuracy: 0.6984 - val_loss: 7.3370e-07 - learning_rate: 0.1000
# Epoch 19/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.6993 - loss: 7.3445e-07 - val_binary_accuracy: 0.6946 - val_loss: 7.3851e-07 - learning_rate: 0.1000
# Epoch 20/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7005 - loss: 7.3439e-07 - val_binary_accuracy: 0.6999 - val_loss: 7.2774e-07 - learning_rate: 0.1000
# Epoch 21/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7008 - loss: 7.3359e-07 - val_binary_accuracy: 0.6932 - val_loss: 7.2878e-07 - learning_rate: 0.1000
# Epoch 22/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7001 - loss: 7.3367e-07 - val_binary_accuracy: 0.6962 - val_loss: 7.3184e-07 - learning_rate: 0.1000
# Epoch 23/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7015 - loss: 7.3263e-07 - val_binary_accuracy: 0.6984 - val_loss: 7.2566e-07 - learning_rate: 0.1000
# Epoch 24/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7005 - loss: 7.3293e-07 - val_binary_accuracy: 0.6938 - val_loss: 7.3390e-07 - learning_rate: 0.1000
# Epoch 25/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7019 - loss: 7.3301e-07 - val_binary_accuracy: 0.6999 - val_loss: 7.2823e-07 - learning_rate: 0.1000
# Epoch 26/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7012 - loss: 7.3305e-07 - val_binary_accuracy: 0.6975 - val_loss: 7.3198e-07 - learning_rate: 0.1000
# Epoch 27/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7013 - loss: 7.3224e-07 - val_binary_accuracy: 0.6975 - val_loss: 7.3692e-07 - learning_rate: 0.1000
# Epoch 28/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7020 - loss: 7.3214e-07 - val_binary_accuracy: 0.6967 - val_loss: 7.2969e-07 - learning_rate: 0.1000
# Epoch 29/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7010 - loss: 7.3218e-07 - val_binary_accuracy: 0.7003 - val_loss: 7.2894e-07 - learning_rate: 0.1000
# Epoch 30/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7013 - loss: 7.3143e-07 - val_binary_accuracy: 0.6954 - val_loss: 7.2935e-07 - learning_rate: 0.1000
# Epoch 31/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7014 - loss: 7.3182e-07 - val_binary_accuracy: 0.6983 - val_loss: 7.2771e-07 - learning_rate: 0.1000
# Epoch 32/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7058 - loss: 7.2395e-07 - val_binary_accuracy: 0.6997 - val_loss: 7.2187e-07 - learning_rate: 0.0010
# Epoch 33/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7071 - loss: 7.2180e-07 - val_binary_accuracy: 0.7005 - val_loss: 7.2064e-07 - learning_rate: 0.0010
# Epoch 34/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7069 - loss: 7.2102e-07 - val_binary_accuracy: 0.7020 - val_loss: 7.2034e-07 - learning_rate: 0.0010
# Epoch 35/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7070 - loss: 7.2060e-07 - val_binary_accuracy: 0.7027 - val_loss: 7.2018e-07 - learning_rate: 0.0010
# Epoch 36/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7073 - loss: 7.2035e-07 - val_binary_accuracy: 0.7028 - val_loss: 7.1988e-07 - learning_rate: 0.0010
# Epoch 37/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7074 - loss: 7.2012e-07 - val_binary_accuracy: 0.7033 - val_loss: 7.1980e-07 - learning_rate: 0.0010
# Epoch 38/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7075 - loss: 7.1998e-07 - val_binary_accuracy: 0.7030 - val_loss: 7.1977e-07 - learning_rate: 0.0010
# Epoch 39/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7076 - loss: 7.1984e-07 - val_binary_accuracy: 0.7025 - val_loss: 7.1988e-07 - learning_rate: 0.0010
# Epoch 40/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7072 - loss: 7.1974e-07 - val_binary_accuracy: 0.7024 - val_loss: 7.1963e-07 - learning_rate: 0.0010
# Epoch 41/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7077 - loss: 7.1965e-07 - val_binary_accuracy: 0.7021 - val_loss: 7.1968e-07 - learning_rate: 0.0010
# Epoch 42/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7074 - loss: 7.1956e-07 - val_binary_accuracy: 0.7021 - val_loss: 7.1954e-07 - learning_rate: 0.0010
# Epoch 43/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7078 - loss: 7.1950e-07 - val_binary_accuracy: 0.7017 - val_loss: 7.1956e-07 - learning_rate: 0.0010
# Epoch 44/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7073 - loss: 7.1944e-07 - val_binary_accuracy: 0.7014 - val_loss: 7.1961e-07 - learning_rate: 0.0010
# Epoch 45/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7077 - loss: 7.1939e-07 - val_binary_accuracy: 0.7016 - val_loss: 7.1943e-07 - learning_rate: 0.0010
# Epoch 46/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7077 - loss: 7.1933e-07 - val_binary_accuracy: 0.7019 - val_loss: 7.1943e-07 - learning_rate: 0.0010
# Epoch 47/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7076 - loss: 7.1930e-07 - val_binary_accuracy: 0.7025 - val_loss: 7.1942e-07 - learning_rate: 0.0010
# Epoch 48/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7077 - loss: 7.1923e-07 - val_binary_accuracy: 0.7014 - val_loss: 7.1943e-07 - learning_rate: 0.0010
# Epoch 49/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7079 - loss: 7.1918e-07 - val_binary_accuracy: 0.7019 - val_loss: 7.1952e-07 - learning_rate: 0.0010
# Epoch 50/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7078 - loss: 7.1915e-07 - val_binary_accuracy: 0.7015 - val_loss: 7.1948e-07 - learning_rate: 0.0010
# Epoch 51/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7074 - loss: 7.1914e-07 - val_binary_accuracy: 0.7016 - val_loss: 7.1958e-07 - learning_rate: 0.0010
# Epoch 52/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7079 - loss: 7.1909e-07 - val_binary_accuracy: 0.7019 - val_loss: 7.1940e-07 - learning_rate: 0.0010
# Epoch 53/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7080 - loss: 7.1906e-07 - val_binary_accuracy: 0.7020 - val_loss: 7.1932e-07 - learning_rate: 0.0010
# Epoch 54/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7078 - loss: 7.1903e-07 - val_binary_accuracy: 0.7019 - val_loss: 7.1927e-07 - learning_rate: 0.0010
# Epoch 55/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7079 - loss: 7.1900e-07 - val_binary_accuracy: 0.7015 - val_loss: 7.1921e-07 - learning_rate: 0.0010
# Epoch 56/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7080 - loss: 7.1898e-07 - val_binary_accuracy: 0.7012 - val_loss: 7.1930e-07 - learning_rate: 0.0010
# Epoch 57/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7080 - loss: 7.1894e-07 - val_binary_accuracy: 0.7015 - val_loss: 7.1928e-07 - learning_rate: 0.0010
# Epoch 58/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7077 - loss: 7.1891e-07 - val_binary_accuracy: 0.7020 - val_loss: 7.1920e-07 - learning_rate: 0.0010
# Epoch 59/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7076 - loss: 7.1890e-07 - val_binary_accuracy: 0.7011 - val_loss: 7.1924e-07 - learning_rate: 0.0010
# Epoch 60/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7080 - loss: 7.1885e-07 - val_binary_accuracy: 0.7007 - val_loss: 7.1939e-07 - learning_rate: 0.0010
# Epoch 61/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7080 - loss: 7.1884e-07 - val_binary_accuracy: 0.7007 - val_loss: 7.1927e-07 - learning_rate: 0.0010
# Epoch 62/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7081 - loss: 7.1862e-07 - val_binary_accuracy: 0.7007 - val_loss: 7.1927e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7081 - loss: 7.1862e-07 - val_binary_accuracy: 0.7007 - val_loss: 7.1927e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1862e-07 - val_binary_accuracy: 0.7007 - val_loss: 7.1927e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1862e-07 - val_binary_accuracy: 0.7008 - val_loss: 7.1927e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1861e-07 - val_binary_accuracy: 0.7008 - val_loss: 7.1927e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1861e-07 - val_binary_accuracy: 0.7008 - val_loss: 7.1927e-07 - learning_rate: 1.0000e-05
# Epoch 68/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1861e-07 - val_binary_accuracy: 0.7008 - val_loss: 7.1926e-07 - learning_rate: 1.0000e-05
# Epoch 69/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1861e-07 - val_binary_accuracy: 0.7006 - val_loss: 7.1926e-07 - learning_rate: 1.0000e-05
# Epoch 70/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1861e-07 - val_binary_accuracy: 0.7006 - val_loss: 7.1926e-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1861e-07 - val_binary_accuracy: 0.7006 - val_loss: 7.1926e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1861e-07 - val_binary_accuracy: 0.7006 - val_loss: 7.1926e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1861e-07 - val_binary_accuracy: 0.7006 - val_loss: 7.1926e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1861e-07 - val_binary_accuracy: 0.7008 - val_loss: 7.1926e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1860e-07 - val_binary_accuracy: 0.7010 - val_loss: 7.1926e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1860e-07 - val_binary_accuracy: 0.7010 - val_loss: 7.1926e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1860e-07 - val_binary_accuracy: 0.7010 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1860e-07 - val_binary_accuracy: 0.7010 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1860e-07 - val_binary_accuracy: 0.7011 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1860e-07 - val_binary_accuracy: 0.7011 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1860e-07 - val_binary_accuracy: 0.7011 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-05
# Epoch 82/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1860e-07 - val_binary_accuracy: 0.7011 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-05
# Epoch 83/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1860e-07 - val_binary_accuracy: 0.7011 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-05
# Epoch 84/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1860e-07 - val_binary_accuracy: 0.7011 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-05
# Epoch 85/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1860e-07 - val_binary_accuracy: 0.7010 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-05
# Epoch 86/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1860e-07 - val_binary_accuracy: 0.7009 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-05
# Epoch 87/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1860e-07 - val_binary_accuracy: 0.7009 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-05
# Epoch 88/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1860e-07 - val_binary_accuracy: 0.7010 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-05
# Epoch 89/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7083 - loss: 7.1860e-07 - val_binary_accuracy: 0.7010 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-05
# Epoch 90/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1860e-07 - val_binary_accuracy: 0.7010 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-05
# Epoch 91/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1860e-07 - val_binary_accuracy: 0.7010 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-05
# Epoch 92/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1859e-07 - val_binary_accuracy: 0.7010 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-07
# Epoch 93/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1859e-07 - val_binary_accuracy: 0.7010 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-07
# Epoch 94/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1859e-07 - val_binary_accuracy: 0.7010 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-07
# Epoch 95/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1859e-07 - val_binary_accuracy: 0.7010 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-07
# Epoch 96/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1859e-07 - val_binary_accuracy: 0.7010 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-07
# Epoch 97/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1859e-07 - val_binary_accuracy: 0.7010 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-07
# Epoch 98/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1859e-07 - val_binary_accuracy: 0.7010 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-07
# Epoch 99/100
# 1945/1945 - 5s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1859e-07 - val_binary_accuracy: 0.7010 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-07
# Epoch 100/100
# 1945/1945 - 4s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.1859e-07 - val_binary_accuracy: 0.7010 - val_loss: 7.1925e-07 - learning_rate: 1.0000e-07
# Finished Training
# /home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/output_training_nominal/output_model_params_ttbar/model_scaler.bin
# 34567/34567 - 36s - 1ms/step
# 0.016815137
# 0.97287965
# 34567/34567 - 38s - 1ms/step
# 14814/14814 - 14s - 958us/step
# 49381/49381 - 41s - 839us/step
# The sum of PDFs is 0.9998212456703186
# Sum of weights of class 0: 0.6999996304512024
# Sum of weights of class 1: 0.700001060962677
# Using swish activation function
# /home/jaySandesara/.conda/envs/NSBI/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 1000)           │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,010,001 (3.85 MB)
#  Trainable params: 1,010,001 (3.85 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# 2025-06-04 22:06:51.487192: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion_1', 8 bytes spill stores, 4 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion', 16 bytes spill stores, 20 bytes spill loads
# 3146/3146 - 8s - 3ms/step - binary_accuracy: 0.6779 - loss: 4.8010e-07 - val_binary_accuracy: 0.6808 - val_loss: 4.7728e-07 - learning_rate: 1.0000
# Epoch 2/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6826 - loss: 4.7523e-07 - val_binary_accuracy: 0.6809 - val_loss: 4.7689e-07 - learning_rate: 1.0000
# Epoch 3/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6832 - loss: 4.7413e-07 - val_binary_accuracy: 0.6819 - val_loss: 4.7467e-07 - learning_rate: 1.0000
# Epoch 4/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6837 - loss: 4.7337e-07 - val_binary_accuracy: 0.6794 - val_loss: 4.7703e-07 - learning_rate: 1.0000
# Epoch 5/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6838 - loss: 4.7308e-07 - val_binary_accuracy: 0.6798 - val_loss: 4.7701e-07 - learning_rate: 1.0000
# Epoch 6/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6842 - loss: 4.7286e-07 - val_binary_accuracy: 0.6820 - val_loss: 4.7509e-07 - learning_rate: 1.0000
# Epoch 7/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6840 - loss: 4.7267e-07 - val_binary_accuracy: 0.6770 - val_loss: 4.8333e-07 - learning_rate: 1.0000
# Epoch 8/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6854 - loss: 4.7192e-07 - val_binary_accuracy: 0.6824 - val_loss: 4.7611e-07 - learning_rate: 1.0000
# Epoch 9/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6875 - loss: 4.6963e-07 - val_binary_accuracy: 0.6843 - val_loss: 4.7211e-07 - learning_rate: 1.0000
# Epoch 10/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6880 - loss: 4.6869e-07 - val_binary_accuracy: 0.6861 - val_loss: 4.7166e-07 - learning_rate: 1.0000
# Epoch 11/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6888 - loss: 4.6808e-07 - val_binary_accuracy: 0.6853 - val_loss: 4.7055e-07 - learning_rate: 1.0000
# Epoch 12/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6892 - loss: 4.6763e-07 - val_binary_accuracy: 0.6844 - val_loss: 4.7260e-07 - learning_rate: 1.0000
# Epoch 13/100
# 3146/3146 - 5s - 2ms/step - binary_accuracy: 0.6897 - loss: 4.6722e-07 - val_binary_accuracy: 0.6882 - val_loss: 4.6820e-07 - learning_rate: 1.0000
# Epoch 14/100
# 3146/3146 - 5s - 2ms/step - binary_accuracy: 0.6904 - loss: 4.6660e-07 - val_binary_accuracy: 0.6889 - val_loss: 4.6772e-07 - learning_rate: 1.0000
# Epoch 15/100
# 3146/3146 - 5s - 2ms/step - binary_accuracy: 0.6906 - loss: 4.6630e-07 - val_binary_accuracy: 0.6776 - val_loss: 4.7575e-07 - learning_rate: 1.0000
# Epoch 16/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6908 - loss: 4.6610e-07 - val_binary_accuracy: 0.6884 - val_loss: 4.6876e-07 - learning_rate: 1.0000
# Epoch 17/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6911 - loss: 4.6605e-07 - val_binary_accuracy: 0.6880 - val_loss: 4.6879e-07 - learning_rate: 1.0000
# Epoch 18/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6913 - loss: 4.6593e-07 - val_binary_accuracy: 0.6867 - val_loss: 4.7014e-07 - learning_rate: 1.0000
# Epoch 19/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6911 - loss: 4.6572e-07 - val_binary_accuracy: 0.6863 - val_loss: 4.6948e-07 - learning_rate: 1.0000
# Epoch 20/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6913 - loss: 4.6575e-07 - val_binary_accuracy: 0.6817 - val_loss: 4.7194e-07 - learning_rate: 1.0000
# Epoch 21/100
# 3146/3146 - 5s - 2ms/step - binary_accuracy: 0.6915 - loss: 4.6570e-07 - val_binary_accuracy: 0.6883 - val_loss: 4.6856e-07 - learning_rate: 1.0000
# Epoch 22/100
# 3146/3146 - 5s - 2ms/step - binary_accuracy: 0.6917 - loss: 4.6563e-07 - val_binary_accuracy: 0.6830 - val_loss: 4.7249e-07 - learning_rate: 1.0000
# Epoch 23/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6913 - loss: 4.6558e-07 - val_binary_accuracy: 0.6891 - val_loss: 4.6856e-07 - learning_rate: 1.0000
# Epoch 24/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6914 - loss: 4.6548e-07 - val_binary_accuracy: 0.6876 - val_loss: 4.6871e-07 - learning_rate: 1.0000
# Epoch 25/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6915 - loss: 4.6552e-07 - val_binary_accuracy: 0.6903 - val_loss: 4.6628e-07 - learning_rate: 1.0000
# Epoch 26/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6915 - loss: 4.6532e-07 - val_binary_accuracy: 0.6803 - val_loss: 4.7447e-07 - learning_rate: 1.0000
# Epoch 27/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6916 - loss: 4.6540e-07 - val_binary_accuracy: 0.6826 - val_loss: 4.7237e-07 - learning_rate: 1.0000
# Epoch 28/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6918 - loss: 4.6528e-07 - val_binary_accuracy: 0.6891 - val_loss: 4.6792e-07 - learning_rate: 1.0000
# Epoch 29/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6919 - loss: 4.6515e-07 - val_binary_accuracy: 0.6864 - val_loss: 4.6998e-07 - learning_rate: 1.0000
# Epoch 30/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6916 - loss: 4.6506e-07 - val_binary_accuracy: 0.6863 - val_loss: 4.7000e-07 - learning_rate: 1.0000
# Epoch 31/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6918 - loss: 4.6492e-07 - val_binary_accuracy: 0.6886 - val_loss: 4.6797e-07 - learning_rate: 1.0000
# Epoch 32/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6953 - loss: 4.6116e-07 - val_binary_accuracy: 0.6925 - val_loss: 4.6309e-07 - learning_rate: 0.0100
# Epoch 33/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6961 - loss: 4.6007e-07 - val_binary_accuracy: 0.6927 - val_loss: 4.6265e-07 - learning_rate: 0.0100
# Epoch 34/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6962 - loss: 4.5981e-07 - val_binary_accuracy: 0.6930 - val_loss: 4.6251e-07 - learning_rate: 0.0100
# Epoch 35/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6963 - loss: 4.5967e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6237e-07 - learning_rate: 0.0100
# Epoch 36/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6964 - loss: 4.5958e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6226e-07 - learning_rate: 0.0100
# Epoch 37/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6964 - loss: 4.5952e-07 - val_binary_accuracy: 0.6930 - val_loss: 4.6218e-07 - learning_rate: 0.0100
# Epoch 38/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6964 - loss: 4.5946e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6222e-07 - learning_rate: 0.0100
# Epoch 39/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6965 - loss: 4.5941e-07 - val_binary_accuracy: 0.6930 - val_loss: 4.6217e-07 - learning_rate: 0.0100
# Epoch 40/100
# 3146/3146 - 6s - 2ms/step - binary_accuracy: 0.6965 - loss: 4.5938e-07 - val_binary_accuracy: 0.6930 - val_loss: 4.6206e-07 - learning_rate: 0.0100
# Epoch 41/100
# 3146/3146 - 5s - 2ms/step - binary_accuracy: 0.6966 - loss: 4.5936e-07 - val_binary_accuracy: 0.6930 - val_loss: 4.6213e-07 - learning_rate: 0.0100
# Epoch 42/100
# 3146/3146 - 5s - 2ms/step - binary_accuracy: 0.6966 - loss: 4.5932e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6203e-07 - learning_rate: 0.0100
# Epoch 43/100
# 3146/3146 - 5s - 2ms/step - binary_accuracy: 0.6966 - loss: 4.5930e-07 - val_binary_accuracy: 0.6928 - val_loss: 4.6201e-07 - learning_rate: 0.0100
# Epoch 44/100
# 3146/3146 - 5s - 2ms/step - binary_accuracy: 0.6966 - loss: 4.5927e-07 - val_binary_accuracy: 0.6929 - val_loss: 4.6201e-07 - learning_rate: 0.0100
# Epoch 45/100
# 3146/3146 - 5s - 2ms/step - binary_accuracy: 0.6966 - loss: 4.5925e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6197e-07 - learning_rate: 0.0100
# Epoch 46/100
# 3146/3146 - 5s - 2ms/step - binary_accuracy: 0.6966 - loss: 4.5923e-07 - val_binary_accuracy: 0.6929 - val_loss: 4.6193e-07 - learning_rate: 0.0100
# Epoch 47/100
# 3146/3146 - 5s - 2ms/step - binary_accuracy: 0.6965 - loss: 4.5922e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6196e-07 - learning_rate: 0.0100
# Epoch 48/100
# 3146/3146 - 5s - 2ms/step - binary_accuracy: 0.6966 - loss: 4.5919e-07 - val_binary_accuracy: 0.6930 - val_loss: 4.6195e-07 - learning_rate: 0.0100
# Epoch 49/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6967 - loss: 4.5919e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6189e-07 - learning_rate: 0.0100
# Epoch 50/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6966 - loss: 4.5917e-07 - val_binary_accuracy: 0.6930 - val_loss: 4.6195e-07 - learning_rate: 0.0100
# Epoch 51/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6968 - loss: 4.5916e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6193e-07 - learning_rate: 0.0100
# Epoch 52/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6968 - loss: 4.5914e-07 - val_binary_accuracy: 0.6933 - val_loss: 4.6188e-07 - learning_rate: 0.0100
# Epoch 53/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6968 - loss: 4.5913e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6187e-07 - learning_rate: 0.0100
# Epoch 54/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6968 - loss: 4.5911e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6186e-07 - learning_rate: 0.0100
# Epoch 55/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6968 - loss: 4.5910e-07 - val_binary_accuracy: 0.6935 - val_loss: 4.6185e-07 - learning_rate: 0.0100
# Epoch 56/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6967 - loss: 4.5909e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6186e-07 - learning_rate: 0.0100
# Epoch 57/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6969 - loss: 4.5907e-07 - val_binary_accuracy: 0.6933 - val_loss: 4.6186e-07 - learning_rate: 0.0100
# Epoch 58/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6969 - loss: 4.5906e-07 - val_binary_accuracy: 0.6934 - val_loss: 4.6185e-07 - learning_rate: 0.0100
# Epoch 59/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6968 - loss: 4.5905e-07 - val_binary_accuracy: 0.6933 - val_loss: 4.6186e-07 - learning_rate: 0.0100
# Epoch 60/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6968 - loss: 4.5905e-07 - val_binary_accuracy: 0.6933 - val_loss: 4.6187e-07 - learning_rate: 0.0100
# Epoch 61/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6968 - loss: 4.5903e-07 - val_binary_accuracy: 0.6934 - val_loss: 4.6182e-07 - learning_rate: 0.0100
# Epoch 62/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6969 - loss: 4.5897e-07 - val_binary_accuracy: 0.6933 - val_loss: 4.6178e-07 - learning_rate: 1.0000e-04
# Epoch 63/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6969 - loss: 4.5894e-07 - val_binary_accuracy: 0.6933 - val_loss: 4.6177e-07 - learning_rate: 1.0000e-04
# Epoch 64/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6969 - loss: 4.5893e-07 - val_binary_accuracy: 0.6933 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 65/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6969 - loss: 4.5893e-07 - val_binary_accuracy: 0.6933 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 66/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6969 - loss: 4.5893e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 67/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6969 - loss: 4.5892e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 68/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6969 - loss: 4.5892e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 69/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6969 - loss: 4.5892e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 70/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5892e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 71/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6969 - loss: 4.5892e-07 - val_binary_accuracy: 0.6933 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 72/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6969 - loss: 4.5892e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 73/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6969 - loss: 4.5892e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 74/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6969 - loss: 4.5892e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 75/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6969 - loss: 4.5891e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 76/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 77/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 78/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 79/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 80/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 81/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 82/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 83/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 84/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 85/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 86/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6932 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 87/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 88/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 89/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 90/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 91/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-04
# Epoch 92/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-06
# Epoch 93/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-06
# Epoch 94/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-06
# Epoch 95/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-06
# Epoch 96/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-06
# Epoch 97/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-06
# Epoch 98/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-06
# Epoch 99/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-06
# Epoch 100/100
# 3146/3146 - 7s - 2ms/step - binary_accuracy: 0.6970 - loss: 4.5891e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6176e-07 - learning_rate: 1.0000e-06
# Finished Training
# /home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/output_training_nominal/output_model_params_ztautau/model_scaler.bin
# 55914/55914 - 59s - 1ms/step
# 0.00089490006
# 0.99006265
# 55914/55914 - 62s - 1ms/step
# 23963/23963 - 27s - 1ms/step
# 79877/79877 - 63s - 787us/step
# The sum of PDFs is 0.9995036721229553

# %% [markdown]
# Check for overtraining by comparing the NN output distributions between training and holdout datasets. The holdout dataset is the subset of events not used during training.

# %%
for process_type in mix_model_hypotheses:
    NN_training_mix_model[process_type].make_overfit_plots()

# %% [markdown]
# Diagnostic Checks
# ===
#
# While traditionally, a NN observable is judged on the basis of its accuracy - for NSBI we are interested in the quality of the density ratios more than the discrimination power. The latter comes from the perfect modelling of the multi-dimensional likelihood ratios.
#
# To ensure correct modelling, we run two main checks on the training:
#
# - **Calibration closure test**
#
#   The NNs are trained using the binary cross-entropy loss, which under ideal conditions leads to the NN converging to the score function:
#
#   $$\hat{s}_\text{pred} = \frac{p_\text{ref}(x)}{p_\text{ref}(x)+p_\text{c}(x)}$$
#
#   that can be converted into the probability ratio we desire (likelihood ratio trick):
#
#   $$\frac{p_\text{c}(x)}{p_\text{ref}(x)} = \frac{\hat{s}_\text{pred}(x)}{1-\hat{s}_\text{pred}(x)}$$
#
#   For the NNs to be well-calibrated, we use the Monte Carlo samples to verify the equality:
#
#
#   $$\left[\frac{p_c(x)}{p_c(x)+p_{ref}(x)}\right]_\text{NN} \sim \left[\frac{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}}{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}+\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}}\right]_\text{MC}$$
#
#   where we bin the events from $p_c$ and $p_\text{ref}$ MC samples, denoted by $\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}$ and $\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}$ respectively where $I(x|\hat{s}_\text{pred})$ returns the index of the $\hat{s}_\text{pred}$ bin in which an event $x$ falls.

# %%
num_bins_cal = 50

for process_type in mix_model_hypotheses:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='score')
# Out:
# observable not recognized
# observable not recognized

# %%
num_bins_cal = 50

for process_type in mix_model_hypotheses:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='llr')

# %% [markdown]
# - **Density ratio reweighting closure tests**
#
#   Despite having a well-calibrated output and thus a robust probabilistic interpretation, the trained density ratios might not capture the full multi-dimensional event information $x$. In other words, the NNs might still be biased estimators of the optimal score function, as defined in the CARL paper (link).
#
#   The next diagnostic involves verifying the following equality using 1D projections of $x$:
#
#   $$\frac{p_c(x)}{p_{ref}(x)} \times p_{ref}(x) \sim p_c(x)$$
#
#   We can do this one-by-one for all the observables used to model the density ratios, and also possibly the observables not used directly in the training but can still be well-estimated due to the NN learning the right physics.

# %%
variables_to_plot=['PRI_lep_pt'] # The 1D variable for reweighting closure
yscale_type='log'
num_bins_plotting=21

for process_type in mix_model_hypotheses:

    NN_training_mix_model[process_type].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
for process_type in mix_model_hypotheses:
    # Evaluate the density ratios p_c/p_ref for the full dataset and save for the inference step
    NN_training_mix_model[process_type].evaluate_and_save_ratios(dataset)
# Out:
# 81211/81211 - 71s - 872us/step
# 81211/81211 - 88s - 1ms/step

# %% [markdown]
# Systematic Uncertainty Modelling
# ===
#
# So far we have left out the nuisance parameter piece of the parameterized density ratio decomposition shown before:
#
# $$g_c(x|\alpha) = \frac{p_c(x|\alpha)}{p_c(x)}$$
#
# which will be estimated in the `Systematic_Uncertainty_Estimation.ipynb` notebook.

# %% [markdown]
# Training an Ensemble of NNs
# ===
#
# In a realistic analysis, a large ensemble of NNs are trained to estimate density ratios, for *each* of the channels. **This reduces not only the variance but has also been found to reduce biases in the final fits.**
#
# In the off-shell Higgs boson analysis, we used k-fold cross-validation, with k=10, to train an ensemble $N_{ens}\sim 250$ of NNs per density ratio $p_c(x)/p_{ref}(x)$. The density ratios used in the final fit are always evaluated on the holdout dataset and by using each of the folds as holdout once, the entire model for $p_c(x)/p_{ref}(x)$ consists of $N_{ens}\times k \sim 2500$ NNs. Each NN in the ensemble is trained by resampling data without replacement from the k-1 folds used for training.
