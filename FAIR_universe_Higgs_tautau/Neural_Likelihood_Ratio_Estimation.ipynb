# %% [markdown]
# Train Neural Networks to estimate Likelihood Ratios
# ===
#
# In this notebook we will setup the neural networks that train unbiased and low-variance density ratios to be then used for inference.

# %%
import os, sys, pathlib, importlib
sys.path.append('../')

# Load the package and modules for training and plotting
import nsbi_common_utils
from nsbi_common_utils import plotting, training
from nsbi_common_utils.training import TrainEvaluate_NN, TrainEvaluatePreselNN


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt
import pickle
import yaml
import random

from utils import preselection_using_score, calculate_preselection_observable

from coffea.analysis_tools import PackedSelection

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

hep.style.use(hep.style.ATLAS)
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/src/nsbi_common_utils/plotting.py:11: FutureWarning: ``set_style`` is deprecated: Naming convention is changing to match mpl. Use ``mplhep.style.use()``.
#   hep.set_style("ATLAS")
# 2025-06-30 10:33:54.543964: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751279634.566022 1218423 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751279634.571490 1218423 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-30 10:33:54.591659: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
with open("config.yml", "r") as f:
    config = yaml.safe_load(f)

# %%
# path prefix for saving cached data used between modules
path_prefix = config['path_prefix']
path_saved_data = config['path_saved_data']
path_preselection_NN_model = config['path_preselection_NN_model']

# Path for saving interemdiate objects, like NN predictions
saved_data = f'{path_prefix}{path_saved_data}'

# Path for saving/loading preselection NN model
path_to_saved_presel_model = f'{path_prefix}{path_preselection_NN_model}'

# %% [markdown]
# Statistical Model
# -
#
# The statistical model we have is:
#
# $$p(x|\mu, \alpha) = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot p_c\left(x|\alpha\right)$$
#
# where $c$ stands for the various physics channels that contribute to the final state $x$, **$\mu$ is the signal-strength parameter and $\alpha$ is the vector of nuisance parameters associated with the various systematic uncertainties in the model**. Note that we are assuming that the parameter $\mu$-dependence is known analytically and that we have simulation models for each of the channels $p_c(x)$.
#
# Setting up the test
# -
#
# The objective is to build the test statistic for composite hypothesis testing:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})}{p(x_i|\hat{\mu}, \hat{\alpha})} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
# A direct approach would then be to model the probability density $p(x|\mu, \alpha)$ using NNs. But that is a more difficult task than training probability density ratios. We use a simple trick:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})/p_{ref}(x)}{p(x_i|\hat{\mu}, \hat{\alpha})/p_{ref}(x)} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
#
# to turn this into a density ratio estimation problem:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot \frac{p_c\left(x|\alpha\right)}{p_{ref}(x)}$$
#
# Factorizing out the $\alpha$-dependence in the density ratios:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\sum_c G_c(\alpha) \cdot f_c(\mu) \cdot \nu_c} \sum_c f_c(\mu) \cdot G_c(\alpha)\cdot \nu_c \cdot g_c(x|\alpha) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}$$
#
# Factorized approach:
# --
#
# Instead of training NNs parameterized on $\mu$ and $\alpha$, we use analytical parameterizations to simplify the problem to training only parameter-independent density ratios.
#
# Let's set this up for the toy $H\to \tau\tau$ model we are using. **Neglecting the nuisance parameter dependence ($G_c(\alpha) = g_c(x|\alpha) = 1$), the probability model can be written as**
#
# $$\sum_c f_c(\mu) \cdot \nu_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} = \mu \cdot \nu_{H \to \tau\tau}(\mu) \cdot  \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)} + \nu_{t\bar{t}}(\mu) \cdot  \frac{p_{t\bar{t}}\left(x\right)}{p_{ref}(x)} + \nu_{Z \to \tau\tau}(\mu) \cdot  \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{ref}(x)}$$
#
# In the NSBI approach presented in this tutorial, the density ratio estimation as a function of the various nuisance parameters is factorized from the nominal density ratio estimation, and will be done in the  `Systematic_Uncertainty_Estimation.ipynb` notebook.

# %%
# Get the dictionary of labels to processes
labels_dict = config["labels_dict"]

# Signal processes in the model
signal_processes = config["signal_processes"]

# Background processes in the model
background_processes = config["background_processes"]

print(signal_processes)
print(background_processes)
# Out:
# ['htautau']
# ['ttbar', 'ztautau']

# %%
# If the preselection NN has already been trained and saved, load from the saved model
USE_SAVED_MODEL_PRESEL = True

# If the preselection NN has already been trained and evaluated, load the numpy array of predictions
USE_SAVED_PRESEL_PREDICTIONS = True

# Input features for training
features = config["features"]

# Subset of the features to standardize before training
features_scaling = config["features_scaling"]

# float factors multiplying the probabilities in the preselection score observable 
pre_factor_preselection_score = config["pre_factor_preselection_score"]

# %%
features
# Out:
# ['DER_mass_transverse_met_lep',
#  'log_DER_mass_vis',
#  'log_DER_pt_h',
#  'DER_deltar_had_lep',
#  'log_DER_pt_tot',
#  'log_DER_sum_pt',
#  'DER_pt_ratio_lep_had',
#  'DER_met_phi_centrality']

# %%
features_scaling
# Out:
# ['DER_mass_transverse_met_lep',
#  'log_DER_mass_vis',
#  'log_DER_pt_h',
#  'DER_deltar_had_lep',
#  'log_DER_pt_tot',
#  'log_DER_sum_pt',
#  'DER_pt_ratio_lep_had',
#  'DER_met_phi_centrality']

# %%
# Load the nominal dataset saved from the pre-processing notebook
dataset_incl_nominal = pd.read_hdf(f"{saved_data}df_nominal.h5", key="dataset", mode='r')

# %%
# Load the MC/data weights and training labels identifying different processes
weights = dataset_incl_nominal.weights.to_numpy()
train_labels = dataset_incl_nominal.train_labels.to_numpy()

# %%
# Normalizing the training weights - only discriminating shapes, not norms
weights_normed = weights.copy()

for key in labels_dict:

    weights_normed[train_labels==labels_dict[key]] /= weights[train_labels==labels_dict[key]].sum()

dataset_incl_nominal['weights_normed'] = weights_normed

# %% [markdown]
# Training the Preselection NN
# ===

# %% [markdown]
# **Choice of reference sample**
#
# The density ratios need to be trained on phase space regions with support for the reference hypothesis $p_{ref}(x) > 0$.
#
# To ensure this, we make a selection that selects events in the phase space regions with $p_{ref}(x) > 0$, or $p_c(x) \gg p_{ref}(x)$, and only perform the NSBI fit in this selected analysis region. **A natural choice for the reference hypothesis is then the signal-rich hypotheses**. This is referred to in the ATLAS publications as the Search-Oriented Mixture Models approach:
#
# $$p_{ref}(x) = \frac{1}{\sum_S \nu_S} \sum_S \frac{d\sigma_S}{dx} = \frac{1}{\nu_{H \to \tau\tau}} \frac{d\sigma_{H \to \tau\tau}}{dx}$$
#
# where the sum runs over all signal hypothesis in the model and the second equality is due to the sole signal hypothesis in our toy model, $pp \to {t\bar{t}}$.

# %%
# What are the signal processes in the user-provided model?
print(signal_processes)
# Out:
# ['htautau']

# %%
# The reference hypothesis is chosen as the sum of signal hypothesis
ref_processes = config["ref_processes"]
print(ref_processes)
# Out:
# ['htautau']

# %% [markdown]
# **Selecting out regions with $p_{ref}\sim 0$**
#
# A multi-class classification NN, with softmax output, is trained to output a score:
#
# $$ \text{NN}_\text{presel} = \log \left[\frac{\sum_S P_S (x)}{\sum_B P_B(x)} \right]$$
#
# where $P_c$ are the probability scores outputted from the softmax layer of the trained NN.

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import TrainEvaluatePreselNN

num_classes = len(labels_dict)

preselectionTraining = TrainEvaluatePreselNN(dataset_incl_nominal, num_classes, features, features_scaling)

# %%
if USE_SAVED_PRESEL_PREDICTIONS:

    pred_NN_incl = np.load(f"{saved_data}pred_NN_incl.npy")
    presel_score = calculate_preselection_observable(pred_NN_incl, labels_dict, signal_processes, background_processes, pre_factor_dict = pre_factor_preselection_score)


else:
    if not USE_SAVED_MODEL_PRESEL:
        preselectionTraining.train(test_size=0.2, 
                                   random_state=42, 
                                   path_to_save=path_to_saved_presel_model,
                                  batch_size=4096,
                                  epochs=50, learning_rate=0.1)
    
    else:
        preselectionTraining.get_trained_model(path_to_saved_presel_model)

    # Get predictions (softmax outputs)
    pred_NN_incl = preselectionTraining.predict(dataset_incl_nominal)

    presel_score = calculate_preselection_observable(pred_NN_incl, labels_dict, signal_processes, background_processes, pre_factor_dict = pre_factor_preselection_score)

    np.save(f"{saved_data}presel_score.npy", presel_score)
    np.save(f"{saved_data}pred_NN_incl.npy", pred_NN_incl)

# %%
min_pred = np.amin(presel_score)
max_pred = np.amax(presel_score)

bins = np.linspace(min_pred, max_pred, num=50)

hist_NN_output = {}
hist_NN_output_errs = {}

for key in labels_dict: 
    hist_NN_output[key], _ = np.histogram(presel_score[train_labels==labels_dict[key]], 
                                          weights = weights[train_labels==labels_dict[key]], bins=bins)
    
    hist_NN_output_errs[key], _ = np.histogram(presel_score[train_labels==labels_dict[key]], 
                                          weights = weights[train_labels==labels_dict[key]]**2, bins=bins)


for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins=bins, 
             alpha=0.6, label=key, 
             density=True, linewidth=2.0, yerr = np.sqrt(hist_NN_output_errs[key]))

plt.xlabel("Preselection Score", size=18)
plt.ylabel("Density", size=18)
plt.legend()
plt.yscale('log')
plt.show()

# %% [markdown]
# Making the cut
# ===
#
# Make a selection cut for regions with $p_{ref} \gg 0$ for performing the NSBI analysis. The remaining events - which by definition are background-dominated - can be used as a **Control Region** for data-driven background estimation, pre-unblinding validations, etc.
#
# Moreover, the preselections act as a tuning know for the tradeoff in selecting as many signal events as possible to go into the **Signal Region** (increasing sensitivity) and the feasibility of training accurate and precise NNs over a large phase space (need bigger models and more statistics). **The preselections can also weed out phase space regions with low background statistics to avoid poorly modelled regions.**
#
# Heres a first cut that you can optimize as much as you like to get the desired final results.

# %%
# Play around with these selections - decrease if estimators are unbiased but need more sensitivity and increase if the model is biased to reduce complexity
preselection_cuts = {'upper': 4.5, 'lower': -1.}
np.save(f"{saved_data}preselection_cuts.npy", preselection_cuts)

for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins = bins, 
             alpha = 0.6, label = key, 
             density = True, linewidth = 2.0, 
                 yerr = np.sqrt(hist_NN_output_errs[key]))

plt.xlabel("Preselection Score", size=18)

for key in preselection_cuts:
    if preselection_cuts[key] != -999:
        plt.axvline(preselection_cuts[key], ymax=0.9, linestyle='--', label=f'preselection cut {key} = {preselection_cuts[key]}')

plt.ylabel("Density", size=18)
plt.legend()
plt.yscale('log')
plt.show()

# %%
for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins = bins, 
             alpha = 0.6, label = key, 
             density = False, linewidth = 2.0, 
                 yerr = np.sqrt(hist_NN_output_errs[key]))

plt.xlabel("Preselection Score", size=18)

for key in preselection_cuts:
    if preselection_cuts[key] != -999:
        plt.axvline(preselection_cuts[key], ymax=0.9, linestyle='--', label=f'preselection cut {key} = {preselection_cuts[key]}')

plt.ylabel("Density", size=18)
plt.legend()
plt.yscale('log')
plt.show()

# %% [markdown]
# Signal and Control Regions
# ===
#
# The high signal over background phase space towards the right of the preselection cut shown above will be categorized as the **Signal Region** where the NSBI analysis is performed.
#
# The low signal phase space towards the left will be used as a **Control Region**, with typical uses such as background estimation, pre-unblinding data-MC checks, etc. In this phase space, we will use a binned summary observable like in any traditional analysis.

# %%
importlib.reload(sys.modules['utils'])
from utils import preselection_using_score


dataset_incl_nominal['presel_score'] = presel_score

channel_selections = {'CR': {'observable': 'presel_score', 
                             'lower_presel': -999, 
                             'upper_presel': preselection_cuts.get('lower'), 
                             'num_bins': 4},
                      'SR_binned': {'observable': 'presel_score', 
                                    'lower_presel': preselection_cuts.get('upper'), 
                                    'upper_presel': -999,
                                    'num_bins': 1},
                      'SR': {'observable': None, 
                             'upper_presel': preselection_cuts.get('upper'), 
                             'lower_presel': preselection_cuts.get('lower')}}

dataset_channels = preselection_using_score(dataset_incl_nominal, channel_selections)

del dataset_incl_nominal

# %%
# Build a summary observable for binned Signal/Control Regions
hist_binned = {}


for channel, dict_observable in channel_selections.items():

    hist_binned[channel] = {}

    fit_observable = dict_observable['observable']

    if fit_observable == None: continue

    kin_variable = dataset_channels[channel][fit_observable].to_numpy()

    min_kin = np.amin(kin_variable)
    max_kin = np.amax(kin_variable)

    num_bin_edges = dict_observable['num_bins'] + 1

    bins = np.linspace(min_kin, max_kin, num = num_bin_edges)

    # Use the high-level preselection NN score as a summary observable for Control Region
    for process in labels_dict:
        dataset_process = dataset_channels[channel][dataset_channels[channel].detailed_labels==process]
        hist_binned[channel][process], bins = np.histogram(np.clip(dataset_process[fit_observable], min_kin, max_kin),
                                    weights = dataset_process['weights'].ravel(),
                                    bins = bins)

    # Save the Control Region observable
    with open(f"{saved_data}hist_binned_{channel}.pkl", "wb") as fp:
        pickle.dump(hist_binned[channel], fp)

    np.save(f"{saved_data}bins_{channel}.npy", bins)

    del dataset_channels[channel]

# del dataset_CR

# %%
hist_binned['SR_binned']['htautau']
# Out:
# array([1.3404816], dtype=float32)

# %%
# Plot the Control Region observable

channel = 'CR'

for process in labels_dict:
    
    hep.histplot(hist_binned[channel][process], label=process, linewidth=2.0)

plt.legend()
plt.xlabel('Binned Signal Region Observable')
plt.yscale('log')
plt.ylabel('Density')
# Out:
# Text(0, 1, 'Density')

# %%
# Plot the Control Region observable

channel = 'SR_binned'

for process in labels_dict:
    
    hep.histplot(hist_binned[channel][process], label=process, linewidth=2.0)

plt.legend()
plt.xlabel('Binned Signal Region Observable')
plt.yscale('log')
plt.ylabel('Density')
# Out:
# Text(0, 1, 'Density')

# %%
dataset = dataset_channels['SR'].copy()

del dataset_channels

# %%
# Save the preselected Nominal dataframe for inference use later on
dataset.to_hdf(f"{saved_data}dataset_preselected_nominal_SR.h5", key="dataset", mode='w')

# %%
top_path = f'{path_prefix}output_training_nominal/'

# %% [markdown]
# Density ratio training
# ===
#
# Now we train the NNs for $\frac{p_c}{p_{ref}}(x)$ density ratios to build the full model. Our choice of reference hypothesis, motivated by the search-oriented mixture model described above, is:
#
# $$p_{ref}(x) = p_\text{higgs}(x) = \frac{1}{\nu_{H \to \tau\tau}} \frac{d\sigma_{H \to \tau\tau}}{dx} $$
#
# gives the POI $\mu-$parameterized model:
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} \right]= \mu + \frac{p_{t\bar{t}}\left(x\right)}{p_{H \to \tau\tau}(x)} + \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{H \to \tau\tau}(x)}$$
#
# The task of estimating the $\mu-$parameterized density ratio is thus reduced to estimating two $\mu-$independent density ratios $\frac{p_\text{single top}}{p_{t\bar{t}}}(x)$ and $\frac{p_\text{wjets}}{p_{t\bar{t}}}(x)$ mixed together with an analytical parameterization (hence the name mixture model).

# %%
# Load the processes that make up the mixture model formula for density ratio estimation
mix_model_hypotheses = config["mix_model_hypotheses"]
print(mix_model_hypotheses)
# Out:
# ['ttbar', 'ztautau']

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import TrainEvaluate_NN

mask_ref = np.isin(dataset.detailed_labels, ref_processes)

NN_training_mix_model = {}

# rnd_seed_traintestsplit = 42 # can also be randomized
rnd_seed_traintestsplit = random.randint(0, 2**32 - 1)

use_log_loss = False

for process_type in mix_model_hypotheses:
    
    mask_process = dataset['type']==process_type
    
    dataset_num = dataset[mask_process].copy()
    dataset_ref = dataset[mask_ref].copy()

    dataset_num['train_labels'] = 1
    dataset_ref['train_labels'] = 0

    dataset_num['weights_normed'] = dataset_num['weights'].to_numpy() / dataset_num['weights'].sum()
    dataset_ref['weights_normed'] = dataset_ref['weights'].to_numpy() / dataset_ref['weights'].sum()

    # Build a training dataset for the training of p_<process_type>/p_<ref_processes> density ratio
    dataset_mix_model = pd.concat([dataset_num, dataset_ref])

    del dataset_num, dataset_ref

    # Save paths
    output_name = f'{process_type}'
    output_dir = f'{top_path}general_output_{process_type}'
    path_to_ratios = f'{top_path}output_ratios_{process_type}/'
    path_to_figures = f'{top_path}output_figures_{process_type}/'
    path_to_models = f'{top_path}output_model_params_{process_type}/'

    NN_training_mix_model[process_type] = TrainEvaluate_NN(dataset_mix_model, 
                                                           dataset_mix_model['weights_normed'],
                                                           dataset_mix_model['train_labels'],
                                                           features, 
                                                           features_scaling, rnd_seed_traintestsplit,
                                                           [process_type, 'ref'], output_dir, output_name, 
                                                            path_to_figures=path_to_figures,
                                                            path_to_ratios=path_to_ratios, 
                                                            path_to_models=path_to_models,
                                                            use_log_loss = use_log_loss)


    del dataset_mix_model

# %%
mask_process = dataset['detailed_labels']=='htautau'
    
dataset_num = dataset[mask_process].copy()

dataset_num.weights.sum()
# Out:
# 847.97815

# %% [markdown]
# Neural Network architecture
# ===
#
# Here we will start with a multi-layer perceptron (simple feed-forward Neural Network with fully-connected layers). This can be supplemented with more complex architectures like transformers.
#
# After detailed tuning during the off-shell Higgs boson analysis effort, we found that a network with very wide layers ($\geq 1000$) and a depth of less than 10 works best - alongside batch size of a few hundreds and a gradually declining learning rate that starts with a value just large enough to not blow up.

# %% [markdown]
# Starting with the training and validation of the various density ratio:
#
# $$\frac{p_{t\bar{t}}(x)}{p_\text{ref}(x)}, \frac{p_{Z \to \tau\tau}(x)}{p_\text{ref}(x)}$$

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 1

# %%
mix_model_hypotheses
# Out:
# ['ttbar', 'ztautau']

# %%
# You can either train your own NNs (in which case set this to False) or you can load the pre-trained NNs. 
# Training NNs without GPUs can be very slow, for the kind of NNs we need for unbiased estimation of density ratios
USE_SAVED_MODELS = False

# Define unique settings for each process type
doCalibration = False
num_bins_cal = 120
scaling_type = 'MinMax'
batch_size = 512
validation_split = 0.1
holdout_split = 0.25

num_epochs = 100
callback_patience = 30

num_layers = 4
num_neurons_per_layer = 1000

training_settings = {
    
    'ttbar': {
        'hidden_layers':        num_layers,
        'neurons':              num_neurons_per_layer,
        'number_of_epochs':     num_epochs,
        'batch_size':           batch_size,
        'learning_rate':        0.1,
        'scalerType':           scaling_type,
        'calibration':          doCalibration,
        'num_bins_cal':         100,
        'callback':             True,
        'callback_patience':    callback_patience,
        'callback_factor':      0.01,
        'validation_split':     validation_split,
        'holdout_split':        holdout_split,
        'verbose':              2,
        'plot_scaled_features': True,
        'load_trained_models':  USE_SAVED_MODELS
    },
    
    'ztautau': {
        'hidden_layers':        num_layers,
        'neurons':              num_neurons_per_layer,
        'number_of_epochs':     num_epochs,
        'batch_size':           batch_size,
        'learning_rate':        0.1,
        'scalerType':           scaling_type,
        'calibration':          doCalibration,
        'num_bins_cal':         num_bins_cal,
        'callback':             True,
        'callback_patience':    callback_patience,
        'callback_factor':      0.01,
        'validation_split':     validation_split,
        'holdout_split':        holdout_split,
        'verbose':              2,
        'plot_scaled_features': True,
        'load_trained_models':  USE_SAVED_MODELS
    }
}

# %%
# Train the density ratio NN
for process_type in mix_model_hypotheses:
    
    settings = training_settings[process_type]

    NN_training_mix_model[process_type].train(**settings)
    NN_training_mix_model[process_type].test_normalization()
# Out:
# Sum of weights of class 0: 0.7500001788139343
# Sum of weights of class 1: 0.7500073313713074
# Using swish activation function
# /home/jaySandesara/.conda/envs/NSBI/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1751279652.016783 1218423 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8787 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:89:00.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │         9,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,013,001 (11.49 MB)
#  Trainable params: 3,013,001 (11.49 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1751279654.296978 1218655 service.cc:148] XLA service 0x7f7a14006210 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1751279654.297009 1218655 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2025-06-30 10:34:14.365055: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1751279654.495826 1218655 cuda_dnn.cc:529] Loaded cuDNN version 90501
# I0000 00:00:1751279655.142920 1218655 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1914/1914 - 8s - 4ms/step - binary_accuracy: 0.7816 - loss: 6.3781e-07 - val_binary_accuracy: 0.7935 - val_loss: 6.1558e-07 - learning_rate: 0.1000
# Epoch 2/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.7947 - loss: 6.1117e-07 - val_binary_accuracy: 0.7960 - val_loss: 6.0867e-07 - learning_rate: 0.1000
# Epoch 3/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.7980 - loss: 6.0414e-07 - val_binary_accuracy: 0.8002 - val_loss: 6.0085e-07 - learning_rate: 0.1000
# Epoch 4/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8005 - loss: 5.9924e-07 - val_binary_accuracy: 0.7970 - val_loss: 6.0273e-07 - learning_rate: 0.1000
# Epoch 5/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8019 - loss: 5.9580e-07 - val_binary_accuracy: 0.7963 - val_loss: 6.0634e-07 - learning_rate: 0.1000
# Epoch 6/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8031 - loss: 5.9266e-07 - val_binary_accuracy: 0.8013 - val_loss: 6.0034e-07 - learning_rate: 0.1000
# Epoch 7/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8043 - loss: 5.9093e-07 - val_binary_accuracy: 0.8053 - val_loss: 5.9503e-07 - learning_rate: 0.1000
# Epoch 8/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8052 - loss: 5.8849e-07 - val_binary_accuracy: 0.8052 - val_loss: 5.8984e-07 - learning_rate: 0.1000
# Epoch 9/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8063 - loss: 5.8600e-07 - val_binary_accuracy: 0.8018 - val_loss: 5.9360e-07 - learning_rate: 0.1000
# Epoch 10/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8082 - loss: 5.8265e-07 - val_binary_accuracy: 0.8084 - val_loss: 5.8152e-07 - learning_rate: 0.1000
# Epoch 11/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8102 - loss: 5.7772e-07 - val_binary_accuracy: 0.8131 - val_loss: 5.7293e-07 - learning_rate: 0.1000
# Epoch 12/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8126 - loss: 5.7364e-07 - val_binary_accuracy: 0.8147 - val_loss: 5.6923e-07 - learning_rate: 0.1000
# Epoch 13/100
# 1914/1914 - 5s - 3ms/step - binary_accuracy: 0.8141 - loss: 5.7015e-07 - val_binary_accuracy: 0.8161 - val_loss: 5.6649e-07 - learning_rate: 0.1000
# Epoch 14/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8151 - loss: 5.6728e-07 - val_binary_accuracy: 0.8180 - val_loss: 5.6404e-07 - learning_rate: 0.1000
# Epoch 15/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8161 - loss: 5.6489e-07 - val_binary_accuracy: 0.8161 - val_loss: 5.6458e-07 - learning_rate: 0.1000
# Epoch 16/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8169 - loss: 5.6320e-07 - val_binary_accuracy: 0.8185 - val_loss: 5.5961e-07 - learning_rate: 0.1000
# Epoch 17/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8176 - loss: 5.6170e-07 - val_binary_accuracy: 0.8181 - val_loss: 5.6165e-07 - learning_rate: 0.1000
# Epoch 18/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8177 - loss: 5.6031e-07 - val_binary_accuracy: 0.8191 - val_loss: 5.5804e-07 - learning_rate: 0.1000
# Epoch 19/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8187 - loss: 5.5904e-07 - val_binary_accuracy: 0.8155 - val_loss: 5.6702e-07 - learning_rate: 0.1000
# Epoch 20/100
# 1914/1914 - 5s - 3ms/step - binary_accuracy: 0.8188 - loss: 5.5758e-07 - val_binary_accuracy: 0.8213 - val_loss: 5.5400e-07 - learning_rate: 0.1000
# Epoch 21/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8192 - loss: 5.5646e-07 - val_binary_accuracy: 0.8217 - val_loss: 5.5410e-07 - learning_rate: 0.1000
# Epoch 22/100
# 1914/1914 - 5s - 3ms/step - binary_accuracy: 0.8199 - loss: 5.5477e-07 - val_binary_accuracy: 0.8222 - val_loss: 5.5356e-07 - learning_rate: 0.1000
# Epoch 23/100
# 1914/1914 - 5s - 3ms/step - binary_accuracy: 0.8203 - loss: 5.5414e-07 - val_binary_accuracy: 0.8228 - val_loss: 5.5086e-07 - learning_rate: 0.1000
# Epoch 24/100
# 1914/1914 - 5s - 3ms/step - binary_accuracy: 0.8212 - loss: 5.5257e-07 - val_binary_accuracy: 0.8215 - val_loss: 5.5585e-07 - learning_rate: 0.1000
# Epoch 25/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8213 - loss: 5.5153e-07 - val_binary_accuracy: 0.8212 - val_loss: 5.6068e-07 - learning_rate: 0.1000
# Epoch 26/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8220 - loss: 5.5053e-07 - val_binary_accuracy: 0.8240 - val_loss: 5.4588e-07 - learning_rate: 0.1000
# Epoch 27/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8222 - loss: 5.4943e-07 - val_binary_accuracy: 0.8229 - val_loss: 5.4807e-07 - learning_rate: 0.1000
# Epoch 28/100
# 1914/1914 - 5s - 3ms/step - binary_accuracy: 0.8228 - loss: 5.4873e-07 - val_binary_accuracy: 0.8198 - val_loss: 5.6064e-07 - learning_rate: 0.1000
# Epoch 29/100
# 1914/1914 - 5s - 3ms/step - binary_accuracy: 0.8227 - loss: 5.4822e-07 - val_binary_accuracy: 0.8232 - val_loss: 5.4751e-07 - learning_rate: 0.1000
# Epoch 30/100
# 1914/1914 - 5s - 3ms/step - binary_accuracy: 0.8232 - loss: 5.4698e-07 - val_binary_accuracy: 0.8242 - val_loss: 5.4949e-07 - learning_rate: 0.1000
# Epoch 31/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8232 - loss: 5.4671e-07 - val_binary_accuracy: 0.8255 - val_loss: 5.4450e-07 - learning_rate: 0.1000
# Epoch 32/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8261 - loss: 5.3864e-07 - val_binary_accuracy: 0.8273 - val_loss: 5.3691e-07 - learning_rate: 0.0010
# Epoch 33/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8268 - loss: 5.3654e-07 - val_binary_accuracy: 0.8276 - val_loss: 5.3610e-07 - learning_rate: 0.0010
# Epoch 34/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8270 - loss: 5.3594e-07 - val_binary_accuracy: 0.8281 - val_loss: 5.3560e-07 - learning_rate: 0.0010
# Epoch 35/100
# 1914/1914 - 5s - 3ms/step - binary_accuracy: 0.8271 - loss: 5.3559e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3546e-07 - learning_rate: 0.0010
# Epoch 36/100
# 1914/1914 - 5s - 3ms/step - binary_accuracy: 0.8271 - loss: 5.3536e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3537e-07 - learning_rate: 0.0010
# Epoch 37/100
# 1914/1914 - 5s - 3ms/step - binary_accuracy: 0.8272 - loss: 5.3519e-07 - val_binary_accuracy: 0.8283 - val_loss: 5.3513e-07 - learning_rate: 0.0010
# Epoch 38/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8273 - loss: 5.3504e-07 - val_binary_accuracy: 0.8279 - val_loss: 5.3505e-07 - learning_rate: 0.0010
# Epoch 39/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3492e-07 - val_binary_accuracy: 0.8283 - val_loss: 5.3502e-07 - learning_rate: 0.0010
# Epoch 40/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8274 - loss: 5.3480e-07 - val_binary_accuracy: 0.8284 - val_loss: 5.3499e-07 - learning_rate: 0.0010
# Epoch 41/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8273 - loss: 5.3473e-07 - val_binary_accuracy: 0.8287 - val_loss: 5.3493e-07 - learning_rate: 0.0010
# Epoch 42/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8273 - loss: 5.3464e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3488e-07 - learning_rate: 0.0010
# Epoch 43/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8273 - loss: 5.3458e-07 - val_binary_accuracy: 0.8286 - val_loss: 5.3488e-07 - learning_rate: 0.0010
# Epoch 44/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8272 - loss: 5.3450e-07 - val_binary_accuracy: 0.8283 - val_loss: 5.3479e-07 - learning_rate: 0.0010
# Epoch 45/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8273 - loss: 5.3445e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3479e-07 - learning_rate: 0.0010
# Epoch 46/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8274 - loss: 5.3439e-07 - val_binary_accuracy: 0.8284 - val_loss: 5.3468e-07 - learning_rate: 0.0010
# Epoch 47/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8274 - loss: 5.3434e-07 - val_binary_accuracy: 0.8281 - val_loss: 5.3478e-07 - learning_rate: 0.0010
# Epoch 48/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8274 - loss: 5.3429e-07 - val_binary_accuracy: 0.8281 - val_loss: 5.3469e-07 - learning_rate: 0.0010
# Epoch 49/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8274 - loss: 5.3425e-07 - val_binary_accuracy: 0.8283 - val_loss: 5.3472e-07 - learning_rate: 0.0010
# Epoch 50/100
# 1914/1914 - 5s - 3ms/step - binary_accuracy: 0.8274 - loss: 5.3422e-07 - val_binary_accuracy: 0.8284 - val_loss: 5.3457e-07 - learning_rate: 0.0010
# Epoch 51/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8275 - loss: 5.3416e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3459e-07 - learning_rate: 0.0010
# Epoch 52/100
# 1914/1914 - 5s - 3ms/step - binary_accuracy: 0.8275 - loss: 5.3412e-07 - val_binary_accuracy: 0.8280 - val_loss: 5.3455e-07 - learning_rate: 0.0010
# Epoch 53/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8274 - loss: 5.3409e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3452e-07 - learning_rate: 0.0010
# Epoch 54/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8275 - loss: 5.3404e-07 - val_binary_accuracy: 0.8281 - val_loss: 5.3459e-07 - learning_rate: 0.0010
# Epoch 55/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8275 - loss: 5.3400e-07 - val_binary_accuracy: 0.8284 - val_loss: 5.3450e-07 - learning_rate: 0.0010
# Epoch 56/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8274 - loss: 5.3397e-07 - val_binary_accuracy: 0.8283 - val_loss: 5.3447e-07 - learning_rate: 0.0010
# Epoch 57/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8275 - loss: 5.3392e-07 - val_binary_accuracy: 0.8283 - val_loss: 5.3443e-07 - learning_rate: 0.0010
# Epoch 58/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8275 - loss: 5.3389e-07 - val_binary_accuracy: 0.8281 - val_loss: 5.3433e-07 - learning_rate: 0.0010
# Epoch 59/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8276 - loss: 5.3386e-07 - val_binary_accuracy: 0.8281 - val_loss: 5.3439e-07 - learning_rate: 0.0010
# Epoch 60/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8276 - loss: 5.3382e-07 - val_binary_accuracy: 0.8281 - val_loss: 5.3438e-07 - learning_rate: 0.0010
# Epoch 61/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8275 - loss: 5.3378e-07 - val_binary_accuracy: 0.8278 - val_loss: 5.3448e-07 - learning_rate: 0.0010
# Epoch 62/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.8275 - loss: 5.3368e-07 - val_binary_accuracy: 0.8279 - val_loss: 5.3440e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8276 - loss: 5.3362e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3436e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8276 - loss: 5.3360e-07 - val_binary_accuracy: 0.8281 - val_loss: 5.3434e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.8276 - loss: 5.3358e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3433e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3357e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3433e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3357e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3432e-07 - learning_rate: 1.0000e-05
# Epoch 68/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3356e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3432e-07 - learning_rate: 1.0000e-05
# Epoch 69/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3356e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3431e-07 - learning_rate: 1.0000e-05
# Epoch 70/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3356e-07 - val_binary_accuracy: 0.8283 - val_loss: 5.3431e-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3356e-07 - val_binary_accuracy: 0.8283 - val_loss: 5.3431e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3356e-07 - val_binary_accuracy: 0.8283 - val_loss: 5.3430e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3356e-07 - val_binary_accuracy: 0.8283 - val_loss: 5.3430e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3356e-07 - val_binary_accuracy: 0.8283 - val_loss: 5.3430e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3355e-07 - val_binary_accuracy: 0.8283 - val_loss: 5.3430e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3355e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3429e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3355e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3429e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3355e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3429e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3355e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3429e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3355e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3429e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3355e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3429e-07 - learning_rate: 1.0000e-05
# Epoch 82/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.8276 - loss: 5.3355e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3429e-07 - learning_rate: 1.0000e-05
# Epoch 83/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3355e-07 - val_binary_accuracy: 0.8281 - val_loss: 5.3428e-07 - learning_rate: 1.0000e-05
# Epoch 84/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3355e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3428e-07 - learning_rate: 1.0000e-05
# Epoch 85/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3355e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3428e-07 - learning_rate: 1.0000e-05
# Epoch 86/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3355e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3428e-07 - learning_rate: 1.0000e-05
# Epoch 87/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3355e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3428e-07 - learning_rate: 1.0000e-05
# Epoch 88/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3355e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3428e-07 - learning_rate: 1.0000e-05
# Epoch 89/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3355e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3428e-07 - learning_rate: 1.0000e-05
# Epoch 90/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3355e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3428e-07 - learning_rate: 1.0000e-05
# Epoch 91/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3355e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3428e-07 - learning_rate: 1.0000e-05
# Epoch 92/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3354e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3428e-07 - learning_rate: 1.0000e-07
# Epoch 93/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3354e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3428e-07 - learning_rate: 1.0000e-07
# Epoch 94/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3354e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3428e-07 - learning_rate: 1.0000e-07
# Epoch 95/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3354e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3428e-07 - learning_rate: 1.0000e-07
# Epoch 96/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3354e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3428e-07 - learning_rate: 1.0000e-07
# Epoch 97/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3354e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3428e-07 - learning_rate: 1.0000e-07
# Epoch 98/100
# 1914/1914 - 5s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3354e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3428e-07 - learning_rate: 1.0000e-07
# Epoch 99/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3354e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3428e-07 - learning_rate: 1.0000e-07
# Epoch 100/100
# 1914/1914 - 4s - 2ms/step - binary_accuracy: 0.8277 - loss: 5.3354e-07 - val_binary_accuracy: 0.8282 - val_loss: 5.3428e-07 - learning_rate: 1.0000e-07
# Finished Training
# /home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/output_training_nominal/output_model_params_ttbar/model_scaler.bin
# 109/109 - 1s - 12ms/step
# 37/37 - 0s - 13ms/step
# 146/146 - 1s - 8ms/step
# The sum of PDFs is 1.0069385766983032
# Sum of weights of class 0: 0.7500002384185791
# Sum of weights of class 1: 0.7499990463256836
# Using swish activation function
# /home/jaySandesara/.conda/envs/NSBI/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │         9,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,013,001 (11.49 MB)
#  Trainable params: 3,013,001 (11.49 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# 2350/2350 - 9s - 4ms/step - binary_accuracy: 0.7218 - loss: 6.3139e-07 - val_binary_accuracy: 0.7240 - val_loss: 6.3312e-07 - learning_rate: 0.1000
# Epoch 2/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7443 - loss: 5.9792e-07 - val_binary_accuracy: 0.7485 - val_loss: 5.8893e-07 - learning_rate: 0.1000
# Epoch 3/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7517 - loss: 5.8165e-07 - val_binary_accuracy: 0.7535 - val_loss: 5.8314e-07 - learning_rate: 0.1000
# Epoch 4/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7540 - loss: 5.7822e-07 - val_binary_accuracy: 0.7545 - val_loss: 5.7811e-07 - learning_rate: 0.1000
# Epoch 5/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7562 - loss: 5.7456e-07 - val_binary_accuracy: 0.7568 - val_loss: 5.7504e-07 - learning_rate: 0.1000
# Epoch 6/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7589 - loss: 5.7000e-07 - val_binary_accuracy: 0.7604 - val_loss: 5.7018e-07 - learning_rate: 0.1000
# Epoch 7/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7608 - loss: 5.6631e-07 - val_binary_accuracy: 0.7617 - val_loss: 5.6722e-07 - learning_rate: 0.1000
# Epoch 8/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7627 - loss: 5.6332e-07 - val_binary_accuracy: 0.7628 - val_loss: 5.6515e-07 - learning_rate: 0.1000
# Epoch 9/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7643 - loss: 5.6123e-07 - val_binary_accuracy: 0.7616 - val_loss: 5.6677e-07 - learning_rate: 0.1000
# Epoch 10/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7651 - loss: 5.5970e-07 - val_binary_accuracy: 0.7670 - val_loss: 5.5942e-07 - learning_rate: 0.1000
# Epoch 11/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7657 - loss: 5.5860e-07 - val_binary_accuracy: 0.7676 - val_loss: 5.5838e-07 - learning_rate: 0.1000
# Epoch 12/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7660 - loss: 5.5760e-07 - val_binary_accuracy: 0.7665 - val_loss: 5.5945e-07 - learning_rate: 0.1000
# Epoch 13/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7669 - loss: 5.5672e-07 - val_binary_accuracy: 0.7634 - val_loss: 5.6771e-07 - learning_rate: 0.1000
# Epoch 14/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7672 - loss: 5.5600e-07 - val_binary_accuracy: 0.7674 - val_loss: 5.5752e-07 - learning_rate: 0.1000
# Epoch 15/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7676 - loss: 5.5522e-07 - val_binary_accuracy: 0.7686 - val_loss: 5.5772e-07 - learning_rate: 0.1000
# Epoch 16/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7684 - loss: 5.5430e-07 - val_binary_accuracy: 0.7670 - val_loss: 5.5846e-07 - learning_rate: 0.1000
# Epoch 17/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7687 - loss: 5.5334e-07 - val_binary_accuracy: 0.7690 - val_loss: 5.5574e-07 - learning_rate: 0.1000
# Epoch 18/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7696 - loss: 5.5247e-07 - val_binary_accuracy: 0.7682 - val_loss: 5.5666e-07 - learning_rate: 0.1000
# Epoch 19/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7697 - loss: 5.5181e-07 - val_binary_accuracy: 0.7708 - val_loss: 5.5364e-07 - learning_rate: 0.1000
# Epoch 20/100
# 2350/2350 - 5s - 2ms/step - binary_accuracy: 0.7702 - loss: 5.5118e-07 - val_binary_accuracy: 0.7692 - val_loss: 5.5541e-07 - learning_rate: 0.1000
# Epoch 21/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7705 - loss: 5.5072e-07 - val_binary_accuracy: 0.7692 - val_loss: 5.5539e-07 - learning_rate: 0.1000
# Epoch 22/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7706 - loss: 5.5036e-07 - val_binary_accuracy: 0.7700 - val_loss: 5.5335e-07 - learning_rate: 0.1000
# Epoch 23/100
# 2350/2350 - 5s - 2ms/step - binary_accuracy: 0.7708 - loss: 5.4991e-07 - val_binary_accuracy: 0.7705 - val_loss: 5.5335e-07 - learning_rate: 0.1000
# Epoch 24/100
# 2350/2350 - 5s - 2ms/step - binary_accuracy: 0.7711 - loss: 5.4954e-07 - val_binary_accuracy: 0.7717 - val_loss: 5.5115e-07 - learning_rate: 0.1000
# Epoch 25/100
# 2350/2350 - 5s - 2ms/step - binary_accuracy: 0.7714 - loss: 5.4930e-07 - val_binary_accuracy: 0.7716 - val_loss: 5.5168e-07 - learning_rate: 0.1000
# Epoch 26/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7713 - loss: 5.4888e-07 - val_binary_accuracy: 0.7718 - val_loss: 5.5084e-07 - learning_rate: 0.1000
# Epoch 27/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7715 - loss: 5.4870e-07 - val_binary_accuracy: 0.7700 - val_loss: 5.5336e-07 - learning_rate: 0.1000
# Epoch 28/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7716 - loss: 5.4839e-07 - val_binary_accuracy: 0.7706 - val_loss: 5.5277e-07 - learning_rate: 0.1000
# Epoch 29/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7717 - loss: 5.4816e-07 - val_binary_accuracy: 0.7715 - val_loss: 5.5174e-07 - learning_rate: 0.1000
# Epoch 30/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7721 - loss: 5.4794e-07 - val_binary_accuracy: 0.7721 - val_loss: 5.5076e-07 - learning_rate: 0.1000
# Epoch 31/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7719 - loss: 5.4773e-07 - val_binary_accuracy: 0.7724 - val_loss: 5.4954e-07 - learning_rate: 0.1000
# Epoch 32/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7742 - loss: 5.4371e-07 - val_binary_accuracy: 0.7738 - val_loss: 5.4744e-07 - learning_rate: 0.0010
# Epoch 33/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7746 - loss: 5.4309e-07 - val_binary_accuracy: 0.7742 - val_loss: 5.4720e-07 - learning_rate: 0.0010
# Epoch 34/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4286e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4720e-07 - learning_rate: 0.0010
# Epoch 35/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4276e-07 - val_binary_accuracy: 0.7742 - val_loss: 5.4700e-07 - learning_rate: 0.0010
# Epoch 36/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4268e-07 - val_binary_accuracy: 0.7744 - val_loss: 5.4691e-07 - learning_rate: 0.0010
# Epoch 37/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4263e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4695e-07 - learning_rate: 0.0010
# Epoch 38/100
# 2350/2350 - 5s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4258e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4696e-07 - learning_rate: 0.0010
# Epoch 39/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4255e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4677e-07 - learning_rate: 0.0010
# Epoch 40/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4252e-07 - val_binary_accuracy: 0.7744 - val_loss: 5.4684e-07 - learning_rate: 0.0010
# Epoch 41/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4248e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4681e-07 - learning_rate: 0.0010
# Epoch 42/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4246e-07 - val_binary_accuracy: 0.7742 - val_loss: 5.4677e-07 - learning_rate: 0.0010
# Epoch 43/100
# 2350/2350 - 5s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4243e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4678e-07 - learning_rate: 0.0010
# Epoch 44/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4242e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4683e-07 - learning_rate: 0.0010
# Epoch 45/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4240e-07 - val_binary_accuracy: 0.7744 - val_loss: 5.4672e-07 - learning_rate: 0.0010
# Epoch 46/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4237e-07 - val_binary_accuracy: 0.7742 - val_loss: 5.4685e-07 - learning_rate: 0.0010
# Epoch 47/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4235e-07 - val_binary_accuracy: 0.7742 - val_loss: 5.4680e-07 - learning_rate: 0.0010
# Epoch 48/100
# 2350/2350 - 5s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4234e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4679e-07 - learning_rate: 0.0010
# Epoch 49/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4233e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4676e-07 - learning_rate: 0.0010
# Epoch 50/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4231e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4667e-07 - learning_rate: 0.0010
# Epoch 51/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4230e-07 - val_binary_accuracy: 0.7741 - val_loss: 5.4675e-07 - learning_rate: 0.0010
# Epoch 52/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4228e-07 - val_binary_accuracy: 0.7744 - val_loss: 5.4676e-07 - learning_rate: 0.0010
# Epoch 53/100
# 2350/2350 - 5s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4227e-07 - val_binary_accuracy: 0.7744 - val_loss: 5.4665e-07 - learning_rate: 0.0010
# Epoch 54/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4227e-07 - val_binary_accuracy: 0.7744 - val_loss: 5.4663e-07 - learning_rate: 0.0010
# Epoch 55/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4223e-07 - val_binary_accuracy: 0.7742 - val_loss: 5.4667e-07 - learning_rate: 0.0010
# Epoch 56/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4224e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4662e-07 - learning_rate: 0.0010
# Epoch 57/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4223e-07 - val_binary_accuracy: 0.7745 - val_loss: 5.4666e-07 - learning_rate: 0.0010
# Epoch 58/100
# 2350/2350 - 5s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4220e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4668e-07 - learning_rate: 0.0010
# Epoch 59/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4220e-07 - val_binary_accuracy: 0.7744 - val_loss: 5.4671e-07 - learning_rate: 0.0010
# Epoch 60/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4219e-07 - val_binary_accuracy: 0.7744 - val_loss: 5.4667e-07 - learning_rate: 0.0010
# Epoch 61/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4217e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4660e-07 - learning_rate: 0.0010
# Epoch 62/100
# 2350/2350 - 5s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4210e-07 - val_binary_accuracy: 0.7744 - val_loss: 5.4659e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4210e-07 - val_binary_accuracy: 0.7742 - val_loss: 5.4659e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4209e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4659e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4209e-07 - val_binary_accuracy: 0.7742 - val_loss: 5.4659e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4209e-07 - val_binary_accuracy: 0.7742 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4209e-07 - val_binary_accuracy: 0.7742 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 68/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4209e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 69/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4209e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 70/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4209e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4209e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 2350/2350 - 5s - 2ms/step - binary_accuracy: 0.7749 - loss: 5.4208e-07 - val_binary_accuracy: 0.7744 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7744 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7744 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 82/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 83/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 84/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 85/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 86/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 87/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 88/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 89/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 90/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 91/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-05
# Epoch 92/100
# 2350/2350 - 5s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-07
# Epoch 93/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-07
# Epoch 94/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-07
# Epoch 95/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-07
# Epoch 96/100
# 2350/2350 - 5s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-07
# Epoch 97/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-07
# Epoch 98/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-07
# Epoch 99/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-07
# Epoch 100/100
# 2350/2350 - 6s - 2ms/step - binary_accuracy: 0.7750 - loss: 5.4208e-07 - val_binary_accuracy: 0.7743 - val_loss: 5.4658e-07 - learning_rate: 1.0000e-07
# Finished Training
# /home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/output_training_nominal/output_model_params_ztautau/model_scaler.bin
# 134/134 - 1s - 10ms/step
# 45/45 - 1s - 13ms/step
# 179/179 - 1s - 8ms/step
# The sum of PDFs is 0.9989332556724548

# %% [markdown]
# Check for overtraining by comparing the NN output distributions between training and holdout datasets. The holdout dataset is the subset of events not used during training.

# %%
for process_type in mix_model_hypotheses:
    NN_training_mix_model[process_type].make_overfit_plots()

# %% [markdown]
# Diagnostic Checks
# ===
#
# While traditionally, a NN observable is judged on the basis of its accuracy - for NSBI we are interested in the quality of the density ratios more than the discrimination power. The latter comes from the perfect modelling of the multi-dimensional likelihood ratios.
#
# To ensure correct modelling, we run two main checks on the training:
#
# - **Calibration closure test**
#
#   The NNs are trained using the binary cross-entropy loss, which under ideal conditions leads to the NN converging to the score function:
#
#   $$\hat{s}_\text{pred} = \frac{p_\text{ref}(x)}{p_\text{ref}(x)+p_\text{c}(x)}$$
#
#   that can be converted into the probability ratio we desire (likelihood ratio trick):
#
#   $$\frac{p_\text{c}(x)}{p_\text{ref}(x)} = \frac{\hat{s}_\text{pred}(x)}{1-\hat{s}_\text{pred}(x)}$$
#
#   For the NNs to be well-calibrated, we use the Monte Carlo samples to verify the equality:
#
#
#   $$\left[\frac{p_c(x)}{p_c(x)+p_{ref}(x)}\right]_\text{NN} \sim \left[\frac{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}}{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}+\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}}\right]_\text{MC}$$
#
#   where we bin the events from $p_c$ and $p_\text{ref}$ MC samples, denoted by $\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}$ and $\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}$ respectively where $I(x|\hat{s}_\text{pred})$ returns the index of the $\hat{s}_\text{pred}$ bin in which an event $x$ falls.

# %%
num_bins_cal = 50

for process_type in mix_model_hypotheses:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='score')

# %% [markdown]
# - **Density ratio reweighting closure tests**
#
#   Despite having a well-calibrated output and thus a robust probabilistic interpretation, the trained density ratios might not capture the full multi-dimensional event information $x$. In other words, the NNs might still be biased estimators of the optimal score function, as defined in the CARL paper (link).
#
#   The next diagnostic involves verifying the following equality using 1D projections of $x$:
#
#   $$\frac{p_c(x)}{p_{ref}(x)} \times p_{ref}(x) \sim p_c(x)$$
#
#   We can do this one-by-one for all the observables used to model the density ratios, and also possibly the observables not used directly in the training but can still be well-estimated due to the NN learning the right physics.

# %%
variables_to_plot=['DER_pt_h'] # The 1D variable for reweighting closure
yscale_type='log'
num_bins_plotting=21

for process_type in mix_model_hypotheses:

    NN_training_mix_model[process_type].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
for process_type in mix_model_hypotheses:
    # Evaluate the density ratios p_c/p_ref for the full dataset and save for the inference step
    NN_training_mix_model[process_type].evaluate_and_save_ratios(dataset)
# Out:
# 197/197 - 2s - 8ms/step
# 197/197 - 1s - 7ms/step

# %% [markdown]
# Systematic Uncertainty Modelling
# ===
#
# So far we have left out the nuisance parameter piece of the parameterized density ratio decomposition shown before:
#
# $$g_c(x|\alpha) = \frac{p_c(x|\alpha)}{p_c(x)}$$
#
# which will be estimated in the `Systematic_Uncertainty_Estimation.ipynb` notebook.

# %% [markdown]
# Training an Ensemble of NNs
# ===
#
# In a realistic analysis, a large ensemble of NNs are trained to estimate density ratios, for *each* of the channels. **This reduces not only the variance but has also been found to reduce biases in the final fits.**
#
# In the off-shell Higgs boson analysis, we used k-fold cross-validation, with k=10, to train an ensemble $N_{ens}\sim 250$ of NNs per density ratio $p_c(x)/p_{ref}(x)$. The density ratios used in the final fit are always evaluated on the holdout dataset and by using each of the folds as holdout once, the entire model for $p_c(x)/p_{ref}(x)$ consists of $N_{ens}\times k \sim 2500$ NNs. Each NN in the ensemble is trained by resampling data without replacement from the k-1 folds used for training.
