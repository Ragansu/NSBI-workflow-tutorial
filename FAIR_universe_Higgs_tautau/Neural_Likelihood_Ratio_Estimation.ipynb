# %% [markdown]
# Train Neural Networks to estimate Likelihood Ratios
# ===
#
# In this notebook we will setup the neural networks that train unbiased and low-variance density ratios to be then used for inference. The statistical model we have is:
#
# $$p(x|\mu, \alpha) = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot p_c\left(x|\alpha\right)$$
#
# where $c$ stands for the various physics channels that contribute to the final state $x$, $\mu$ is the signal-strength parameter and $\alpha$ is the vector of nuisance parameters associated with the various systematic uncertainties in the model. Note that we are assuming that the parameter $\mu$-dependence is known analytically and that we have simulation models for each of the channels $p_c(x)$.
#
# The objective is to build the test statistic for composite hypothesis testing:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})}{p(x_i|\hat{\mu}, \hat{\alpha})} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
# A direct approach would then be to model the probability density $p(x|\mu, \alpha)$ using NNs. But that is a more difficult task than training probability density ratios. We use a simple trick:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})/p_{ref}(x)}{p(x_i|\hat{\mu}, \hat{\alpha})/p_{ref}(x)} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
#
# to turn this into a density ratio estimation problem:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot \frac{p_c\left(x|\alpha\right)}{p_{ref}(x)}$$
#
# Factorizing out the $\alpha$-dependence in the density ratios:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\sum_c G_c(\alpha) \cdot f_c(\mu) \cdot \nu_c} \sum_c f_c(\mu) \cdot G_c(\alpha)\cdot \nu_c \cdot g_c(x|\alpha) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}$$
#
# **Factorized approach:**
#
# Instead of training NNs parameterized on $\mu$ and $\alpha$, we use analytical parameterizations to simplify the problem to training only parameter-independent density ratios.
#
# Let's set this up for the toy ttbar model we are using. Neglecting the nuisance parameter dependence for now,
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}\right] = \mu \cdot \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)} + \frac{p_{t\bar{t}}\left(x\right)}{p_{ref}(x)} + \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{ref}(x)}$$

# %%
# %cd "/home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/"
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau

# %%
import os, sys, pathlib, importlib
sys.path.append('../')

# Load the package and modules for training and plotting
import nsbi_common_utils
from nsbi_common_utils import plotting, training
from nsbi_common_utils.training import TrainEvaluate_NN, TrainEvaluatePreselNN


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt
import pickle
import yaml
import random

from utils import preselection_using_score, calculate_preselection_observable

from coffea.analysis_tools import PackedSelection

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

hep.style.use(hep.style.ATLAS)

# %%
with open("config.yml", "r") as f:
    config = yaml.safe_load(f)

# %%
# path prefix for saving cached data used between modules
path_prefix = config['path_prefix']
path_saved_data = config['path_saved_data']
path_preselection_NN_model = config['path_preselection_NN_model']

# Path for saving interemdiate objects, like NN predictions
saved_data = f'{path_prefix}{path_saved_data}'

# Path for saving/loading preselection NN model
path_to_saved_presel_model = f'{path_prefix}{path_preselection_NN_model}'

# %%
# If the preselection NN has already been trained and saved, load from the saved model
USE_SAVED_MODEL_PRESEL = True

# If the preselection NN has already been trained and evaluated, load the numpy array of predictions
USE_SAVED_PRESEL_PREDICTIONS = True

# Input features for training
columns = config["columns"]

# Subset of the features to standardize before training
columns_scaling = config["columns_scaling"]

# Get the dictionary of labels to processes
labels_dict = config["labels_dict"]

# Signal processes in the model
signal_processes = config["signal_processes"]

# Background processes in the model
background_processes = config["background_processes"]

# float factors multiplying the probabilities in the preselection score observable 
pre_factor_preselection_score = config["pre_factor_preselection_score"]

# %%
columns
# Out:
# ['DER_mass_transverse_met_lep',
#  'log_DER_mass_vis',
#  'log_DER_pt_h',
#  'DER_deltar_had_lep',
#  'log_DER_pt_tot',
#  'log_DER_sum_pt',
#  'DER_pt_ratio_lep_had',
#  'DER_met_phi_centrality']

# %%
columns_scaling
# Out:
# ['DER_mass_transverse_met_lep',
#  'log_DER_mass_vis',
#  'log_DER_pt_h',
#  'DER_deltar_had_lep',
#  'log_DER_pt_tot',
#  'log_DER_sum_pt',
#  'DER_pt_ratio_lep_had',
#  'DER_met_phi_centrality']

# %%
# Load the nominal dataset saved from the pre-processing notebook
dataset_incl_nominal = pd.read_hdf(f"{saved_data}df_nominal.h5", key="dataset", mode='r')

# %%
# Load the MC/data weights and training labels identifying different processes
weights = dataset_incl_nominal.weights.to_numpy()
train_labels = dataset_incl_nominal.train_labels.to_numpy()

# %%
# Normalizing the training weights - only discriminating shapes, not norms
weights_normed = weights.copy()

for key in labels_dict:

    weights_normed[train_labels==labels_dict[key]] /= weights[train_labels==labels_dict[key]].sum()

dataset_incl_nominal['weights_normed'] = weights_normed

# %% [markdown]
# Training the Preselection NN
# ===

# %% [markdown]
# **Choice of reference sample**
#
# The density ratios need to be trained on phase space regions with support for the reference hypothesis $p_{ref}(x) > 0$.
#
# To ensure this, we make a selection that selects events in the phase space regions with $p_{ref}(x) > 0$, or $p_c(x) \gg p_{ref}(x)$, and only perform the NSBI fit in this selected analysis region. **A natural choice for the reference hypothesis is then the signal-rich hypotheses**. This is referred to in the ATLAS publications as the Search-Oriented Mixture Models approach:
#
# $$p_{ref}(x) = \frac{1}{\sum_S \nu_S} \sum_S \frac{d\sigma_S}{dx} = \frac{1}{\nu_{H \to \tau\tau}} \frac{d\sigma_{H \to \tau\tau}}{dx}$$
#
# where the sum runs over all signal hypothesis in the model and the second equality is due to the sole signal hypothesis in our toy model, $pp \to {t\bar{t}}$.

# %%
# What are the signal processes in the user-provided model?
print(signal_processes)
# Out:
# ['htautau']

# %%
# The reference hypothesis is chosen as the sum of signal hypothesis
ref_processes = config["ref_processes"]
print(ref_processes)
# Out:
# ['htautau']

# %% [markdown]
# **Selecting out regions with $p_{ref}\sim 0$**
#
# A multi-class classification NN, with softmax output, is trained to output a score:
#
# $$ \text{NN}_\text{presel} = \log \left[\frac{\sum_S P_S (x)}{\sum_B P_B(x)} \right]$$
#
# where $P_c$ are the probability scores outputted from the softmax layer of the trained NN.

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import TrainEvaluatePreselNN

num_classes = len(labels_dict)

preselectionTraining = TrainEvaluatePreselNN(dataset_incl_nominal, num_classes, columns, columns_scaling)

# %%
if USE_SAVED_PRESEL_PREDICTIONS:

    pred_NN_incl = np.load(f"{saved_data}pred_NN_incl.npy")
    presel_score = calculate_preselection_observable(pred_NN_incl, labels_dict, signal_processes, background_processes, pre_factor_dict = pre_factor_preselection_score)


else:
    if not USE_SAVED_MODEL_PRESEL:
        preselectionTraining.train(test_size=0.2, 
                                   random_state=42, 
                                   path_to_save=path_to_saved_presel_model,
                                  batch_size=4096,
                                  epochs=50, learning_rate=0.1)
    
    else:
        preselectionTraining.get_trained_model(path_to_saved_presel_model)

    # Get predictions (softmax outputs)
    pred_NN_incl = preselectionTraining.predict(dataset_incl_nominal)

    presel_score = calculate_preselection_observable(pred_NN_incl, labels_dict, signal_processes, background_processes, pre_factor_dict = pre_factor_preselection_score)

    np.save(f"{saved_data}presel_score.npy", presel_score)
    np.save(f"{saved_data}pred_NN_incl.npy", pred_NN_incl)

# %%
min_pred = np.amin(presel_score)
max_pred = np.amax(presel_score)

bins = np.linspace(min_pred, max_pred, num=50)

hist_NN_output = {}
hist_NN_output_errs = {}

for key in labels_dict: 
    hist_NN_output[key], _ = np.histogram(presel_score[train_labels==labels_dict[key]], 
                                          weights = weights[train_labels==labels_dict[key]], bins=bins)
    
    hist_NN_output_errs[key], _ = np.histogram(presel_score[train_labels==labels_dict[key]], 
                                          weights = weights[train_labels==labels_dict[key]]**2, bins=bins)


for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins=bins, 
             alpha=0.6, label=key, 
             density=True, linewidth=2.0, yerr = np.sqrt(hist_NN_output_errs[key]))

plt.xlabel("Preselection Score", size=18)
plt.ylabel("Density", size=18)
plt.legend()
plt.yscale('log')
plt.show()

# %% [markdown]
# Making the cut
# ===
#
# Make a selection cut for regions with $p_{ref} \gg 0$ for performing the NSBI analysis. The remaining events - which by definition are background-dominated - can be used as a **Control Region** for data-driven background estimation, pre-unblinding validations, etc.
#
# Moreover, the preselections act as a tuning know for the tradeoff in selecting as many signal events as possible to go into the **Signal Region** (increasing sensitivity) and the feasibility of training accurate and precise NNs over a large phase space (need bigger models and more statistics). **The preselections can also weed out phase space regions with low background statistics to avoid poorly modelled regions.**
#
# Heres a first cut that you can optimize as much as you like to get the desired final results.

# %%
# Play around with these selections - decrease if estimators are unbiased but need more sensitivity and increase if the model is biased to reduce complexity
preselection_cuts = {'upper': 4., 'lower': -1.}
np.save(f"{saved_data}preselection_cuts.npy", preselection_cuts)

for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins = bins, 
             alpha = 0.6, label = key, 
             density = True, linewidth = 2.0, 
                 yerr = np.sqrt(hist_NN_output_errs[key]))

plt.xlabel("Preselection Score", size=18)

for key in preselection_cuts:
    if preselection_cuts[key] != -999:
        plt.axvline(preselection_cuts[key], ymax=0.9, linestyle='--', label=f'preselection cut {key} = {preselection_cuts[key]}')

plt.ylabel("Density", size=18)
plt.legend()
plt.yscale('log')
plt.show()

# %%
for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins = bins, 
             alpha = 0.6, label = key, 
             density = False, linewidth = 2.0, 
                 yerr = np.sqrt(hist_NN_output_errs[key]))

plt.xlabel("Preselection Score", size=18)

for key in preselection_cuts:
    if preselection_cuts[key] != -999:
        plt.axvline(preselection_cuts[key], ymax=0.9, linestyle='--', label=f'preselection cut {key} = {preselection_cuts[key]}')

plt.ylabel("Density", size=18)
plt.legend()
plt.yscale('log')
plt.show()

# %% [markdown]
# Signal and Control Regions
# ===
#
# The high signal over background phase space towards the right of the preselection cut shown above will be categorized as the **Signal Region** where the NSBI analysis is performed.
#
# The low signal phase space towards the left will be used as a **Control Region**, with typical uses such as background estimation, pre-unblinding data-MC checks, etc. In this phase space, we will use a binned summary observable like in any traditional analysis.

# %%
importlib.reload(sys.modules['utils'])
from utils import preselection_using_score


dataset_incl_nominal['presel_score'] = presel_score

channel_selections = {'CR': {'observable': 'presel_score', 
                             'lower_presel': -999, 
                             'upper_presel': preselection_cuts.get('lower'), 
                             'num_bins': 4},
                      'SR_binned': {'observable': 'presel_score', 
                                    'lower_presel': preselection_cuts.get('upper'), 
                                    'upper_presel': -999,
                                    'num_bins': 1},
                      'SR': {'observable': None, 
                             'upper_presel': preselection_cuts.get('upper'), 
                             'lower_presel': preselection_cuts.get('lower')}}

dataset_channels = preselection_using_score(dataset_incl_nominal, channel_selections)

del dataset_incl_nominal

# %%
# Build a summary observable for binned Signal/Control Regions
hist_binned = {}


for channel, dict_observable in channel_selections.items():

    hist_binned[channel] = {}

    fit_observable = dict_observable['observable']

    if fit_observable == None: continue

    kin_variable = dataset_channels[channel][fit_observable].to_numpy()

    min_kin = np.amin(kin_variable)
    max_kin = np.amax(kin_variable)

    num_bin_edges = dict_observable['num_bins'] + 1

    bins = np.linspace(min_kin, max_kin, num = num_bin_edges)

    # Use the high-level preselection NN score as a summary observable for Control Region
    for process in labels_dict:
        dataset_process = dataset_channels[channel][dataset_channels[channel].detailed_labels==process]
        hist_binned[channel][process], bins = np.histogram(np.clip(dataset_process[fit_observable], min_kin, max_kin),
                                    weights = dataset_process['weights'].ravel(),
                                    bins = bins)

    # Save the Control Region observable
    with open(f"{saved_data}hist_binned_{channel}.pkl", "wb") as fp:
        pickle.dump(hist_binned[channel], fp)

    np.save(f"{saved_data}bins_{channel}.npy", bins)

    del dataset_channels[channel]

# del dataset_CR

# %%
hist_binned['SR_binned']['htautau']
# Out:
# array([4.7001405], dtype=float32)

# %%
# Plot the Control Region observable

channel = 'CR'

for process in labels_dict:
    
    hep.histplot(hist_binned[channel][process], label=process, linewidth=2.0)

plt.legend()
plt.xlabel('Binned Signal Region Observable')
plt.yscale('log')
plt.ylabel('Density')
# Out:
# Text(0, 1, 'Density')

# %%
# Plot the Control Region observable

channel = 'SR_binned'

for process in labels_dict:
    
    hep.histplot(hist_binned[channel][process], label=process, linewidth=2.0)

plt.legend()
plt.xlabel('Binned Signal Region Observable')
plt.yscale('log')
plt.ylabel('Density')
# Out:
# Text(0, 1, 'Density')

# %%
dataset = dataset_channels['SR'].copy()

del dataset_channels

# %%
# Save the preselected Nominal dataframe for inference use later on
dataset.to_hdf(f"{saved_data}dataset_preselected_nominal_SR.h5", key="dataset", mode='w')

# %%
top_path = f'{path_prefix}output_training_nominal/'

# %% [markdown]
# Density ratio training
# ===
#
# Now we train the NNs for $\frac{p_c}{p_{ref}}(x)$ density ratios to build the full model. Our choice of reference hypothesis, motivated by the search-oriented mixture model described above, is:
#
# $$p_{ref}(x) = p_\text{higgs}(x) = \frac{1}{\nu_{H \to \tau\tau}} \frac{d\sigma_{H \to \tau\tau}}{dx} $$
#
# gives the POI $\mu-$parameterized model:
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} \right]= \mu + \frac{p_{t\bar{t}}\left(x\right)}{p_{H \to \tau\tau}(x)} + \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{H \to \tau\tau}(x)}$$
#
# The task of estimating the $\mu-$parameterized density ratio is thus reduced to estimating two $\mu-$independent density ratios $\frac{p_\text{single top}}{p_{t\bar{t}}}(x)$ and $\frac{p_\text{wjets}}{p_{t\bar{t}}}(x)$ mixed together with an analytical parameterization (hence the name mixture model).

# %%
# Load the processes that make up the mixture model formula for density ratio estimation
mix_model_hypotheses = config["mix_model_hypotheses"]
print(mix_model_hypotheses)
# Out:
# ['ttbar', 'ztautau']

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import TrainEvaluate_NN

mask_ref = np.isin(dataset.detailed_labels, ref_processes)

NN_training_mix_model = {}

# rnd_seed_traintestsplit = 42 # can also be randomized
rnd_seed_traintestsplit = random.randint(0, 2**32 - 1)

use_log_loss = False

for process_type in mix_model_hypotheses:
    
    mask_process = dataset['type']==process_type
    
    dataset_num = dataset[mask_process].copy()
    dataset_ref = dataset[mask_ref].copy()

    dataset_num['train_labels'] = 1
    dataset_ref['train_labels'] = 0

    dataset_num['weights_normed'] = dataset_num['weights'].to_numpy() / dataset_num['weights'].sum()
    dataset_ref['weights_normed'] = dataset_ref['weights'].to_numpy() / dataset_ref['weights'].sum()

    # Build a training dataset for the training of p_<process_type>/p_<ref_processes> density ratio
    dataset_mix_model = pd.concat([dataset_num, dataset_ref])

    del dataset_num, dataset_ref

    # Save paths
    output_name = f'{process_type}'
    output_dir = f'{top_path}general_output_{process_type}'
    path_to_ratios = f'{top_path}output_ratios_{process_type}/'
    path_to_figures = f'{top_path}output_figures_{process_type}/'
    path_to_models = f'{top_path}output_model_params_{process_type}/'

    NN_training_mix_model[process_type] = TrainEvaluate_NN(dataset_mix_model, 
                                                           dataset_mix_model['weights_normed'],
                                                           dataset_mix_model['train_labels'],
                                                           columns, 
                                                           columns_scaling, rnd_seed_traintestsplit,
                                                           [process_type, 'ref'], output_dir, output_name, 
                                                            path_to_figures=path_to_figures,
                                                            path_to_ratios=path_to_ratios, 
                                                            path_to_models=path_to_models,
                                                            use_log_loss = use_log_loss)


    del dataset_mix_model

# %%
mask_process = dataset['detailed_labels']=='htautau'
    
dataset_num = dataset[mask_process].copy()

dataset_num.weights.sum()
# Out:
# 844.6183

# %% [markdown]
# Neural Network architecture
# ===
#
# Here we will start with a multi-layer perceptron (simple feed-forward Neural Network with fully-connected layers). This can be supplemented with more complex architectures like transformers.
#
# After detailed tuning during the off-shell Higgs boson analysis effort, we found that a network with very wide layers ($\geq 1000$) and a depth of less than 10 works best - alongside batch size of a few hundreds and a gradually declining learning rate that starts with a value just large enough to not blow up.

# %% [markdown]
# Starting with the training and validation of the various density ratio:
#
# $$\frac{p_{t\bar{t}}(x)}{p_\text{ref}(x)}, \frac{p_{Z \to \tau\tau}(x)}{p_\text{ref}(x)}$$

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 1

# %%
mix_model_hypotheses
# Out:
# ['ttbar', 'ztautau']

# %%
# Define unique settings for each process type

doCalibration = False
num_bins_cal = 120
scaling_type = 'MinMax'
batch_size = 512
validation_split = 0.1
holdout_split = 0.25

num_epochs = 100
callback_patience = 30

training_settings = {
    
    'ttbar': {
        'hidden_layers':        4,
        'neurons':              1000,
        'number_of_epochs':     num_epochs,
        'batch_size':           batch_size,
        'learning_rate':        0.1,
        'scalerType':           scaling_type,
        'calibration':          False,
        'num_bins_cal':         100,
        'callback':             True,
        'callback_patience':    callback_patience,
        'callback_factor':      0.01,
        'validation_split':     validation_split,
        'holdout_split':        holdout_split,
        'verbose':              2,
        'plot_scaled_features': True
    },
    
    'ztautau': {
        'hidden_layers':        4,
        'neurons':              1000,
        'number_of_epochs':     num_epochs,
        'batch_size':           batch_size,
        'learning_rate':        0.1,
        'scalerType':           scaling_type,
        'calibration':          doCalibration,
        'num_bins_cal':         num_bins_cal,
        'callback':             True,
        'callback_patience':    callback_patience,
        'callback_factor':      0.01,
        'validation_split':     validation_split,
        'holdout_split':        holdout_split,
        'verbose':              2,
        'plot_scaled_features': True
    }
}

# %%
# Train the density ratio NN
for process_type in mix_model_hypotheses:
    
    settings = training_settings[process_type]

    NN_training_mix_model[process_type].train(**settings)
    NN_training_mix_model[process_type].test_normalization()
# Out:
# Sum of weights of class 0: 0.7499993443489075
# Sum of weights of class 1: 0.7499918341636658
# Using swish activation function
# /home/jaySandesara/.conda/envs/NSBI/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1750659714.318923  900494 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9615 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:1a:00.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │         9,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,013,001 (11.49 MB)
#  Trainable params: 3,013,001 (11.49 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1750659716.623946  900729 service.cc:148] XLA service 0x7fcb14006770 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1750659716.623976  900729 service.cc:156]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2025-06-23 06:21:56.692545: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1750659716.824039  900729 cuda_dnn.cc:529] Loaded cuDNN version 90501
# I0000 00:00:1750659717.466794  900729 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1907/1907 - 8s - 4ms/step - binary_accuracy: 0.7805 - loss: 6.4150e-07 - val_binary_accuracy: 0.7888 - val_loss: 6.2408e-07 - learning_rate: 0.1000
# Epoch 2/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.7946 - loss: 6.1432e-07 - val_binary_accuracy: 0.7952 - val_loss: 6.0731e-07 - learning_rate: 0.1000
# Epoch 3/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.7977 - loss: 6.0769e-07 - val_binary_accuracy: 0.7993 - val_loss: 5.9815e-07 - learning_rate: 0.1000
# Epoch 4/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8005 - loss: 6.0203e-07 - val_binary_accuracy: 0.8015 - val_loss: 5.9456e-07 - learning_rate: 0.1000
# Epoch 5/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8026 - loss: 5.9712e-07 - val_binary_accuracy: 0.8059 - val_loss: 5.8682e-07 - learning_rate: 0.1000
# Epoch 6/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8066 - loss: 5.9121e-07 - val_binary_accuracy: 0.8082 - val_loss: 5.8195e-07 - learning_rate: 0.1000
# Epoch 7/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8084 - loss: 5.8593e-07 - val_binary_accuracy: 0.8091 - val_loss: 5.8609e-07 - learning_rate: 0.1000
# Epoch 8/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8110 - loss: 5.7994e-07 - val_binary_accuracy: 0.8137 - val_loss: 5.6995e-07 - learning_rate: 0.1000
# Epoch 9/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8130 - loss: 5.7579e-07 - val_binary_accuracy: 0.8106 - val_loss: 5.7428e-07 - learning_rate: 0.1000
# Epoch 10/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8145 - loss: 5.7233e-07 - val_binary_accuracy: 0.8144 - val_loss: 5.6470e-07 - learning_rate: 0.1000
# Epoch 11/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8153 - loss: 5.6962e-07 - val_binary_accuracy: 0.8147 - val_loss: 5.6797e-07 - learning_rate: 0.1000
# Epoch 12/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8159 - loss: 5.6680e-07 - val_binary_accuracy: 0.8176 - val_loss: 5.6064e-07 - learning_rate: 0.1000
# Epoch 13/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8169 - loss: 5.6480e-07 - val_binary_accuracy: 0.8168 - val_loss: 5.5988e-07 - learning_rate: 0.1000
# Epoch 14/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8177 - loss: 5.6283e-07 - val_binary_accuracy: 0.8142 - val_loss: 5.6424e-07 - learning_rate: 0.1000
# Epoch 15/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8182 - loss: 5.6143e-07 - val_binary_accuracy: 0.8192 - val_loss: 5.5465e-07 - learning_rate: 0.1000
# Epoch 16/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8187 - loss: 5.6004e-07 - val_binary_accuracy: 0.8184 - val_loss: 5.5627e-07 - learning_rate: 0.1000
# Epoch 17/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8194 - loss: 5.5858e-07 - val_binary_accuracy: 0.8199 - val_loss: 5.5240e-07 - learning_rate: 0.1000
# Epoch 18/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8199 - loss: 5.5739e-07 - val_binary_accuracy: 0.8205 - val_loss: 5.5230e-07 - learning_rate: 0.1000
# Epoch 19/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8204 - loss: 5.5640e-07 - val_binary_accuracy: 0.8202 - val_loss: 5.5112e-07 - learning_rate: 0.1000
# Epoch 20/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8206 - loss: 5.5541e-07 - val_binary_accuracy: 0.8182 - val_loss: 5.5572e-07 - learning_rate: 0.1000
# Epoch 21/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8206 - loss: 5.5471e-07 - val_binary_accuracy: 0.8220 - val_loss: 5.5287e-07 - learning_rate: 0.1000
# Epoch 22/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8213 - loss: 5.5362e-07 - val_binary_accuracy: 0.8202 - val_loss: 5.4901e-07 - learning_rate: 0.1000
# Epoch 23/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8212 - loss: 5.5310e-07 - val_binary_accuracy: 0.8208 - val_loss: 5.4891e-07 - learning_rate: 0.1000
# Epoch 24/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8218 - loss: 5.5233e-07 - val_binary_accuracy: 0.8222 - val_loss: 5.4422e-07 - learning_rate: 0.1000
# Epoch 25/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8219 - loss: 5.5171e-07 - val_binary_accuracy: 0.8184 - val_loss: 5.5340e-07 - learning_rate: 0.1000
# Epoch 26/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8221 - loss: 5.5121e-07 - val_binary_accuracy: 0.8222 - val_loss: 5.4479e-07 - learning_rate: 0.1000
# Epoch 27/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8224 - loss: 5.5069e-07 - val_binary_accuracy: 0.8201 - val_loss: 5.4970e-07 - learning_rate: 0.1000
# Epoch 28/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8226 - loss: 5.4999e-07 - val_binary_accuracy: 0.8221 - val_loss: 5.4597e-07 - learning_rate: 0.1000
# Epoch 29/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8231 - loss: 5.4959e-07 - val_binary_accuracy: 0.8234 - val_loss: 5.4250e-07 - learning_rate: 0.1000
# Epoch 30/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8230 - loss: 5.4906e-07 - val_binary_accuracy: 0.8237 - val_loss: 5.4346e-07 - learning_rate: 0.1000
# Epoch 31/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8232 - loss: 5.4856e-07 - val_binary_accuracy: 0.8202 - val_loss: 5.5235e-07 - learning_rate: 0.1000
# Epoch 32/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8257 - loss: 5.4139e-07 - val_binary_accuracy: 0.8251 - val_loss: 5.3786e-07 - learning_rate: 0.0010
# Epoch 33/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8263 - loss: 5.3914e-07 - val_binary_accuracy: 0.8252 - val_loss: 5.3699e-07 - learning_rate: 0.0010
# Epoch 34/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8266 - loss: 5.3858e-07 - val_binary_accuracy: 0.8261 - val_loss: 5.3655e-07 - learning_rate: 0.0010
# Epoch 35/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8265 - loss: 5.3827e-07 - val_binary_accuracy: 0.8259 - val_loss: 5.3629e-07 - learning_rate: 0.0010
# Epoch 36/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8267 - loss: 5.3806e-07 - val_binary_accuracy: 0.8258 - val_loss: 5.3621e-07 - learning_rate: 0.0010
# Epoch 37/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8267 - loss: 5.3791e-07 - val_binary_accuracy: 0.8259 - val_loss: 5.3595e-07 - learning_rate: 0.0010
# Epoch 38/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8269 - loss: 5.3783e-07 - val_binary_accuracy: 0.8258 - val_loss: 5.3585e-07 - learning_rate: 0.0010
# Epoch 39/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8269 - loss: 5.3771e-07 - val_binary_accuracy: 0.8263 - val_loss: 5.3573e-07 - learning_rate: 0.0010
# Epoch 40/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8268 - loss: 5.3763e-07 - val_binary_accuracy: 0.8261 - val_loss: 5.3565e-07 - learning_rate: 0.0010
# Epoch 41/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8269 - loss: 5.3754e-07 - val_binary_accuracy: 0.8264 - val_loss: 5.3553e-07 - learning_rate: 0.0010
# Epoch 42/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8269 - loss: 5.3749e-07 - val_binary_accuracy: 0.8261 - val_loss: 5.3545e-07 - learning_rate: 0.0010
# Epoch 43/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8269 - loss: 5.3743e-07 - val_binary_accuracy: 0.8262 - val_loss: 5.3549e-07 - learning_rate: 0.0010
# Epoch 44/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8268 - loss: 5.3739e-07 - val_binary_accuracy: 0.8259 - val_loss: 5.3542e-07 - learning_rate: 0.0010
# Epoch 45/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8269 - loss: 5.3732e-07 - val_binary_accuracy: 0.8263 - val_loss: 5.3540e-07 - learning_rate: 0.0010
# Epoch 46/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8268 - loss: 5.3729e-07 - val_binary_accuracy: 0.8264 - val_loss: 5.3517e-07 - learning_rate: 0.0010
# Epoch 47/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8269 - loss: 5.3724e-07 - val_binary_accuracy: 0.8264 - val_loss: 5.3520e-07 - learning_rate: 0.0010
# Epoch 48/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8270 - loss: 5.3719e-07 - val_binary_accuracy: 0.8263 - val_loss: 5.3517e-07 - learning_rate: 0.0010
# Epoch 49/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8269 - loss: 5.3716e-07 - val_binary_accuracy: 0.8268 - val_loss: 5.3511e-07 - learning_rate: 0.0010
# Epoch 50/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8270 - loss: 5.3712e-07 - val_binary_accuracy: 0.8263 - val_loss: 5.3519e-07 - learning_rate: 0.0010
# Epoch 51/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8270 - loss: 5.3710e-07 - val_binary_accuracy: 0.8264 - val_loss: 5.3512e-07 - learning_rate: 0.0010
# Epoch 52/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8269 - loss: 5.3705e-07 - val_binary_accuracy: 0.8264 - val_loss: 5.3511e-07 - learning_rate: 0.0010
# Epoch 53/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3703e-07 - val_binary_accuracy: 0.8264 - val_loss: 5.3495e-07 - learning_rate: 0.0010
# Epoch 54/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8270 - loss: 5.3697e-07 - val_binary_accuracy: 0.8263 - val_loss: 5.3507e-07 - learning_rate: 0.0010
# Epoch 55/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8269 - loss: 5.3695e-07 - val_binary_accuracy: 0.8264 - val_loss: 5.3503e-07 - learning_rate: 0.0010
# Epoch 56/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3694e-07 - val_binary_accuracy: 0.8264 - val_loss: 5.3492e-07 - learning_rate: 0.0010
# Epoch 57/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8272 - loss: 5.3690e-07 - val_binary_accuracy: 0.8263 - val_loss: 5.3488e-07 - learning_rate: 0.0010
# Epoch 58/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8271 - loss: 5.3687e-07 - val_binary_accuracy: 0.8265 - val_loss: 5.3493e-07 - learning_rate: 0.0010
# Epoch 59/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8272 - loss: 5.3684e-07 - val_binary_accuracy: 0.8265 - val_loss: 5.3489e-07 - learning_rate: 0.0010
# Epoch 60/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8270 - loss: 5.3682e-07 - val_binary_accuracy: 0.8263 - val_loss: 5.3500e-07 - learning_rate: 0.0010
# Epoch 61/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3680e-07 - val_binary_accuracy: 0.8266 - val_loss: 5.3484e-07 - learning_rate: 0.0010
# Epoch 62/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3662e-07 - val_binary_accuracy: 0.8267 - val_loss: 5.3483e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3662e-07 - val_binary_accuracy: 0.8267 - val_loss: 5.3482e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3661e-07 - val_binary_accuracy: 0.8267 - val_loss: 5.3481e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8271 - loss: 5.3660e-07 - val_binary_accuracy: 0.8267 - val_loss: 5.3481e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8271 - loss: 5.3660e-07 - val_binary_accuracy: 0.8267 - val_loss: 5.3480e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8271 - loss: 5.3659e-07 - val_binary_accuracy: 0.8267 - val_loss: 5.3480e-07 - learning_rate: 1.0000e-05
# Epoch 68/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3659e-07 - val_binary_accuracy: 0.8266 - val_loss: 5.3479e-07 - learning_rate: 1.0000e-05
# Epoch 69/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3659e-07 - val_binary_accuracy: 0.8266 - val_loss: 5.3479e-07 - learning_rate: 1.0000e-05
# Epoch 70/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8271 - loss: 5.3659e-07 - val_binary_accuracy: 0.8266 - val_loss: 5.3478e-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3658e-07 - val_binary_accuracy: 0.8266 - val_loss: 5.3478e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8271 - loss: 5.3658e-07 - val_binary_accuracy: 0.8267 - val_loss: 5.3478e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3658e-07 - val_binary_accuracy: 0.8266 - val_loss: 5.3478e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3658e-07 - val_binary_accuracy: 0.8267 - val_loss: 5.3477e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3658e-07 - val_binary_accuracy: 0.8266 - val_loss: 5.3477e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3658e-07 - val_binary_accuracy: 0.8266 - val_loss: 5.3477e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3658e-07 - val_binary_accuracy: 0.8266 - val_loss: 5.3477e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3658e-07 - val_binary_accuracy: 0.8266 - val_loss: 5.3477e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3657e-07 - val_binary_accuracy: 0.8265 - val_loss: 5.3477e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3657e-07 - val_binary_accuracy: 0.8265 - val_loss: 5.3477e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8271 - loss: 5.3657e-07 - val_binary_accuracy: 0.8265 - val_loss: 5.3477e-07 - learning_rate: 1.0000e-05
# Epoch 82/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8271 - loss: 5.3657e-07 - val_binary_accuracy: 0.8265 - val_loss: 5.3477e-07 - learning_rate: 1.0000e-05
# Epoch 83/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8271 - loss: 5.3657e-07 - val_binary_accuracy: 0.8266 - val_loss: 5.3477e-07 - learning_rate: 1.0000e-05
# Epoch 84/100
# 1907/1907 - 4s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3657e-07 - val_binary_accuracy: 0.8266 - val_loss: 5.3476e-07 - learning_rate: 1.0000e-05
# Epoch 85/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3657e-07 - val_binary_accuracy: 0.8266 - val_loss: 5.3476e-07 - learning_rate: 1.0000e-05
# Epoch 86/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3657e-07 - val_binary_accuracy: 0.8266 - val_loss: 5.3476e-07 - learning_rate: 1.0000e-05
# Epoch 87/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3657e-07 - val_binary_accuracy: 0.8266 - val_loss: 5.3476e-07 - learning_rate: 1.0000e-05
# Epoch 88/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3657e-07 - val_binary_accuracy: 0.8266 - val_loss: 5.3476e-07 - learning_rate: 1.0000e-05
# Epoch 89/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8271 - loss: 5.3657e-07 - val_binary_accuracy: 0.8266 - val_loss: 5.3476e-07 - learning_rate: 1.0000e-05
# Epoch 90/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8271 - loss: 5.3657e-07 - val_binary_accuracy: 0.8266 - val_loss: 5.3476e-07 - learning_rate: 1.0000e-05
# Epoch 91/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8271 - loss: 5.3657e-07 - val_binary_accuracy: 0.8265 - val_loss: 5.3476e-07 - learning_rate: 1.0000e-05
# Epoch 92/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8271 - loss: 5.3656e-07 - val_binary_accuracy: 0.8265 - val_loss: 5.3476e-07 - learning_rate: 1.0000e-07
# Epoch 93/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3656e-07 - val_binary_accuracy: 0.8265 - val_loss: 5.3476e-07 - learning_rate: 1.0000e-07
# Epoch 94/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3657e-07 - val_binary_accuracy: 0.8265 - val_loss: 5.3476e-07 - learning_rate: 1.0000e-07
# Epoch 95/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8271 - loss: 5.3657e-07 - val_binary_accuracy: 0.8265 - val_loss: 5.3476e-07 - learning_rate: 1.0000e-07
# Epoch 96/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8271 - loss: 5.3657e-07 - val_binary_accuracy: 0.8265 - val_loss: 5.3476e-07 - learning_rate: 1.0000e-07
# Epoch 97/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8271 - loss: 5.3656e-07 - val_binary_accuracy: 0.8265 - val_loss: 5.3476e-07 - learning_rate: 1.0000e-07
# Epoch 98/100
# 1907/1907 - 5s - 3ms/step - binary_accuracy: 0.8271 - loss: 5.3656e-07 - val_binary_accuracy: 0.8265 - val_loss: 5.3476e-07 - learning_rate: 1.0000e-07
# Epoch 99/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3656e-07 - val_binary_accuracy: 0.8265 - val_loss: 5.3476e-07 - learning_rate: 1.0000e-07
# Epoch 100/100
# 1907/1907 - 5s - 2ms/step - binary_accuracy: 0.8271 - loss: 5.3656e-07 - val_binary_accuracy: 0.8265 - val_loss: 5.3476e-07 - learning_rate: 1.0000e-07
# Finished Training
# /home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/output_training_nominal/output_model_params_ttbar/model_scaler.bin
# 109/109 - 1s - 12ms/step
# 37/37 - 0s - 12ms/step
# 145/145 - 1s - 8ms/step
# The sum of PDFs is 1.0075218677520752
# Sum of weights of class 0: 0.7499995231628418
# Sum of weights of class 1: 0.749998927116394
# Using swish activation function
# /home/jaySandesara/.conda/envs/NSBI/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │         9,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,013,001 (11.49 MB)
#  Trainable params: 3,013,001 (11.49 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# 2344/2344 - 9s - 4ms/step - binary_accuracy: 0.7207 - loss: 6.3425e-07 - val_binary_accuracy: 0.7287 - val_loss: 6.2520e-07 - learning_rate: 0.1000
# Epoch 2/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7432 - loss: 6.0398e-07 - val_binary_accuracy: 0.7456 - val_loss: 5.9467e-07 - learning_rate: 0.1000
# Epoch 3/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7520 - loss: 5.8349e-07 - val_binary_accuracy: 0.7471 - val_loss: 5.8965e-07 - learning_rate: 0.1000
# Epoch 4/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7549 - loss: 5.7878e-07 - val_binary_accuracy: 0.7531 - val_loss: 5.7978e-07 - learning_rate: 0.1000
# Epoch 5/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7569 - loss: 5.7551e-07 - val_binary_accuracy: 0.7554 - val_loss: 5.7686e-07 - learning_rate: 0.1000
# Epoch 6/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7586 - loss: 5.7222e-07 - val_binary_accuracy: 0.7580 - val_loss: 5.7389e-07 - learning_rate: 0.1000
# Epoch 7/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7612 - loss: 5.6795e-07 - val_binary_accuracy: 0.7611 - val_loss: 5.7030e-07 - learning_rate: 0.1000
# Epoch 8/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7630 - loss: 5.6482e-07 - val_binary_accuracy: 0.7575 - val_loss: 5.7498e-07 - learning_rate: 0.1000
# Epoch 9/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7642 - loss: 5.6315e-07 - val_binary_accuracy: 0.7640 - val_loss: 5.6367e-07 - learning_rate: 0.1000
# Epoch 10/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7651 - loss: 5.6168e-07 - val_binary_accuracy: 0.7618 - val_loss: 5.6822e-07 - learning_rate: 0.1000
# Epoch 11/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7654 - loss: 5.6074e-07 - val_binary_accuracy: 0.7648 - val_loss: 5.6353e-07 - learning_rate: 0.1000
# Epoch 12/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7660 - loss: 5.5993e-07 - val_binary_accuracy: 0.7641 - val_loss: 5.6554e-07 - learning_rate: 0.1000
# Epoch 13/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7666 - loss: 5.5910e-07 - val_binary_accuracy: 0.7621 - val_loss: 5.6486e-07 - learning_rate: 0.1000
# Epoch 14/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7672 - loss: 5.5828e-07 - val_binary_accuracy: 0.7675 - val_loss: 5.6026e-07 - learning_rate: 0.1000
# Epoch 15/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7673 - loss: 5.5778e-07 - val_binary_accuracy: 0.7656 - val_loss: 5.6144e-07 - learning_rate: 0.1000
# Epoch 16/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7678 - loss: 5.5717e-07 - val_binary_accuracy: 0.7672 - val_loss: 5.5772e-07 - learning_rate: 0.1000
# Epoch 17/100
# 2344/2344 - 5s - 2ms/step - binary_accuracy: 0.7682 - loss: 5.5646e-07 - val_binary_accuracy: 0.7665 - val_loss: 5.5935e-07 - learning_rate: 0.1000
# Epoch 18/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7683 - loss: 5.5588e-07 - val_binary_accuracy: 0.7649 - val_loss: 5.6102e-07 - learning_rate: 0.1000
# Epoch 19/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7691 - loss: 5.5533e-07 - val_binary_accuracy: 0.7687 - val_loss: 5.5795e-07 - learning_rate: 0.1000
# Epoch 20/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7693 - loss: 5.5470e-07 - val_binary_accuracy: 0.7672 - val_loss: 5.5649e-07 - learning_rate: 0.1000
# Epoch 21/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7695 - loss: 5.5431e-07 - val_binary_accuracy: 0.7685 - val_loss: 5.5704e-07 - learning_rate: 0.1000
# Epoch 22/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7698 - loss: 5.5366e-07 - val_binary_accuracy: 0.7663 - val_loss: 5.6213e-07 - learning_rate: 0.1000
# Epoch 23/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7699 - loss: 5.5327e-07 - val_binary_accuracy: 0.7677 - val_loss: 5.5671e-07 - learning_rate: 0.1000
# Epoch 24/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7704 - loss: 5.5267e-07 - val_binary_accuracy: 0.7700 - val_loss: 5.5483e-07 - learning_rate: 0.1000
# Epoch 25/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7708 - loss: 5.5225e-07 - val_binary_accuracy: 0.7704 - val_loss: 5.5308e-07 - learning_rate: 0.1000
# Epoch 26/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7707 - loss: 5.5179e-07 - val_binary_accuracy: 0.7701 - val_loss: 5.5300e-07 - learning_rate: 0.1000
# Epoch 27/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7709 - loss: 5.5167e-07 - val_binary_accuracy: 0.7713 - val_loss: 5.5305e-07 - learning_rate: 0.1000
# Epoch 28/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7711 - loss: 5.5112e-07 - val_binary_accuracy: 0.7703 - val_loss: 5.5269e-07 - learning_rate: 0.1000
# Epoch 29/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7714 - loss: 5.5085e-07 - val_binary_accuracy: 0.7687 - val_loss: 5.5569e-07 - learning_rate: 0.1000
# Epoch 30/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7717 - loss: 5.5056e-07 - val_binary_accuracy: 0.7673 - val_loss: 5.6132e-07 - learning_rate: 0.1000
# Epoch 31/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7743 - loss: 5.4532e-07 - val_binary_accuracy: 0.7733 - val_loss: 5.4841e-07 - learning_rate: 0.0010
# Epoch 35/100
# 2344/2344 - 6s - 3ms/step - binary_accuracy: 0.7744 - loss: 5.4523e-07 - val_binary_accuracy: 0.7735 - val_loss: 5.4833e-07 - learning_rate: 0.0010
# Epoch 36/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7744 - loss: 5.4515e-07 - val_binary_accuracy: 0.7734 - val_loss: 5.4830e-07 - learning_rate: 0.0010
# Epoch 37/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7745 - loss: 5.4510e-07 - val_binary_accuracy: 0.7734 - val_loss: 5.4818e-07 - learning_rate: 0.0010
# Epoch 38/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7745 - loss: 5.4506e-07 - val_binary_accuracy: 0.7732 - val_loss: 5.4818e-07 - learning_rate: 0.0010
# Epoch 39/100
# 2344/2344 - 6s - 3ms/step - binary_accuracy: 0.7745 - loss: 5.4504e-07 - val_binary_accuracy: 0.7734 - val_loss: 5.4815e-07 - learning_rate: 0.0010
# Epoch 40/100
# 2344/2344 - 6s - 3ms/step - binary_accuracy: 0.7746 - loss: 5.4501e-07 - val_binary_accuracy: 0.7735 - val_loss: 5.4813e-07 - learning_rate: 0.0010
# Epoch 41/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7745 - loss: 5.4498e-07 - val_binary_accuracy: 0.7733 - val_loss: 5.4814e-07 - learning_rate: 0.0010
# Epoch 42/100
# 2344/2344 - 6s - 3ms/step - binary_accuracy: 0.7746 - loss: 5.4494e-07 - val_binary_accuracy: 0.7738 - val_loss: 5.4809e-07 - learning_rate: 0.0010
# Epoch 43/100
# 2344/2344 - 6s - 3ms/step - binary_accuracy: 0.7745 - loss: 5.4492e-07 - val_binary_accuracy: 0.7734 - val_loss: 5.4813e-07 - learning_rate: 0.0010
# Epoch 44/100
# 2344/2344 - 6s - 3ms/step - binary_accuracy: 0.7747 - loss: 5.4489e-07 - val_binary_accuracy: 0.7733 - val_loss: 5.4810e-07 - learning_rate: 0.0010
# Epoch 45/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7746 - loss: 5.4489e-07 - val_binary_accuracy: 0.7735 - val_loss: 5.4803e-07 - learning_rate: 0.0010
# Epoch 46/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7746 - loss: 5.4487e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4803e-07 - learning_rate: 0.0010
# Epoch 47/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7746 - loss: 5.4484e-07 - val_binary_accuracy: 0.7735 - val_loss: 5.4807e-07 - learning_rate: 0.0010
# Epoch 48/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4483e-07 - val_binary_accuracy: 0.7735 - val_loss: 5.4804e-07 - learning_rate: 0.0010
# Epoch 49/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7746 - loss: 5.4482e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4801e-07 - learning_rate: 0.0010
# Epoch 50/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4480e-07 - val_binary_accuracy: 0.7738 - val_loss: 5.4799e-07 - learning_rate: 0.0010
# Epoch 51/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4479e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4797e-07 - learning_rate: 0.0010
# Epoch 52/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7746 - loss: 5.4478e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4797e-07 - learning_rate: 0.0010
# Epoch 53/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7746 - loss: 5.4477e-07 - val_binary_accuracy: 0.7737 - val_loss: 5.4801e-07 - learning_rate: 0.0010
# Epoch 54/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4475e-07 - val_binary_accuracy: 0.7738 - val_loss: 5.4797e-07 - learning_rate: 0.0010
# Epoch 55/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4473e-07 - val_binary_accuracy: 0.7732 - val_loss: 5.4798e-07 - learning_rate: 0.0010
# Epoch 56/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4472e-07 - val_binary_accuracy: 0.7737 - val_loss: 5.4795e-07 - learning_rate: 0.0010
# Epoch 57/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7746 - loss: 5.4472e-07 - val_binary_accuracy: 0.7737 - val_loss: 5.4792e-07 - learning_rate: 0.0010
# Epoch 58/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7746 - loss: 5.4469e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4793e-07 - learning_rate: 0.0010
# Epoch 59/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4470e-07 - val_binary_accuracy: 0.7737 - val_loss: 5.4793e-07 - learning_rate: 0.0010
# Epoch 60/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4467e-07 - val_binary_accuracy: 0.7737 - val_loss: 5.4794e-07 - learning_rate: 0.0010
# Epoch 61/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4467e-07 - val_binary_accuracy: 0.7737 - val_loss: 5.4801e-07 - learning_rate: 0.0010
# Epoch 62/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4465e-07 - val_binary_accuracy: 0.7735 - val_loss: 5.4795e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4461e-07 - val_binary_accuracy: 0.7734 - val_loss: 5.4793e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 2344/2344 - 5s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4459e-07 - val_binary_accuracy: 0.7734 - val_loss: 5.4791e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4458e-07 - val_binary_accuracy: 0.7733 - val_loss: 5.4790e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 2344/2344 - 6s - 3ms/step - binary_accuracy: 0.7747 - loss: 5.4458e-07 - val_binary_accuracy: 0.7734 - val_loss: 5.4790e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
# 2344/2344 - 6s - 3ms/step - binary_accuracy: 0.7747 - loss: 5.4457e-07 - val_binary_accuracy: 0.7734 - val_loss: 5.4789e-07 - learning_rate: 1.0000e-05
# Epoch 68/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4457e-07 - val_binary_accuracy: 0.7734 - val_loss: 5.4789e-07 - learning_rate: 1.0000e-05
# Epoch 69/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4457e-07 - val_binary_accuracy: 0.7734 - val_loss: 5.4789e-07 - learning_rate: 1.0000e-05
# Epoch 70/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4457e-07 - val_binary_accuracy: 0.7734 - val_loss: 5.4789e-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4457e-07 - val_binary_accuracy: 0.7734 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4457e-07 - val_binary_accuracy: 0.7734 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4457e-07 - val_binary_accuracy: 0.7734 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4457e-07 - val_binary_accuracy: 0.7734 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4457e-07 - val_binary_accuracy: 0.7735 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4457e-07 - val_binary_accuracy: 0.7735 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4457e-07 - val_binary_accuracy: 0.7735 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4457e-07 - val_binary_accuracy: 0.7735 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4457e-07 - val_binary_accuracy: 0.7735 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4457e-07 - val_binary_accuracy: 0.7735 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4457e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 82/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4457e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 83/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4456e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 84/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4457e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 85/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4456e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 86/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4457e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 87/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4456e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 88/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7748 - loss: 5.4456e-07 - val_binary_accuracy: 0.7735 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 89/100
# 2344/2344 - 5s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4456e-07 - val_binary_accuracy: 0.7735 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 90/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4456e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 91/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4456e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-05
# Epoch 92/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4456e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-07
# Epoch 93/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4456e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-07
# Epoch 94/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4456e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-07
# Epoch 95/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4456e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-07
# Epoch 96/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4456e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-07
# Epoch 97/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4456e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-07
# Epoch 98/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4456e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-07
# Epoch 99/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4456e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-07
# Epoch 100/100
# 2344/2344 - 6s - 2ms/step - binary_accuracy: 0.7747 - loss: 5.4456e-07 - val_binary_accuracy: 0.7736 - val_loss: 5.4788e-07 - learning_rate: 1.0000e-07
# Finished Training
# /home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/output_training_nominal/output_model_params_ztautau/model_scaler.bin
# 134/134 - 1s - 10ms/step
# 45/45 - 1s - 12ms/step
# 178/178 - 1s - 8ms/step
# The sum of PDFs is 1.0008305311203003

# %% [markdown]
# Check for overtraining by comparing the NN output distributions between training and holdout datasets. The holdout dataset is the subset of events not used during training.

# %%
for process_type in mix_model_hypotheses:
    NN_training_mix_model[process_type].make_overfit_plots()

# %% [markdown]
# Diagnostic Checks
# ===
#
# While traditionally, a NN observable is judged on the basis of its accuracy - for NSBI we are interested in the quality of the density ratios more than the discrimination power. The latter comes from the perfect modelling of the multi-dimensional likelihood ratios.
#
# To ensure correct modelling, we run two main checks on the training:
#
# - **Calibration closure test**
#
#   The NNs are trained using the binary cross-entropy loss, which under ideal conditions leads to the NN converging to the score function:
#
#   $$\hat{s}_\text{pred} = \frac{p_\text{ref}(x)}{p_\text{ref}(x)+p_\text{c}(x)}$$
#
#   that can be converted into the probability ratio we desire (likelihood ratio trick):
#
#   $$\frac{p_\text{c}(x)}{p_\text{ref}(x)} = \frac{\hat{s}_\text{pred}(x)}{1-\hat{s}_\text{pred}(x)}$$
#
#   For the NNs to be well-calibrated, we use the Monte Carlo samples to verify the equality:
#
#
#   $$\left[\frac{p_c(x)}{p_c(x)+p_{ref}(x)}\right]_\text{NN} \sim \left[\frac{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}}{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}+\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}}\right]_\text{MC}$$
#
#   where we bin the events from $p_c$ and $p_\text{ref}$ MC samples, denoted by $\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}$ and $\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}$ respectively where $I(x|\hat{s}_\text{pred})$ returns the index of the $\hat{s}_\text{pred}$ bin in which an event $x$ falls.

# %%
num_bins_cal = 50

for process_type in mix_model_hypotheses:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='score')

# %% [markdown]
# - **Density ratio reweighting closure tests**
#
#   Despite having a well-calibrated output and thus a robust probabilistic interpretation, the trained density ratios might not capture the full multi-dimensional event information $x$. In other words, the NNs might still be biased estimators of the optimal score function, as defined in the CARL paper (link).
#
#   The next diagnostic involves verifying the following equality using 1D projections of $x$:
#
#   $$\frac{p_c(x)}{p_{ref}(x)} \times p_{ref}(x) \sim p_c(x)$$
#
#   We can do this one-by-one for all the observables used to model the density ratios, and also possibly the observables not used directly in the training but can still be well-estimated due to the NN learning the right physics.

# %%
variables_to_plot=['DER_pt_h'] # The 1D variable for reweighting closure
yscale_type='log'
num_bins_plotting=21

for process_type in mix_model_hypotheses:

    NN_training_mix_model[process_type].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
for process_type in mix_model_hypotheses:
    # Evaluate the density ratios p_c/p_ref for the full dataset and save for the inference step
    NN_training_mix_model[process_type].evaluate_and_save_ratios(dataset)
# Out:
# 197/197 - 2s - 8ms/step
# 197/197 - 1s - 7ms/step

# %% [markdown]
# Systematic Uncertainty Modelling
# ===
#
# So far we have left out the nuisance parameter piece of the parameterized density ratio decomposition shown before:
#
# $$g_c(x|\alpha) = \frac{p_c(x|\alpha)}{p_c(x)}$$
#
# which will be estimated in the `Systematic_Uncertainty_Estimation.ipynb` notebook.

# %% [markdown]
# Training an Ensemble of NNs
# ===
#
# In a realistic analysis, a large ensemble of NNs are trained to estimate density ratios, for *each* of the channels. **This reduces not only the variance but has also been found to reduce biases in the final fits.**
#
# In the off-shell Higgs boson analysis, we used k-fold cross-validation, with k=10, to train an ensemble $N_{ens}\sim 250$ of NNs per density ratio $p_c(x)/p_{ref}(x)$. The density ratios used in the final fit are always evaluated on the holdout dataset and by using each of the folds as holdout once, the entire model for $p_c(x)/p_{ref}(x)$ consists of $N_{ens}\times k \sim 2500$ NNs. Each NN in the ensemble is trained by resampling data without replacement from the k-1 folds used for training.
