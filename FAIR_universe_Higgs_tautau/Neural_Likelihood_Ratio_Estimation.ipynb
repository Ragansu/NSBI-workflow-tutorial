# %% [markdown]
# Train Neural Networks to estimate Likelihood Ratios
# ===
#
# In this notebook we will setup the neural networks that train unbiased and low-variance density ratios to be then used for inference.

# %%
import os, sys, pathlib, importlib
sys.path.append('../')

# Load the package and modules for training and plotting
import nsbi_common_utils
from nsbi_common_utils import plotting, training, datasets, configuration
from nsbi_common_utils.training import TrainEvaluate_NN, TrainEvaluatePreselNN


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt
import pickle
import yaml
import random

from utils import preselection_using_score, calculate_preselection_observable

from coffea.analysis_tools import PackedSelection

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

hep.style.use(hep.style.ATLAS)

# %%
importlib.reload(sys.modules['nsbi_common_utils.configuration'])
from nsbi_common_utils import configuration

config = nsbi_common_utils.configuration.ConfigManager(file_path_string = './config.yml')

# %%
# Input features for training
features, features_scaling = config.get_training_features()

# %% [markdown]
# Statistical Model
# -
#
# The statistical model we have is:
#
# $$p(x|\mu, \alpha) = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot p_c\left(x|\alpha\right)$$
#
# where $c$ stands for the various physics channels that contribute to the final state $x$, **$\mu$ is the signal-strength parameter and $\alpha$ is the vector of nuisance parameters associated with the various systematic uncertainties in the model**. Note that we are assuming that the parameter $\mu$-dependence is known analytically and that we have simulation models for each of the channels $p_c(x)$.
#
# Setting up the test
# -
#
# The objective is to build the test statistic for composite hypothesis testing:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})}{p(x_i|\hat{\mu}, \hat{\alpha})} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
# A direct approach would then be to model the probability density $p(x|\mu, \alpha)$ using NNs. But that is a more difficult task than training probability density ratios. We use a simple trick:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})/p_{ref}(x)}{p(x_i|\hat{\mu}, \hat{\alpha})/p_{ref}(x)} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
#
# to turn this into a density ratio estimation problem:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot \frac{p_c\left(x|\alpha\right)}{p_{ref}(x)}$$
#
# Factorizing out the $\alpha$-dependence in the density ratios:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\sum_c G_c(\alpha) \cdot f_c(\mu) \cdot \nu_c} \sum_c f_c(\mu) \cdot G_c(\alpha)\cdot \nu_c \cdot g_c(x|\alpha) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}$$
#
# Factorized approach:
# --
#
# Instead of training NNs parameterized on $\mu$ and $\alpha$, we use analytical parameterizations to simplify the problem to training only parameter-independent density ratios.
#
# Let's set this up for the toy $H\to \tau\tau$ model we are using. **Neglecting the nuisance parameter dependence ($G_c(\alpha) = g_c(x|\alpha) = 1$), the probability model can be written as**
#
# $$\sum_c f_c(\mu) \cdot \nu_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} = \mu \cdot \nu_{H \to \tau\tau}(\mu) \cdot  \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)} + \nu_{t\bar{t}}(\mu) \cdot  \frac{p_{t\bar{t}}\left(x\right)}{p_{ref}(x)} + \nu_{Z \to \tau\tau}(\mu) \cdot  \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{ref}(x)}$$
#
# In the NSBI approach presented in this tutorial, the density ratio estimation as a function of the various nuisance parameters is factorized from the nominal density ratio estimation, and will be done in the  `Systematic_Uncertainty_Estimation.ipynb` notebook.

# %%
importlib.reload(sys.modules['nsbi_common_utils.datasets'])
from nsbi_common_utils import datasets

branches_to_load = features + ['presel_score']

Datasets = nsbi_common_utils.datasets.datasets(config_path = './config.yml',
                                                branches_to_load =  branches_to_load)

# %%
dataset_incl_dict      = Datasets.load_datasets_from_config(load_systematics = False)

dataset_incl_nominal   = dataset_SR_dict["Nominal"].copy()

dataset_SR_nominal     = Datasets.filter_region_dataset(dataset_incl_nominal,
                                                       region = "SR")

# %% [markdown]
# Density ratio training
# ===
#
# Now we train the NNs for $\frac{p_c}{p_{ref}}(x)$ density ratios to build the full model. Our choice of reference hypothesis, motivated by the search-oriented mixture model described above, would be:
#
# $$p_{ref}(x) = p_{H \to \tau\tau}(x) = \frac{1}{\nu_{H \to \tau\tau}} \frac{d\sigma_{H \to \tau\tau}}{dx} $$
#
# gives the POI $\mu-$parameterized model:
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} \right]= \mu + \frac{p_{t\bar{t}}\left(x\right)}{p_{H \to \tau\tau}(x)} + \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{H \to \tau\tau}(x)}$$
#
# But this has shown to cause numerical issues, since the ratio corresponding to the $\mu$-scaling signal term is exactly 1. In the absence of additional signal production mechansims, we instead use:
#
# $$p_{ref}(x) = \frac{1}{\nu_{H \to \tau\tau} + \nu_{t\bar{t}}} \left[\frac{d\sigma_{H \to \tau\tau}}{dx} + \frac{d\sigma_{t\bar{t}}}{dx} \right]$$
#
# giving a more numerically stable model:
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} \right]= \mu \cdot \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)} + \frac{p_{t\bar{t}}\left(x\right)}{p_{ref}(x)} + \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{ref}(x)}$$
#
# The task of estimating the $\mu-$parameterized density ratio is thus reduced to estimating three $\mu-$independent density ratios $\frac{p_{H \to \tau\tau}}{p_{ref}}(x)$, $\frac{p_{t\bar{t}}}{p_{ref}}(x)$ and $\frac{p_{Z \to \tau\tau}}{p_{ref}}(x)$ mixed together with an analytical parameterization (hence the name mixture model).
#
# **NB**: This is the same as the *morphing-aware* approach of density ratio estimation in MadMiner

# %%
# Define the processes that make up the mixture model formula for density ratio estimation

PATH_TO_SAVED_DATA = './saved_data/'
TRAINING_OUTPUT_PATH = f'{PATH_TO_SAVED_DATA}output_training_nominal/'

# Signal processes in the model
basis_processes = config.get_basis_samples()
print(basis_processes)

ref_processes = config.get_reference_samples()
print(ref_processes)
# Out:
# ['htautau', 'ttbar', 'ztautau']
# ['htautau', 'ttbar']

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import TrainEvaluate_NN

ref_train_label_sample_dict = {**{ref: 0 for ref in ref_processes}}

dataset_ref     = Datasets.merge_dataframe_dict_for_training(dataset_SR_nominal, 
                                                            ref_train_label_sample_dict, 
                                                            samples_to_merge = ref_processes)

NN_training_mix_model = {}

use_log_loss = False

# DELETE_EXISTING_MODELS = True
DELETE_EXISTING_MODELS = False

path_to_ratios = {}
path_to_figures = {}
path_to_models = {}

for process_type in basis_processes:

    # Get the dictionary of labels to processes
    _train_label_sample_dict = {process_type        : 1}

    dataset_num     = Datasets.merge_dataframe_dict_for_training(dataset_SR_nominal, 
                                                                _train_label_sample_dict, 
                                                                samples_to_merge = [process_type])

    # Build a training dataset for the training of p_<process_type>/p_<ref_processes> density ratio
    dataset_mix_model = pd.concat([dataset_num, dataset_ref])

    # Save paths
    output_name                     = f'{process_type}'
    output_dir                      = f'{TRAINING_OUTPUT_PATH}general_output_{process_type}'
    path_to_ratios[process_type]    = f'{TRAINING_OUTPUT_PATH}output_ratios_{process_type}/'
    path_to_figures[process_type]   = f'{TRAINING_OUTPUT_PATH}output_figures_{process_type}/'
    path_to_models[process_type]    = f'{TRAINING_OUTPUT_PATH}output_model_params_{process_type}/'

    NN_training_mix_model[process_type] = TrainEvaluate_NN(dataset_mix_model, 
                                                           dataset_mix_model['weights_normed'].to_numpy(),
                                                           dataset_mix_model['train_labels'].to_numpy(),
                                                           features, 
                                                           features_scaling, 
                                                           [process_type, 'ref'], 
                                                            output_dir, output_name, 
                                                            path_to_figures=path_to_figures[process_type],
                                                            path_to_ratios=path_to_ratios[process_type], 
                                                            path_to_models=path_to_models[process_type],
                                                            use_log_loss = use_log_loss,
                                                            delete_existing_models = DELETE_EXISTING_MODELS)


    del dataset_mix_model

# %% [markdown]
# Neural Network architecture
# ===
#
# Here we will start with a multi-layer perceptron (simple feed-forward Neural Network with fully-connected layers). This can be supplemented with more complex architectures like transformers.
#
# After detailed tuning during the off-shell Higgs boson analysis effort, we found that a network with very wide layers ($\geq 1000$) and a depth of less than 10 works best - alongside batch size of a few hundreds and a gradually declining learning rate that starts with a value just large enough to not blow up.

# %% [markdown]
# Starting with the training and validation of the various density ratio:
#
# $$\frac{p_{H\to\tau\tau}(x)}{p_\text{ref}(x)}, \frac{p_{t\bar{t}}(x)}{p_\text{ref}(x)}, \frac{p_{Z \to \tau\tau}(x)}{p_\text{ref}(x)}$$

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 1

# %%
# You can either train your own NNs (in which case set this to False) or you can load the pre-trained NNs. 
# Training NNs without GPUs can be very slow, for the kind of NNs we need for unbiased estimation of density ratios
USE_SAVED_MODELS = True

# Define unique settings for each process type
doCalibration = True
num_bins_cal = 100
scaling_type = 'MinMax'
batch_size = 512
validation_split = 0.1
holdout_split = 0.25

num_epochs = 100
callback_patience = 30

num_layers = 4
num_neurons_per_layer = 1000

num_ensemble_members = 1

verbose_level = 1

training_settings = {

    'htautau': {
        'hidden_layers':        num_layers,
        'neurons':              num_neurons_per_layer,
        'number_of_epochs':     num_epochs,
        'batch_size':           batch_size,
        'learning_rate':        0.1,
        'scalerType':           scaling_type,
        'calibration':          doCalibration,
        'num_bins_cal':         num_bins_cal,
        'callback':             True,
        'callback_patience':    callback_patience,
        'callback_factor':      0.01,
        'validation_split':     validation_split,
        'holdout_split':        holdout_split,
        'verbose':              verbose_level,
        'plot_scaled_features': True,
        'load_trained_models':  USE_SAVED_MODELS,
        'num_ensemble_members': num_ensemble_members
    },
    
    'ttbar': {
        'hidden_layers':        num_layers,
        'neurons':              num_neurons_per_layer,
        'number_of_epochs':     num_epochs,
        'batch_size':           batch_size,
        'learning_rate':        0.1,
        'scalerType':           scaling_type,
        'calibration':          doCalibration,
        'num_bins_cal':         num_bins_cal,
        'callback':             True,
        'callback_patience':    callback_patience,
        'callback_factor':      0.01,
        'validation_split':     validation_split,
        'holdout_split':        holdout_split,
        'verbose':              verbose_level,
        'plot_scaled_features': True,
        'load_trained_models':  USE_SAVED_MODELS,
        'num_ensemble_members': num_ensemble_members
    },
    
    'ztautau': {
        'hidden_layers':        num_layers,
        'neurons':              num_neurons_per_layer,
        'number_of_epochs':     num_epochs,
        'batch_size':           batch_size,
        'learning_rate':        0.1,
        'scalerType':           scaling_type,
        'calibration':          doCalibration,
        'num_bins_cal':         num_bins_cal,
        'callback':             True,
        'callback_patience':    callback_patience,
        'callback_factor':      0.01,
        'validation_split':     validation_split,
        'holdout_split':        holdout_split,
        'verbose':              verbose_level,
        'plot_scaled_features': True,
        'load_trained_models':  USE_SAVED_MODELS,
        'num_ensemble_members': num_ensemble_members
    }
}

# %%
# Train the density ratio NN
for process_type in basis_processes:
    
    settings = training_settings[process_type]

    NN_training_mix_model[process_type].train_ensemble(**settings)
    NN_training_mix_model[process_type].test_normalization()
# Out:
# starting ensemble training
# Sum of weights of class 0: 0.7494027243161214
# Sum of weights of class 1: 0.7500018094283041
# Using swish activation function
# /home/jsandesara_umass_edu/NSBI-workflow-tutorial/.pixi/envs/nsbi-env-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-09-01 14:14:17.299208: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79193 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:bf:00.0, compute capability: 8.0
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │         9,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,013,001 (11.49 MB)
#  Trainable params: 3,013,001 (11.49 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# 2025-09-01 14:14:21.162752: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-09-01 14:14:21.368848: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 19s 5ms/step - binary_accuracy: 0.7412 - loss: 3.9870e-07 - val_binary_accuracy: 0.7522 - val_loss: 3.8829e-07 - learning_rate: 0.1000
# Epoch 2/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7523 - loss: 3.8741e-07 - val_binary_accuracy: 0.7535 - val_loss: 3.8509e-07 - learning_rate: 0.1000
# Epoch 3/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7552 - loss: 3.8436e-07 - val_binary_accuracy: 0.7565 - val_loss: 3.8186e-07 - learning_rate: 0.1000
# Epoch 4/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - binary_accuracy: 0.7577 - loss: 3.8213e-07 - val_binary_accuracy: 0.7594 - val_loss: 3.8047e-07 - learning_rate: 0.1000
# Epoch 5/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - binary_accuracy: 0.7599 - loss: 3.8000e-07 - val_binary_accuracy: 0.7617 - val_loss: 3.7767e-07 - learning_rate: 0.1000
# Epoch 6/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7613 - loss: 3.7860e-07 - val_binary_accuracy: 0.7636 - val_loss: 3.7591e-07 - learning_rate: 0.1000
# Epoch 7/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7630 - loss: 3.7700e-07 - val_binary_accuracy: 0.7659 - val_loss: 3.7545e-07 - learning_rate: 0.1000
# Epoch 8/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7652 - loss: 3.7512e-07 - val_binary_accuracy: 0.7662 - val_loss: 3.7387e-07 - learning_rate: 0.1000
# Epoch 9/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - binary_accuracy: 0.7673 - loss: 3.7324e-07 - val_binary_accuracy: 0.7711 - val_loss: 3.6994e-07 - learning_rate: 0.1000
# Epoch 10/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - binary_accuracy: 0.7686 - loss: 3.7164e-07 - val_binary_accuracy: 0.7704 - val_loss: 3.6973e-07 - learning_rate: 0.1000
# Epoch 11/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7697 - loss: 3.7006e-07 - val_binary_accuracy: 0.7734 - val_loss: 3.6814e-07 - learning_rate: 0.1000
# Epoch 12/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - binary_accuracy: 0.7710 - loss: 3.6884e-07 - val_binary_accuracy: 0.7733 - val_loss: 3.6776e-07 - learning_rate: 0.1000
# Epoch 13/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7719 - loss: 3.6778e-07 - val_binary_accuracy: 0.7756 - val_loss: 3.6532e-07 - learning_rate: 0.1000
# Epoch 14/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7729 - loss: 3.6687e-07 - val_binary_accuracy: 0.7760 - val_loss: 3.6491e-07 - learning_rate: 0.1000
# Epoch 15/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7735 - loss: 3.6610e-07 - val_binary_accuracy: 0.7749 - val_loss: 3.6453e-07 - learning_rate: 0.1000
# Epoch 16/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7740 - loss: 3.6541e-07 - val_binary_accuracy: 0.7738 - val_loss: 3.6660e-07 - learning_rate: 0.1000
# Epoch 17/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7745 - loss: 3.6477e-07 - val_binary_accuracy: 0.7756 - val_loss: 3.6410e-07 - learning_rate: 0.1000
# Epoch 18/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7752 - loss: 3.6424e-07 - val_binary_accuracy: 0.7747 - val_loss: 3.6502e-07 - learning_rate: 0.1000
# Epoch 19/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7752 - loss: 3.6384e-07 - val_binary_accuracy: 0.7750 - val_loss: 3.6396e-07 - learning_rate: 0.1000
# Epoch 20/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7760 - loss: 3.6322e-07 - val_binary_accuracy: 0.7780 - val_loss: 3.6247e-07 - learning_rate: 0.1000
# Epoch 21/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7764 - loss: 3.6295e-07 - val_binary_accuracy: 0.7778 - val_loss: 3.6188e-07 - learning_rate: 0.1000
# Epoch 22/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7765 - loss: 3.6258e-07 - val_binary_accuracy: 0.7787 - val_loss: 3.6055e-07 - learning_rate: 0.1000
# Epoch 23/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7764 - loss: 3.6224e-07 - val_binary_accuracy: 0.7765 - val_loss: 3.6224e-07 - learning_rate: 0.1000
# Epoch 24/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7767 - loss: 3.6194e-07 - val_binary_accuracy: 0.7786 - val_loss: 3.6218e-07 - learning_rate: 0.1000
# Epoch 25/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7773 - loss: 3.6148e-07 - val_binary_accuracy: 0.7759 - val_loss: 3.6428e-07 - learning_rate: 0.1000
# Epoch 26/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7775 - loss: 3.6141e-07 - val_binary_accuracy: 0.7790 - val_loss: 3.6071e-07 - learning_rate: 0.1000
# Epoch 27/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7775 - loss: 3.6110e-07 - val_binary_accuracy: 0.7770 - val_loss: 3.6306e-07 - learning_rate: 0.1000
# Epoch 28/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7776 - loss: 3.6086e-07 - val_binary_accuracy: 0.7784 - val_loss: 3.6060e-07 - learning_rate: 0.1000
# Epoch 29/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7779 - loss: 3.6054e-07 - val_binary_accuracy: 0.7786 - val_loss: 3.6078e-07 - learning_rate: 0.1000
# Epoch 30/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7783 - loss: 3.6019e-07 - val_binary_accuracy: 0.7795 - val_loss: 3.6084e-07 - learning_rate: 0.1000
# Epoch 31/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7788 - loss: 3.6009e-07 - val_binary_accuracy: 0.7784 - val_loss: 3.6075e-07 - learning_rate: 0.1000
# Epoch 32/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - binary_accuracy: 0.7807 - loss: 3.5710e-07 - val_binary_accuracy: 0.7817 - val_loss: 3.5714e-07 - learning_rate: 0.0010
# Epoch 33/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - binary_accuracy: 0.7810 - loss: 3.5652e-07 - val_binary_accuracy: 0.7824 - val_loss: 3.5687e-07 - learning_rate: 0.0010
# Epoch 34/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7811 - loss: 3.5636e-07 - val_binary_accuracy: 0.7827 - val_loss: 3.5679e-07 - learning_rate: 0.0010
# Epoch 35/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7811 - loss: 3.5626e-07 - val_binary_accuracy: 0.7825 - val_loss: 3.5674e-07 - learning_rate: 0.0010
# Epoch 36/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7813 - loss: 3.5617e-07 - val_binary_accuracy: 0.7827 - val_loss: 3.5675e-07 - learning_rate: 0.0010
# Epoch 37/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7812 - loss: 3.5612e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5671e-07 - learning_rate: 0.0010
# Epoch 38/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7813 - loss: 3.5608e-07 - val_binary_accuracy: 0.7825 - val_loss: 3.5662e-07 - learning_rate: 0.0010
# Epoch 39/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7814 - loss: 3.5604e-07 - val_binary_accuracy: 0.7829 - val_loss: 3.5662e-07 - learning_rate: 0.0010
# Epoch 40/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7815 - loss: 3.5600e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5665e-07 - learning_rate: 0.0010
# Epoch 41/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7813 - loss: 3.5598e-07 - val_binary_accuracy: 0.7821 - val_loss: 3.5661e-07 - learning_rate: 0.0010
# Epoch 42/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7815 - loss: 3.5595e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5655e-07 - learning_rate: 0.0010
# Epoch 43/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7814 - loss: 3.5594e-07 - val_binary_accuracy: 0.7821 - val_loss: 3.5660e-07 - learning_rate: 0.0010
# Epoch 44/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7814 - loss: 3.5591e-07 - val_binary_accuracy: 0.7827 - val_loss: 3.5663e-07 - learning_rate: 0.0010
# Epoch 45/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7815 - loss: 3.5589e-07 - val_binary_accuracy: 0.7825 - val_loss: 3.5654e-07 - learning_rate: 0.0010
# Epoch 46/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7816 - loss: 3.5588e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5653e-07 - learning_rate: 0.0010
# Epoch 47/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7815 - loss: 3.5586e-07 - val_binary_accuracy: 0.7823 - val_loss: 3.5652e-07 - learning_rate: 0.0010
# Epoch 48/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7817 - loss: 3.5584e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5653e-07 - learning_rate: 0.0010
# Epoch 49/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7816 - loss: 3.5583e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5649e-07 - learning_rate: 0.0010
# Epoch 50/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 13s 4ms/step - binary_accuracy: 0.7816 - loss: 3.5581e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5649e-07 - learning_rate: 0.0010
# Epoch 51/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7816 - loss: 3.5579e-07 - val_binary_accuracy: 0.7820 - val_loss: 3.5655e-07 - learning_rate: 0.0010
# Epoch 52/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7816 - loss: 3.5579e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5651e-07 - learning_rate: 0.0010
# Epoch 53/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7817 - loss: 3.5578e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5647e-07 - learning_rate: 0.0010
# Epoch 54/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7817 - loss: 3.5577e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5649e-07 - learning_rate: 0.0010
# Epoch 55/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7816 - loss: 3.5575e-07 - val_binary_accuracy: 0.7824 - val_loss: 3.5645e-07 - learning_rate: 0.0010
# Epoch 56/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5573e-07 - val_binary_accuracy: 0.7828 - val_loss: 3.5654e-07 - learning_rate: 0.0010
# Epoch 57/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7817 - loss: 3.5573e-07 - val_binary_accuracy: 0.7825 - val_loss: 3.5648e-07 - learning_rate: 0.0010
# Epoch 58/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5572e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5649e-07 - learning_rate: 0.0010
# Epoch 59/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7817 - loss: 3.5570e-07 - val_binary_accuracy: 0.7823 - val_loss: 3.5644e-07 - learning_rate: 0.0010
# Epoch 60/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7817 - loss: 3.5569e-07 - val_binary_accuracy: 0.7822 - val_loss: 3.5652e-07 - learning_rate: 0.0010
# Epoch 61/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 15s 4ms/step - binary_accuracy: 0.7817 - loss: 3.5568e-07 - val_binary_accuracy: 0.7824 - val_loss: 3.5646e-07 - learning_rate: 0.0010
# Epoch 62/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7817 - loss: 3.5563e-07 - val_binary_accuracy: 0.7824 - val_loss: 3.5645e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7817 - loss: 3.5562e-07 - val_binary_accuracy: 0.7825 - val_loss: 3.5644e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7817 - loss: 3.5562e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5644e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7817 - loss: 3.5562e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5644e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7817 - loss: 3.5562e-07 - val_binary_accuracy: 0.7825 - val_loss: 3.5643e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7817 - loss: 3.5561e-07 - val_binary_accuracy: 0.7825 - val_loss: 3.5643e-07 - learning_rate: 1.0000e-05
# Epoch 68/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5643e-07 - learning_rate: 1.0000e-05
# Epoch 69/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5643e-07 - learning_rate: 1.0000e-05
# Epoch 70/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5643e-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5643e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5643e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5643e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-05
# Epoch 82/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-05
# Epoch 83/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7817 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-05
# Epoch 84/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-05
# Epoch 85/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-05
# Epoch 86/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-05
# Epoch 87/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7827 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-05
# Epoch 88/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7827 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-05
# Epoch 89/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7827 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-05
# Epoch 90/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-05
# Epoch 91/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-05
# Epoch 92/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5560e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-07
# Epoch 93/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5560e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-07
# Epoch 94/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5560e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-07
# Epoch 95/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5560e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-07
# Epoch 96/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5561e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-07
# Epoch 97/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5560e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-07
# Epoch 98/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5560e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-07
# Epoch 99/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5560e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-07
# Epoch 100/100
# 3573/3573 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - binary_accuracy: 0.7818 - loss: 3.5560e-07 - val_binary_accuracy: 0.7826 - val_loss: 3.5642e-07 - learning_rate: 1.0000e-07
# Finished Training
# 2025-09-01 14:37:55.579254: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-09-01 14:37:55.585910: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79193 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:bf:00.0, compute capability: 8.0
# 2025-09-01 14:37:55.789138: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79193 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:bf:00.0, compute capability: 8.0
# 2025-09-01 14:37:55.805506: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-09-01 14:37:55.812087: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79193 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:bf:00.0, compute capability: 8.0
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# The sum of PDFs in ensemble member 0 is 1.0017733879622788
#
#
# The sum of PDFs using the whole ensemble is 1.0017733879622788
#
#
#
# starting ensemble training
# Sum of weights of class 0: 0.7487637359716782
# Sum of weights of class 1: 0.7499933722283458
# Using swish activation function
# /home/jsandesara_umass_edu/NSBI-workflow-tutorial/.pixi/envs/nsbi-env-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │         9,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,013,001 (11.49 MB)
#  Trainable params: 3,013,001 (11.49 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 14s 5ms/step - binary_accuracy: 0.5269 - loss: 8.4439e-07 - val_binary_accuracy: 0.5362 - val_loss: 8.4079e-07 - learning_rate: 0.1000
# Epoch 2/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5330 - loss: 8.3880e-07 - val_binary_accuracy: 0.5215 - val_loss: 8.4070e-07 - learning_rate: 0.1000
# Epoch 3/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5347 - loss: 8.3810e-07 - val_binary_accuracy: 0.5404 - val_loss: 8.3868e-07 - learning_rate: 0.1000
# Epoch 4/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5343 - loss: 8.3784e-07 - val_binary_accuracy: 0.5250 - val_loss: 8.3975e-07 - learning_rate: 0.1000
# Epoch 5/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5351 - loss: 8.3751e-07 - val_binary_accuracy: 0.5321 - val_loss: 8.4172e-07 - learning_rate: 0.1000
# Epoch 6/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5360 - loss: 8.3713e-07 - val_binary_accuracy: 0.5364 - val_loss: 8.3864e-07 - learning_rate: 0.1000
# Epoch 7/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5366 - loss: 8.3677e-07 - val_binary_accuracy: 0.4978 - val_loss: 8.4021e-07 - learning_rate: 0.1000
# Epoch 8/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5365 - loss: 8.3651e-07 - val_binary_accuracy: 0.5403 - val_loss: 8.3750e-07 - learning_rate: 0.1000
# Epoch 9/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5361 - loss: 8.3636e-07 - val_binary_accuracy: 0.5430 - val_loss: 8.3714e-07 - learning_rate: 0.1000
# Epoch 10/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5366 - loss: 8.3608e-07 - val_binary_accuracy: 0.5432 - val_loss: 8.3720e-07 - learning_rate: 0.1000
# Epoch 11/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5366 - loss: 8.3605e-07 - val_binary_accuracy: 0.5416 - val_loss: 8.3876e-07 - learning_rate: 0.1000
# Epoch 12/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5386 - loss: 8.3577e-07 - val_binary_accuracy: 0.5430 - val_loss: 8.3679e-07 - learning_rate: 0.1000
# Epoch 13/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5372 - loss: 8.3575e-07 - val_binary_accuracy: 0.5434 - val_loss: 8.3704e-07 - learning_rate: 0.1000
# Epoch 14/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5375 - loss: 8.3585e-07 - val_binary_accuracy: 0.5424 - val_loss: 8.3706e-07 - learning_rate: 0.1000
# Epoch 15/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5371 - loss: 8.3575e-07 - val_binary_accuracy: 0.5400 - val_loss: 8.3779e-07 - learning_rate: 0.1000
# Epoch 16/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5382 - loss: 8.3550e-07 - val_binary_accuracy: 0.5431 - val_loss: 8.3764e-07 - learning_rate: 0.1000
# Epoch 17/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5378 - loss: 8.3545e-07 - val_binary_accuracy: 0.5434 - val_loss: 8.3640e-07 - learning_rate: 0.1000
# Epoch 18/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5379 - loss: 8.3553e-07 - val_binary_accuracy: 0.5422 - val_loss: 8.3675e-07 - learning_rate: 0.1000
# Epoch 19/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5378 - loss: 8.3550e-07 - val_binary_accuracy: 0.5398 - val_loss: 8.3728e-07 - learning_rate: 0.1000
# Epoch 20/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5380 - loss: 8.3534e-07 - val_binary_accuracy: 0.5428 - val_loss: 8.3947e-07 - learning_rate: 0.1000
# Epoch 21/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5380 - loss: 8.3532e-07 - val_binary_accuracy: 0.5399 - val_loss: 8.3704e-07 - learning_rate: 0.1000
# Epoch 22/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5377 - loss: 8.3524e-07 - val_binary_accuracy: 0.5423 - val_loss: 8.3657e-07 - learning_rate: 0.1000
# Epoch 23/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5385 - loss: 8.3527e-07 - val_binary_accuracy: 0.5421 - val_loss: 8.3695e-07 - learning_rate: 0.1000
# Epoch 24/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5379 - loss: 8.3518e-07 - val_binary_accuracy: 0.5413 - val_loss: 8.3781e-07 - learning_rate: 0.1000
# Epoch 25/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5377 - loss: 8.3519e-07 - val_binary_accuracy: 0.5409 - val_loss: 8.3778e-07 - learning_rate: 0.1000
# Epoch 26/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5372 - loss: 8.3520e-07 - val_binary_accuracy: 0.5422 - val_loss: 8.3682e-07 - learning_rate: 0.1000
# Epoch 27/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5380 - loss: 8.3516e-07 - val_binary_accuracy: 0.5384 - val_loss: 8.3851e-07 - learning_rate: 0.1000
# Epoch 28/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5380 - loss: 8.3502e-07 - val_binary_accuracy: 0.5409 - val_loss: 8.3705e-07 - learning_rate: 0.1000
# Epoch 29/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5375 - loss: 8.3515e-07 - val_binary_accuracy: 0.5424 - val_loss: 8.3654e-07 - learning_rate: 0.1000
# Epoch 30/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5387 - loss: 8.3506e-07 - val_binary_accuracy: 0.5363 - val_loss: 8.3797e-07 - learning_rate: 0.1000
# Epoch 31/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5373 - loss: 8.3514e-07 - val_binary_accuracy: 0.5424 - val_loss: 8.3642e-07 - learning_rate: 0.1000
# Epoch 32/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5404 - loss: 8.3402e-07 - val_binary_accuracy: 0.5425 - val_loss: 8.3628e-07 - learning_rate: 0.0010
# Epoch 33/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5403 - loss: 8.3396e-07 - val_binary_accuracy: 0.5426 - val_loss: 8.3620e-07 - learning_rate: 0.0010
# Epoch 34/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5403 - loss: 8.3394e-07 - val_binary_accuracy: 0.5420 - val_loss: 8.3629e-07 - learning_rate: 0.0010
# Epoch 35/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5403 - loss: 8.3393e-07 - val_binary_accuracy: 0.5421 - val_loss: 8.3631e-07 - learning_rate: 0.0010
# Epoch 36/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5402 - loss: 8.3392e-07 - val_binary_accuracy: 0.5422 - val_loss: 8.3617e-07 - learning_rate: 0.0010
# Epoch 37/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5403 - loss: 8.3392e-07 - val_binary_accuracy: 0.5422 - val_loss: 8.3619e-07 - learning_rate: 0.0010
# Epoch 38/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5402 - loss: 8.3391e-07 - val_binary_accuracy: 0.5421 - val_loss: 8.3621e-07 - learning_rate: 0.0010
# Epoch 39/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5404 - loss: 8.3391e-07 - val_binary_accuracy: 0.5422 - val_loss: 8.3615e-07 - learning_rate: 0.0010
# Epoch 40/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3391e-07 - val_binary_accuracy: 0.5423 - val_loss: 8.3631e-07 - learning_rate: 0.0010
# Epoch 41/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5403 - loss: 8.3391e-07 - val_binary_accuracy: 0.5423 - val_loss: 8.3622e-07 - learning_rate: 0.0010
# Epoch 42/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5404 - loss: 8.3390e-07 - val_binary_accuracy: 0.5423 - val_loss: 8.3615e-07 - learning_rate: 0.0010
# Epoch 43/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3390e-07 - val_binary_accuracy: 0.5420 - val_loss: 8.3630e-07 - learning_rate: 0.0010
# Epoch 44/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5403 - loss: 8.3390e-07 - val_binary_accuracy: 0.5423 - val_loss: 8.3622e-07 - learning_rate: 0.0010
# Epoch 45/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5404 - loss: 8.3390e-07 - val_binary_accuracy: 0.5422 - val_loss: 8.3631e-07 - learning_rate: 0.0010
# Epoch 46/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5404 - loss: 8.3390e-07 - val_binary_accuracy: 0.5422 - val_loss: 8.3628e-07 - learning_rate: 0.0010
# Epoch 47/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3390e-07 - val_binary_accuracy: 0.5420 - val_loss: 8.3617e-07 - learning_rate: 0.0010
# Epoch 48/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5403 - loss: 8.3389e-07 - val_binary_accuracy: 0.5421 - val_loss: 8.3619e-07 - learning_rate: 0.0010
# Epoch 49/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3389e-07 - val_binary_accuracy: 0.5425 - val_loss: 8.3626e-07 - learning_rate: 0.0010
# Epoch 50/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5403 - loss: 8.3389e-07 - val_binary_accuracy: 0.5422 - val_loss: 8.3622e-07 - learning_rate: 0.0010
# Epoch 51/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3388e-07 - val_binary_accuracy: 0.5425 - val_loss: 8.3615e-07 - learning_rate: 0.0010
# Epoch 52/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3389e-07 - val_binary_accuracy: 0.5421 - val_loss: 8.3623e-07 - learning_rate: 0.0010
# Epoch 53/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3388e-07 - val_binary_accuracy: 0.5421 - val_loss: 8.3620e-07 - learning_rate: 0.0010
# Epoch 54/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3388e-07 - val_binary_accuracy: 0.5422 - val_loss: 8.3619e-07 - learning_rate: 0.0010
# Epoch 55/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5403 - loss: 8.3388e-07 - val_binary_accuracy: 0.5422 - val_loss: 8.3620e-07 - learning_rate: 0.0010
# Epoch 56/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3388e-07 - val_binary_accuracy: 0.5424 - val_loss: 8.3622e-07 - learning_rate: 0.0010
# Epoch 57/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5404 - loss: 8.3387e-07 - val_binary_accuracy: 0.5420 - val_loss: 8.3621e-07 - learning_rate: 0.0010
# Epoch 58/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3387e-07 - val_binary_accuracy: 0.5424 - val_loss: 8.3635e-07 - learning_rate: 0.0010
# Epoch 59/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3387e-07 - val_binary_accuracy: 0.5433 - val_loss: 8.3638e-07 - learning_rate: 0.0010
# Epoch 60/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3388e-07 - val_binary_accuracy: 0.5418 - val_loss: 8.3620e-07 - learning_rate: 0.0010
# Epoch 61/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3387e-07 - val_binary_accuracy: 0.5424 - val_loss: 8.3616e-07 - learning_rate: 0.0010
# Epoch 62/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3385e-07 - val_binary_accuracy: 0.5423 - val_loss: 8.3616e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3385e-07 - val_binary_accuracy: 0.5422 - val_loss: 8.3616e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5423 - val_loss: 8.3616e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5423 - val_loss: 8.3616e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5423 - val_loss: 8.3616e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5423 - val_loss: 8.3617e-07 - learning_rate: 1.0000e-05
# Epoch 68/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5423 - val_loss: 8.3617e-07 - learning_rate: 1.0000e-05
# Epoch 69/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3385e-07 - val_binary_accuracy: 0.5422 - val_loss: 8.3617e-07 - learning_rate: 1.0000e-05
# Epoch 70/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5423 - val_loss: 8.3617e-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5422 - val_loss: 8.3617e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5422 - val_loss: 8.3617e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5422 - val_loss: 8.3617e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3385e-07 - val_binary_accuracy: 0.5422 - val_loss: 8.3618e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3385e-07 - val_binary_accuracy: 0.5422 - val_loss: 8.3618e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3385e-07 - val_binary_accuracy: 0.5422 - val_loss: 8.3618e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3385e-07 - val_binary_accuracy: 0.5420 - val_loss: 8.3618e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3385e-07 - val_binary_accuracy: 0.5420 - val_loss: 8.3618e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3385e-07 - val_binary_accuracy: 0.5420 - val_loss: 8.3618e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3385e-07 - val_binary_accuracy: 0.5420 - val_loss: 8.3618e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3385e-07 - val_binary_accuracy: 0.5420 - val_loss: 8.3618e-07 - learning_rate: 1.0000e-05
# Epoch 82/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3385e-07 - val_binary_accuracy: 0.5420 - val_loss: 8.3618e-07 - learning_rate: 1.0000e-05
# Epoch 83/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5420 - val_loss: 8.3618e-07 - learning_rate: 1.0000e-05
# Epoch 84/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5419 - val_loss: 8.3619e-07 - learning_rate: 1.0000e-05
# Epoch 85/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3385e-07 - val_binary_accuracy: 0.5419 - val_loss: 8.3619e-07 - learning_rate: 1.0000e-05
# Epoch 86/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5419 - val_loss: 8.3619e-07 - learning_rate: 1.0000e-05
# Epoch 87/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3385e-07 - val_binary_accuracy: 0.5419 - val_loss: 8.3619e-07 - learning_rate: 1.0000e-05
# Epoch 88/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3385e-07 - val_binary_accuracy: 0.5419 - val_loss: 8.3619e-07 - learning_rate: 1.0000e-05
# Epoch 89/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5420 - val_loss: 8.3619e-07 - learning_rate: 1.0000e-05
# Epoch 90/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5420 - val_loss: 8.3619e-07 - learning_rate: 1.0000e-05
# Epoch 91/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5419 - val_loss: 8.3619e-07 - learning_rate: 1.0000e-05
# Epoch 92/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5419 - val_loss: 8.3619e-07 - learning_rate: 1.0000e-07
# Epoch 93/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5419 - val_loss: 8.3619e-07 - learning_rate: 1.0000e-07
# Epoch 94/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5419 - val_loss: 8.3619e-07 - learning_rate: 1.0000e-07
# Epoch 95/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5419 - val_loss: 8.3619e-07 - learning_rate: 1.0000e-07
# Epoch 96/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5419 - val_loss: 8.3619e-07 - learning_rate: 1.0000e-07
# Epoch 97/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5419 - val_loss: 8.3619e-07 - learning_rate: 1.0000e-07
# Epoch 98/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5419 - val_loss: 8.3619e-07 - learning_rate: 1.0000e-07
# Epoch 99/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5405 - loss: 8.3385e-07 - val_binary_accuracy: 0.5419 - val_loss: 8.3619e-07 - learning_rate: 1.0000e-07
# Epoch 100/100
# 2146/2146 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - binary_accuracy: 0.5406 - loss: 8.3385e-07 - val_binary_accuracy: 0.5419 - val_loss: 8.3619e-07 - learning_rate: 1.0000e-07
# Finished Training
# 2025-09-01 14:52:55.689579: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-09-01 14:52:55.696156: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79193 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:bf:00.0, compute capability: 8.0
# 2025-09-01 14:52:55.864424: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79193 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:bf:00.0, compute capability: 8.0
# 2025-09-01 14:52:55.880424: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-09-01 14:52:55.887957: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79193 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:bf:00.0, compute capability: 8.0
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# The sum of PDFs in ensemble member 0 is 1.0001161587719254
#
#
# The sum of PDFs using the whole ensemble is 1.0001161587719254
#
#
#
# starting ensemble training
# Sum of weights of class 0: 0.7506399207412349
# Sum of weights of class 1: 0.7500003637369446
# Using swish activation function
# /home/jsandesara_umass_edu/NSBI-workflow-tutorial/.pixi/envs/nsbi-env-gpu/lib/python3.11/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │         9,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,013,001 (11.49 MB)
#  Trainable params: 3,013,001 (11.49 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 15s 5ms/step - binary_accuracy: 0.8689 - loss: 3.3854e-07 - val_binary_accuracy: 0.8744 - val_loss: 3.2203e-07 - learning_rate: 0.1000
# Epoch 2/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8759 - loss: 3.1911e-07 - val_binary_accuracy: 0.8762 - val_loss: 3.1714e-07 - learning_rate: 0.1000
# Epoch 3/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8786 - loss: 3.1032e-07 - val_binary_accuracy: 0.8788 - val_loss: 3.0829e-07 - learning_rate: 0.1000
# Epoch 4/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8800 - loss: 3.0705e-07 - val_binary_accuracy: 0.8798 - val_loss: 3.0666e-07 - learning_rate: 0.1000
# Epoch 5/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8813 - loss: 3.0467e-07 - val_binary_accuracy: 0.8807 - val_loss: 3.0377e-07 - learning_rate: 0.1000
# Epoch 6/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8818 - loss: 3.0280e-07 - val_binary_accuracy: 0.8827 - val_loss: 3.0322e-07 - learning_rate: 0.1000
# Epoch 7/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8825 - loss: 3.0134e-07 - val_binary_accuracy: 0.8825 - val_loss: 3.0184e-07 - learning_rate: 0.1000
# Epoch 8/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8833 - loss: 2.9985e-07 - val_binary_accuracy: 0.8837 - val_loss: 2.9937e-07 - learning_rate: 0.1000
# Epoch 9/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8837 - loss: 2.9849e-07 - val_binary_accuracy: 0.8832 - val_loss: 2.9923e-07 - learning_rate: 0.1000
# Epoch 10/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8842 - loss: 2.9737e-07 - val_binary_accuracy: 0.8847 - val_loss: 2.9701e-07 - learning_rate: 0.1000
# Epoch 11/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8845 - loss: 2.9640e-07 - val_binary_accuracy: 0.8840 - val_loss: 2.9827e-07 - learning_rate: 0.1000
# Epoch 12/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8848 - loss: 2.9537e-07 - val_binary_accuracy: 0.8833 - val_loss: 2.9647e-07 - learning_rate: 0.1000
# Epoch 13/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8853 - loss: 2.9466e-07 - val_binary_accuracy: 0.8849 - val_loss: 2.9487e-07 - learning_rate: 0.1000
# Epoch 14/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8857 - loss: 2.9397e-07 - val_binary_accuracy: 0.8856 - val_loss: 2.9365e-07 - learning_rate: 0.1000
# Epoch 15/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8858 - loss: 2.9346e-07 - val_binary_accuracy: 0.8862 - val_loss: 2.9211e-07 - learning_rate: 0.1000
# Epoch 16/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8861 - loss: 2.9274e-07 - val_binary_accuracy: 0.8840 - val_loss: 2.9551e-07 - learning_rate: 0.1000
# Epoch 17/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8861 - loss: 2.9229e-07 - val_binary_accuracy: 0.8854 - val_loss: 2.9380e-07 - learning_rate: 0.1000
# Epoch 18/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8864 - loss: 2.9173e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9099e-07 - learning_rate: 0.1000
# Epoch 19/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8866 - loss: 2.9140e-07 - val_binary_accuracy: 0.8868 - val_loss: 2.9129e-07 - learning_rate: 0.1000
# Epoch 20/100
# ...
# Epoch 21/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8873 - loss: 2.9047e-07 - val_binary_accuracy: 0.8855 - val_loss: 2.9546e-07 - learning_rate: 0.1000
# Epoch 22/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8870 - loss: 2.8995e-07 - val_binary_accuracy: 0.8872 - val_loss: 2.9037e-07 - learning_rate: 0.1000
# Epoch 23/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8871 - loss: 2.8957e-07 - val_binary_accuracy: 0.8871 - val_loss: 2.9095e-07 - learning_rate: 0.1000
# Epoch 24/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8873 - loss: 2.8928e-07 - val_binary_accuracy: 0.8883 - val_loss: 2.9071e-07 - learning_rate: 0.1000
# Epoch 25/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8876 - loss: 2.8898e-07 - val_binary_accuracy: 0.8848 - val_loss: 2.9442e-07 - learning_rate: 0.1000
# Epoch 26/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8878 - loss: 2.8863e-07 - val_binary_accuracy: 0.8874 - val_loss: 2.9027e-07 - learning_rate: 0.1000
# Epoch 27/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8882 - loss: 2.8814e-07 - val_binary_accuracy: 0.8872 - val_loss: 2.8876e-07 - learning_rate: 0.1000
# Epoch 28/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8879 - loss: 2.8790e-07 - val_binary_accuracy: 0.8881 - val_loss: 2.8923e-07 - learning_rate: 0.1000
# Epoch 29/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8882 - loss: 2.8754e-07 - val_binary_accuracy: 0.8879 - val_loss: 2.8816e-07 - learning_rate: 0.1000
# Epoch 30/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8883 - loss: 2.8724e-07 - val_binary_accuracy: 0.8885 - val_loss: 2.8852e-07 - learning_rate: 0.1000
# Epoch 31/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8886 - loss: 2.8693e-07 - val_binary_accuracy: 0.8879 - val_loss: 2.8937e-07 - learning_rate: 0.1000
# Epoch 32/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8897 - loss: 2.8383e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8560e-07 - learning_rate: 0.0010
# Epoch 33/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8901 - loss: 2.8273e-07 - val_binary_accuracy: 0.8892 - val_loss: 2.8528e-07 - learning_rate: 0.0010
# Epoch 34/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8902 - loss: 2.8249e-07 - val_binary_accuracy: 0.8891 - val_loss: 2.8504e-07 - learning_rate: 0.0010
# Epoch 35/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8900 - loss: 2.8237e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8494e-07 - learning_rate: 0.0010
# Epoch 36/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8902 - loss: 2.8228e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8489e-07 - learning_rate: 0.0010
# Epoch 37/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8901 - loss: 2.8221e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8484e-07 - learning_rate: 0.0010
# Epoch 38/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8903 - loss: 2.8216e-07 - val_binary_accuracy: 0.8897 - val_loss: 2.8481e-07 - learning_rate: 0.0010
# Epoch 39/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8902 - loss: 2.8212e-07 - val_binary_accuracy: 0.8896 - val_loss: 2.8479e-07 - learning_rate: 0.0010
# Epoch 40/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8903 - loss: 2.8209e-07 - val_binary_accuracy: 0.8894 - val_loss: 2.8474e-07 - learning_rate: 0.0010
# Epoch 41/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8903 - loss: 2.8205e-07 - val_binary_accuracy: 0.8896 - val_loss: 2.8477e-07 - learning_rate: 0.0010
# Epoch 42/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8903 - loss: 2.8201e-07 - val_binary_accuracy: 0.8896 - val_loss: 2.8473e-07 - learning_rate: 0.0010
# Epoch 43/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8902 - loss: 2.8199e-07 - val_binary_accuracy: 0.8895 - val_loss: 2.8470e-07 - learning_rate: 0.0010
# Epoch 44/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8903 - loss: 2.8196e-07 - val_binary_accuracy: 0.8897 - val_loss: 2.8472e-07 - learning_rate: 0.0010
# Epoch 45/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8903 - loss: 2.8195e-07 - val_binary_accuracy: 0.8897 - val_loss: 2.8464e-07 - learning_rate: 0.0010
# Epoch 46/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8903 - loss: 2.8192e-07 - val_binary_accuracy: 0.8897 - val_loss: 2.8469e-07 - learning_rate: 0.0010
# Epoch 47/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8904 - loss: 2.8189e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8466e-07 - learning_rate: 0.0010
# Epoch 48/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8188e-07 - val_binary_accuracy: 0.8896 - val_loss: 2.8465e-07 - learning_rate: 0.0010
# Epoch 49/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8903 - loss: 2.8186e-07 - val_binary_accuracy: 0.8896 - val_loss: 2.8461e-07 - learning_rate: 0.0010
# Epoch 50/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8904 - loss: 2.8184e-07 - val_binary_accuracy: 0.8897 - val_loss: 2.8462e-07 - learning_rate: 0.0010
# Epoch 51/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8903 - loss: 2.8183e-07 - val_binary_accuracy: 0.8896 - val_loss: 2.8465e-07 - learning_rate: 0.0010
# Epoch 52/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8904 - loss: 2.8181e-07 - val_binary_accuracy: 0.8899 - val_loss: 2.8460e-07 - learning_rate: 0.0010
# Epoch 53/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8903 - loss: 2.8180e-07 - val_binary_accuracy: 0.8900 - val_loss: 2.8457e-07 - learning_rate: 0.0010
# Epoch 54/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8178e-07 - val_binary_accuracy: 0.8897 - val_loss: 2.8456e-07 - learning_rate: 0.0010
# Epoch 55/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8904 - loss: 2.8177e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8454e-07 - learning_rate: 0.0010
# Epoch 56/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8175e-07 - val_binary_accuracy: 0.8897 - val_loss: 2.8451e-07 - learning_rate: 0.0010
# Epoch 57/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8904 - loss: 2.8172e-07 - val_binary_accuracy: 0.8900 - val_loss: 2.8449e-07 - learning_rate: 0.0010
# Epoch 58/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8172e-07 - val_binary_accuracy: 0.8899 - val_loss: 2.8449e-07 - learning_rate: 0.0010
# Epoch 59/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8170e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8455e-07 - learning_rate: 0.0010
# Epoch 60/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8169e-07 - val_binary_accuracy: 0.8899 - val_loss: 2.8449e-07 - learning_rate: 0.0010
# Epoch 61/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8904 - loss: 2.8168e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8450e-07 - learning_rate: 0.0010
# Epoch 62/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8162e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8450e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8161e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8449e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8161e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8449e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8161e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8449e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8161e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8448e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8160e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8448e-07 - learning_rate: 1.0000e-05
# Epoch 68/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8160e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8448e-07 - learning_rate: 1.0000e-05
# Epoch 69/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8160e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8448e-07 - learning_rate: 1.0000e-05
# Epoch 70/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8160e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8448e-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8160e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8448e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8160e-07 - val_binary_accuracy: 0.8899 - val_loss: 2.8447e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8160e-07 - val_binary_accuracy: 0.8899 - val_loss: 2.8447e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8159e-07 - val_binary_accuracy: 0.8899 - val_loss: 2.8447e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8447e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8159e-07 - val_binary_accuracy: 0.8899 - val_loss: 2.8447e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8159e-07 - val_binary_accuracy: 0.8899 - val_loss: 2.8447e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8447e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8447e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8447e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8447e-07 - learning_rate: 1.0000e-05
# Epoch 82/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8447e-07 - learning_rate: 1.0000e-05
# Epoch 83/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8446e-07 - learning_rate: 1.0000e-05
# Epoch 84/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8446e-07 - learning_rate: 1.0000e-05
# Epoch 85/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8446e-07 - learning_rate: 1.0000e-05
# Epoch 86/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8446e-07 - learning_rate: 1.0000e-05
# Epoch 87/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8446e-07 - learning_rate: 1.0000e-05
# Epoch 88/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8446e-07 - learning_rate: 1.0000e-05
# Epoch 89/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8446e-07 - learning_rate: 1.0000e-05
# Epoch 90/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8446e-07 - learning_rate: 1.0000e-05
# Epoch 91/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8905 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8446e-07 - learning_rate: 1.0000e-05
# Epoch 92/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8906 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8446e-07 - learning_rate: 1.0000e-07
# Epoch 93/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8906 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8446e-07 - learning_rate: 1.0000e-07
# Epoch 94/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8906 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8446e-07 - learning_rate: 1.0000e-07
# Epoch 95/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8906 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8446e-07 - learning_rate: 1.0000e-07
# Epoch 96/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8906 - loss: 2.8158e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8446e-07 - learning_rate: 1.0000e-07
# Epoch 97/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8906 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8446e-07 - learning_rate: 1.0000e-07
# Epoch 98/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8906 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8446e-07 - learning_rate: 1.0000e-07
# Epoch 99/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - binary_accuracy: 0.8906 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8446e-07 - learning_rate: 1.0000e-07
# Epoch 100/100
# 2563/2563 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - binary_accuracy: 0.8906 - loss: 2.8159e-07 - val_binary_accuracy: 0.8898 - val_loss: 2.8446e-07 - learning_rate: 1.0000e-07
# Finished Training
# 2025-09-01 15:10:37.547919: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-09-01 15:10:37.556491: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79193 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:bf:00.0, compute capability: 8.0
# 2025-09-01 15:10:37.745033: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79193 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:bf:00.0, compute capability: 8.0
# 2025-09-01 15:10:37.761893: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2025-09-01 15:10:37.768497: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 79193 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-80GB, pci bus id: 0000:bf:00.0, compute capability: 8.0
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# The sum of PDFs in ensemble member 0 is 1.0054836281833424
#
#
# The sum of PDFs using the whole ensemble is 1.0054836281833424

# %% [markdown]
# Check for overtraining by comparing the NN output distributions between training and holdout datasets. The holdout dataset is the subset of events not used during training.

# %%
for process_type in basis_processes:
    NN_training_mix_model[process_type].make_overfit_plots()

# %% [markdown]
# Diagnostic Checks
# ===
#
# While traditionally, a NN observable is judged on the basis of its accuracy - for NSBI we are interested in the quality of the density ratios more than the discrimination power. The latter comes from the perfect modelling of the multi-dimensional likelihood ratios.
#
# To ensure correct modelling, we run two main checks on the training:
#
# - **Calibration closure test**
#
#   The NNs are trained using the binary cross-entropy loss, which under ideal conditions leads to the NN converging to the score function:
#
#   $$\hat{s}_\text{pred} = \frac{p_\text{ref}(x)}{p_\text{ref}(x)+p_\text{c}(x)}$$
#
#   that can be converted into the probability ratio we desire (likelihood ratio trick):
#
#   $$\frac{p_\text{c}(x)}{p_\text{ref}(x)} = \frac{\hat{s}_\text{pred}(x)}{1-\hat{s}_\text{pred}(x)}$$
#
#   For the NNs to be well-calibrated, we use the Monte Carlo samples to verify the equality:
#
#
#   $$\left[\frac{p_c(x)}{p_c(x)+p_{ref}(x)}\right]_\text{NN} \sim \left[\frac{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}}{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}+\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}}\right]_\text{MC}$$
#
#   where we bin the events from $p_c$ and $p_\text{ref}$ MC samples, denoted by $\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}$ and $\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}$ respectively where $I(x|\hat{s}_\text{pred})$ returns the index of the $\hat{s}_\text{pred}$ bin in which an event $x$ falls.

# %%
num_bins_cal = 50

for process_type in basis_processes:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='score')

# %% [markdown]
# ## Density ratio reweighting closure tests
#
#   Despite having a well-calibrated output and thus a robust probabilistic interpretation, the trained density ratios might not capture the full multi-dimensional event information $x$. In other words, the NNs might still be biased estimators of the optimal score function, as defined in the CARL paper (link).
#
#   The next diagnostic involves verifying the following equality using 1D projections of $x$:
#
#   $$\frac{p_c(x)}{p_{ref}(x)} \times p_{ref}(x) \sim p_c(x)$$
#
#   We can do this one-by-one for all the observables used to model the density ratios, and also possibly the observables not used directly in the training but can still be well-estimated due to the NN learning the right physics.

# %%
variables_to_plot=['log_DER_pt_h'] # The 1D variable for reweighting closure
yscale_type='log'
num_bins_plotting=21

for process_type in basis_processes:

    NN_training_mix_model[process_type].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
path_to_saved_ratios = {}

for process_type in basis_processes:
    # Evaluate the density ratios p_c/p_ref for the full dataset and save for the inference step
    path_to_saved_ratios[process_type] = NN_training_mix_model[process_type].evaluate_and_save_ratios(dataset, 
                                                                                                     aggregation_type = 'median_score')

# %%
for i, channel_dict in enumerate(config["Regions"]):
    
    if channel_dict.get("Name") == "SR":

        config["Regions"][i]["TrainedModels"] = []

        for process_type in basis_processes:
        
            config["Regions"][i]["TrainedModels"].append(
                {
                    "Name"     : process_type,
                    "Models"   : path_to_models[process_type],
                    "Ratios"   : path_to_saved_ratios[process_type]
                }
            )

# %% [markdown]
# Systematic Uncertainty Modelling
# ===
#
# So far we have left out the nuisance parameter piece of the parameterized density ratio decomposition shown before:
#
# $$g_c(x|\alpha) = \frac{p_c(x|\alpha)}{p_c(x)}$$
#
# which will be estimated in the `Systematic_Uncertainty_Estimation.ipynb` notebook.

# %% [markdown]
# Training an Ensemble of NNs
# ===
#
# In a realistic analysis, a large ensemble of NNs are trained to estimate density ratios, for *each* of the channels. **This reduces not only the variance but has also been found to reduce biases in the final fits.**
#
# In the off-shell Higgs boson analysis, we used k-fold cross-validation, with k=10, to train an ensemble $N_{ens}\sim 250$ of NNs per density ratio $p_c(x)/p_{ref}(x)$. The density ratios used in the final fit are always evaluated on the holdout dataset and by using each of the folds as holdout once, the entire model for $p_c(x)/p_{ref}(x)$ consists of $N_{ens}\times k \sim 2500$ NNs. Each NN in the ensemble is trained by resampling data without replacement from the k-1 folds used for training.
