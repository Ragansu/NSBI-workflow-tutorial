# %% [markdown]
# Train Neural Networks to estimate Likelihood Ratios
# ===
#
# In this notebook we will setup the neural networks that train unbiased and low-variance density ratios to be then used for inference. The statistical model we have is:
#
# $$p(x|\mu, \alpha) = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot p_c\left(x|\alpha\right)$$
#
# where $c$ stands for the various physics channels that contribute to the final state $x$, $\mu$ is the signal-strength parameter and $\alpha$ is the vector of nuisance parameters associated with the various systematic uncertainties in the model. Note that we are assuming that the parameter $\mu$-dependence is known analytically and that we have simulation models for each of the channels $p_c(x)$.
#
# The objective is to build the test statistic for composite hypothesis testing:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})}{p(x_i|\hat{\mu}, \hat{\alpha})} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
# A direct approach would then be to model the probability density $p(x|\mu, \alpha)$ using NNs. But that is a more difficult task than training probability density ratios. We use a simple trick:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})/p_{ref}(x)}{p(x_i|\hat{\mu}, \hat{\alpha})/p_{ref}(x)} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
#
# to turn this into a density ratio estimation problem:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot \frac{p_c\left(x|\alpha\right)}{p_{ref}(x)}$$
#
# Factorizing out the $\alpha$-dependence in the density ratios:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\sum_c G_c(\alpha) \cdot f_c(\mu) \cdot \nu_c} \sum_c f_c(\mu) \cdot G_c(\alpha)\cdot \nu_c \cdot g_c(x|\alpha) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}$$
#
# **Factorized approach:**
#
# Instead of training NNs parameterized on $\mu$ and $\alpha$, we use analytical parameterizations to simplify the problem to training only parameter-independent density ratios.
#
# Let's set this up for the toy ttbar model we are using. Neglecting the nuisance parameter dependence for now,
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}\right] = \mu \cdot \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)} + \frac{p_{t\bar{t}}\left(x\right)}{p_{ref}(x)} + \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)}$$

# %%
import os, sys, importlib
sys.path.append('../')

import nsbi_common_utils
from nsbi_common_utils import plotting, training
from nsbi_common_utils.training import TrainEvaluate_NN, TrainEvaluatePreselNN
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt
import pickle

from coffea.analysis_tools import PackedSelection

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

hep.style.use(hep.style.ATLAS)
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/src/nsbi_common_utils/plotting.py:10: FutureWarning: ``set_style`` is deprecated: Naming convention is changing to match mpl. Use ``mplhep.style.use()``.
#   hep.set_style("ATLAS")
# 2025-06-03 19:23:47.105996: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748978627.118990     122 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748978627.122966     122 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-03 19:23:47.137593: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# If the preselection NN has already been trained and saved, load from the saved model
USE_SAVED_MODEL_PRESEL=True
# If the preselection NN has already been trained and evaluated, load the numpy array of predictions
USE_SAVED_PRESEL_PREDICTIONS=True

path_prefix = '/home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/'

# Path for saving interemdiate objects, like NN predictions
saved_data = f'{path_prefix}cached_data/'

# Path for saving/loading preselection NN model
path_to_saved_presel_model = f'{path_prefix}preselection_saved_NN/'

# %%
# Load the nominal dataset saved from the pre-processing notebook
dataset_incl_nominal = pd.read_hdf(f"{saved_data}df_nominal.h5", key="dataset", mode='r')

# Load the MC/data weights and training labels identifying different processes
weights = dataset_incl_nominal.weights.to_numpy()
train_labels = dataset_incl_nominal.train_labels.to_numpy()

# %%
# Get the dictionary of labels to processes
labels_dict = np.load(f"{saved_data}labels_dictionary.npy", allow_pickle=True).item()

# %%
# Normalizing the training weights - only discriminating shapes, not norms
weights_normed = weights.copy()

for key in labels_dict:

    weights_normed[train_labels==labels_dict[key]] /= weights[train_labels==labels_dict[key]].sum()

dataset_incl_nominal['weights_normed'] = weights_normed

# %% [markdown]
# Training the Preselection NN
# ===

# %% [markdown]
# **Choice of reference sample**
#
# The density ratios need to be trained on phase space regions with support for the reference hypothesis $p_{ref}(x) > 0$.
#
# To ensure this, we make a selection that selects events in the phase space regions with $p_{ref}(x) > 0$, or $p_c(x) \gg p_{ref}(x)$, and only perform the NSBI fit in this selected analysis region. **A natural choice for the reference hypothesis is then the signal-rich hypotheses**. This is referred to in the ATLAS publications as the Search-Oriented Mixture Models approach:
#
# $$p_{ref}(x) = \frac{1}{\sum_S \nu_S} \sum_S \frac{d\sigma_S}{dx} = \frac{1}{\nu_{H \to \tau\tau}} \frac{d\sigma_{H \to \tau\tau}}{dx}$$
#
# where the sum runs over all signal hypothesis in the model and the second equality is due to the sole signal hypothesis in our toy model, $pp \to {t\bar{t}}$.
#
# **Selecting out regions with $p_{ref}\sim 0$**
#
# A multi-class classification NN, with softmax output, is trained to output a score:
#
# $$ \text{NN}_\text{presel} = \log \left[\frac{\sum_S P_S (x)}{\sum_B P_B(x)} \right]$$
#
# where $P_c$ are the probability scores outputted from the softmax layer of the trained NN.

# %%
dataset_incl_nominal.columns.unique()
# Out:
# Index(['PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi',
#        'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi', 'PRI_jet_all_pt',
#        'PRI_n_jets', 'weights', 'detailed_labels', 'type', 'train_labels',
#        'weights_normed'],
#       dtype='object')

# %%
# Features to use for training NNs
columns = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi']
columns_scaling = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi']

columns = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi', 'PRI_jet_all_pt', 'PRI_n_jets']
columns_scaling = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi', 'PRI_jet_all_pt']

np.save(f"{saved_data}columns.npy", columns)
np.save(f"{saved_data}columns_scaling.npy", columns_scaling)

# %%
print(labels_dict)
# Out:
# {'htautau': 0, 'ztautau': 1, 'ttbar': 2}

# %%
signal_processes = ["htautau"]
background_processes = ["ttbar", "ztautau"]
# background_processes = ["ttbar", "ztautau", "diboson"]

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import TrainEvaluatePreselNN

num_classes = len(labels_dict)

preselectionTraining = TrainEvaluatePreselNN(dataset_incl_nominal, num_classes, columns, columns_scaling)

# %%
if USE_SAVED_PRESEL_PREDICTIONS:
    presel_score = np.load(f"{saved_data}presel_score.npy")


else:
    if not USE_SAVED_MODEL_PRESEL:
        preselectionTraining.train(test_size=0.25, 
                                   random_state=42, 
                                   path_to_save=path_to_saved_presel_model,
                                  batch_size=4096,
                                  epochs=50)
    
    else:
        preselectionTraining.get_trained_model(path_to_saved_presel_model)

    # Get predictions (softmax outputs)
    pred_NN_incl = preselectionTraining.predict(dataset_incl_nominal)

# %%
if not USE_SAVED_PRESEL_PREDICTIONS:

    signal_sum = np.sum(
        [pred_NN_incl[:, labels_dict[signal]] for signal in signal_processes], axis=0
    )

    background_sum = np.sum(
        [pred_NN_incl[:, labels_dict[background]] for background in background_processes], axis=0
    )
    # the preselection score as defined above - log(P_S/P_B)
    presel_score = np.log(signal_sum/background_sum)
    # presel_score = (signal_sum/background_sum)
    np.save(f"{saved_data}presel_score.npy", presel_score)

    del pred_NN_incl

# %%
min_pred = np.amin(presel_score)
max_pred = np.amax(presel_score)

bins = np.linspace(min_pred, max_pred, num=50)

hist_NN_output = {}
hist_NN_output_errs = {}

for key in labels_dict: 
    hist_NN_output[key], _ = np.histogram(presel_score[train_labels==labels_dict[key]], 
                                          weights = weights[train_labels==labels_dict[key]], bins=bins)
    
    hist_NN_output_errs[key], _ = np.histogram(presel_score[train_labels==labels_dict[key]], 
                                          weights = weights[train_labels==labels_dict[key]]**2, bins=bins)


for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins=bins, 
             alpha=0.6, label=key, 
             density=True, linewidth=2.0, yerr = np.sqrt(hist_NN_output_errs[key]))

plt.xlabel("Preselection Score", size=18)
plt.ylabel("Density", size=18)
plt.legend()
plt.yscale('log')
plt.show()

# %% [markdown]
# Making the cut
# ===
#
# Make a selection cut for regions with $p_{ref} \gg 0$ for performing the NSBI analysis. The remaining events - which by definition are background-dominated - can be used as a **Control Region** for data-driven background estimation, pre-unblinding validations, etc.
#
# Moreover, the preselections act as a tuning know for the tradeoff in selecting as many signal events as possible to go into the **Signal Region** (increasing sensitivity) and the feasibility of training accurate and precise NNs over a large phase space (need bigger models and more statistics). **The preselections can also weed out phase space regions with low background statistics to avoid poorly modelled regions.**
#
# Heres a first cut that you can optimize as much as you like to get the desired final results.

# %%
# Play around with these selections - decrease if estimators are unbiased but need more sensitivity and increase if the model is biased to reduce complexity
preselection_cuts = {'upper': 4, 'lower': 0.0}
np.save(f"{saved_data}preselection_cuts.npy", preselection_cuts)


for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins = bins, 
             alpha = 0.6, label = key, 
             density = True, linewidth = 2.0, 
                 yerr = np.sqrt(hist_NN_output_errs[key]))

plt.xlabel("Preselection Score", size=18)

for key in preselection_cuts:
    if preselection_cuts[key] != -999:
        plt.axvline(preselection_cuts[key], ymax=0.9, linestyle='--', label=f'preselection cut {key} = {preselection_cuts[key]}')

plt.ylabel("Density", size=18)
plt.legend(loc='upper left')
plt.yscale('log')
plt.show()

# %% [markdown]
# Signal and Control Regions
# ===
#
# The high signal over background phase space towards the right of the preselection cut shown above will be categorized as the **Signal Region** where the NSBI analysis is performed.
#
# The low signal phase space towards the left will be used as a **Control Region**, with typical uses such as background estimation, pre-unblinding data-MC checks, etc. In this phase space, we will use a binned summary observable like in any traditional analysis.

# %%
dataset_incl_nominal['presel_score'] = presel_score

lower_cut = preselection_cuts.get('lower')
upper_cut = preselection_cuts.get('upper')

masks = {
    'SR': pd.Series(True, index=dataset_incl_nominal.index),
    'CR': pd.Series(False, index=dataset_incl_nominal.index)
}

# CASE A: both lower and upper exist (and are “active”, i.e. not -999)
if (lower_cut != -999) and (upper_cut != -999):
    masks['SR'] = (
        (dataset_incl_nominal.presel_score >= lower_cut) &
        (dataset_incl_nominal.presel_score <= upper_cut)
    )
    masks['CR'] = ~masks['SR']  

# CASE B: only a lower‐side cut is active
elif (lower_cut != -999):
    masks['SR'] = (dataset_incl_nominal.presel_score >= lower_cut)
    masks['CR'] = (dataset_incl_nominal.presel_score <  lower_cut)

# CASE C: only an upper‐side cut is active
elif (upper_cut != -999):
    masks['SR'] = (dataset_incl_nominal.presel_score <= upper_cut)
    masks['CR'] = (dataset_incl_nominal.presel_score >  upper_cut)


dataset   = dataset_incl_nominal[masks['SR']].copy()
dataset_CR = dataset_incl_nominal[masks['CR']].copy()

del dataset_incl_nominal

# %%
# Build a summary observable for Control Region
hist_CR = {}
num_bins = 10

CR_observable='PRI_lep_pt'

kin_variable = dataset_CR[CR_observable].to_numpy()

min_kin = np.amin(kin_variable)
max_kin = np.amax(kin_variable)
max_kin = 80.0

bins = np.linspace(min_kin, max_kin, num=num_bins)

# Use the high-level preselection NN score as a summary observable for Control Region
for channel_ in labels_dict:
    dataset_CR_process = dataset_CR[dataset_CR.detailed_labels==channel_]
    hist_CR[channel_], bins = np.histogram(dataset_CR_process[CR_observable].ravel(), 
                                  weights = dataset_CR_process['weights'].ravel(),
                                  bins = bins)

# Save the Control Region observable
with open(f"{saved_data}hist_CR_ttbar.pkl", "wb") as fp:
    pickle.dump(hist_CR, fp)

np.save(f"{saved_data}CRbins.npy", bins)

del dataset_CR

# %%
# Plot the Control Region observable

for channel_ in labels_dict:
    hep.histplot(hist_CR[channel_], bins=bins, label=channel_, density=1, linewidth=2.0)

plt.legend()
plt.xlabel('Control Region Observable')
# plt.yscale('log')
plt.ylabel('Density')
# Out:
# Text(0, 1, 'Density')

# %%
# Save the preselected Nominal dataframe for inference use later on
dataset.to_hdf(f"{saved_data}dataset_preselected_nominal_SR.h5", key="dataset", mode='w')

# %%
top_path = f'{path_prefix}output_training_nominal/'

# %% [markdown]
# Density ratio training
# ===
#
# Now we train the NNs for $\frac{p_c}{p_{ref}}(x)$ density ratios to build the full model. Our choice of reference hypothesis, motivated by the search-oriented mixture model described above, is:
#
# $$p_{ref}(x) = p_\text{higgs}(x) = \frac{1}{\nu_{H \to \tau\tau}} \frac{d\sigma_{H \to \tau\tau}}{dx} $$
#
# gives the POI $\mu-$parameterized model:
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} \right]= \mu + \frac{p_{t\bar{t}}\left(x\right)}{p_{H \to \tau\tau}(x)} + \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{H \to \tau\tau}(x)}$$
#
# The task of estimating the $\mu-$parameterized density ratio is thus reduced to estimating two $\mu-$independent density ratios $\frac{p_\text{single top}}{p_{t\bar{t}}}(x)$ and $\frac{p_\text{wjets}}{p_{t\bar{t}}}(x)$ mixed together with an analytical parameterization (hence the name mixture model).

# %%
 dataset['type'] =  dataset['detailed_labels'].to_numpy()

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import TrainEvaluate_NN

mix_model_hypotheses = signal_processes + background_processes
mix_model_hypotheses = background_processes
ref_processes = signal_processes

np.save(f"{saved_data}mix_model_hypotheses.npy", mix_model_hypotheses)
np.save(f"{saved_data}ref_processes.npy", ref_processes)

mask_ref = np.isin(dataset.detailed_labels, ref_processes)

NN_training_mix_model = {}

rnd_seed_traintestsplit = 42 # can also be randomized, fixed for now

for process_type in mix_model_hypotheses:
    
    mask_process = dataset['type']==process_type
    
    dataset_num = dataset[mask_process].copy()
    dataset_ref = dataset[mask_ref].copy()

    dataset_num['train_labels'] = 1
    dataset_ref['train_labels'] = 0

    dataset_num['weights_normed'] = dataset_num['weights'].to_numpy() / dataset_num['weights'].sum()
    dataset_ref['weights_normed'] = dataset_ref['weights'].to_numpy() / dataset_ref['weights'].sum()

    # Build a training dataset for the training of p_<process_type>/p_<ref_processes> density ratio
    dataset_mix_model = pd.concat([dataset_num, dataset_ref])

    del dataset_num, dataset_ref

    # Save paths
    output_name = f'{process_type}'
    output_dir = f'{top_path}general_output_{process_type}'
    path_to_ratios = f'{top_path}output_ratios_{process_type}/'
    path_to_figures = f'{top_path}output_figures_{process_type}/'
    path_to_models = f'{top_path}output_model_params_{process_type}/'

    NN_training_mix_model[process_type] = TrainEvaluate_NN(dataset_mix_model, 
                                                           dataset_mix_model['weights_normed'],
                                                           dataset_mix_model['train_labels'],
                                                           columns, 
                                                           columns_scaling, rnd_seed_traintestsplit,
                                                           [process_type, 'ref'], output_dir, output_name, 
                                                            path_to_figures=path_to_figures,
                                                            path_to_ratios=path_to_ratios, 
                                                            path_to_models=path_to_models)


    del dataset_mix_model

# %% [markdown]
# Neural Network architecture
# ===
#
# Here we will start with a multi-layer perceptron (simple feed-forward Neural Network with fully-connected layers). This can be supplemented with more complex architectures like transformers.
#
# After detailed tuning during the off-shell Higgs boson analysis effort, we found that a network with very wide layers ($\geq 1000$) and a depth of less than 10 works best - alongside batch size of a few hundreds and a gradually declining learning rate that starts with a value just large enough to not blow up.

# %% [markdown]
# Starting with the training and validation of the various density ratio:
#
# $$\frac{p_{t\bar{t}}(x)}{p_\text{ref}(x)}, \frac{p_{Z \to \tau\tau}(x)}{p_\text{ref}(x)}$$

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 1

# %%
mix_model_hypotheses
# Out:
# ['ttbar', 'ztautau']

# %%
# Define unique settings for each process type

training_settings = {
    'ttbar': {
        'hidden_layers':        2,
        'neurons':              1000,
        'number_of_epochs':     100,
        'batch_size':           512,
        'learning_rate':        0.1,
        'scalerType':           'StandardScaler',
        'calibration':          False,
        'num_bins_cal':         100,
        'callback':             True,
        'callback_patience':    30,
        'callback_factor':      0.01,
        'verbose':              2
    },
    
    'ztautau': {
        'hidden_layers':        2,
        'neurons':              1000,
        'number_of_epochs':     100,
        'batch_size':           512,
        'learning_rate':        1.0,
        'scalerType':           'StandardScaler',
        'calibration':          False,
        'num_bins_cal':         100,
        'callback':             True,
        'callback_patience':    30,
        'callback_factor':      0.01,
        'verbose':              2
    }
}

# %%
# Train the density ratio NN
for process_type in mix_model_hypotheses:
    
    settings = training_settings[process_type]

    NN_training_mix_model[process_type].train(**settings)
    NN_training_mix_model[process_type].test_normalization()
# Out:
# Sum of weights of class 0: 0.7000011205673218
# Sum of weights of class 1: 0.7000294923782349
# Using swish activation function
# /home/jaySandesara/.conda/envs/NSBI/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 1000)           │        11,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,013,001 (3.86 MB)
#  Trainable params: 1,013,001 (3.86 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# 2025-06
-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7673 - loss: 5.5227e-07 - val_binary_accuracy: 0.7568 - val_loss: 5.9733e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7672 - loss: 5.5227e-07 - val_binary_accuracy: 0.7567 - val_loss: 5.9732e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7671 - loss: 5.5226e-07 - val_binary_accuracy: 0.7572 - val_loss: 5.9732e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7672 - loss: 5.5226e-07 - val_binary_accuracy: 0.7572 - val_loss: 5.9731e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7671 - loss: 5.5225e-07 - val_binary_accuracy: 0.7572 - val_loss: 5.9730e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7671 - loss: 5.5225e-07 - val_binary_accuracy: 0.7571 - val_loss: 5.9730e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7671 - loss: 5.5224e-07 - val_binary_accuracy: 0.7571 - val_loss: 5.9730e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7670 - loss: 5.5224e-07 - val_binary_accuracy: 0.7571 - val_loss: 5.9729e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7671 - loss: 5.5224e-07 - val_binary_accuracy: 0.7571 - val_loss: 5.9729e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7671 - loss: 5.5223e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9729e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7673 - loss: 5.5223e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9728e-07 - learning_rate: 1.0000e-05
# Epoch 82/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7673 - loss: 5.5222e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9728e-07 - learning_rate: 1.0000e-05
# Epoch 83/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7672 - loss: 5.5222e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9728e-07 - learning_rate: 1.0000e-05
# Epoch 84/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7675 - loss: 5.5221e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9728e-07 - learning_rate: 1.0000e-05
# Epoch 85/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7675 - loss: 5.5221e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9729e-07 - learning_rate: 1.0000e-05
# Epoch 86/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7675 - loss: 5.5221e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9728e-07 - learning_rate: 1.0000e-05
# Epoch 87/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7676 - loss: 5.5220e-07 - val_binary_accuracy: 0.7583 - val_loss: 5.9728e-07 - learning_rate: 1.0000e-05
# Epoch 88/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7675 - loss: 5.5220e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9728e-07 - learning_rate: 1.0000e-05
# Epoch 89/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7676 - loss: 5.5219e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9728e-07 - learning_rate: 1.0000e-05
# Epoch 90/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7675 - loss: 5.5219e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9727e-07 - learning_rate: 1.0000e-05
# Epoch 91/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7677 - loss: 5.5219e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9728e-07 - learning_rate: 1.0000e-05
# Epoch 92/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7677 - loss: 5.5217e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9728e-07 - learning_rate: 1.0000e-07
# Epoch 93/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7677 - loss: 5.5217e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9728e-07 - learning_rate: 1.0000e-07
# Epoch 94/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7677 - loss: 5.5217e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9728e-07 - learning_rate: 1.0000e-07
# Epoch 95/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7677 - loss: 5.5217e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9728e-07 - learning_rate: 1.0000e-07
# Epoch 96/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7677 - loss: 5.5217e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9728e-07 - learning_rate: 1.0000e-07
# Epoch 97/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7677 - loss: 5.5217e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9728e-07 - learning_rate: 1.0000e-07
# Epoch 98/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7677 - loss: 5.5217e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9727e-07 - learning_rate: 1.0000e-07
# Epoch 99/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7677 - loss: 5.5217e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9727e-07 - learning_rate: 1.0000e-07
# Epoch 100/100
# 2110/2110 - 4s - 2ms/step - binary_accuracy: 0.7677 - loss: 5.5217e-07 - val_binary_accuracy: 0.7582 - val_loss: 5.9727e-07 - learning_rate: 1.0000e-07
# Finished Training
# /home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/output_training_nominal/output_model_params_ttbar/model_scaler.bin
# 37501/37501 - 23s - 619us/step
# 16072/16072 - 9s - 591us/step
# 53572/53572 - 33s - 625us/step
# The sum of PDFs is 1.0122431516647339
# Sum of weights of class 0: 0.7000011205673218
# Sum of weights of class 1: 0.7000001072883606
# Using swish activation function
# /home/jaySandesara/.conda/envs/NSBI/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_9 (Dense)                 │ (None, 1000)           │        11,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,013,001 (3.86 MB)
#  Trainable params: 1,013,001 (3.86 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# 2025-06-03 21:05:47.294549: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion_1', 8 bytes spill stores, 4 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion', 16 bytes spill stores, 20 bytes spill loads
#
# 2025-06-03 21:05:52.595409: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion', 4 bytes spill stores, 4 bytes spill loads
# 2852/2852 - 8s - 3ms/step - binary_accuracy: 0.6824 - loss: 5.2548e-07 - val_binary_accuracy: 0.6884 - val_loss: 5.2061e-07 - learning_rate: 1.0000
# Epoch 2/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.6896 - loss: 5.1811e-07 - val_binary_accuracy: 0.6866 - val_loss: 5.2236e-07 - learning_rate: 1.0000
# Epoch 3/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.6910 - loss: 5.1593e-07 - val_binary_accuracy: 0.6909 - val_loss: 5.1609e-07 - learning_rate: 1.0000
# Epoch 4/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.6915 - loss: 5.1505e-07 - val_binary_accuracy: 0.6882 - val_loss: 5.1684e-07 - learning_rate: 1.0000
# Epoch 5/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.6936 - loss: 5.1301e-07 - val_binary_accuracy: 0.6928 - val_loss: 5.1455e-07 - learning_rate: 1.0000
# Epoch 6/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.6953 - loss: 5.1062e-07 - val_binary_accuracy: 0.6980 - val_loss: 5.0634e-07 - learning_rate: 1.0000
# Epoch 7/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7019 - loss: 5.0343e-07 - val_binary_accuracy: 0.7022 - val_loss: 5.0451e-07 - learning_rate: 1.0000
# Epoch 8/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7111 - loss: 4.9458e-07 - val_binary_accuracy: 0.7120 - val_loss: 4.9455e-07 - learning_rate: 1.0000
# Epoch 9/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7130 - loss: 4.9173e-07 - val_binary_accuracy: 0.7097 - val_loss: 5.0060e-07 - learning_rate: 1.0000
# Epoch 10/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7142 - loss: 4.9045e-07 - val_binary_accuracy: 0.7128 - val_loss: 4.9154e-07 - learning_rate: 1.0000
# Epoch 11/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7150 - loss: 4.8934e-07 - val_binary_accuracy: 0.7141 - val_loss: 4.8870e-07 - learning_rate: 1.0000
# Epoch 12/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7163 - loss: 4.8787e-07 - val_binary_accuracy: 0.7160 - val_loss: 4.8943e-07 - learning_rate: 1.0000
# Epoch 13/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7176 - loss: 4.8633e-07 - val_binary_accuracy: 0.7190 - val_loss: 4.8471e-07 - learning_rate: 1.0000
# Epoch 14/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7186 - loss: 4.8522e-07 - val_binary_accuracy: 0.7171 - val_loss: 4.8865e-07 - learning_rate: 1.0000
# Epoch 15/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7193 - loss: 4.8431e-07 - val_binary_accuracy: 0.7155 - val_loss: 4.9087e-07 - learning_rate: 1.0000
# Epoch 16/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7198 - loss: 4.8365e-07 - val_binary_accuracy: 0.7156 - val_loss: 4.9016e-07 - learning_rate: 1.0000
# Epoch 17/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7199 - loss: 4.8326e-07 - val_binary_accuracy: 0.7167 - val_loss: 4.8950e-07 - learning_rate: 1.0000
# Epoch 18/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7209 - loss: 4.8229e-07 - val_binary_accuracy: 0.7172 - val_loss: 4.8763e-07 - learning_rate: 1.0000
# Epoch 19/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7214 - loss: 4.8181e-07 - val_binary_accuracy: 0.7187 - val_loss: 4.8247e-07 - learning_rate: 1.0000
# Epoch 20/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7212 - loss: 4.8158e-07 - val_binary_accuracy: 0.7164 - val_loss: 4.8978e-07 - learning_rate: 1.0000
# Epoch 21/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7215 - loss: 4.8152e-07 - val_binary_accuracy: 0.7143 - val_loss: 4.8668e-07 - learning_rate: 1.0000
# Epoch 22/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7218 - loss: 4.8103e-07 - val_binary_accuracy: 0.7163 - val_loss: 4.9023e-07 - learning_rate: 1.0000
# Epoch 23/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7220 - loss: 4.8093e-07 - val_binary_accuracy: 0.7169 - val_loss: 4.8466e-07 - learning_rate: 1.0000
# Epoch 24/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7224 - loss: 4.8047e-07 - val_binary_accuracy: 0.7189 - val_loss: 4.8894e-07 - learning_rate: 1.0000
# Epoch 25/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7225 - loss: 4.8063e-07 - val_binary_accuracy: 0.7240 - val_loss: 4.8010e-07 - learning_rate: 1.0000
# Epoch 26/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7219 - loss: 4.8070e-07 - val_binary_accuracy: 0.7095 - val_loss: 4.9667e-07 - learning_rate: 1.0000
# Epoch 27/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7219 - loss: 4.8060e-07 - val_binary_accuracy: 0.7205 - val_loss: 4.8409e-07 - learning_rate: 1.0000
# Epoch 28/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7226 - loss: 4.8034e-07 - val_binary_accuracy: 0.7066 - val_loss: 5.0611e-07 - learning_rate: 1.0000
# Epoch 29/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7227 - loss: 4.8021e-07 - val_binary_accuracy: 0.7183 - val_loss: 4.8346e-07 - learning_rate: 1.0000
# Epoch 30/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7224 - loss: 4.8018e-07 - val_binary_accuracy: 0.7211 - val_loss: 4.8418e-07 - learning_rate: 1.0000
# Epoch 31/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7223 - loss: 4.7990e-07 - val_binary_accuracy: 0.7079 - val_loss: 4.9776e-07 - learning_rate: 1.0000
# Epoch 32/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7346 - loss: 4.6526e-07 - val_binary_accuracy: 0.7347 - val_loss: 4.6594e-07 - learning_rate: 0.0100
# Epoch 33/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7377 - loss: 4.6125e-07 - val_binary_accuracy: 0.7356 - val_loss: 4.6448e-07 - learning_rate: 0.0100
# Epoch 34/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7382 - loss: 4.6020e-07 - val_binary_accuracy: 0.7360 - val_loss: 4.6387e-07 - learning_rate: 0.0100
# Epoch 35/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7385 - loss: 4.5958e-07 - val_binary_accuracy: 0.7358 - val_loss: 4.6346e-07 - learning_rate: 0.0100
# Epoch 36/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7389 - loss: 4.5912e-07 - val_binary_accuracy: 0.7365 - val_loss: 4.6304e-07 - learning_rate: 0.0100
# Epoch 37/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7392 - loss: 4.5876e-07 - val_binary_accuracy: 0.7366 - val_loss: 4.6274e-07 - learning_rate: 0.0100
# Epoch 38/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7393 - loss: 4.5847e-07 - val_binary_accuracy: 0.7365 - val_loss: 4.6246e-07 - learning_rate: 0.0100
# Epoch 39/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7395 - loss: 4.5822e-07 - val_binary_accuracy: 0.7372 - val_loss: 4.6222e-07 - learning_rate: 0.0100
# Epoch 40/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7396 - loss: 4.5799e-07 - val_binary_accuracy: 0.7373 - val_loss: 4.6195e-07 - learning_rate: 0.0100
# Epoch 41/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7397 - loss: 4.5778e-07 - val_binary_accuracy: 0.7375 - val_loss: 4.6180e-07 - learning_rate: 0.0100
# Epoch 42/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7399 - loss: 4.5760e-07 - val_binary_accuracy: 0.7374 - val_loss: 4.6161e-07 - learning_rate: 0.0100
# Epoch 43/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7397 - loss: 4.5744e-07 - val_binary_accuracy: 0.7376 - val_loss: 4.6148e-07 - learning_rate: 0.0100
# Epoch 44/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7399 - loss: 4.5729e-07 - val_binary_accuracy: 0.7377 - val_loss: 4.6131e-07 - learning_rate: 0.0100
# Epoch 45/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7400 - loss: 4.5715e-07 - val_binary_accuracy: 0.7379 - val_loss: 4.6114e-07 - learning_rate: 0.0100
# Epoch 46/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7400 - loss: 4.5702e-07 - val_binary_accuracy: 0.7379 - val_loss: 4.6109e-07 - learning_rate: 0.0100
# Epoch 47/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7401 - loss: 4.5691e-07 - val_binary_accuracy: 0.7381 - val_loss: 4.6100e-07 - learning_rate: 0.0100
# Epoch 48/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7402 - loss: 4.5679e-07 - val_binary_accuracy: 0.7379 - val_loss: 4.6111e-07 - learning_rate: 0.0100
# Epoch 49/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7403 - loss: 4.5670e-07 - val_binary_accuracy: 0.7382 - val_loss: 4.6088e-07 - learning_rate: 0.0100
# Epoch 50/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7404 - loss: 4.5657e-07 - val_binary_accuracy: 0.7380 - val_loss: 4.6054e-07 - learning_rate: 0.0100
# Epoch 51/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7404 - loss: 4.5647e-07 - val_binary_accuracy: 0.7386 - val_loss: 4.6055e-07 - learning_rate: 0.0100
# Epoch 52/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7404 - loss: 4.5641e-07 - val_binary_accuracy: 0.7386 - val_loss: 4.6059e-07 - learning_rate: 0.0100
# Epoch 53/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7404 - loss: 4.5631e-07 - val_binary_accuracy: 0.7387 - val_loss: 4.6051e-07 - learning_rate: 0.0100
# Epoch 54/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7405 - loss: 4.5622e-07 - val_binary_accuracy: 0.7385 - val_loss: 4.6035e-07 - learning_rate: 0.0100
# Epoch 55/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7405 - loss: 4.5615e-07 - val_binary_accuracy: 0.7382 - val_loss: 4.6039e-07 - learning_rate: 0.0100
# Epoch 56/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7407 - loss: 4.5605e-07 - val_binary_accuracy: 0.7387 - val_loss: 4.6040e-07 - learning_rate: 0.0100
# Epoch 57/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7406 - loss: 4.5603e-07 - val_binary_accuracy: 0.7383 - val_loss: 4.6031e-07 - learning_rate: 0.0100
# Epoch 58/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7408 - loss: 4.5593e-07 - val_binary_accuracy: 0.7385 - val_loss: 4.6050e-07 - learning_rate: 0.0100
# Epoch 59/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7409 - loss: 4.5586e-07 - val_binary_accuracy: 0.7387 - val_loss: 4.6007e-07 - learning_rate: 0.0100
# Epoch 60/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7409 - loss: 4.5583e-07 - val_binary_accuracy: 0.7390 - val_loss: 4.6005e-07 - learning_rate: 0.0100
# Epoch 61/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7407 - loss: 4.5574e-07 - val_binary_accuracy: 0.7383 - val_loss: 4.6010e-07 - learning_rate: 0.0100
# Epoch 62/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7411 - loss: 4.5537e-07 - val_binary_accuracy: 0.7389 - val_loss: 4.5984e-07 - learning_rate: 1.0000e-04
# Epoch 63/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7412 - loss: 4.5525e-07 - val_binary_accuracy: 0.7388 - val_loss: 4.5979e-07 - learning_rate: 1.0000e-04
# Epoch 64/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7412 - loss: 4.5521e-07 - val_binary_accuracy: 0.7389 - val_loss: 4.5976e-07 - learning_rate: 1.0000e-04
# Epoch 65/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7412 - loss: 4.5519e-07 - val_binary_accuracy: 0.7389 - val_loss: 4.5974e-07 - learning_rate: 1.0000e-04
# Epoch 66/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7412 - loss: 4.5518e-07 - val_binary_accuracy: 0.7390 - val_loss: 4.5972e-07 - learning_rate: 1.0000e-04
# Epoch 67/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7412 - loss: 4.5516e-07 - val_binary_accuracy: 0.7389 - val_loss: 4.5971e-07 - learning_rate: 1.0000e-04
# Epoch 68/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5516e-07 - val_binary_accuracy: 0.7390 - val_loss: 4.5970e-07 - learning_rate: 1.0000e-04
# Epoch 69/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7412 - loss: 4.5515e-07 - val_binary_accuracy: 0.7390 - val_loss: 4.5969e-07 - learning_rate: 1.0000e-04
# Epoch 70/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7412 - loss: 4.5514e-07 - val_binary_accuracy: 0.7391 - val_loss: 4.5969e-07 - learning_rate: 1.0000e-04
# Epoch 71/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7412 - loss: 4.5514e-07 - val_binary_accuracy: 0.7391 - val_loss: 4.5968e-07 - learning_rate: 1.0000e-04
# Epoch 72/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5514e-07 - val_binary_accuracy: 0.7391 - val_loss: 4.5968e-07 - learning_rate: 1.0000e-04
# Epoch 73/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5513e-07 - val_binary_accuracy: 0.7391 - val_loss: 4.5968e-07 - learning_rate: 1.0000e-04
# Epoch 74/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5513e-07 - val_binary_accuracy: 0.7392 - val_loss: 4.5968e-07 - learning_rate: 1.0000e-04
# Epoch 75/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7412 - loss: 4.5513e-07 - val_binary_accuracy: 0.7392 - val_loss: 4.5967e-07 - learning_rate: 1.0000e-04
# Epoch 76/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7412 - loss: 4.5512e-07 - val_binary_accuracy: 0.7392 - val_loss: 4.5967e-07 - learning_rate: 1.0000e-04
# Epoch 77/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5512e-07 - val_binary_accuracy: 0.7392 - val_loss: 4.5967e-07 - learning_rate: 1.0000e-04
# Epoch 78/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5512e-07 - val_binary_accuracy: 0.7392 - val_loss: 4.5967e-07 - learning_rate: 1.0000e-04
# Epoch 79/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5512e-07 - val_binary_accuracy: 0.7393 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-04
# Epoch 80/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5512e-07 - val_binary_accuracy: 0.7392 - val_loss: 4.5967e-07 - learning_rate: 1.0000e-04
# Epoch 81/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5511e-07 - val_binary_accuracy: 0.7392 - val_loss: 4.5967e-07 - learning_rate: 1.0000e-04
# Epoch 82/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5511e-07 - val_binary_accuracy: 0.7393 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-04
# Epoch 83/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5511e-07 - val_binary_accuracy: 0.7393 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-04
# Epoch 84/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5511e-07 - val_binary_accuracy: 0.7392 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-04
# Epoch 85/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5511e-07 - val_binary_accuracy: 0.7393 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-04
# Epoch 86/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5511e-07 - val_binary_accuracy: 0.7393 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-04
# Epoch 87/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5510e-07 - val_binary_accuracy: 0.7393 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-04
# Epoch 88/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5510e-07 - val_binary_accuracy: 0.7393 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-04
# Epoch 89/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5510e-07 - val_binary_accuracy: 0.7393 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-04
# Epoch 90/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5510e-07 - val_binary_accuracy: 0.7392 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-04
# Epoch 91/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5510e-07 - val_binary_accuracy: 0.7393 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-04
# Epoch 92/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5509e-07 - val_binary_accuracy: 0.7393 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-06
# Epoch 93/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5509e-07 - val_binary_accuracy: 0.7393 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-06
# Epoch 94/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5509e-07 - val_binary_accuracy: 0.7393 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-06
# Epoch 95/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5509e-07 - val_binary_accuracy: 0.7393 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-06
# Epoch 96/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5509e-07 - val_binary_accuracy: 0.7393 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-06
# Epoch 97/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5509e-07 - val_binary_accuracy: 0.7393 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-06
# Epoch 98/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5509e-07 - val_binary_accuracy: 0.7393 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-06
# Epoch 99/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5509e-07 - val_binary_accuracy: 0.7393 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-06
# Epoch 100/100
# 2852/2852 - 5s - 2ms/step - binary_accuracy: 0.7413 - loss: 4.5509e-07 - val_binary_accuracy: 0.7393 - val_loss: 4.5966e-07 - learning_rate: 1.0000e-06
# Finished Training
# /home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/output_training_nominal/output_model_params_ztautau/model_scaler.bin
# 50695/50695 - 29s - 575us/step
# 21727/21727 - 12s - 530us/step
# 72421/72421 - 37s - 515us/step
# The sum of PDFs is 1.0298389196395874

# %% [markdown]
# Check for overtraining by comparing the NN output distributions between training and holdout datasets. The holdout dataset is the subset of events not used during training.

# %%
for process_type in mix_model_hypotheses:
    NN_training_mix_model[process_type].make_overfit_plots()

# %% [markdown]
# Diagnostic Checks
# ===
#
# While traditionally, a NN observable is judged on the basis of its accuracy - for NSBI we are interested in the quality of the density ratios more than the discrimination power. The latter comes from the perfect modelling of the multi-dimensional likelihood ratios.
#
# To ensure correct modelling, we run two main checks on the training:
#
# - **Calibration closure test**
#
#   The NNs are trained using the binary cross-entropy loss, which under ideal conditions leads to the NN converging to the score function:
#
#   $$\hat{s}_\text{pred} = \frac{p_\text{ref}(x)}{p_\text{ref}(x)+p_\text{c}(x)}$$
#
#   that can be converted into the probability ratio we desire (likelihood ratio trick):
#
#   $$\frac{p_\text{c}(x)}{p_\text{ref}(x)} = \frac{\hat{s}_\text{pred}(x)}{1-\hat{s}_\text{pred}(x)}$$
#
#   For the NNs to be well-calibrated, we use the Monte Carlo samples to verify the equality:
#
#
#   $$\left[\frac{p_c(x)}{p_c(x)+p_{ref}(x)}\right]_\text{NN} \sim \left[\frac{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}}{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}+\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}}\right]_\text{MC}$$
#
#   where we bin the events from $p_c$ and $p_\text{ref}$ MC samples, denoted by $\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}$ and $\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}$ respectively where $I(x|\hat{s}_\text{pred})$ returns the index of the $\hat{s}_\text{pred}$ bin in which an event $x$ falls.

# %%
num_bins_cal = 50

for process_type in mix_model_hypotheses:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='score')
# Out:
# observable not recognized
# observable not recognized

# %%
num_bins_cal = 50

for process_type in mix_model_hypotheses:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='llr')

# %% [markdown]
# - **Density ratio reweighting closure tests**
#
#   Despite having a well-calibrated output and thus a robust probabilistic interpretation, the trained density ratios might not capture the full multi-dimensional event information $x$. In other words, the NNs might still be biased estimators of the optimal score function, as defined in the CARL paper (link).
#
#   The next diagnostic involves verifying the following equality using 1D projections of $x$:
#
#   $$\frac{p_c(x)}{p_{ref}(x)} \times p_{ref}(x) \sim p_c(x)$$
#
#   We can do this one-by-one for all the observables used to model the density ratios, and also possibly the observables not used directly in the training but can still be well-estimated due to the NN learning the right physics.

# %%
variables_to_plot=['PRI_lep_pt'] # The 1D variable for reweighting closure
yscale_type='log'
num_bins_plotting=21

for process_type in mix_model_hypotheses:

    NN_training_mix_model[process_type].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
for process_type in mix_model_hypotheses:
    # Evaluate the density ratios p_c/p_ref for the full dataset and save for the inference step
    NN_training_mix_model[process_type].evaluate_and_save_ratios(dataset)
# Out:
# 72816/72816 - 40s - 548us/step
# 72816/72816 - 40s - 544us/step

# %% [markdown]
# Systematic Uncertainty Modelling
# ===
#
# So far we have left out the nuisance parameter piece of the parameterized density ratio decomposition shown before:
#
# $$g_c(x|\alpha) = \frac{p_c(x|\alpha)}{p_c(x)}$$
#
# which will be estimated in the `Systematic_Uncertainty_Estimation.ipynb` notebook.

# %% [markdown]
# Training an Ensemble of NNs
# ===
#
# In a realistic analysis, a large ensemble of NNs are trained to estimate density ratios, for *each* of the channels. **This reduces not only the variance but has also been found to reduce biases in the final fits.**
#
# In the off-shell Higgs boson analysis, we used k-fold cross-validation, with k=10, to train an ensemble $N_{ens}\sim 250$ of NNs per density ratio $p_c(x)/p_{ref}(x)$. The density ratios used in the final fit are always evaluated on the holdout dataset and by using each of the folds as holdout once, the entire model for $p_c(x)/p_{ref}(x)$ consists of $N_{ens}\times k \sim 2500$ NNs. Each NN in the ensemble is trained by resampling data without replacement from the k-1 folds used for training.
