# %% [markdown]
# Train Neural Networks to estimate Likelihood Ratios
# ===
#
# In this notebook we will setup the neural networks that train unbiased and low-variance density ratios to be then used for inference.

# %%
import os, sys, pathlib, importlib
sys.path.append('../')

# Load the package and modules for training and plotting
import nsbi_common_utils
from nsbi_common_utils import plotting, training, datasets, configuration
from nsbi_common_utils.training import TrainEvaluate_NN, TrainEvaluatePreselNN


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt
import pickle
import yaml
import random

from utils import preselection_using_score, calculate_preselection_observable

from coffea.analysis_tools import PackedSelection

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

hep.style.use(hep.style.ATLAS)
# Out:
# /home/jsandesara_umass_edu/NSBI-workflow-tutorial/src/nsbi_common_utils/plotting.py:11: FutureWarning: ``set_style`` is deprecated: Naming convention is changing to match mpl. Use ``mplhep.style.use()``.
#   hep.set_style("ATLAS")
# 2025-08-30 09:19:03.287284: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-30 09:19:03.297067: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-08-30 09:19:03.308594: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-08-30 09:19:03.312479: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-08-30 09:19:03.321557: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
importlib.reload(sys.modules['nsbi_common_utils.configuration'])
from nsbi_common_utils import configuration

config = nsbi_common_utils.configuration.ConfigManager(file_path_string = './config.yml')

# %%
# Input features for training
features, features_scaling = config.get_training_features()

# %% [markdown]
# Statistical Model
# -
#
# The statistical model we have is:
#
# $$p(x|\mu, \alpha) = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot p_c\left(x|\alpha\right)$$
#
# where $c$ stands for the various physics channels that contribute to the final state $x$, **$\mu$ is the signal-strength parameter and $\alpha$ is the vector of nuisance parameters associated with the various systematic uncertainties in the model**. Note that we are assuming that the parameter $\mu$-dependence is known analytically and that we have simulation models for each of the channels $p_c(x)$.
#
# Setting up the test
# -
#
# The objective is to build the test statistic for composite hypothesis testing:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})}{p(x_i|\hat{\mu}, \hat{\alpha})} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
# A direct approach would then be to model the probability density $p(x|\mu, \alpha)$ using NNs. But that is a more difficult task than training probability density ratios. We use a simple trick:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})/p_{ref}(x)}{p(x_i|\hat{\mu}, \hat{\alpha})/p_{ref}(x)} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
#
# to turn this into a density ratio estimation problem:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot \frac{p_c\left(x|\alpha\right)}{p_{ref}(x)}$$
#
# Factorizing out the $\alpha$-dependence in the density ratios:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\sum_c G_c(\alpha) \cdot f_c(\mu) \cdot \nu_c} \sum_c f_c(\mu) \cdot G_c(\alpha)\cdot \nu_c \cdot g_c(x|\alpha) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}$$
#
# Factorized approach:
# --
#
# Instead of training NNs parameterized on $\mu$ and $\alpha$, we use analytical parameterizations to simplify the problem to training only parameter-independent density ratios.
#
# Let's set this up for the toy $H\to \tau\tau$ model we are using. **Neglecting the nuisance parameter dependence ($G_c(\alpha) = g_c(x|\alpha) = 1$), the probability model can be written as**
#
# $$\sum_c f_c(\mu) \cdot \nu_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} = \mu \cdot \nu_{H \to \tau\tau}(\mu) \cdot  \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)} + \nu_{t\bar{t}}(\mu) \cdot  \frac{p_{t\bar{t}}\left(x\right)}{p_{ref}(x)} + \nu_{Z \to \tau\tau}(\mu) \cdot  \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{ref}(x)}$$
#
# In the NSBI approach presented in this tutorial, the density ratio estimation as a function of the various nuisance parameters is factorized from the nominal density ratio estimation, and will be done in the  `Systematic_Uncertainty_Estimation.ipynb` notebook.

# %%
importlib.reload(sys.modules['nsbi_common_utils.datasets'])
from nsbi_common_utils import datasets

Datasets = nsbi_common_utils.datasets.datasets(config = config.config,
                                                branches_to_load = features)

# %%
dataset_incl_dict = Datasets.load_datasets_from_config(load_systematics = False)

dataset_incl_nominal = dataset_incl_dict["Nominal"].copy()

# %% [markdown]
# Density ratio training
# ===
#
# Now we train the NNs for $\frac{p_c}{p_{ref}}(x)$ density ratios to build the full model. Our choice of reference hypothesis, motivated by the search-oriented mixture model described above, would be:
#
# $$p_{ref}(x) = p_{H \to \tau\tau}(x) = \frac{1}{\nu_{H \to \tau\tau}} \frac{d\sigma_{H \to \tau\tau}}{dx} $$
#
# gives the POI $\mu-$parameterized model:
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} \right]= \mu + \frac{p_{t\bar{t}}\left(x\right)}{p_{H \to \tau\tau}(x)} + \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{H \to \tau\tau}(x)}$$
#
# But this has shown to cause numerical issues, since the ratio corresponding to the $\mu$-scaling signal term is exactly 1. In the absence of additional signal production mechansims, we instead use:
#
# $$p_{ref}(x) = \frac{1}{\nu_{H \to \tau\tau} + \nu_{t\bar{t}}} \left[\frac{d\sigma_{H \to \tau\tau}}{dx} + \frac{d\sigma_{t\bar{t}}}{dx} \right]$$
#
# giving a more numerically stable model:
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} \right]= \mu \cdot \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)} + \frac{p_{t\bar{t}}\left(x\right)}{p_{ref}(x)} + \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{ref}(x)}$$
#
# The task of estimating the $\mu-$parameterized density ratio is thus reduced to estimating three $\mu-$independent density ratios $\frac{p_{H \to \tau\tau}}{p_{ref}}(x)$, $\frac{p_{t\bar{t}}}{p_{ref}}(x)$ and $\frac{p_{Z \to \tau\tau}}{p_{ref}}(x)$ mixed together with an analytical parameterization (hence the name mixture model).
#
# **NB**: This is the same as the *morphing-aware* approach of density ratio estimation in MadMiner

# %%
# Define the processes that make up the mixture model formula for density ratio estimation

PATH_TO_SAVED_DATA = './saved_data/'
TRAINING_OUTPUT_PATH = f'{PATH_TO_SAVED_DATA}output_training_nominal/'

# Signal processes in the model
basis_processes = config.get_basis_samples()
print(basis_processes)

ref_processes = config.get_reference_samples()
print(ref_processes)
# Out:
# ['htautau', 'ttbar', 'ztautau']
# ['htautau', 'ttbar']

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import TrainEvaluate_NN

ref_train_label_sample_dict = {**{ref: 0 for ref in ref_processes}}

dataset_ref     = Datasets.merge_dataframe_dict_for_training(dataset_incl_nominal, 
                                                            ref_train_label_sample_dict, 
                                                            samples_to_merge = ref_processes)

NN_training_mix_model = {}

use_log_loss = False

# DELETE_EXISTING_MODELS = True
DELETE_EXISTING_MODELS = False

path_to_ratios = {}
path_to_figures = {}
path_to_models = {}

for process_type in basis_processes:

    # Get the dictionary of labels to processes
    _train_label_sample_dict = {process_type        : 1}

    dataset_num     = Datasets.merge_dataframe_dict_for_training(dataset_incl_nominal, 
                                                                _train_label_sample_dict, 
                                                                samples_to_merge = [process_type])

    # Build a training dataset for the training of p_<process_type>/p_<ref_processes> density ratio
    dataset_mix_model = pd.concat([dataset_num, dataset_ref])

    # Save paths
    output_name                     = f'{process_type}'
    output_dir                      = f'{TRAINING_OUTPUT_PATH}general_output_{process_type}'
    path_to_ratios[process_type]    = f'{TRAINING_OUTPUT_PATH}output_ratios_{process_type}/'
    path_to_figures[process_type]   = f'{TRAINING_OUTPUT_PATH}output_figures_{process_type}/'
    path_to_models[process_type]    = f'{TRAINING_OUTPUT_PATH}output_model_params_{process_type}/'

    NN_training_mix_model[process_type] = TrainEvaluate_NN(dataset_mix_model, 
                                                           dataset_mix_model['weights_normed'].to_numpy(),
                                                           dataset_mix_model['train_labels'].to_numpy(),
                                                           features, 
                                                           features_scaling, 
                                                           [process_type, 'ref'], 
                                                            output_dir, output_name, 
                                                            path_to_figures=path_to_figures[process_type],
                                                            path_to_ratios=path_to_ratios[process_type], 
                                                            path_to_models=path_to_models[process_type],
                                                            use_log_loss = use_log_loss,
                                                            delete_existing_models = DELETE_EXISTING_MODELS)


    del dataset_mix_model

# %% [markdown]
# Neural Network architecture
# ===
#
# Here we will start with a multi-layer perceptron (simple feed-forward Neural Network with fully-connected layers). This can be supplemented with more complex architectures like transformers.
#
# After detailed tuning during the off-shell Higgs boson analysis effort, we found that a network with very wide layers ($\geq 1000$) and a depth of less than 10 works best - alongside batch size of a few hundreds and a gradually declining learning rate that starts with a value just large enough to not blow up.

# %% [markdown]
# Starting with the training and validation of the various density ratio:
#
# $$\frac{p_{H\to\tau\tau}(x)}{p_\text{ref}(x)}, \frac{p_{t\bar{t}}(x)}{p_\text{ref}(x)}, \frac{p_{Z \to \tau\tau}(x)}{p_\text{ref}(x)}$$

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 1

# %%
# You can either train your own NNs (in which case set this to False) or you can load the pre-trained NNs. 
# Training NNs without GPUs can be very slow, for the kind of NNs we need for unbiased estimation of density ratios
USE_SAVED_MODELS = True

# Define unique settings for each process type
doCalibration = True
num_bins_cal = 100
scaling_type = 'MinMax'
batch_size = 512
validation_split = 0.1
holdout_split = 0.25

num_epochs = 100
callback_patience = 30

num_layers = 4
num_neurons_per_layer = 1000

num_ensemble_members = 1

verbose_level = 1

training_settings = {

    'htautau': {
        'hidden_layers':        num_layers,
        'neurons':              num_neurons_per_layer,
        'number_of_epochs':     num_epochs,
        'batch_size':           batch_size,
        'learning_rate':        0.1,
        'scalerType':           scaling_type,
        'calibration':          doCalibration,
        'num_bins_cal':         num_bins_cal,
        'callback':             True,
        'callback_patience':    callback_patience,
        'callback_factor':      0.01,
        'validation_split':     validation_split,
        'holdout_split':        holdout_split,
        'verbose':              verbose_level,
        'plot_scaled_features': True,
        'load_trained_models':  USE_SAVED_MODELS,
        'num_ensemble_members': num_ensemble_members
    },
    
    'ttbar': {
        'hidden_layers':        num_layers,
        'neurons':              num_neurons_per_layer,
        'number_of_epochs':     num_epochs,
        'batch_size':           batch_size,
        'learning_rate':        0.1,
        'scalerType':           scaling_type,
        'calibration':          doCalibration,
        'num_bins_cal':         num_bins_cal,
        'callback':             True,
        'callback_patience':    callback_patience,
        'callback_factor':      0.01,
        'validation_split':     validation_split,
        'holdout_split':        holdout_split,
        'verbose':              verbose_level,
        'plot_scaled_features': True,
        'load_trained_models':  USE_SAVED_MODELS,
        'num_ensemble_members': num_ensemble_members
    },
    
    'ztautau': {
        'hidden_layers':        num_layers,
        'neurons':              num_neurons_per_layer,
        'number_of_epochs':     num_epochs,
        'batch_size':           batch_size,
        'learning_rate':        0.1,
        'scalerType':           scaling_type,
        'calibration':          doCalibration,
        'num_bins_cal':         num_bins_cal,
        'callback':             True,
        'callback_patience':    callback_patience,
        'callback_factor':      0.01,
        'validation_split':     validation_split,
        'holdout_split':        holdout_split,
        'verbose':              verbose_level,
        'plot_scaled_features': True,
        'load_trained_models':  USE_SAVED_MODELS,
        'num_ensemble_members': num_ensemble_members
    }
}

# %%
# Train the density ratio NN
for process_type in basis_processes:
    
    settings = training_settings[process_type]

    NN_training_mix_model[process_type].train_ensemble(**settings)
    NN_training_mix_model[process_type].test_normalization()
# Out:
# starting ensemble training
# Loading existing model for ensemble member 0
# Reading saved models from ./saved_data/output_training_nominal/output_model_params_htautau/
# 2025-08-30 09:19:31.819241: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1237 MB memory:  -> device: 0, name: NVIDIA A16, pci bus id: 0000:05:00.0, compute capability: 8.6
# 2025-08-30 09:19:38.283422: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-08-30 09:19:38.304264: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 91100
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step
# L 509 calibrator object loaded = [<nsbi_common_utils.calibration.HistogramCalibrator object at 0x71ee180f2220>]
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step
#
#
#
# The sum of PDFs in ensemble member 0 is 1.0023603089502204
#
#
# The sum of PDFs using the whole ensemble is 1.0023603089502204
#
#
#
# starting ensemble training
# Loading existing model for ensemble member 0
# Reading saved models from ./saved_data/output_training_nominal/output_model_params_ttbar/
# 335/335 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step
# L 509 calibrator object loaded = [<nsbi_common_utils.calibration.HistogramCalibrator object at 0x71ee19af5a60>]
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step
# 447/447 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step
#
#
#
# The sum of PDFs in ensemble member 0 is 1.0000054217312726
#
#
# The sum of PDFs using the whole ensemble is 1.0000054217312726
#
#
#
# starting ensemble training
# Sum of weights of class 0: 0.7499209259115284
# Sum of weights of class 1: 0.7499984182202456
# Using swish activation function
# /home/jsandesara_umass_edu/.conda/envs/nsbi_env/lib/python3.9/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1000)           │         9,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,013,001 (11.49 MB)
#  Trainable params: 3,013,001 (11.49 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 40s 7ms/step - binary_accuracy: 0.9487 - loss: 6.6685e-08 - val_binary_accuracy: 0.9582 - val_loss: 5.1850e-08 - learning_rate: 0.1000
# Epoch 2/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 38s 6ms/step - binary_accuracy: 0.9587 - loss: 5.1580e-08 - val_binary_accuracy: 0.9597 - val_loss: 5.0221e-08 - learning_rate: 0.1000
# Epoch 3/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 38s 6ms/step - binary_accuracy: 0.9592 - loss: 5.0985e-08 - val_binary_accuracy: 0.9598 - val_loss: 4.9962e-08 - learning_rate: 0.1000
# Epoch 4/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 38s 6ms/step - binary_accuracy: 0.9600 - loss: 5.0128e-08 - val_binary_accuracy: 0.9600 - val_loss: 4.9566e-08 - learning_rate: 0.1000
# Epoch 5/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 26s 4ms/step - binary_accuracy: 0.9599 - loss: 4.9952e-08 - val_binary_accuracy: 0.9604 - val_loss: 4.9186e-08 - learning_rate: 0.1000
# Epoch 6/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9602 - loss: 4.9573e-08 - val_binary_accuracy: 0.9607 - val_loss: 4.8438e-08 - learning_rate: 0.1000
# Epoch 7/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9606 - loss: 4.9056e-08 - val_binary_accuracy: 0.9607 - val_loss: 4.8348e-08 - learning_rate: 0.1000
# Epoch 8/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9617 - loss: 4.7847e-08 - val_binary_accuracy: 0.9621 - val_loss: 4.7170e-08 - learning_rate: 0.1000
# Epoch 9/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9617 - loss: 4.7788e-08 - val_binary_accuracy: 0.9619 - val_loss: 4.7075e-08 - learning_rate: 0.1000
# Epoch 10/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9619 - loss: 4.7486e-08 - val_binary_accuracy: 0.9622 - val_loss: 4.6798e-08 - learning_rate: 0.1000
# Epoch 11/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9626 - loss: 4.6857e-08 - val_binary_accuracy: 0.9625 - val_loss: 4.6555e-08 - learning_rate: 0.1000
# Epoch 12/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9623 - loss: 4.6998e-08 - val_binary_accuracy: 0.9625 - val_loss: 4.6674e-08 - learning_rate: 0.1000
# Epoch 13/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9625 - loss: 4.6759e-08 - val_binary_accuracy: 0.9630 - val_loss: 4.6057e-08 - learning_rate: 0.1000
# Epoch 14/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9630 - loss: 4.6407e-08 - val_binary_accuracy: 0.9631 - val_loss: 4.5802e-08 - learning_rate: 0.1000
# Epoch 15/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9629 - loss: 4.6253e-08 - val_binary_accuracy: 0.9632 - val_loss: 4.5730e-08 - learning_rate: 0.1000
# Epoch 16/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9630 - loss: 4.6113e-08 - val_binary_accuracy: 0.9632 - val_loss: 4.5605e-08 - learning_rate: 0.1000
# Epoch 17/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9631 - loss: 4.6111e-08 - val_binary_accuracy: 0.9636 - val_loss: 4.5366e-08 - learning_rate: 0.1000
# Epoch 18/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9632 - loss: 4.5845e-08 - val_binary_accuracy: 0.9634 - val_loss: 4.5295e-08 - learning_rate: 0.1000
# Epoch 19/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9634 - loss: 4.5832e-08 - val_binary_accuracy: 0.9636 - val_loss: 4.5414e-08 - learning_rate: 0.1000
# Epoch 20/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9634 - loss: 4.5741e-08 - val_binary_accuracy: 0.9638 - val_loss: 4.4946e-08 - learning_rate: 0.1000
# Epoch 21/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9633 - loss: 4.5672e-08 - val_binary_accuracy: 0.9637 - val_loss: 4.5013e-08 - learning_rate: 0.1000
# Epoch 22/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9634 - loss: 4.5745e-08 - val_binary_accuracy: 0.9639 - val_loss: 4.5035e-08 - learning_rate: 0.1000
# Epoch 23/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - binary_accuracy: 0.9639 - loss: 4.5373e-08 - val_binary_accuracy: 0.9639 - val_loss: 4.4877e-08 - learning_rate: 0.1000
# Epoch 24/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9634 - loss: 4.5473e-08 - val_binary_accuracy: 0.9638 - val_loss: 4.4720e-08 - learning_rate: 0.1000
# Epoch 25/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9638 - loss: 4.5266e-08 - val_binary_accuracy: 0.9638 - val_loss: 4.4834e-08 - learning_rate: 0.1000
# Epoch 26/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9636 - loss: 4.5490e-08 - val_binary_accuracy: 0.9640 - val_loss: 4.4668e-08 - learning_rate: 0.1000
# Epoch 27/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9640 - loss: 4.5124e-08 - val_binary_accuracy: 0.9641 - val_loss: 4.4576e-08 - learning_rate: 0.1000
# Epoch 28/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9641 - loss: 4.4951e-08 - val_binary_accuracy: 0.9641 - val_loss: 4.4760e-08 - learning_rate: 0.1000
# Epoch 29/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9641 - loss: 4.5133e-08 - val_binary_accuracy: 0.9641 - val_loss: 4.4635e-08 - learning_rate: 0.1000
# Epoch 30/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9638 - loss: 4.5142e-08 - val_binary_accuracy: 0.9641 - val_loss: 4.4408e-08 - learning_rate: 0.1000
# Epoch 31/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9641 - loss: 4.4882e-08 - val_binary_accuracy: 0.9639 - val_loss: 4.4482e-08 - learning_rate: 0.1000
# Epoch 32/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4732e-08 - val_binary_accuracy: 0.9643 - val_loss: 4.4198e-08 - learning_rate: 0.0010
# Epoch 33/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4570e-08 - val_binary_accuracy: 0.9644 - val_loss: 4.4173e-08 - learning_rate: 0.0010
# Epoch 34/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4552e-08 - val_binary_accuracy: 0.9644 - val_loss: 4.4163e-08 - learning_rate: 0.0010
# Epoch 35/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4658e-08 - val_binary_accuracy: 0.9644 - val_loss: 4.4160e-08 - learning_rate: 0.0010
# Epoch 36/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9645 - loss: 4.4580e-08 - val_binary_accuracy: 0.9644 - val_loss: 4.4152e-08 - learning_rate: 0.0010
# Epoch 37/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4503e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4153e-08 - learning_rate: 0.0010
# Epoch 38/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9644 - loss: 4.4569e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4145e-08 - learning_rate: 0.0010
# Epoch 39/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9644 - loss: 4.4456e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4149e-08 - learning_rate: 0.0010
# Epoch 40/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9646 - loss: 4.4358e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4147e-08 - learning_rate: 0.0010
# Epoch 41/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9644 - loss: 4.4494e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4140e-08 - learning_rate: 0.0010
# Epoch 42/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9645 - loss: 4.4470e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4145e-08 - learning_rate: 0.0010
# Epoch 43/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9644 - loss: 4.4394e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4139e-08 - learning_rate: 0.0010
# Epoch 44/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9644 - loss: 4.4623e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4140e-08 - learning_rate: 0.0010
# Epoch 45/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4612e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4139e-08 - learning_rate: 0.0010
# Epoch 46/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9644 - loss: 4.4560e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4137e-08 - learning_rate: 0.0010
# Epoch 47/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9644 - loss: 4.4515e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4138e-08 - learning_rate: 0.0010
# Epoch 48/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9644 - loss: 4.4589e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4133e-08 - learning_rate: 0.0010
# Epoch 49/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - binary_accuracy: 0.9644 - loss: 4.4546e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4136e-08 - learning_rate: 0.0010
# Epoch 50/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4703e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4134e-08 - learning_rate: 0.0010
# Epoch 51/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9642 - loss: 4.4544e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4139e-08 - learning_rate: 0.0010
# Epoch 52/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4522e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4136e-08 - learning_rate: 0.0010
# Epoch 53/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - binary_accuracy: 0.9642 - loss: 4.4728e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4126e-08 - learning_rate: 0.0010
# Epoch 54/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9645 - loss: 4.4466e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4131e-08 - learning_rate: 0.0010
# Epoch 55/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4774e-08 - val_binary_accuracy: 0.9646 - val_loss: 4.4132e-08 - learning_rate: 0.0010
# Epoch 56/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9644 - loss: 4.4407e-08 - val_binary_accuracy: 0.9646 - val_loss: 4.4139e-08 - learning_rate: 0.0010
# Epoch 57/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9645 - loss: 4.4602e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4134e-08 - learning_rate: 0.0010
# Epoch 58/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9646 - loss: 4.4339e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4128e-08 - learning_rate: 0.0010
# Epoch 59/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9644 - loss: 4.4619e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4123e-08 - learning_rate: 0.0010
# Epoch 60/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9646 - loss: 4.4374e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4126e-08 - learning_rate: 0.0010
# Epoch 61/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4481e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4125e-08 - learning_rate: 0.0010
# Epoch 62/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9645 - loss: 4.4414e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4125e-08 - learning_rate: 1.0000e-05
# Epoch 63/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9646 - loss: 4.4384e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 64/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - binary_accuracy: 0.9645 - loss: 4.4392e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 65/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9646 - loss: 4.4314e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 66/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9645 - loss: 4.4437e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 67/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9646 - loss: 4.4445e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 68/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4502e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 69/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9644 - loss: 4.4438e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 70/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9646 - loss: 4.4400e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 71/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9645 - loss: 4.4492e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 72/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4527e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 73/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4551e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 74/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9644 - loss: 4.4573e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 75/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9644 - loss: 4.4472e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 76/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9644 - loss: 4.4412e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 77/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4491e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 78/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4567e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 79/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9647 - loss: 4.4262e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 80/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4496e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 81/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4644e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 82/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9645 - loss: 4.4391e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 83/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4534e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 84/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - binary_accuracy: 0.9644 - loss: 4.4596e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 85/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9645 - loss: 4.4355e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 86/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9644 - loss: 4.4563e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 87/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 3ms/step - binary_accuracy: 0.9646 - loss: 4.4494e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 88/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9644 - loss: 4.4605e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 89/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4685e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 90/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4669e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 91/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4606e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-05
# Epoch 92/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9644 - loss: 4.4541e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-07
# Epoch 93/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9642 - loss: 4.4553e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-07
# Epoch 94/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9645 - loss: 4.4448e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-07
# Epoch 95/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9644 - loss: 4.4446e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-07
# Epoch 96/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4611e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-07
# Epoch 97/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9642 - loss: 4.4641e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-07
# Epoch 98/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9644 - loss: 4.4568e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-07
# Epoch 99/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9645 - loss: 4.4463e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-07
# Epoch 100/100
# 5937/5937 ━━━━━━━━━━━━━━━━━━━━ 21s 4ms/step - binary_accuracy: 0.9643 - loss: 4.4444e-08 - val_binary_accuracy: 0.9645 - val_loss: 4.4124e-08 - learning_rate: 1.0000e-07
# Finished Training
# ./saved_data/output_training_nominal/output_model_params_ztautau/model_scaler0.bin
# 338/338 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step
# 6.8418956e-07
# 0.99903595
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step
#
#
#
# The sum of PDFs in ensemble member 0 is 0.9994756424213367
#
#
# The sum of PDFs using the whole ensemble is 0.9994756424213367

# %% [markdown]
# Check for overtraining by comparing the NN output distributions between training and holdout datasets. The holdout dataset is the subset of events not used during training.

# %%
for process_type in basis_processes:
    NN_training_mix_model[process_type].make_overfit_plots()

# %% [markdown]
# Diagnostic Checks
# ===
#
# While traditionally, a NN observable is judged on the basis of its accuracy - for NSBI we are interested in the quality of the density ratios more than the discrimination power. The latter comes from the perfect modelling of the multi-dimensional likelihood ratios.
#
# To ensure correct modelling, we run two main checks on the training:
#
# - **Calibration closure test**
#
#   The NNs are trained using the binary cross-entropy loss, which under ideal conditions leads to the NN converging to the score function:
#
#   $$\hat{s}_\text{pred} = \frac{p_\text{ref}(x)}{p_\text{ref}(x)+p_\text{c}(x)}$$
#
#   that can be converted into the probability ratio we desire (likelihood ratio trick):
#
#   $$\frac{p_\text{c}(x)}{p_\text{ref}(x)} = \frac{\hat{s}_\text{pred}(x)}{1-\hat{s}_\text{pred}(x)}$$
#
#   For the NNs to be well-calibrated, we use the Monte Carlo samples to verify the equality:
#
#
#   $$\left[\frac{p_c(x)}{p_c(x)+p_{ref}(x)}\right]_\text{NN} \sim \left[\frac{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}}{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}+\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}}\right]_\text{MC}$$
#
#   where we bin the events from $p_c$ and $p_\text{ref}$ MC samples, denoted by $\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}$ and $\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}$ respectively where $I(x|\hat{s}_\text{pred})$ returns the index of the $\hat{s}_\text{pred}$ bin in which an event $x$ falls.

# %%
num_bins_cal = 50

for process_type in basis_processes:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='score')

# %% [markdown]
# ## Density ratio reweighting closure tests
#
#   Despite having a well-calibrated output and thus a robust probabilistic interpretation, the trained density ratios might not capture the full multi-dimensional event information $x$. In other words, the NNs might still be biased estimators of the optimal score function, as defined in the CARL paper (link).
#
#   The next diagnostic involves verifying the following equality using 1D projections of $x$:
#
#   $$\frac{p_c(x)}{p_{ref}(x)} \times p_{ref}(x) \sim p_c(x)$$
#
#   We can do this one-by-one for all the observables used to model the density ratios, and also possibly the observables not used directly in the training but can still be well-estimated due to the NN learning the right physics.

# %%
variables_to_plot=['log_DER_pt_h'] # The 1D variable for reweighting closure
yscale_type='log'
num_bins_plotting=21

for process_type in basis_processes:

    NN_training_mix_model[process_type].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
path_to_saved_ratios = {}

for process_type in basis_processes:
    # Evaluate the density ratios p_c/p_ref for the full dataset and save for the inference step
    path_to_saved_ratios[process_type] = NN_training_mix_model[process_type].evaluate_and_save_ratios(dataset, 
                                                                                                     aggregation_type = 'median_score')
# Out:
# Evaluating density ratios
# Evaluating density ratios
# Evaluating density ratios

# %%
for i, channel_dict in enumerate(config["Regions"]):
    
    if channel_dict.get("Name") == "SR":

        config["Regions"][i]["TrainedModels"] = []

        for process_type in basis_processes:
        
            config["Regions"][i]["TrainedModels"].append(
                {
                    "Name"     : process_type,
                    "Models"   : path_to_models[process_type],
                    "Ratios"   : path_to_saved_ratios[process_type]
                }
            )

# %% [markdown]
# Systematic Uncertainty Modelling
# ===
#
# So far we have left out the nuisance parameter piece of the parameterized density ratio decomposition shown before:
#
# $$g_c(x|\alpha) = \frac{p_c(x|\alpha)}{p_c(x)}$$
#
# which will be estimated in the `Systematic_Uncertainty_Estimation.ipynb` notebook.

# %% [markdown]
# Training an Ensemble of NNs
# ===
#
# In a realistic analysis, a large ensemble of NNs are trained to estimate density ratios, for *each* of the channels. **This reduces not only the variance but has also been found to reduce biases in the final fits.**
#
# In the off-shell Higgs boson analysis, we used k-fold cross-validation, with k=10, to train an ensemble $N_{ens}\sim 250$ of NNs per density ratio $p_c(x)/p_{ref}(x)$. The density ratios used in the final fit are always evaluated on the holdout dataset and by using each of the folds as holdout once, the entire model for $p_c(x)/p_{ref}(x)$ consists of $N_{ens}\times k \sim 2500$ NNs. Each NN in the ensemble is trained by resampling data without replacement from the k-1 folds used for training.
