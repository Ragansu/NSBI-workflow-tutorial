# %% [markdown]
# Train Neural Networks to estimate Likelihood Ratios
# ===
#
# In this notebook we will setup the neural networks that train unbiased and low-variance density ratios to be then used for inference. The statistical model we have is:
#
# $$p(x|\mu, \alpha) = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot p_c\left(x|\alpha\right)$$
#
# where $c$ stands for the various physics channels that contribute to the final state $x$, $\mu$ is the signal-strength parameter and $\alpha$ is the vector of nuisance parameters associated with the various systematic uncertainties in the model. Note that we are assuming that the parameter $\mu$-dependence is known analytically and that we have simulation models for each of the channels $p_c(x)$.
#
# The objective is to build the test statistic for composite hypothesis testing:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})}{p(x_i|\hat{\mu}, \hat{\alpha})} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
# A direct approach would then be to model the probability density $p(x|\mu, \alpha)$ using NNs. But that is a more difficult task than training probability density ratios. We use a simple trick:
#
# $$t_\mu = -2 \cdot \frac{\text{Pois}(\mathcal{N}_\text{evts}|\mu, \hat{\hat{\alpha}})}{\text{Pois}(\mathcal{N}_\text{evts}|\hat{\mu}, \hat{\alpha})} -2 \cdot \sum_i^{\mathcal{N}_\text{evts}} w_i \times \log \frac{p(x_i|\mu, \hat{\hat{\alpha}})/p_{ref}(x)}{p(x_i|\hat{\mu}, \hat{\alpha})/p_{ref}(x)} + \sum_m^{N_\text{systs}} \alpha_m^2$$
#
#
# to turn this into a density ratio estimation problem:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\nu(\mu, \alpha)} \sum_c f_c(\mu) \cdot \nu_c(\alpha) \cdot \frac{p_c\left(x|\alpha\right)}{p_{ref}(x)}$$
#
# Factorizing out the $\alpha$-dependence in the density ratios:
#
# $$\frac{p(x|\mu, \alpha)}{p_{ref}(x)} = \frac{1}{\sum_c G_c(\alpha) \cdot f_c(\mu) \cdot \nu_c} \sum_c f_c(\mu) \cdot G_c(\alpha)\cdot \nu_c \cdot g_c(x|\alpha) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}$$
#
# **Factorized approach:**
#
# Instead of training NNs parameterized on $\mu$ and $\alpha$, we use analytical parameterizations to simplify the problem to training only parameter-independent density ratios.
#
# Let's set this up for the toy ttbar model we are using. Neglecting the nuisance parameter dependence for now,
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)}\right] = \mu \cdot \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)} + \frac{p_{t\bar{t}}\left(x\right)}{p_{ref}(x)} + \frac{p_{H \to \tau\tau}\left(x\right)}{p_{ref}(x)}$$

# %%
import os, sys, importlib
sys.path.append('../')

import nsbi_common_utils
from nsbi_common_utils import plotting, training
from nsbi_common_utils.training import TrainEvaluate_NN, TrainEvaluatePreselNN
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Nadam
import mplhep as hep
import matplotlib.pyplot as plt
import pickle

from coffea.analysis_tools import PackedSelection

import warnings
warnings.filterwarnings("ignore", category=RuntimeWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

hep.style.use(hep.style.ATLAS)
# Out:
# /data/jaySandesara/NSBI_workflow_tutorial/src/nsbi_common_utils/plotting.py:10: FutureWarning: ``set_style`` is deprecated: Naming convention is changing to match mpl. Use ``mplhep.style.use()``.
#   hep.set_style("ATLAS")
# 2025-06-04 14:35:26.097631: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1749047726.111348     255 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1749047726.115638     255 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-04 14:35:26.131074: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# If the preselection NN has already been trained and saved, load from the saved model
USE_SAVED_MODEL_PRESEL=False
# If the preselection NN has already been trained and evaluated, load the numpy array of predictions
USE_SAVED_PRESEL_PREDICTIONS=False

path_prefix = '/home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/'

# Path for saving interemdiate objects, like NN predictions
saved_data = f'{path_prefix}cached_data/'

# Path for saving/loading preselection NN model
path_to_saved_presel_model = f'{path_prefix}preselection_saved_NN/'

# %%
# Load the nominal dataset saved from the pre-processing notebook
dataset_incl_nominal = pd.read_hdf(f"{saved_data}df_nominal.h5", key="dataset", mode='r')

# Load the MC/data weights and training labels identifying different processes
weights = dataset_incl_nominal.weights.to_numpy()
train_labels = dataset_incl_nominal.train_labels.to_numpy()

# %%
# Get the dictionary of labels to processes
labels_dict = np.load(f"{saved_data}labels_dictionary.npy", allow_pickle=True).item()

# %%
# Normalizing the training weights - only discriminating shapes, not norms
weights_normed = weights.copy()

for key in labels_dict:

    weights_normed[train_labels==labels_dict[key]] /= weights[train_labels==labels_dict[key]].sum()

dataset_incl_nominal['weights_normed'] = weights_normed

# %% [markdown]
# Training the Preselection NN
# ===

# %% [markdown]
# **Choice of reference sample**
#
# The density ratios need to be trained on phase space regions with support for the reference hypothesis $p_{ref}(x) > 0$.
#
# To ensure this, we make a selection that selects events in the phase space regions with $p_{ref}(x) > 0$, or $p_c(x) \gg p_{ref}(x)$, and only perform the NSBI fit in this selected analysis region. **A natural choice for the reference hypothesis is then the signal-rich hypotheses**. This is referred to in the ATLAS publications as the Search-Oriented Mixture Models approach:
#
# $$p_{ref}(x) = \frac{1}{\sum_S \nu_S} \sum_S \frac{d\sigma_S}{dx} = \frac{1}{\nu_{H \to \tau\tau}} \frac{d\sigma_{H \to \tau\tau}}{dx}$$
#
# where the sum runs over all signal hypothesis in the model and the second equality is due to the sole signal hypothesis in our toy model, $pp \to {t\bar{t}}$.
#
# **Selecting out regions with $p_{ref}\sim 0$**
#
# A multi-class classification NN, with softmax output, is trained to output a score:
#
# $$ \text{NN}_\text{presel} = \log \left[\frac{\sum_S P_S (x)}{\sum_B P_B(x)} \right]$$
#
# where $P_c$ are the probability scores outputted from the softmax layer of the trained NN.

# %%
dataset_incl_nominal.columns.unique()
# Out:
# Index(['PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi',
#        'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi', 'PRI_jet_all_pt',
#        'PRI_jet_leading_pt', 'PRI_jet_leading_eta', 'PRI_n_jets', 'weights',
#        'detailed_labels', 'type', 'train_labels', 'weights_normed'],
#       dtype='object')

# %%
print(dataset_incl_nominal[dataset_incl_nominal.type=='htautau'].weights.sum())
print(dataset_incl_nominal[dataset_incl_nominal.type=='ttbar'].weights.sum())
print(dataset_incl_nominal[dataset_incl_nominal.type=='ztautau'].weights.sum())
# Out:
# 950.12067
# 39255.598
# 900465.7

# %%
dataset_incl_nominal['has_jets'] = np.where(
    dataset_incl_nominal['PRI_n_jets'] > 0, 1, 0
)

# %%
# Features to use for training NNs
columns = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi']
columns_scaling = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi']

# columns = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi', 'PRI_jet_all_pt', 'PRI_n_jets', 'has_jets']
# columns_scaling = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi', 'PRI_jet_all_pt']

# columns = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi', 'PRI_jet_all_pt', 'PRI_jet_leading_pt', 'PRI_jet_leading_eta', 'has_jets']
# columns_scaling = ['PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi', 'PRI_had_pt', 'PRI_had_eta', 'PRI_had_phi', 'PRI_jet_all_pt', 'PRI_jet_leading_pt', 'PRI_jet_leading_eta']


np.save(f"{saved_data}columns.npy", columns)
np.save(f"{saved_data}columns_scaling.npy", columns_scaling)

# %%
print(labels_dict)
# Out:
# {'htautau': 0, 'ztautau': 1, 'ttbar': 2}

# %%
signal_processes = ["htautau"]
background_processes = ["ttbar", "ztautau"]
# background_processes = ["ttbar", "ztautau", "diboson"]

pre_factor = {}

pre_factor['htautau'] = 1.0
pre_factor['ttbar'] = 1.0
pre_factor['ztautau'] = 1.0

np.save(f"{saved_data}signal_processes.npy", signal_processes)
np.save(f"{saved_data}background_processes.npy", background_processes)
np.save(f"{saved_data}pre_factor_preselection.npy", pre_factor)

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import TrainEvaluatePreselNN

num_classes = len(labels_dict)

preselectionTraining = TrainEvaluatePreselNN(dataset_incl_nominal, num_classes, columns, columns_scaling)

# %%
if USE_SAVED_PRESEL_PREDICTIONS:
    presel_score = np.load(f"{saved_data}presel_score.npy")


else:
    if not USE_SAVED_MODEL_PRESEL:
        preselectionTraining.train(test_size=0.2, 
                                   random_state=4242, 
                                   path_to_save=path_to_saved_presel_model,
                                  batch_size=4096,
                                  epochs=50, learning_rate=0.1)
    
    else:
        preselectionTraining.get_trained_model(path_to_saved_presel_model)

    # Get predictions (softmax outputs)
    pred_NN_incl = preselectionTraining.predict(dataset_incl_nominal)

    presel_score = calculate_preselection_observable(pred_NN_incl, labels_dict, signal_processes, background_processes, pre_factor_dict = pre_factor)
# Out:
# Epoch 1/50
# 2025-06-04 14:58:42.610167: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion', 8 bytes spill stores, 4 bytes spill loads
# 1367/1367 - 10s - 7ms/step - accuracy: 0.6936 - loss: 3.0605e-07 - val_accuracy: 0.7126 - val_loss: 2.9030e-07 - learning_rate: 0.1000
# Epoch 2/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7136 - loss: 2.8872e-07 - val_accuracy: 0.7134 - val_loss: 2.8771e-07 - learning_rate: 0.1000
# Epoch 3/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7150 - loss: 2.8646e-07 - val_accuracy: 0.7151 - val_loss: 2.8570e-07 - learning_rate: 0.1000
# Epoch 4/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7158 - loss: 2.8524e-07 - val_accuracy: 0.7156 - val_loss: 2.8491e-07 - learning_rate: 0.1000
# Epoch 5/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7162 - loss: 2.8461e-07 - val_accuracy: 0.7165 - val_loss: 2.8432e-07 - learning_rate: 0.1000
# Epoch 6/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7163 - loss: 2.8417e-07 - val_accuracy: 0.7163 - val_loss: 2.8396e-07 - learning_rate: 0.1000
# Epoch 7/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7165 - loss: 2.8379e-07 - val_accuracy: 0.7171 - val_loss: 2.8353e-07 - learning_rate: 0.1000
# Epoch 8/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7168 - loss: 2.8344e-07 - val_accuracy: 0.7164 - val_loss: 2.8352e-07 - learning_rate: 0.1000
# Epoch 9/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7169 - loss: 2.8312e-07 - val_accuracy: 0.7175 - val_loss: 2.8274e-07 - learning_rate: 0.1000
# Epoch 10/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7173 - loss: 2.8270e-07 - val_accuracy: 0.7174 - val_loss: 2.8250e-07 - learning_rate: 0.1000
# Epoch 11/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7179 - loss: 2.8212e-07 - val_accuracy: 0.7179 - val_loss: 2.8163e-07 - learning_rate: 0.1000
# Epoch 12/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7185 - loss: 2.8131e-07 - val_accuracy: 0.7192 - val_loss: 2.8061e-07 - learning_rate: 0.1000
# Epoch 13/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7188 - loss: 2.8061e-07 - val_accuracy: 0.7190 - val_loss: 2.8044e-07 - learning_rate: 0.1000
# Epoch 14/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7190 - loss: 2.8010e-07 - val_accuracy: 0.7198 - val_loss: 2.7967e-07 - learning_rate: 0.1000
# Epoch 15/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7192 - loss: 2.7962e-07 - val_accuracy: 0.7200 - val_loss: 2.7917e-07 - learning_rate: 0.1000
# Epoch 16/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7194 - loss: 2.7924e-07 - val_accuracy: 0.7203 - val_loss: 2.7865e-07 - learning_rate: 0.1000
# Epoch 17/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7197 - loss: 2.7879e-07 - val_accuracy: 0.7205 - val_loss: 2.7805e-07 - learning_rate: 0.1000
# Epoch 18/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7196 - loss: 2.7843e-07 - val_accuracy: 0.7203 - val_loss: 2.7794e-07 - learning_rate: 0.1000
# Epoch 19/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7197 - loss: 2.7818e-07 - val_accuracy: 0.7202 - val_loss: 2.7783e-07 - learning_rate: 0.1000
# Epoch 20/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7196 - loss: 2.7790e-07 - val_accuracy: 0.7197 - val_loss: 2.7762e-07 - learning_rate: 0.1000
# Epoch 21/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7198 - loss: 2.7771e-07 - val_accuracy: 0.7203 - val_loss: 2.7719e-07 - learning_rate: 0.1000
# Epoch 22/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7199 - loss: 2.7749e-07 - val_accuracy: 0.7206 - val_loss: 2.7686e-07 - learning_rate: 0.1000
# Epoch 23/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7199 - loss: 2.7725e-07 - val_accuracy: 0.7207 - val_loss: 2.7662e-07 - learning_rate: 0.1000
# Epoch 24/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7202 - loss: 2.7707e-07 - val_accuracy: 0.7204 - val_loss: 2.7680e-07 - learning_rate: 0.1000
# Epoch 25/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7201 - loss: 2.7683e-07 - val_accuracy: 0.7207 - val_loss: 2.7633e-07 - learning_rate: 0.1000
# Epoch 26/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7203 - loss: 2.7665e-07 - val_accuracy: 0.7211 - val_loss: 2.7617e-07 - learning_rate: 0.1000
# Epoch 27/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7204 - loss: 2.7643e-07 - val_accuracy: 0.7211 - val_loss: 2.7619e-07 - learning_rate: 0.1000
# Epoch 28/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7206 - loss: 2.7625e-07 - val_accuracy: 0.7211 - val_loss: 2.7582e-07 - learning_rate: 0.1000
# Epoch 29/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7205 - loss: 2.7609e-07 - val_accuracy: 0.7211 - val_loss: 2.7586e-07 - learning_rate: 0.1000
# Epoch 30/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7209 - loss: 2.7589e-07 - val_accuracy: 0.7210 - val_loss: 2.7573e-07 - learning_rate: 0.1000
# Epoch 31/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7209 - loss: 2.7575e-07 - val_accuracy: 0.7210 - val_loss: 2.7549e-07 - learning_rate: 0.1000
# Epoch 32/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7216 - loss: 2.7499e-07 - val_accuracy: 0.7223 - val_loss: 2.7479e-07 - learning_rate: 0.0010
# Epoch 33/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7218 - loss: 2.7484e-07 - val_accuracy: 0.7222 - val_loss: 2.7474e-07 - learning_rate: 0.0010
# Epoch 34/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7218 - loss: 2.7481e-07 - val_accuracy: 0.7222 - val_loss: 2.7472e-07 - learning_rate: 0.0010
# Epoch 35/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7219 - loss: 2.7480e-07 - val_accuracy: 0.7223 - val_loss: 2.7471e-07 - learning_rate: 0.0010
# Epoch 36/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7218 - loss: 2.7478e-07 - val_accuracy: 0.7222 - val_loss: 2.7470e-07 - learning_rate: 0.0010
# Epoch 37/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7219 - loss: 2.7477e-07 - val_accuracy: 0.7223 - val_loss: 2.7469e-07 - learning_rate: 0.0010
# Epoch 38/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7218 - loss: 2.7477e-07 - val_accuracy: 0.7221 - val_loss: 2.7469e-07 - learning_rate: 0.0010
# Epoch 39/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7219 - loss: 2.7476e-07 - val_accuracy: 0.7222 - val_loss: 2.7469e-07 - learning_rate: 0.0010
# Epoch 40/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7219 - loss: 2.7475e-07 - val_accuracy: 0.7222 - val_loss: 2.7468e-07 - learning_rate: 0.0010
# Epoch 41/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7219 - loss: 2.7475e-07 - val_accuracy: 0.7222 - val_loss: 2.7467e-07 - learning_rate: 0.0010
# Epoch 42/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7219 - loss: 2.7475e-07 - val_accuracy: 0.7223 - val_loss: 2.7467e-07 - learning_rate: 0.0010
# Epoch 43/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7218 - loss: 2.7474e-07 - val_accuracy: 0.7222 - val_loss: 2.7468e-07 - learning_rate: 0.0010
# Epoch 44/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7219 - loss: 2.7473e-07 - val_accuracy: 0.7224 - val_loss: 2.7466e-07 - learning_rate: 0.0010
# Epoch 45/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7219 - loss: 2.7473e-07 - val_accuracy: 0.7224 - val_loss: 2.7466e-07 - learning_rate: 0.0010
# Epoch 46/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7219 - loss: 2.7473e-07 - val_accuracy: 0.7222 - val_loss: 2.7465e-07 - learning_rate: 0.0010
# Epoch 47/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7219 - loss: 2.7472e-07 - val_accuracy: 0.7222 - val_loss: 2.7465e-07 - learning_rate: 0.0010
# Epoch 48/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7218 - loss: 2.7472e-07 - val_accuracy: 0.7222 - val_loss: 2.7466e-07 - learning_rate: 0.0010
# Epoch 49/50
# 1367/1367 - 8s - 6ms/step - accuracy: 0.7219 - loss: 2.7472e-07 - val_accuracy: 0.7222 - val_loss: 2.7465e-07 - learning_rate: 0.0010
# Epoch 50/50
# 1367/1367 - 7s - 5ms/step - accuracy: 0.7219 - loss: 2.7471e-07 - val_accuracy: 0.7222 - val_loss: 2.7464e-07 - learning_rate: 0.0010
# 218656/218656 ━━━━━━━━━━━━━━━━━━━━ 125s 571us/step

# %%
mix_model_hypotheses = signal_processes + background_processes
mix_model_hypotheses = background_processes
ref_processes = signal_processes

np.save(f"{saved_data}mix_model_hypotheses.npy", mix_model_hypotheses)
np.save(f"{saved_data}ref_processes.npy", ref_processes)



if not USE_SAVED_PRESEL_PREDICTIONS:

    
    # presel_score = (signal_sum/background_sum)
    np.save(f"{saved_data}presel_score.npy", presel_score)
    np.save(f"{saved_data}pred_NN_incl.npy", presel_score)

    # del pred_NN_incl

# %%
min_pred = np.amin(presel_score)
max_pred = np.amax(presel_score)

bins = np.linspace(min_pred, max_pred, num=50)

hist_NN_output = {}
hist_NN_output_errs = {}

for key in labels_dict: 
    hist_NN_output[key], _ = np.histogram(presel_score[train_labels==labels_dict[key]], 
                                          weights = weights[train_labels==labels_dict[key]], bins=bins)
    
    hist_NN_output_errs[key], _ = np.histogram(presel_score[train_labels==labels_dict[key]], 
                                          weights = weights[train_labels==labels_dict[key]]**2, bins=bins)


for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins=bins, 
             alpha=0.6, label=key, 
             density=True, linewidth=2.0, yerr = np.sqrt(hist_NN_output_errs[key]))

plt.xlabel("Preselection Score", size=18)
plt.ylabel("Density", size=18)
plt.legend()
plt.yscale('log')
plt.show()

# %% [markdown]
# Making the cut
# ===
#
# Make a selection cut for regions with $p_{ref} \gg 0$ for performing the NSBI analysis. The remaining events - which by definition are background-dominated - can be used as a **Control Region** for data-driven background estimation, pre-unblinding validations, etc.
#
# Moreover, the preselections act as a tuning know for the tradeoff in selecting as many signal events as possible to go into the **Signal Region** (increasing sensitivity) and the feasibility of training accurate and precise NNs over a large phase space (need bigger models and more statistics). **The preselections can also weed out phase space regions with low background statistics to avoid poorly modelled regions.**
#
# Heres a first cut that you can optimize as much as you like to get the desired final results.

# %%
# Play around with these selections - decrease if estimators are unbiased but need more sensitivity and increase if the model is biased to reduce complexity
preselection_cuts = {'upper': 2.2, 'lower': -0.5}
np.save(f"{saved_data}preselection_cuts.npy", preselection_cuts)


for key in labels_dict:  
    hep.histplot(hist_NN_output[key], bins = bins, 
             alpha = 0.6, label = key, 
             density = True, linewidth = 2.0, 
                 yerr = np.sqrt(hist_NN_output_errs[key]))

plt.xlabel("Preselection Score", size=18)

for key in preselection_cuts:
    if preselection_cuts[key] != -999:
        plt.axvline(preselection_cuts[key], ymax=0.9, linestyle='--', label=f'preselection cut {key} = {preselection_cuts[key]}')

plt.ylabel("Density", size=18)
plt.legend(loc='upper left')
plt.yscale('log')
plt.show()

# %% [markdown]
# Signal and Control Regions
# ===
#
# The high signal over background phase space towards the right of the preselection cut shown above will be categorized as the **Signal Region** where the NSBI analysis is performed.
#
# The low signal phase space towards the left will be used as a **Control Region**, with typical uses such as background estimation, pre-unblinding data-MC checks, etc. In this phase space, we will use a binned summary observable like in any traditional analysis.

# %%
dataset_incl_nominal['presel_score'] = presel_score

lower_cut = preselection_cuts.get('lower')
upper_cut = preselection_cuts.get('upper')

masks = {
    'SR': pd.Series(True, index=dataset_incl_nominal.index),
    'CR': pd.Series(False, index=dataset_incl_nominal.index)
}

# CASE A: both lower and upper exist (and are “active”, i.e. not -999)
if (lower_cut != -999) and (upper_cut != -999):
    masks['SR'] = (
        (dataset_incl_nominal.presel_score >= lower_cut) &
        (dataset_incl_nominal.presel_score <= upper_cut)
    )
    masks['CR'] = ~masks['SR']  

# CASE B: only a lower‐side cut is active
elif (lower_cut != -999):
    masks['SR'] = (dataset_incl_nominal.presel_score >= lower_cut)
    masks['CR'] = (dataset_incl_nominal.presel_score <  lower_cut)

# CASE C: only an upper‐side cut is active
elif (upper_cut != -999):
    masks['SR'] = (dataset_incl_nominal.presel_score <= upper_cut)
    masks['CR'] = (dataset_incl_nominal.presel_score >  upper_cut)


dataset   = dataset_incl_nominal[masks['SR']].copy()
dataset_CR = dataset_incl_nominal[masks['CR']].copy()

del dataset_incl_nominal

# %%
# Build a summary observable for Control Region
hist_CR = {}
num_bins = 10

CR_observable='PRI_lep_pt'

kin_variable = dataset_CR[CR_observable].to_numpy()

min_kin = np.amin(kin_variable)
max_kin = np.amax(kin_variable)
max_kin = 80.0

bins = np.linspace(min_kin, max_kin, num=num_bins)

# Use the high-level preselection NN score as a summary observable for Control Region
for channel_ in labels_dict:
    dataset_CR_process = dataset_CR[dataset_CR.detailed_labels==channel_]
    hist_CR[channel_], bins = np.histogram(dataset_CR_process[CR_observable].ravel(), 
                                  weights = dataset_CR_process['weights'].ravel(),
                                  bins = bins)

# Save the Control Region observable
with open(f"{saved_data}hist_CR_ttbar.pkl", "wb") as fp:
    pickle.dump(hist_CR, fp)

np.save(f"{saved_data}CRbins.npy", bins)

del dataset_CR

# %%
# Plot the Control Region observable

for channel_ in labels_dict:
    hep.histplot(hist_CR[channel_], bins=bins, label=channel_, density=1, linewidth=2.0)

plt.legend()
plt.xlabel('Control Region Observable')
# plt.yscale('log')
plt.ylabel('Density')
# Out:
# Text(0, 1, 'Density')

# %%
# Save the preselected Nominal dataframe for inference use later on
dataset.to_hdf(f"{saved_data}dataset_preselected_nominal_SR.h5", key="dataset", mode='w')

# %%
top_path = f'{path_prefix}output_training_nominal/'

# %% [markdown]
# Density ratio training
# ===
#
# Now we train the NNs for $\frac{p_c}{p_{ref}}(x)$ density ratios to build the full model. Our choice of reference hypothesis, motivated by the search-oriented mixture model described above, is:
#
# $$p_{ref}(x) = p_\text{higgs}(x) = \frac{1}{\nu_{H \to \tau\tau}} \frac{d\sigma_{H \to \tau\tau}}{dx} $$
#
# gives the POI $\mu-$parameterized model:
#
# $$\sum_c \left[f_c(\mu) \cdot \frac{p_c\left(x\right)}{p_{ref}(x)} \right]= \mu + \frac{p_{t\bar{t}}\left(x\right)}{p_{H \to \tau\tau}(x)} + \frac{p_{Z \to \tau\tau}\left(x\right)}{p_{H \to \tau\tau}(x)}$$
#
# The task of estimating the $\mu-$parameterized density ratio is thus reduced to estimating two $\mu-$independent density ratios $\frac{p_\text{single top}}{p_{t\bar{t}}}(x)$ and $\frac{p_\text{wjets}}{p_{t\bar{t}}}(x)$ mixed together with an analytical parameterization (hence the name mixture model).

# %%
 dataset['type'] =  dataset['detailed_labels'].to_numpy()

# %%
importlib.reload(sys.modules['nsbi_common_utils.training'])
from nsbi_common_utils.training import TrainEvaluate_NN

mask_ref = np.isin(dataset.detailed_labels, ref_processes)

NN_training_mix_model = {}

rnd_seed_traintestsplit = 42 # can also be randomized, fixed for now

for process_type in mix_model_hypotheses:
    
    mask_process = dataset['type']==process_type
    
    dataset_num = dataset[mask_process].copy()
    dataset_ref = dataset[mask_ref].copy()

    dataset_num['train_labels'] = 1
    dataset_ref['train_labels'] = 0

    dataset_num['weights_normed'] = dataset_num['weights'].to_numpy() / dataset_num['weights'].sum()
    dataset_ref['weights_normed'] = dataset_ref['weights'].to_numpy() / dataset_ref['weights'].sum()

    # Build a training dataset for the training of p_<process_type>/p_<ref_processes> density ratio
    dataset_mix_model = pd.concat([dataset_num, dataset_ref])

    del dataset_num, dataset_ref

    # Save paths
    output_name = f'{process_type}'
    output_dir = f'{top_path}general_output_{process_type}'
    path_to_ratios = f'{top_path}output_ratios_{process_type}/'
    path_to_figures = f'{top_path}output_figures_{process_type}/'
    path_to_models = f'{top_path}output_model_params_{process_type}/'

    NN_training_mix_model[process_type] = TrainEvaluate_NN(dataset_mix_model, 
                                                           dataset_mix_model['weights_normed'],
                                                           dataset_mix_model['train_labels'],
                                                           columns, 
                                                           columns_scaling, rnd_seed_traintestsplit,
                                                           [process_type, 'ref'], output_dir, output_name, 
                                                            path_to_figures=path_to_figures,
                                                            path_to_ratios=path_to_ratios, 
                                                            path_to_models=path_to_models)


    del dataset_mix_model

# %% [markdown]
# Neural Network architecture
# ===
#
# Here we will start with a multi-layer perceptron (simple feed-forward Neural Network with fully-connected layers). This can be supplemented with more complex architectures like transformers.
#
# After detailed tuning during the off-shell Higgs boson analysis effort, we found that a network with very wide layers ($\geq 1000$) and a depth of less than 10 works best - alongside batch size of a few hundreds and a gradually declining learning rate that starts with a value just large enough to not blow up.

# %% [markdown]
# Starting with the training and validation of the various density ratio:
#
# $$\frac{p_{t\bar{t}}(x)}{p_\text{ref}(x)}, \frac{p_{Z \to \tau\tau}(x)}{p_\text{ref}(x)}$$

# %%
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available: 1

# %%
mix_model_hypotheses
# Out:
# ['ttbar', 'ztautau']

# %%
# Define unique settings for each process type

training_settings = {
    'ttbar': {
        'hidden_layers':        2,
        'neurons':              1000,
        'number_of_epochs':     100,
        'batch_size':           512,
        'learning_rate':        0.1,
        'scalerType':           'StandardScaler',
        'calibration':          False,
        'num_bins_cal':         50,
        'callback':             True,
        'callback_patience':    30,
        'callback_factor':      0.01,
        'verbose':              2
    },
    
    'ztautau': {
        'hidden_layers':        2,
        'neurons':              1000,
        'number_of_epochs':     100,
        'batch_size':           512,
        'learning_rate':        0.1,
        'scalerType':           'StandardScaler',
        'calibration':          False,
        'num_bins_cal':         50,
        'callback':             True,
        'callback_patience':    30,
        'callback_factor':      0.01,
        'verbose':              2
    }
}

# %%
# Train the density ratio NN
for process_type in mix_model_hypotheses:
    
    settings = training_settings[process_type]

    NN_training_mix_model[process_type].train(**settings)
    NN_training_mix_model[process_type].test_normalization()
# Out:
# Sum of weights of class 0: 0.7000000476837158
# Sum of weights of class 1: 0.7000091671943665
# Using swish activation function
# /home/jaySandesara/.conda/envs/NSBI/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 1000)           │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,010,001 (3.85 MB)
#  Trainable params: 1,010,001 (3.85 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# 2025-06-04 15:10:43.904382: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion_1', 8 bytes spill stores, 4 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion', 16 bytes spill stores, 20 bytes spill loads
#
# 2025-06-04 15:10:47.248474: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion', 4 bytes spill stores, 4 bytes spill loads
# 1940/1940 - 6s - 3ms/step - binary_accuracy: 0.6732 - loss: 7.8178e-07 - val_binary_accuracy: 0.6797 - val_loss: 7.5942e-07 - learning_rate: 0.1000
# Epoch 2/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.6867 - loss: 7.6374e-07 - val_binary_accuracy: 0.6854 - val_loss: 7.5402e-07 - learning_rate: 0.1000
# Epoch 3/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.6886 - loss: 7.6092e-07 - val_binary_accuracy: 0.6877 - val_loss: 7.4348e-07 - learning_rate: 0.1000
# Epoch 4/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.6905 - loss: 7.5682e-07 - val_binary_accuracy: 0.6886 - val_loss: 7.4449e-07 - learning_rate: 0.1000
# Epoch 5/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.6933 - loss: 7.5332e-07 - val_binary_accuracy: 0.6933 - val_loss: 7.3996e-07 - learning_rate: 0.1000
# Epoch 6/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.6935 - loss: 7.5174e-07 - val_binary_accuracy: 0.6916 - val_loss: 7.4149e-07 - learning_rate: 0.1000
# Epoch 7/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.6950 - loss: 7.4883e-07 - val_binary_accuracy: 0.6870 - val_loss: 7.5067e-07 - learning_rate: 0.1000
# Epoch 8/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.6967 - loss: 7.4550e-07 - val_binary_accuracy: 0.6900 - val_loss: 7.3722e-07 - learning_rate: 0.1000
# Epoch 9/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.6983 - loss: 7.4333e-07 - val_binary_accuracy: 0.6868 - val_loss: 7.4249e-07 - learning_rate: 0.1000
# Epoch 10/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.6980 - loss: 7.4244e-07 - val_binary_accuracy: 0.6951 - val_loss: 7.3066e-07 - learning_rate: 0.1000
# Epoch 11/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.6991 - loss: 7.4122e-07 - val_binary_accuracy: 0.6979 - val_loss: 7.2925e-07 - learning_rate: 0.1000
# Epoch 12/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.6976 - loss: 7.4119e-07 - val_binary_accuracy: 0.6969 - val_loss: 7.2863e-07 - learning_rate: 0.1000
# Epoch 13/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.6994 - loss: 7.4045e-07 - val_binary_accuracy: 0.6989 - val_loss: 7.3267e-07 - learning_rate: 0.1000
# Epoch 14/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.6997 - loss: 7.4016e-07 - val_binary_accuracy: 0.6947 - val_loss: 7.2954e-07 - learning_rate: 0.1000
# Epoch 15/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.6992 - loss: 7.3980e-07 - val_binary_accuracy: 0.6994 - val_loss: 7.2995e-07 - learning_rate: 0.1000
# Epoch 16/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.6994 - loss: 7.3977e-07 - val_binary_accuracy: 0.6961 - val_loss: 7.3231e-07 - learning_rate: 0.1000
# Epoch 17/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7001 - loss: 7.3826e-07 - val_binary_accuracy: 0.6975 - val_loss: 7.3224e-07 - learning_rate: 0.1000
# Epoch 18/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.6996 - loss: 7.3730e-07 - val_binary_accuracy: 0.6979 - val_loss: 7.2553e-07 - learning_rate: 0.1000
# Epoch 19/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7010 - loss: 7.3616e-07 - val_binary_accuracy: 0.7007 - val_loss: 7.2407e-07 - learning_rate: 0.1000
# Epoch 20/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7019 - loss: 7.3604e-07 - val_binary_accuracy: 0.6974 - val_loss: 7.2676e-07 - learning_rate: 0.1000
# Epoch 21/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7012 - loss: 7.3553e-07 - val_binary_accuracy: 0.6980 - val_loss: 7.2190e-07 - learning_rate: 0.1000
# Epoch 22/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7009 - loss: 7.3508e-07 - val_binary_accuracy: 0.6990 - val_loss: 7.2450e-07 - learning_rate: 0.1000
# Epoch 23/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7019 - loss: 7.3483e-07 - val_binary_accuracy: 0.6998 - val_loss: 7.2568e-07 - learning_rate: 0.1000
# Epoch 24/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7029 - loss: 7.3461e-07 - val_binary_accuracy: 0.6995 - val_loss: 7.2613e-07 - learning_rate: 0.1000
# Epoch 25/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7013 - loss: 7.3465e-07 - val_binary_accuracy: 0.7007 - val_loss: 7.2737e-07 - learning_rate: 0.1000
# Epoch 26/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7022 - loss: 7.3414e-07 - val_binary_accuracy: 0.6917 - val_loss: 7.3290e-07 - learning_rate: 0.1000
# Epoch 27/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7027 - loss: 7.3370e-07 - val_binary_accuracy: 0.6970 - val_loss: 7.2572e-07 - learning_rate: 0.1000
# Epoch 28/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7026 - loss: 7.3316e-07 - val_binary_accuracy: 0.7006 - val_loss: 7.2470e-07 - learning_rate: 0.1000
# Epoch 29/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7033 - loss: 7.3319e-07 - val_binary_accuracy: 0.6969 - val_loss: 7.2492e-07 - learning_rate: 0.1000
# Epoch 30/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7015 - loss: 7.3364e-07 - val_binary_accuracy: 0.6977 - val_loss: 7.2399e-07 - learning_rate: 0.1000
# Epoch 31/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7031 - loss: 7.3345e-07 - val_binary_accuracy: 0.6886 - val_loss: 7.3298e-07 - learning_rate: 0.1000
# Epoch 32/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7048 - loss: 7.2601e-07 - val_binary_accuracy: 0.7022 - val_loss: 7.1846e-07 - learning_rate: 0.0010
# Epoch 33/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7073 - loss: 7.2256e-07 - val_binary_accuracy: 0.7020 - val_loss: 7.1742e-07 - learning_rate: 0.0010
# Epoch 34/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7078 - loss: 7.2177e-07 - val_binary_accuracy: 0.7019 - val_loss: 7.1696e-07 - learning_rate: 0.0010
# Epoch 35/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7082 - loss: 7.2131e-07 - val_binary_accuracy: 0.7012 - val_loss: 7.1690e-07 - learning_rate: 0.0010
# Epoch 36/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7079 - loss: 7.2100e-07 - val_binary_accuracy: 0.7023 - val_loss: 7.1663e-07 - learning_rate: 0.0010
# Epoch 37/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7081 - loss: 7.2079e-07 - val_binary_accuracy: 0.7025 - val_loss: 7.1650e-07 - learning_rate: 0.0010
# Epoch 38/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7089 - loss: 7.2060e-07 - val_binary_accuracy: 0.7022 - val_loss: 7.1634e-07 - learning_rate: 0.0010
# Epoch 39/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7088 - loss: 7.2044e-07 - val_binary_accuracy: 0.7025 - val_loss: 7.1634e-07 - learning_rate: 0.0010
# Epoch 40/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7089 - loss: 7.2033e-07 - val_binary_accuracy: 0.7018 - val_loss: 7.1634e-07 - learning_rate: 0.0010
# Epoch 41/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7087 - loss: 7.2022e-07 - val_binary_accuracy: 0.7020 - val_loss: 7.1631e-07 - learning_rate: 0.0010
# Epoch 42/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7088 - loss: 7.2012e-07 - val_binary_accuracy: 0.7025 - val_loss: 7.1626e-07 - learning_rate: 0.0010
# Epoch 43/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7092 - loss: 7.2001e-07 - val_binary_accuracy: 0.7025 - val_loss: 7.1634e-07 - learning_rate: 0.0010
# Epoch 44/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7090 - loss: 7.1994e-07 - val_binary_accuracy: 0.7025 - val_loss: 7.1625e-07 - learning_rate: 0.0010
# Epoch 45/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7091 - loss: 7.1985e-07 - val_binary_accuracy: 0.7025 - val_loss: 7.1612e-07 - learning_rate: 0.0010
# Epoch 46/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7093 - loss: 7.1980e-07 - val_binary_accuracy: 0.7025 - val_loss: 7.1621e-07 - learning_rate: 0.0010
# Epoch 47/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7094 - loss: 7.1968e-07 - val_binary_accuracy: 0.7027 - val_loss: 7.1665e-07 - learning_rate: 0.0010
# Epoch 48/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7097 - loss: 7.1966e-07 - val_binary_accuracy: 0.7029 - val_loss: 7.1621e-07 - learning_rate: 0.0010
# Epoch 49/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7096 - loss: 7.1962e-07 - val_binary_accuracy: 0.7032 - val_loss: 7.1616e-07 - learning_rate: 0.0010
# Epoch 50/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7096 - loss: 7.1956e-07 - val_binary_accuracy: 0.7030 - val_loss: 7.1617e-07 - learning_rate: 0.0010
# Epoch 51/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7094 - loss: 7.1950e-07 - val_binary_accuracy: 0.7030 - val_loss: 7.1619e-07 - learning_rate: 0.0010
# Epoch 52/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7094 - loss: 7.1945e-07 - val_binary_accuracy: 0.7033 - val_loss: 7.1603e-07 - learning_rate: 0.0010
# Epoch 53/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7099 - loss: 7.1940e-07 - val_binary_accuracy: 0.7035 - val_loss: 7.1603e-07 - learning_rate: 0.0010
# Epoch 54/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7098 - loss: 7.1936e-07 - val_binary_accuracy: 0.7032 - val_loss: 7.1618e-07 - learning_rate: 0.0010
# Epoch 55/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7097 - loss: 7.1933e-07 - val_binary_accuracy: 0.7034 - val_loss: 7.1610e-07 - learning_rate: 0.0010
# Epoch 56/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7101 - loss: 7.1928e-07 - val_binary_accuracy: 0.7032 - val_loss: 7.1608e-07 - learning_rate: 0.0010
# Epoch 57/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7097 - loss: 7.1925e-07 - val_binary_accuracy: 0.7039 - val_loss: 7.1614e-07 - learning_rate: 0.0010
# Epoch 58/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7098 - loss: 7.1920e-07 - val_binary_accuracy: 0.7030 - val_loss: 7.1622e-07 - learning_rate: 0.0010
# Epoch 59/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7096 - loss: 7.1918e-07 - val_binary_accuracy: 0.7040 - val_loss: 7.1590e-07 - learning_rate: 0.0010
# Epoch 60/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7097 - loss: 7.1912e-07 - val_binary_accuracy: 0.7047 - val_loss: 7.1596e-07 - learning_rate: 0.0010
# Epoch 61/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7097 - loss: 7.1913e-07 - val_binary_accuracy: 0.7036 - val_loss: 7.1612e-07 - learning_rate: 0.0010
# Epoch 62/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7101 - loss: 7.1885e-07 - val_binary_accuracy: 0.7036 - val_loss: 7.1611e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7101 - loss: 7.1885e-07 - val_binary_accuracy: 0.7036 - val_loss: 7.1611e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7101 - loss: 7.1885e-07 - val_binary_accuracy: 0.7035 - val_loss: 7.1611e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7101 - loss: 7.1885e-07 - val_binary_accuracy: 0.7035 - val_loss: 7.1611e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7102 - loss: 7.1885e-07 - val_binary_accuracy: 0.7034 - val_loss: 7.1611e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7101 - loss: 7.1885e-07 - val_binary_accuracy: 0.7034 - val_loss: 7.1611e-07 - learning_rate: 1.0000e-05
# Epoch 68/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7101 - loss: 7.1884e-07 - val_binary_accuracy: 0.7034 - val_loss: 7.1610e-07 - learning_rate: 1.0000e-05
# Epoch 69/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7101 - loss: 7.1884e-07 - val_binary_accuracy: 0.7034 - val_loss: 7.1610e-07 - learning_rate: 1.0000e-05
# Epoch 70/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7101 - loss: 7.1884e-07 - val_binary_accuracy: 0.7034 - val_loss: 7.1610e-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7100 - loss: 7.1884e-07 - val_binary_accuracy: 0.7034 - val_loss: 7.1610e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7100 - loss: 7.1884e-07 - val_binary_accuracy: 0.7035 - val_loss: 7.1610e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7100 - loss: 7.1884e-07 - val_binary_accuracy: 0.7035 - val_loss: 7.1610e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7100 - loss: 7.1884e-07 - val_binary_accuracy: 0.7037 - val_loss: 7.1610e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7099 - loss: 7.1884e-07 - val_binary_accuracy: 0.7037 - val_loss: 7.1609e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7099 - loss: 7.1884e-07 - val_binary_accuracy: 0.7036 - val_loss: 7.1609e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7099 - loss: 7.1884e-07 - val_binary_accuracy: 0.7036 - val_loss: 7.1609e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7100 - loss: 7.1884e-07 - val_binary_accuracy: 0.7036 - val_loss: 7.1609e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7099 - loss: 7.1884e-07 - val_binary_accuracy: 0.7036 - val_loss: 7.1609e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7100 - loss: 7.1884e-07 - val_binary_accuracy: 0.7036 - val_loss: 7.1609e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7099 - loss: 7.1884e-07 - val_binary_accuracy: 0.7038 - val_loss: 7.1609e-07 - learning_rate: 1.0000e-05
# Epoch 82/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7099 - loss: 7.1884e-07 - val_binary_accuracy: 0.7038 - val_loss: 7.1608e-07 - learning_rate: 1.0000e-05
# Epoch 83/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7099 - loss: 7.1883e-07 - val_binary_accuracy: 0.7038 - val_loss: 7.1608e-07 - learning_rate: 1.0000e-05
# Epoch 84/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7100 - loss: 7.1884e-07 - val_binary_accuracy: 0.7037 - val_loss: 7.1608e-07 - learning_rate: 1.0000e-05
# Epoch 85/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7099 - loss: 7.1883e-07 - val_binary_accuracy: 0.7037 - val_loss: 7.1608e-07 - learning_rate: 1.0000e-05
# Epoch 86/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7100 - loss: 7.1883e-07 - val_binary_accuracy: 0.7037 - val_loss: 7.1608e-07 - learning_rate: 1.0000e-05
# Epoch 87/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7100 - loss: 7.1883e-07 - val_binary_accuracy: 0.7037 - val_loss: 7.1608e-07 - learning_rate: 1.0000e-05
# Epoch 88/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7100 - loss: 7.1883e-07 - val_binary_accuracy: 0.7037 - val_loss: 7.1608e-07 - learning_rate: 1.0000e-05
# Epoch 89/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7099 - loss: 7.1883e-07 - val_binary_accuracy: 0.7037 - val_loss: 7.1608e-07 - learning_rate: 1.0000e-05
# Epoch 90/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7100 - loss: 7.1883e-07 - val_binary_accuracy: 0.7037 - val_loss: 7.1608e-07 - learning_rate: 1.0000e-05
# Epoch 91/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7099 - loss: 7.1883e-07 - val_binary_accuracy: 0.7037 - val_loss: 7.1608e-07 - learning_rate: 1.0000e-05
# Epoch 92/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7100 - loss: 7.1883e-07 - val_binary_accuracy: 0.7037 - val_loss: 7.1608e-07 - learning_rate: 1.0000e-07
# Epoch 93/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7100 - loss: 7.1883e-07 - val_binary_accuracy: 0.7037 - val_loss: 7.1608e-07 - learning_rate: 1.0000e-07
# Epoch 94/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7099 - loss: 7.1883e-07 - val_binary_accuracy: 0.7037 - val_loss: 7.1608e-07 - learning_rate: 1.0000e-07
# Epoch 95/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7100 - loss: 7.1883e-07 - val_binary_accuracy: 0.7037 - val_loss: 7.1608e-07 - learning_rate: 1.0000e-07
# Epoch 96/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7099 - loss: 7.1883e-07 - val_binary_accuracy: 0.7037 - val_loss: 7.1608e-07 - learning_rate: 1.0000e-07
# Epoch 97/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7100 - loss: 7.1883e-07 - val_binary_accuracy: 0.7037 - val_loss: 7.1608e-07 - learning_rate: 1.0000e-07
# Epoch 98/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7100 - loss: 7.1883e-07 - val_binary_accuracy: 0.7037 - val_loss: 7.1608e-07 - learning_rate: 1.0000e-07
# Epoch 99/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7099 - loss: 7.1883e-07 - val_binary_accuracy: 0.7037 - val_loss: 7.1608e-07 - learning_rate: 1.0000e-07
# Epoch 100/100
# 1940/1940 - 3s - 2ms/step - binary_accuracy: 0.7100 - loss: 7.1883e-07 - val_binary_accuracy: 0.7037 - val_loss: 7.1608e-07 - learning_rate: 1.0000e-07
# Finished Training
# /home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/output_training_nominal/output_model_params_ttbar/model_scaler.bin
# 34481/34481 - 18s - 530us/step
# 14778/14778 - 8s - 514us/step
# 49259/49259 - 25s - 518us/step
# The sum of PDFs is 1.0044199228286743
# Sum of weights of class 0: 0.699999988079071
# Sum of weights of class 1: 0.7000007629394531
# Using swish activation function
# /home/jaySandesara/.conda/envs/NSBI/lib/python3.11/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_15 (Dense)                │ (None, 1000)           │         8,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 1000)           │     1,001,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 1)              │         1,001 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,010,001 (3.85 MB)
#  Trainable params: 1,010,001 (3.85 MB)
#  Non-trainable params: 0 (0.00 B)
# Using Callbacks
# Epoch 1/100
# 2025-06-04 15:17:49.532015: I external/local_xla/xla/stream_executor/cuda/cuda_asm_compiler.cc:397] ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion_1', 8 bytes spill stores, 4 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'input_multiply_reduce_fusion', 16 bytes spill stores, 20 bytes spill loads
# 3134/3134 - 8s - 2ms/step - binary_accuracy: 0.6664 - loss: 4.9344e-07 - val_binary_accuracy: 0.6811 - val_loss: 4.7863e-07 - learning_rate: 0.1000
# Epoch 2/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6801 - loss: 4.7902e-07 - val_binary_accuracy: 0.6817 - val_loss: 4.7701e-07 - learning_rate: 0.1000
# Epoch 3/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6810 - loss: 4.7778e-07 - val_binary_accuracy: 0.6827 - val_loss: 4.7598e-07 - learning_rate: 0.1000
# Epoch 4/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6825 - loss: 4.7640e-07 - val_binary_accuracy: 0.6844 - val_loss: 4.7460e-07 - learning_rate: 0.1000
# Epoch 5/100
# 3134/3134 - 6s - 2ms/step - binary_accuracy: 0.6841 - loss: 4.7517e-07 - val_binary_accuracy: 0.6860 - val_loss: 4.7320e-07 - learning_rate: 0.1000
# Epoch 6/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6851 - loss: 4.7452e-07 - val_binary_accuracy: 0.6869 - val_loss: 4.7295e-07 - learning_rate: 0.1000
# Epoch 7/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6852 - loss: 4.7405e-07 - val_binary_accuracy: 0.6860 - val_loss: 4.7280e-07 - learning_rate: 0.1000
# Epoch 8/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6857 - loss: 4.7344e-07 - val_binary_accuracy: 0.6876 - val_loss: 4.7131e-07 - learning_rate: 0.1000
# Epoch 9/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6862 - loss: 4.7270e-07 - val_binary_accuracy: 0.6883 - val_loss: 4.7045e-07 - learning_rate: 0.1000
# Epoch 10/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6866 - loss: 4.7197e-07 - val_binary_accuracy: 0.6883 - val_loss: 4.7042e-07 - learning_rate: 0.1000
# Epoch 11/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6874 - loss: 4.7107e-07 - val_binary_accuracy: 0.6887 - val_loss: 4.6893e-07 - learning_rate: 0.1000
# Epoch 12/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6889 - loss: 4.6978e-07 - val_binary_accuracy: 0.6899 - val_loss: 4.6965e-07 - learning_rate: 0.1000
# Epoch 13/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6899 - loss: 4.6895e-07 - val_binary_accuracy: 0.6916 - val_loss: 4.6728e-07 - learning_rate: 0.1000
# Epoch 14/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6903 - loss: 4.6834e-07 - val_binary_accuracy: 0.6898 - val_loss: 4.6858e-07 - learning_rate: 0.1000
# Epoch 15/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6906 - loss: 4.6799e-07 - val_binary_accuracy: 0.6918 - val_loss: 4.6718e-07 - learning_rate: 0.1000
# Epoch 16/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6906 - loss: 4.6762e-07 - val_binary_accuracy: 0.6923 - val_loss: 4.6718e-07 - learning_rate: 0.1000
# Epoch 17/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6911 - loss: 4.6723e-07 - val_binary_accuracy: 0.6887 - val_loss: 4.6859e-07 - learning_rate: 0.1000
# Epoch 18/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6913 - loss: 4.6690e-07 - val_binary_accuracy: 0.6925 - val_loss: 4.6550e-07 - learning_rate: 0.1000
# Epoch 19/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6918 - loss: 4.6654e-07 - val_binary_accuracy: 0.6923 - val_loss: 4.6550e-07 - learning_rate: 0.1000
# Epoch 20/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6921 - loss: 4.6633e-07 - val_binary_accuracy: 0.6935 - val_loss: 4.6487e-07 - learning_rate: 0.1000
# Epoch 21/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6920 - loss: 4.6610e-07 - val_binary_accuracy: 0.6926 - val_loss: 4.6595e-07 - learning_rate: 0.1000
# Epoch 22/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6921 - loss: 4.6588e-07 - val_binary_accuracy: 0.6936 - val_loss: 4.6491e-07 - learning_rate: 0.1000
# Epoch 23/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6923 - loss: 4.6575e-07 - val_binary_accuracy: 0.6933 - val_loss: 4.6486e-07 - learning_rate: 0.1000
# Epoch 24/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6925 - loss: 4.6562e-07 - val_binary_accuracy: 0.6930 - val_loss: 4.6509e-07 - learning_rate: 0.1000
# Epoch 25/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6928 - loss: 4.6553e-07 - val_binary_accuracy: 0.6929 - val_loss: 4.6469e-07 - learning_rate: 0.1000
# Epoch 26/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6926 - loss: 4.6540e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6457e-07 - learning_rate: 0.1000
# Epoch 27/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6929 - loss: 4.6528e-07 - val_binary_accuracy: 0.6940 - val_loss: 4.6396e-07 - learning_rate: 0.1000
# Epoch 28/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6932 - loss: 4.6513e-07 - val_binary_accuracy: 0.6931 - val_loss: 4.6510e-07 - learning_rate: 0.1000
# Epoch 29/100
# 3134/3134 - 6s - 2ms/step - binary_accuracy: 0.6930 - loss: 4.6508e-07 - val_binary_accuracy: 0.6945 - val_loss: 4.6392e-07 - learning_rate: 0.1000
# Epoch 30/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6931 - loss: 4.6505e-07 - val_binary_accuracy: 0.6953 - val_loss: 4.6368e-07 - learning_rate: 0.1000
# Epoch 31/100
# 3134/3134 - 6s - 2ms/step - binary_accuracy: 0.6932 - loss: 4.6487e-07 - val_binary_accuracy: 0.6954 - val_loss: 4.6342e-07 - learning_rate: 0.1000
# Epoch 32/100
# 3134/3134 - 6s - 2ms/step - binary_accuracy: 0.6943 - loss: 4.6360e-07 - val_binary_accuracy: 0.6961 - val_loss: 4.6244e-07 - learning_rate: 0.0010
# Epoch 33/100
# 3134/3134 - 6s - 2ms/step - binary_accuracy: 0.6944 - loss: 4.6328e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6234e-07 - learning_rate: 0.0010
# Epoch 34/100
# 3134/3134 - 6s - 2ms/step - binary_accuracy: 0.6945 - loss: 4.6320e-07 - val_binary_accuracy: 0.6957 - val_loss: 4.6229e-07 - learning_rate: 0.0010
# Epoch 35/100
# 3134/3134 - 6s - 2ms/step - binary_accuracy: 0.6945 - loss: 4.6316e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6227e-07 - learning_rate: 0.0010
# Epoch 36/100
# 3134/3134 - 6s - 2ms/step - binary_accuracy: 0.6945 - loss: 4.6314e-07 - val_binary_accuracy: 0.6958 - val_loss: 4.6224e-07 - learning_rate: 0.0010
# Epoch 37/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6946 - loss: 4.6312e-07 - val_binary_accuracy: 0.6957 - val_loss: 4.6224e-07 - learning_rate: 0.0010
# Epoch 38/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6946 - loss: 4.6311e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6223e-07 - learning_rate: 0.0010
# Epoch 39/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6946 - loss: 4.6309e-07 - val_binary_accuracy: 0.6958 - val_loss: 4.6223e-07 - learning_rate: 0.0010
# Epoch 40/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6947 - loss: 4.6308e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6222e-07 - learning_rate: 0.0010
# Epoch 41/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6946 - loss: 4.6307e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6222e-07 - learning_rate: 0.0010
# Epoch 42/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6946 - loss: 4.6307e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6221e-07 - learning_rate: 0.0010
# Epoch 43/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6946 - loss: 4.6306e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6221e-07 - learning_rate: 0.0010
# Epoch 44/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6946 - loss: 4.6305e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6220e-07 - learning_rate: 0.0010
# Epoch 45/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6947 - loss: 4.6304e-07 - val_binary_accuracy: 0.6958 - val_loss: 4.6219e-07 - learning_rate: 0.0010
# Epoch 46/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6304e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6219e-07 - learning_rate: 0.0010
# Epoch 47/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6947 - loss: 4.6303e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6218e-07 - learning_rate: 0.0010
# Epoch 48/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6947 - loss: 4.6303e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6218e-07 - learning_rate: 0.0010
# Epoch 49/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6302e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6220e-07 - learning_rate: 0.0010
# Epoch 50/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6302e-07 - val_binary_accuracy: 0.6958 - val_loss: 4.6217e-07 - learning_rate: 0.0010
# Epoch 51/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6302e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6218e-07 - learning_rate: 0.0010
# Epoch 52/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6947 - loss: 4.6301e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6218e-07 - learning_rate: 0.0010
# Epoch 53/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6947 - loss: 4.6300e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6218e-07 - learning_rate: 0.0010
# Epoch 54/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6947 - loss: 4.6300e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6216e-07 - learning_rate: 0.0010
# Epoch 55/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6300e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6216e-07 - learning_rate: 0.0010
# Epoch 56/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6299e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6216e-07 - learning_rate: 0.0010
# Epoch 57/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6299e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6216e-07 - learning_rate: 0.0010
# Epoch 58/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6298e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6216e-07 - learning_rate: 0.0010
# Epoch 59/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6298e-07 - val_binary_accuracy: 0.6961 - val_loss: 4.6216e-07 - learning_rate: 0.0010
# Epoch 60/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6947 - loss: 4.6298e-07 - val_binary_accuracy: 0.6961 - val_loss: 4.6216e-07 - learning_rate: 0.0010
# Epoch 61/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6297e-07 - val_binary_accuracy: 0.6961 - val_loss: 4.6215e-07 - learning_rate: 0.0010
# Epoch 62/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6296e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6215e-07 - learning_rate: 1.0000e-05
# Epoch 63/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6295e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 64/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6295e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 65/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6295e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 66/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6295e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 67/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6958 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 68/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 69/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 70/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 71/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 72/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 73/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 74/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 75/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 76/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 77/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 78/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 79/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 80/100
# 3134/3134 - 6s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 81/100
# 3134/3134 - 6s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 82/100
# 3134/3134 - 6s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 83/100
# 3134/3134 - 6s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 84/100
# 3134/3134 - 6s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 85/100
# 3134/3134 - 6s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6959 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 86/100
# 3134/3134 - 6s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 87/100
# 3134/3134 - 6s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 88/100
# 3134/3134 - 6s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 89/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 90/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 91/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-05
# Epoch 92/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-07
# Epoch 93/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-07
# Epoch 94/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-07
# Epoch 95/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-07
# Epoch 96/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-07
# Epoch 97/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-07
# Epoch 98/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-07
# Epoch 99/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-07
# Epoch 100/100
# 3134/3134 - 5s - 2ms/step - binary_accuracy: 0.6948 - loss: 4.6294e-07 - val_binary_accuracy: 0.6960 - val_loss: 4.6214e-07 - learning_rate: 1.0000e-07
# Finished Training
# /home/jaySandesara/NSBI_workflow_tutorial/FAIR_universe_Higgs_tautau/output_training_nominal/output_model_params_ztautau/model_scaler.bin
# 55706/55706 - 29s - 527us/step
# 23874/23874 - 12s - 519us/step
# 79580/79580 - 42s - 528us/step
# The sum of PDFs is 1.0014687776565552

# %% [markdown]
# Check for overtraining by comparing the NN output distributions between training and holdout datasets. The holdout dataset is the subset of events not used during training.

# %%
for process_type in mix_model_hypotheses:
    NN_training_mix_model[process_type].make_overfit_plots()

# %% [markdown]
# Diagnostic Checks
# ===
#
# While traditionally, a NN observable is judged on the basis of its accuracy - for NSBI we are interested in the quality of the density ratios more than the discrimination power. The latter comes from the perfect modelling of the multi-dimensional likelihood ratios.
#
# To ensure correct modelling, we run two main checks on the training:
#
# - **Calibration closure test**
#
#   The NNs are trained using the binary cross-entropy loss, which under ideal conditions leads to the NN converging to the score function:
#
#   $$\hat{s}_\text{pred} = \frac{p_\text{ref}(x)}{p_\text{ref}(x)+p_\text{c}(x)}$$
#
#   that can be converted into the probability ratio we desire (likelihood ratio trick):
#
#   $$\frac{p_\text{c}(x)}{p_\text{ref}(x)} = \frac{\hat{s}_\text{pred}(x)}{1-\hat{s}_\text{pred}(x)}$$
#
#   For the NNs to be well-calibrated, we use the Monte Carlo samples to verify the equality:
#
#
#   $$\left[\frac{p_c(x)}{p_c(x)+p_{ref}(x)}\right]_\text{NN} \sim \left[\frac{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}}{\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}+\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}}\right]_\text{MC}$$
#
#   where we bin the events from $p_c$ and $p_\text{ref}$ MC samples, denoted by $\mathcal{N}_c^{I(x|\hat{s}_\text{pred})}$ and $\mathcal{N}_\text{ref}^{I(x|\hat{s}_\text{pred})}$ respectively where $I(x|\hat{s}_\text{pred})$ returns the index of the $\hat{s}_\text{pred}$ bin in which an event $x$ falls.

# %%
num_bins_cal = 50

for process_type in mix_model_hypotheses:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='score')
# Out:
# observable not recognized
# observable not recognized

# %%
num_bins_cal = 50

for process_type in mix_model_hypotheses:
    NN_training_mix_model[process_type].make_calib_plots(nbins=num_bins_cal, observable='llr')

# %% [markdown]
# - **Density ratio reweighting closure tests**
#
#   Despite having a well-calibrated output and thus a robust probabilistic interpretation, the trained density ratios might not capture the full multi-dimensional event information $x$. In other words, the NNs might still be biased estimators of the optimal score function, as defined in the CARL paper (link).
#
#   The next diagnostic involves verifying the following equality using 1D projections of $x$:
#
#   $$\frac{p_c(x)}{p_{ref}(x)} \times p_{ref}(x) \sim p_c(x)$$
#
#   We can do this one-by-one for all the observables used to model the density ratios, and also possibly the observables not used directly in the training but can still be well-estimated due to the NN learning the right physics.

# %%
variables_to_plot=['PRI_lep_pt'] # The 1D variable for reweighting closure
yscale_type='log'
num_bins_plotting=21

for process_type in mix_model_hypotheses:

    NN_training_mix_model[process_type].make_reweighted_plots(variables_to_plot, yscale_type, num_bins_plotting)

# %%
for process_type in mix_model_hypotheses:
    # Evaluate the density ratios p_c/p_ref for the full dataset and save for the inference step
    NN_training_mix_model[process_type].evaluate_and_save_ratios(dataset)
# Out:
# 80940/80940 - 42s - 522us/step
# 80940/80940 - 43s - 529us/step

# %% [markdown]
# Systematic Uncertainty Modelling
# ===
#
# So far we have left out the nuisance parameter piece of the parameterized density ratio decomposition shown before:
#
# $$g_c(x|\alpha) = \frac{p_c(x|\alpha)}{p_c(x)}$$
#
# which will be estimated in the `Systematic_Uncertainty_Estimation.ipynb` notebook.

# %% [markdown]
# Training an Ensemble of NNs
# ===
#
# In a realistic analysis, a large ensemble of NNs are trained to estimate density ratios, for *each* of the channels. **This reduces not only the variance but has also been found to reduce biases in the final fits.**
#
# In the off-shell Higgs boson analysis, we used k-fold cross-validation, with k=10, to train an ensemble $N_{ens}\sim 250$ of NNs per density ratio $p_c(x)/p_{ref}(x)$. The density ratios used in the final fit are always evaluated on the holdout dataset and by using each of the folds as holdout once, the entire model for $p_c(x)/p_{ref}(x)$ consists of $N_{ens}\times k \sim 2500$ NNs. Each NN in the ensemble is trained by resampling data without replacement from the k-1 folds used for training.
