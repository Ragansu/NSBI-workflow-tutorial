# %% [markdown]
# # Workspace Building
#
# This notebook demonstrates how to build a serialized workspace from a YAML fit configuration file.
# The workspace is a JSON dictionary (following a pyhf-like schema) that contains all the information
# needed to construct the statistical model: binned histograms, density ratios, systematic variations,
# normalization factors, and measurement definitions.
#
# Once built, the workspace is saved to disk as JSON and can be loaded independently for fitting
# in `parameter_fitting.ipynb` — no config file or ROOT files needed at fit time.

# %%
import os
import pprint
import nsbi_common_utils

# %% [markdown]
# ## Configuration
#
# Point to your fit configuration YAML files. These define samples, regions, systematics,
# and paths to ROOT files and density ratio `.npy` files.

# %%
hist_config_path = "./config_fit_histogram.yml"
nsbi_config_path = "./config_fit_nsbi.yml"

output_dir = "./workspaces"
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# ## Build histogram workspace
#
# The histogram workspace contains only binned channels (control regions, binned signal region).
# This is the traditional HistFactory-style analysis.

# %%
builder_hist = nsbi_common_utils.workspace_builder.WorkspaceBuilder(config_path=hist_config_path)
ws_hist = builder_hist.build()
builder_hist.dump_workspace(ws_hist, os.path.join(output_dir, "workspace_histogram.json"))
# Out:
# Wrote ./workspaces/workspace_histogram.json

# %% [markdown]
# ## Build NSBI workspace
#
# The NSBI workspace extends the histogram workspace with unbinned channels that use
# neural density ratios. It references pre-computed `.npy` ratio files and Asimov weights.

# %%
builder_nsbi = nsbi_common_utils.workspace_builder.WorkspaceBuilder(config_path=nsbi_config_path)
ws_nsbi = builder_nsbi.build()
builder_nsbi.dump_workspace(ws_nsbi, os.path.join(output_dir, "workspace_nsbi.json"))
# Out:
# Wrote ./workspaces/workspace_nsbi.json

# %% [markdown]
# ## Inspect the workspace
#
# The workspace is a dictionary with `channels`, `measurements`, and `version` keys.
# Each channel contains samples with nominal data, modifiers (normfactors, systematics),
# and for unbinned channels, paths to density ratio arrays.

# %%
print("NSBI workspace keys:", list(ws_nsbi.keys()))
print(f"\nNumber of channels: {len(ws_nsbi['channels'])}")
for ch in ws_nsbi['channels']:
    print(f"  - {ch['name']} (type: {ch.get('type', 'binned')}, samples: {[s['name'] for s in ch['samples']]})")
print(f"\nMeasurement: {ws_nsbi['measurements'][0]['name']}")
print(f"POI: {ws_nsbi['measurements'][0]['config']['poi']}")
print(f"Parameters: {[p['name'] for p in ws_nsbi['measurements'][0]['config']['parameters']]}")
# Out:
# NSBI workspace keys: ['channels', 'measurements', 'version']
#
# Number of channels: 3
#   - CR (type: binned, samples: ['ztautau', 'ttbar', 'htautau'])
#   - SR_binned (type: binned, samples: ['ztautau', 'ttbar', 'htautau'])
#   - SR (type: unbinned, samples: ['ztautau', 'ttbar', 'htautau'])
#
# Measurement: higgs_tautau_signal_strength
# POI: mu_htautau
# Parameters: ['mu_htautau', 'mu_ztautau', 'mu_ttbar', 'JES', 'TES']

# %%
print("Full NSBI workspace:\n")
pprint.pprint(ws_nsbi)
# Out:
# Full NSBI workspace:
#
# {'channels': [{'name': 'CR',
#                'samples': [{'data': [512.9336, 55316.402, 625509.5],
#                             'modifiers': [{'data': None,
#                                            'name': 'mu_ztautau',
#                                            'type': 'normfactor'},
#                                           {'data': {'hi_data': [0.9936936,
#                                                                 0.99546325,
#                                                                 0.99919593],
#                                                     'lo_data': [1.0090088,
#                                                                 1.0038515,
#                                                                 1.0007826]},
#                                            'name': 'JES',
#                                            'type': 'normplusshape'},
#                                           {'data': {'hi_data': [0.9954955,
#                                                                 0.9939928,
#                                                                 0.99756396],
#                                                     'lo_data': [0.99999976,
#                                                                 1.0057814,
#                                                                 1.0024503]},
#                                            'name': 'TES',
#                                            'type': 'normplusshape'}],
#                             'name': 'ztautau'},
#                            {'data': [13736.219, 16437.613, 7434.5312],
#                             'modifiers': [{'data': None,
#                                            'name': 'mu_ttbar',
#                                            'type': 'normfactor'},
#                                           {'data': {'hi_data': [1.0007262,
#                                                                 0.9999731,
#                                                                 0.99871165],
#                                                     'lo_data': [0.9992038,
#                                                                 1.000066,
#                                                                 1.0014092]},
#                                            'name': 'JES',
#                                            'type': 'normplusshape'},
#                                           {'data': {'hi_data': [0.99936587,
#                                                                 1.0007203,
#                                                                 0.9999033],
#                                                     'lo_data': [1.0006754,
#                                                                 0.99934196,
#                                                                 0.99975544]},
#                                            'name': 'TES',
#                                            'type': 'normplusshape'}],
#                             'name': 'ttbar'},
#                            {'data': [3.6519132, 17.720905, 144.56474],
#                             'modifiers': [{'data': None,
#                                            'name': 'mu_htautau',
#                                            'type': 'normfactor'},
#                                           {'data': {'hi_data': [0.9999846,
#                                                                 0.999477,
#                                                                 0.998037],
#                                                     'lo_data': [0.9997316,
#                                                                 1.0008985,
#                                                                 1.0017496]},
#                                            'name': 'JES',
#                                            'type': 'normplusshape'},
#                                           {'data': {'hi_data': [0.9989608,
#                                                                 0.99828345,
#                                                                 0.9954776],
#                                                     'lo_data': [1.0011641,
#                                                                 1.0018463,
#                                                                 1.0042247]},
#                                            'name': 'TES',
#                                            'type': 'normplusshape'}],
#                             'name': 'htautau'}],
#                'type': 'binned'},
#               {'name': 'SR_binned',
#                'samples': [{'data': [19.40829],
#                             'modifiers': [{'data': None,
#                                            'name': 'mu_ztautau',
#                                            'type': 'normfactor'},
#                                           {'data': {'hi_data': [1.0],
#                                                     'lo_data': [0.9523809]},
#                                            'name': 'JES',
#                                            'type': 'normplusshape'},
#                                           {'data': {'hi_data': [0.97619045],
#                                                     'lo_data': [1.0]},
#                                            'name': 'TES',
#                                            'type': 'normplusshape'}],
#                             'name': 'ztautau'},
#                            {'data': [0.75399595],
#                             'modifiers': [{'data': None,
#                                            'name': 'mu_ttbar',
#                                            'type': 'normfactor'},
#                                           {'data': {'hi_data': [1.0],
#                                                     'lo_data': [0.9997701]},
#                                            'name': 'JES',
#                                            'type': 'normplusshape'},
#                                           {'data': {'hi_data': [1.0],
#                                                     'lo_data': [1.0]},
#                                            'name': 'TES',
#                                            'type': 'normplusshape'}],
#                             'name': 'ttbar'},
#                            {'data': [2.6284044],
#                             'modifiers': [{'data': None,
#                                            'name': 'mu_htautau',
#                                            'type': 'normfactor'},
#                                           {'data': {'hi_data': [1.0210011],
#                                                     'lo_data': [0.97867316]},
#                                            'name': 'JES',
#                                            'type': 'normplusshape'},
#                                           {'data': {'hi_data': [1.0001736],
#                                                     'lo_data': [1.0001771]},
#                                            'name': 'TES',
#                                            'type': 'normplusshape'}],
#                             'name': 'htautau'}],
#                'type': 'binned'},
#               {'name': 'SR',
#                'samples': [{'data': [321362.38],
#                             'modifiers': [{'data': None,
#                                            'name': 'mu_ztautau',
#                                            'type': 'normfactor'},
#                                           {'data': {'hi_data': [1.002358],
#                                                     'hi_ratio': './saved_datasets/output_training_systematics/output_ratios_ztautau_JES_Up/ratio_ztautau.npy',
#                                                     'lo_data': [0.99780196],
#                                                     'lo_ratio': './saved_datasets/output_training_systematics/output_ratios_ztautau_JES_Dn/ratio_ztautau.npy'},
#                                            'name': 'JES',
#                                            'type': 'normplusshape'},
#                                           {'data': {'hi_data': [1.0057962],
#                                                     'hi_ratio': './saved_datasets/output_training_systematics/output_ratios_ztautau_TES_Up/ratio_ztautau.npy',
#                                                     'lo_data': [0.9942212],
#                                                     'lo_ratio': './saved_datasets/output_training_systematics/output_ratios_ztautau_TES_Dn/ratio_ztautau.npy'},
#                                            'name': 'TES',
#                                            'type': 'normplusshape'}],
#                             'name': 'ztautau',
#                             'ratios': './saved_datasets/output_training_nominal/output_ratios_ztautau/ratio_ztautau.npy'},
#                            {'data': [5392.3887],
#                             'modifiers': [{'data': None,
#                                            'name': 'mu_ttbar',
#                                            'type': 'normfactor'},
#                                           {'data': {'hi_data': [0.9995804],
#                                                     'hi_ratio': './saved_datasets/output_training_systematics/output_ratios_ttbar_JES_Up/ratio_ttbar.npy',
#                                                     'lo_data': [1.0003119],
#                                                     'lo_ratio': './saved_datasets/output_training_systematics/output_ratios_ttbar_JES_Dn/ratio_ttbar.npy'},
#                                            'name': 'JES',
#                                            'type': 'normplusshape'},
#                                           {'data': {'hi_data': [0.9995506],
#                                                     'hi_ratio': './saved_datasets/output_training_systematics/output_ratios_ttbar_TES_Up/ratio_ttbar.npy',
#                                                     'lo_data': [1.000597],
#                                                     'lo_ratio': './saved_datasets/output_training_systematics/output_ratios_ttbar_TES_Dn/ratio_ttbar.npy'},
#                                            'name': 'TES',
#                                            'type': 'normplusshape'}],
#                             'name': 'ttbar',
#                             'ratios': './saved_datasets/output_training_nominal/output_ratios_ttbar/ratio_ttbar.npy'},
#                            {'data': [841.8276],
#                             'modifiers': [{'data': None,
#                                            'name': 'mu_htautau',
#                                            'type': 'normfactor'},
#                                           {'data': {'hi_data': [1.00021],
#                                                     'hi_ratio': './saved_datasets/output_training_systematics/output_ratios_htautau_JES_Up/ratio_htautau.npy',
#                                                     'lo_data': [0.9998162],
#                                                     'lo_ratio': './saved_datasets/output_training_systematics/output_ratios_htautau_JES_Dn/ratio_htautau.npy'},
#                                            'name': 'JES',
#                                            'type': 'normplusshape'},
#                                           {'data': {'hi_data': [1.0008153],
#                                                     'hi_ratio': './saved_datasets/output_training_systematics/output_ratios_htautau_TES_Up/ratio_htautau.npy',
#                                                     'lo_data': [0.99922997],
#                                                     'lo_ratio': './saved_datasets/output_training_systematics/output_ratios_htautau_TES_Dn/ratio_htautau.npy'},
#                                            'name': 'TES',
#                                            'type': 'normplusshape'}],
#                             'name': 'htautau',
#                             'ratios': './saved_datasets/output_training_nominal/output_ratios_htautau/ratio_htautau.npy'}],
#                'type': 'unbinned',
#                'weights': './saved_datasets/asimov_weights.npy'}],
#  'measurements': [{'config': {'parameters': [{'bounds': [[0, 10]],
#                                               'inits': [1],
#                                               'name': 'mu_htautau'},
#                                              {'bounds': [[0, 10]],
#                                               'inits': [1],
#                                               'name': 'mu_ztautau'},
#                                              {'bounds': [[0, 10]],
#                                               'inits': [1],
#                                               'name': 'mu_ttbar'},
#                                              {'inits': [0], 'name': 'JES'},
#                                              {'inits': [0], 'name': 'TES'}],
#                               'poi': 'mu_htautau'},
#                    'name': 'higgs_tautau_signal_strength'}],
#  'version': '1.0.0'}

# %% [markdown]
# ## Next steps
#
# The saved workspace JSON files can now be loaded in `parameter_fitting.ipynb` for
# model construction and hypothesis testing — without needing the original config files
# or ROOT files at fit time.
#
# ```python
# ws = nsbi_common_utils.workspace_builder.WorkspaceBuilder.load_workspace("workspaces/workspace_nsbi.json")
# model = nsbi_common_utils.models.sbi_parametric_model(workspace=ws, measurement_to_fit="my_measurement")
# ```
